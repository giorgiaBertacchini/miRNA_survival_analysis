# %%
import pandas as pd
import numpy as np
import os

# %%
GTF_PATH = "../../datasets/gencode.v49.chr_patch_hapl_scaff.annotation.gtf"
miRNA_GTF_PATH = "../../datasets/preprocessed/miRNA_gtf.csv"

pd.set_option('display.max_colwidth', None)

# %%
cols = ["seqname", "source", "feature", "start", "end", "score", "strand", "frame", "attribute"]

gtf_df = pd.read_csv(GTF_PATH, sep='\t', comment='#', names=cols)
gtf_df.shape
# Out:
# (8063229, 9)

# %%
def parse_attributes(attr):
    d = {}
    for a in attr.split(";"):
        a = a.strip()
        if a == "":
            continue
        if " " in a:
            key, val = a.split(" ", 1)
            d[key] = val.strip('"')
    return d

chunks = np.array_split(gtf_df, 10)
results = []
for i, chunk in enumerate(chunks):
    print(f"Processing chunk {i+1}/{len(chunks)} ...")    
    attr_df = chunk['attribute'].apply(parse_attributes).apply(pd.Series)
    merged = pd.concat([chunk.drop(columns=['attribute']), attr_df], axis=1)    
    results.append(merged)

complete_gtf_df = pd.concat(results, ignore_index=True)
# Out:
# c:\users\giorg\appdata\local\programs\python\python39\lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Processing chunk 1/10 ...
# Processing chunk 2/10 ...
# Processing chunk 3/10 ...
# Processing chunk 4/10 ...
# Processing chunk 5/10 ...
# Processing chunk 6/10 ...
# Processing chunk 7/10 ...
# Processing chunk 8/10 ...
# Processing chunk 9/10 ...
# Processing chunk 10/10 ...

# %%
complete_gtf_df.head()
# Out:
#   seqname  source     feature  start    end score strand frame  \
# 0    chr1  HAVANA        gene  11121  24894     .      +     .
# 1    chr1  HAVANA  transcript  11121  14413     .      +     .
# 2    chr1  HAVANA        exon  11121  11211     .      +     .
# 3    chr1  HAVANA        exon  12010  12227     .      +     .
# 4    chr1  HAVANA        exon  12613  12721     .      +     .
#
#              gene_id gene_type  ... exon_number            exon_id  \
# 0  ENSG00000290825.2    lncRNA  ...         NaN                NaN
# 1  ENSG00000290825.2    lncRNA  ...         NaN                NaN
# 2  ENSG00000290825.2    lncRNA  ...           1  ENSE00004248723.1
# 3  ENSG00000290825.2    lncRNA  ...           2  ENSE00004248735.1
# 4  ENSG00000290825.2    lncRNA  ...           3  ENSE00003582793.1
#
#   transcript_support_level havana_transcript hgnc_id havana_gene  ont  \
# 0                      NaN               NaN     NaN         NaN  NaN
# 1                      NaN               NaN     NaN         NaN  NaN
# 2                      NaN               NaN     NaN         NaN  NaN
# 3                      NaN               NaN     NaN         NaN  NaN
# 4                      NaN               NaN     NaN         NaN  NaN
#
#   protein_id ccdsid artif_dupl
# 0        NaN    NaN        NaN
# 1        NaN    NaN        NaN
# 2        NaN    NaN        NaN
# 3        NaN    NaN        NaN
# 4        NaN    NaN        NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Try to search for a specific miRNA ID

# %%
result = complete_gtf_df[complete_gtf_df.astype(str).apply(lambda x: x.str.contains('hsa-let-7a-1', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, gene_type, gene_name, level, tag, transcript_id, transcript_type, transcript_name, exon_number, exon_id, transcript_support_level, havana_transcript, hgnc_id, havana_gene, ont, protein_id, ccdsid, artif_dupl]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# No results found about 'hsa-let-7a-1'. Try another miRNA ID.

# %%
result = complete_gtf_df[complete_gtf_df.astype(str).apply(lambda x: x.str.contains('hsa-mir-103b-1', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, gene_type, gene_name, level, tag, transcript_id, transcript_type, transcript_name, exon_number, exon_id, transcript_support_level, havana_transcript, hgnc_id, havana_gene, ont, protein_id, ccdsid, artif_dupl]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# No results found about 'hsa-mir-103b-1'.

# %%
result = complete_gtf_df[complete_gtf_df.astype(str).apply(lambda x: x.str.contains('MIR1254-1', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, gene_type, gene_name, level, tag, transcript_id, transcript_type, transcript_name, exon_number, exon_id, transcript_support_level, havana_transcript, hgnc_id, havana_gene, ont, protein_id, ccdsid, artif_dupl]
# Index: []
#
# [0 rows x 26 columns]

# %%
result = complete_gtf_df[
    complete_gtf_df.astype(str).apply(lambda x: x.str.contains('MIR', case=False, na=False)).any(axis=1)]
result.head()
# Out:
#      seqname   source     feature  start    end score strand frame  \
# 2415    chr1  ENSEMBL        gene  17369  17436     .      -     .
# 2416    chr1  ENSEMBL  transcript  17369  17436     .      -     .
# 2417    chr1  ENSEMBL        exon  17369  17436     .      -     .
# 2418    chr1   HAVANA        gene  28589  31109     .      +     .
# 2419    chr1   HAVANA  transcript  28589  29345     .      +     .
#
#                 gene_id gene_type  ... exon_number            exon_id  \
# 2415  ENSG00000278267.1     miRNA  ...         NaN                NaN
# 2416  ENSG00000278267.1     miRNA  ...         NaN                NaN
# 2417  ENSG00000278267.1     miRNA  ...           1  ENSE00003746039.1
# 2418  ENSG00000243485.6    lncRNA  ...         NaN                NaN
# 2419  ENSG00000243485.6    lncRNA  ...         NaN                NaN
#
#      transcript_support_level havana_transcript     hgnc_id  \
# 2415                      NaN               NaN  HGNC:50039
# 2416                       NA               NaN  HGNC:50039
# 2417                       NA               NaN  HGNC:50039
# 2418                      NaN               NaN  HGNC:52482
# 2419                      NaN               NaN  HGNC:52482
#
#                havana_gene  ont protein_id ccdsid artif_dupl
# 2415                   NaN  NaN        NaN    NaN        NaN
# 2416                   NaN  NaN        NaN    NaN        NaN
# 2417                   NaN  NaN        NaN    NaN        NaN
# 2418  OTTHUMG00000000959.2  NaN        NaN    NaN        NaN
# 2419  OTTHUMG00000000959.2  NaN        NaN    NaN        NaN
#
# [5 rows x 26 columns]

# %%
result = complete_gtf_df[
    complete_gtf_df.astype(str).apply(lambda x: x.str.contains('ENST00000408257.1', case=False, na=False)).any(axis=1)]
result.head()
# Out:
#         seqname   source     feature     start       end score strand frame  \
# 4013594   chr10  ENSEMBL  transcript  68759318  68759414     .      +     .
# 4013595   chr10  ENSEMBL        exon  68759318  68759414     .      +     .
#
#                    gene_id gene_type  ... exon_number            exon_id  \
# 4013594  ENSG00000221184.1     miRNA  ...         NaN                NaN
# 4013595  ENSG00000221184.1     miRNA  ...           1  ENSE00001564892.1
#
#         transcript_support_level havana_transcript hgnc_id havana_gene  ont  \
# 4013594                       NA               NaN     NaN         NaN  NaN
# 4013595                       NA               NaN     NaN         NaN  NaN
#
#         protein_id ccdsid artif_dupl
# 4013594        NaN    NaN        NaN
# 4013595        NaN    NaN        NaN
#
# [2 rows x 26 columns]

# %% [markdown]
# ### Filter miRNA entries by searching for 'miRNA' keyword

# %%
mirna_df = complete_gtf_df[complete_gtf_df.astype(str).apply(lambda x: x.str.contains('miRNA', case=False, na=False)).any(axis=1)]
mirna_df.shape
# Out:
# (5835, 26)

# %% [markdown]
# It is sufficient to filter only by **'gene_type'** column.

# %%
mirna_df = complete_gtf_df[complete_gtf_df['gene_type'] == 'miRNA']
mirna_df.shape
# Out:
# (5835, 26)

# %%
mirna_df.head()
# Out:
#      seqname   source     feature  start    end score strand frame  \
# 2415    chr1  ENSEMBL        gene  17369  17436     .      -     .
# 2416    chr1  ENSEMBL  transcript  17369  17436     .      -     .
# 2417    chr1  ENSEMBL        exon  17369  17436     .      -     .
# 2433    chr1  ENSEMBL        gene  30366  30503     .      +     .
# 2434    chr1  ENSEMBL  transcript  30366  30503     .      +     .
#
#                 gene_id gene_type  ... exon_number            exon_id  \
# 2415  ENSG00000278267.1     miRNA  ...         NaN                NaN
# 2416  ENSG00000278267.1     miRNA  ...         NaN                NaN
# 2417  ENSG00000278267.1     miRNA  ...           1  ENSE00003746039.1
# 2433  ENSG00000284332.1     miRNA  ...         NaN                NaN
# 2434  ENSG00000284332.1     miRNA  ...         NaN                NaN
#
#      transcript_support_level havana_transcript     hgnc_id havana_gene  ont  \
# 2415                      NaN               NaN  HGNC:50039         NaN  NaN
# 2416                       NA               NaN  HGNC:50039         NaN  NaN
# 2417                       NA               NaN  HGNC:50039         NaN  NaN
# 2433                      NaN               NaN  HGNC:35294         NaN  NaN
# 2434                       NA               NaN  HGNC:35294         NaN  NaN
#
#      protein_id ccdsid artif_dupl
# 2415        NaN    NaN        NaN
# 2416        NaN    NaN        NaN
# 2417        NaN    NaN        NaN
# 2433        NaN    NaN        NaN
# 2434        NaN    NaN        NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Save the preprocessed miRNA GTF data as CSV file

# %%
mirna_df.to_csv(miRNA_GTF_PATH, index=False)

# %% [markdown]
# ## Reload created CSV file

# %%
df = pd.read_csv(miRNA_GTF_PATH)
df.shape
# Out:
# (5835, 26)

# %%
pd.set_option('display.max_colwidth', None)
df.describe()
# Out:
#               start           end   level  exon_number  \
# count  5.835000e+03  5.835000e+03  5835.0       1945.0
# mean   7.399684e+07  7.399692e+07     3.0          1.0
# std    5.639511e+07  5.639511e+07     0.0          0.0
# min    2.050000e+03  2.164000e+03     3.0          1.0
# 25%    2.895858e+07  2.895866e+07     3.0          1.0
# 50%    6.119980e+07  6.119988e+07     3.0          1.0
# 75%    1.102849e+08  1.102849e+08     3.0          1.0
# max    2.488264e+08  2.488264e+08     3.0          1.0
#
#        transcript_support_level  havana_transcript  havana_gene  ont  \
# count                       0.0                0.0          0.0  0.0
# mean                        NaN                NaN          NaN  NaN
# std                         NaN                NaN          NaN  NaN
# min                         NaN                NaN          NaN  NaN
# 25%                         NaN                NaN          NaN  NaN
# 50%                         NaN                NaN          NaN  NaN
# 75%                         NaN                NaN          NaN  NaN
# max                         NaN                NaN          NaN  NaN
#
#        protein_id  ccdsid  artif_dupl
# count         0.0     0.0         0.0
# mean          NaN     NaN         NaN
# std           NaN     NaN         NaN
# min           NaN     NaN         NaN
# 25%           NaN     NaN         NaN
# 50%           NaN     NaN         NaN
# 75%           NaN     NaN         NaN
# max           NaN     NaN         NaN

# %%
df[['gene_name', 'gene_id', 'transcript_id']].head()
# Out:
#    gene_name            gene_id      transcript_id
# 0  MIR6859-1  ENSG00000278267.1                NaN
# 1  MIR6859-1  ENSG00000278267.1  ENST00000619216.1
# 2  MIR6859-1  ENSG00000278267.1  ENST00000619216.1
# 3  MIR1302-2  ENSG00000284332.1                NaN
# 4  MIR1302-2  ENSG00000284332.1  ENST00000607096.1

# %% [markdown]
# ## Map miRNA gene names to miRBase IDs using pybiomart

# %%
from pybiomart import Server

server = Server(host='http://www.ensembl.org')
mart = server['ENSEMBL_MART_ENSEMBL']
dataset = mart['hsapiens_gene_ensembl']

mapping = dataset.query(
    attributes=['ensembl_gene_id', 'external_gene_name', 'mirbase_id', 'mirbase_accession'],
    filters={'biotype': 'miRNA'}
)
mapping = mapping[mapping['miRBase ID'].notnull()].drop_duplicates()

print(mapping.head())
mapping.shape
# Out:
#     Gene stable ID  Gene name      miRBase ID miRBase accession
# 0  ENSG00000283344  MIR1244-4  hsa-mir-1244-1         MI0006379
# 1  ENSG00000283344  MIR1244-4  hsa-mir-1244-2         MI0015974
# 2  ENSG00000283344  MIR1244-4  hsa-mir-1244-3         MI0015975
# 3  ENSG00000283344  MIR1244-4  hsa-mir-1244-4         MI0031511
# 4  ENSG00000292346    MIR6089  hsa-mir-6089-1         MI0020366
# (2135, 4)

# %%
server = Server(host='http://grch37.ensembl.org')
mart = server['ENSEMBL_MART_ENSEMBL']
dataset = mart['hsapiens_gene_ensembl']

mapping_grch37 = dataset.query(
    attributes=['ensembl_gene_id', 'external_gene_name', 'mirbase_id', 'mirbase_accession'],
    filters={'biotype': 'miRNA'}
)
mapping_grch37 = mapping_grch37[mapping_grch37['miRBase ID'].notnull()].drop_duplicates()

print(mapping_grch37.head())
# Out:
#      Gene stable ID Gene name    miRBase ID miRBase accession
# 2   ENSG00000252695   MIR2276  hsa-mir-2276         MI0011282
# 5   ENSG00000263399   MIR3170  hsa-mir-3170         MI0014201
# 7   ENSG00000207719    MIR623   hsa-mir-623         MI0003637
# 9   ENSG00000263615   MIR4306  hsa-mir-4306         MI0015836
# 12  ENSG00000265164   MIR2681  hsa-mir-2681         MI0012062

# %%
from Bio import SeqIO

records = SeqIO.parse("../../datasets/hairpin.fa", "fasta")
mirna_data = [
    {
        'mirbase_id': r.id,
        'description': r.description,
        'sequence': str(r.seq)
    }
    for r in records
]

mirna_data
# Out:
# [{'mirbase_id': 'cel-let-7',
#   'description': 'cel-let-7 MI0000001 Caenorhabditis elegans let-7 stem-loop',
#   'sequence': 'UACACUGUGGAUCCGGUGAGGUAGUAGGUUGUAUAGUUUGGAAUAUUACCACCGGUGAACUAUGCAAUUUUCUACCUUACCGGAGACAGAACUCUUCGA'},
#  {'mirbase_id': 'cel-lin-4',
#   'description': 'cel-lin-4 MI0000002 Caenorhabditis elegans lin-4 stem-loop',
#   'sequence': 'AUGCUUCCGGCCUGUUCCCUGAGACCUCAAGUGUGAGUGUACUAUUGAUGCUUCACACCUGGGCUCUCCGGGUACCAGGACGGUUUGAGCAGAU'},
#  {'mirbase_id': 'cel-mir-1',
#   'description': 'cel-mir-1 MI0000003 Caenorhabditis elegans miR-1 stem-loop',
#   'sequence': 'AAAGUGACCGUACCGAGCUGCAUACUUCCUUACAUGCCCAUACUAUAUCAUAAAUGGAUAUGGAAUGUAAAGAAGUAUGUAGAACGGGGUGGUAGU'},
#  {'mirbase_id': 'cel-mir-2',
#   'description': 'cel-mir-2 MI0000004 Caenorhabditis elegans miR-2 stem-loop',
#   'sequence': 'UAAACAGUAUACAGAAAGCCAUCAAAGCGGUGGUUGAUGUGUUGCAAAUUAUGACUUUCAUAUCACAGCCAGCUUUGAUGUGCUGCCUGUUGCACUGU'},
#  {'mirbase_id': 'cel-mir-34',
#   'description': 'cel-mir-34 MI0000005 Caenorhabditis elegans miR-34 stem-loop',
#   'sequence': 'CGGACAAUGCUCGAGAGGCAGUGUGGUUAGCUGGUUGCAUAUUUCCUUGACAACGGCUACCUUCACUGCCACCCCGAACAUGUCGUCCAUCUUUGAA'},
#  {'mirbase_id': 'cel-mir-35',
#   'description': 'cel-mir-35 MI0000006 Caenorhabditis elegans miR-35 stem-loop',
#   'sequence': 'UCUCGGAUCAGAUCGAGCCAUUGCUGGUUUCUUCCACAGUGGUACUUUCCAUUAGAACUAUCACCGGGUGGAAACUAGCAGUGGCUCGAUCUUUUCC'},
#  {'mirbase_id': 'cel-mir-36',
#   'description': 'cel-mir-36 MI0000007 Caenorhabditis elegans miR-36 stem-loop',
#   'sequence': 'CACCGCUGUCGGGGAACCGCGCCAAUUUUCGCUUCAGUGCUAGACCAUCCAAAGUGUCUAUCACCGGGUGAAAAUUCGCAUGGGUCCCCGACGCGGA'},
#  {'mirbase_id': 'cel-mir-37',
#   'description': 'cel-mir-37 MI0000008 Caenorhabditis elegans miR-37 stem-loop',
#   'sequence': 'UUCUAGAAACCCUUGGACCAGUGUGGGUGUCCGUUGCGGUGCUACAUUCUCUAAUCUGUAUCACCGGGUGAACACUUGCAGUGGUCCUCGUGGUUUCU'},
#  {'mirbase_id': 'cel-mir-38',
#   'description': 'cel-mir-38 MI0000009 Caenorhabditis elegans miR-38 stem-loop',
#   'sequence': 'GUGAGCCAGGUCCUGUUCCGGUUUUUUCCGUGGUGAUAACGCAUCCAAAAGUCUCUAUCACCGGGAGAAAAACUGGAGUAGGACCUGUGACUCAU'},
#  {'mirbase_id': 'cel-mir-39',
#   'description': 'cel-mir-39 MI0000010 Caenorhabditis elegans miR-39 stem-loop',
#   'sequence': 'UAUACCGAGAGCCCAGCUGAUUUCGUCUUGGUAAUAAGCUCGUCAUUGAGAUUAUCACCGGGUGUAAAUCAGCUUGGCUCUGGUGUC'},
#  {'mirbase_id': 'cel-mir-40',
#   'description': 'cel-mir-40 MI0000011 Caenorhabditis elegans miR-40 stem-loop',
#   'sequence': 'UCCUGUCCGCACCUCAGUGGAUGUAUGCCAUGAUGAUAAGAUAUCAGAAAUCCUAUCACCGGGUGUACAUCAGCUAAGGUGCGGGUACAGGU'},
#  {'mirbase_id': 'cel-mir-41',
#   'description': 'cel-mir-41 MI0000012 Caenorhabditis elegans miR-41 stem-loop',
#   'sequence': 'GGGUCCCAGAGACCUUGGUGGUUUUUCUCUGCAGUGAUAGAUACUUCUAACAACUCGCUAUCACCGGGUGAAAAAUCACCUAGGUCUGGAGCCUCCU'},
#  {'mirbase_id': 'cel-mir-42',
#   'description': 'cel-mir-42 MI0000013 Caenorhabditis elegans miR-42 stem-loop',
#   'sequence': 'UUCGCGGACCUUUGUGGGUGUUUGCUUUUUCGGUGAAGUUGUCUUCCGUAGCUUCUUCUUCACCGGGUUAACAUCUACAGAGGUCCAAAAAGGGG'},
#  {'mirbase_id': 'cel-mir-43',
#   'description': 'cel-mir-43 MI0000014 Caenorhabditis elegans miR-43 stem-loop',
#   'sequence': 'UAUUGGCACUAGUCGCCCGUGACAUCAAGAAACUAGUGAUUAUGCCAAACCACAGGGACAUAUCACAGUUUACUUGCUGUCGCGGGCGGUGCUGAGUU'},
#  {'mirbase_id': 'cel-mir-44',
#   'description': 'cel-mir-44 MI0000015 Caenorhabditis elegans miR-44 stem-loop',
#   'sequence': 'GAGAAAAUGGCCAAUCUGGAUGUGCUCGUUGGUCAUAGACGUCAACACGAACUGUUCAUAUGACUAGAGACACAUUCAGCUUGGCCUGCUUCUCUA'},
#  {'mirbase_id': 'cel-mir-45',
#   'description': 'cel-mir-45 MI0000016 Caenorhabditis elegans miR-45 stem-loop',
#   'sequence': 'CACCAUGUGCCACGCUGGAUGUGCUCGUUAGUCAUAAUAUCCUCCACAAAGCAAGGACUAUGACUAGAGACACAUUCAGCUUGGCGCCGAAUGCAU'},
#  {'mirbase_id': 'cel-mir-46',
#   'description': 'cel-mir-46 MI0000017 Caenorhabditis elegans miR-46 stem-loop',
#   'sequence': 'CUGAGGUGAAGCUGAAGAGAGCCGUCUAUUGACAGUUCAAGACCACGAGUCGUUGUGUGCUGUCAUGGAGUCGCUCUCUUCAGAUGAUCCGGUCAAU'},
#  {'mirbase_id': 'cel-mir-47',
#   'description': 'cel-mir-47 MI0000018 Caenorhabditis elegans miR-47 stem-loop',
#   'sequence': 'GAGAGCCGACUGAAACUGAAGAGAGCAGUCUAUUGACAGUCGGUUACUCGAAAUCUUUACUGUCAUGGAGGCGCUCUCUUCAGAUGAUGUCUGGCCC'},
#  {'mirbase_id': 'cel-mir-48',
#   'description': 'cel-mir-48 MI0000019 Caenorhabditis elegans miR-48 stem-loop',
#   'sequence': 'AAACUCCCGGGAACUUGAGGUAGGCUCAGUAGAUGCGAAUUGAACGGUAUCUCACAUCCACCAGCCUAGCUCGCAUUCCCAGAGUUUACGGUAUUGUU'},
#  {'mirbase_id': 'cel-mir-49',
#   'description': 'cel-mir-49 MI0000020 Caenorhabditis elegans miR-49 stem-loop',
#   'sequence': 'UUUUGAAAAAGACCACCGUCCGCAGUUUGUUGUGAUGUGCUCCAAGCAAUCAUGAGUCUGAAGCACCACGAGAAGCUGCAGAUGGAGGUUCUGAUUU'},
#  {'mirbase_id': 'cel-mir-50',
#   'description': 'cel-mir-50 MI0000021 Caenorhabditis elegans miR-50 stem-loop',
#   'sequence': 'CUGCCCGCCGGCCGCUGAUAUGUCUGGUAUUCUUGGGUUUGAACUUCCAGCGUUGAACCCGCAUAUUAGACGUAUCGACGGCCGGCGGGGCAGGUAAUG'},
#  {'mirbase_id': 'cel-mir-51',
#   'description': 'cel-mir-51 MI0000022 Caenorhabditis elegans miR-51 stem-loop',
#   'sequence': 'GUCCGAAAAGUCCGUCUACCCGUAGCUCCUAUCCAUGUUACUGGUCAAAAAGUGAACAUGGAAGCAGGUACAGGUGCACGGCGAGUAGGGUCAUGAAGCU'},
#  {'mirbase_id': 'cel-mir-52',
#   'description': 'cel-mir-52 MI0000023 Caenorhabditis elegans miR-52 stem-loop',
#   'sequence': 'UCCAACUCUAACAGUCCACCCGUACAUAUGUUUCCGUGCUUGACAGCGAAGCUCAAUCACGUUACAAUGAAAGGGUAGCCGGUUAUUGAAGUUGGGUCUU'},
#  {'mirbase_id': 'cel-mir-53',
#   'description': 'cel-mir-53 MI0000024 Caenorhabditis elegans miR-53 stem-loop',
#   'sequence': 'CCGAUUCUGACAGUCCACCCGUACAUUUGUUUCCGUGCUUGACUUCAAAGCUCAAUCACGGCACAAUAUAUGGGUCGCCAGUCAUUGUAGUCGGAAUUU'},
#  {'mirbase_id': 'cel-mir-54',
#   'description': 'cel-mir-54 MI0000025 Caenorhabditis elegans miR-54 stem-loop',
#   'sequence': 'GUGAGUCGCGCUCUGACUAGGAUAUGAGACGACGAGAACAUUGCUUUUUUAAAAGACUUGUACCCGUAAUCUUCAUAAUCCGAGUCAGGGCUAGCUGAC'},
#  {'mirbase_id': 'cel-mir-55',
#   'description': 'cel-mir-55 MI0000026 Caenorhabditis elegans miR-55 stem-loop',
#   'sequence': 'AGAUUUGGAACUUAAUGGGACUCGGCAGAAACCUAUCGGUUAUACUUUUUGGAUAUGCUAUACCCGUAUAAGUUUCUGCUGAGCCCCUUAUUCCUGUU'},
#  {'mirbase_id': 'cel-mir-56',
#   'description': 'cel-mir-56 MI0000027 Caenorhabditis elegans miR-56 stem-loop',
#   'sequence': 'GAGCCAGUGUCUGUUCUUGGCGGAUCCAUUUUGGGUUGUACCUCAUCCUAAAUUUGACGGUACCCGUAAUGUUUCCGCUGAGAACCGACUGUGCACC'},
#  {'mirbase_id': 'cel-mir-57',
#   'description': 'cel-mir-57 MI0000028 Caenorhabditis elegans miR-57 stem-loop',
#   'sequence': 'AUCGACAUGCUCGUCUACCCUGUAGAUCGAGCUGUGUGUUUGAAACAAUCAUACACGAGCUAGACUACAAGGUGCACGAACAAACCGAAGAUUUAUGAA'},
#  {'mirbase_id': 'cel-mir-58a',
#   'description': 'cel-mir-58a MI0000029 Caenorhabditis elegans miR-58 stem-loop',
#   'sequence': 'GCUCGUCAUAUCCAUUGCCCUACUCUUCGCAUCUCAUCACUUCGUCCAAUACCAUAGGGAUGAGAUCGUUCAGUACGGCAAUGGACUGAGCUAGAGU'},
#  {'mirbase_id': 'cel-mir-59',
#   'description': 'cel-mir-59 MI0000030 Caenorhabditis elegans miR-59 stem-loop',
#   'sequence': 'AGUUGAUCUAGAUAUGACAUCGUCCUGAAAACGAAACGGAACAAAAGUUCAAGAUAUUGAUUUCGAAUCGUUUAUCAGGAUGAUGUGAUUAAAAUCAACU'},
#  {'mirbase_id': 'cel-mir-60',
#   'description': 'cel-mir-60 MI0000031 Caenorhabditis elegans miR-60 stem-loop',
#   'sequence': 'CUCGAAAACCGCUUGUUCUUGAACUGGAAGAGUGCCAUAAAAUCAUGACAAAGUACGUGAUAUUAUGCACAUUUUCUAGUUCAAGACUUGAGAAAUCG'},
#  {'mirbase_id': 'cel-mir-61',
#   'description': 'cel-mir-61 MI0000032 Caenorhabditis elegans miR-61 stem-loop',
#   'sequence': 'UUCCAUUAUCGCUGAACCUCGAGAUGGGUUACGGGGCUUAGUCCUUCCUCCGUAUGGCAAUGACUAGAACCGUUACUCAUCUCGAGGUUUCGGUGAU'},
#  {'mirbase_id': 'cel-mir-62',
#   'description': 'cel-mir-62 MI0000033 Caenorhabditis elegans miR-62 stem-loop',
#   'sequence': 'GUGAGUUAGAUCUCAUAUCCUUCCGCAAAAUGGAAAUGAUAUGUAAUCUAGCUUACAG'},
#  {'mirbase_id': 'cel-mir-63',
#   'description': 'cel-mir-63 MI0000034 Caenorhabditis elegans miR-63 stem-loop',
#   'sequence': 'UCAACAAGCAGACACAAUUUCUAACUCGUCGGUAGUCAUCGUUCUAGCUGAAAAGGACACUAUGACACUGAAGCGAGUUGGAAAUAGUGGUUCUACUUGAGCAA'},
#  {'mirbase_id': 'cel-mir-64',
#   'description': 'cel-mir-64 MI0000035 Caenorhabditis elegans miR-64 stem-loop',
#   'sequence': 'CUCCCCGCUGACCUCGCCGAAUAUGACACUGAAGCGUUACCGAACCGUUUUCCCACACCUGGAUUCGGUGCAACGAUCAGUGGCAUGCUCGGCUAGCGCCAGUUAAGUAU'},
#  {'mirbase_id': 'cel-mir-65',
#   'description': 'cel-mir-65 MI0000036 Caenorhabditis elegans miR-65 stem-loop',
#   'sequence': 'AUGGAGCCUUCGCCGAUUAUGACACUGAAGCGUAACCGAACACCAUAUUUUGAGAUUCUGCUACGCGCAGUGCCAUGCUCGGCGCGUUGGCUCCAUUAAA'},
#  {'mirbase_id': 'cel-mir-66',
#   'description': 'cel-mir-66 MI0000037 Caenorhabditis elegans miR-66 stem-loop',
#   'sequence': 'CCACAAAAAUGCCAUACAUGACACUGAUUAGGGAUGUGAUGAAUGUUAAGAUCCCGAUCAAAUUCCUAACGGUGUCAAACAUGGCGUAUGUGGUUGUAG'},
#  {'mirbase_id': 'cel-mir-67',
#   'description': 'cel-mir-67 MI0000038 Caenorhabditis elegans miR-67 stem-loop',
#   'sequence': 'GAUCAAAGAUUCGUCGAUCCGCUCAUUCUGCCGGUUGUUAUGCUAUUAUCAGAUUAAGCAUCACAACCUCCUAGAAAGAGUAGAUCGAUUUUAAAACUU'},
#  {'mirbase_id': 'cel-mir-70',
#   'description': 'cel-mir-70 MI0000041 Caenorhabditis elegans miR-70 stem-loop',
#   'sequence': 'UCAAAAUAAAACGAUGAAAACUAUCGAAAUACUAUCGACGAAUAACACUUAUGAAGAAAUGUAAUACGUCGUUGGUGUUUCCAUAGUUUGAAUUGUUUAU'},
#  {'mirbase_id': 'cel-mir-71',
#   'description': 'cel-mir-71 MI0000042 Caenorhabditis elegans miR-71 stem-loop',
#   'sequence': 'GUCUGCUCUGAACGAUGAAAGACAUGGGUAGUGAGACGUCGGAGCCUCGUCGUAUCACUAUUCUGUUUUUCGCCGUCGGGAUCGUGACCUGGAA'},
#  {'mirbase_id': 'cel-mir-72',
#   'description': 'cel-mir-72 MI0000043 Caenorhabditis elegans miR-72 stem-loop',
#   'sequence': 'AGGUCCCGUCAGAGCUAGGCAAGAUGUUGGCAUAGCUGAAUGAUCGCUAUAACAACUAUCAGCUUCGCCACAUUCUGCCACGCACUGAUGUGAGGACCU'},
#  {'mirbase_id': 'cel-mir-73',
#   'description': 'cel-mir-73 MI0000044 Caenorhabditis elegans miR-73 stem-loop',
#   'sequence': 'CAGUGAGAGUCCCACACACGACUGGACUUCCAUAUCGAGCCACAGCUAUCAACGAAUUUGCUGGCAAGAUGUAGGCAGUUCAGUUGUGCGUUUAUGGAG'},
#  {'mirbase_id': 'cel-mir-74',
#   'description': 'cel-mir-74 MI0000045 Caenorhabditis elegans miR-74 stem-loop',
#   'sequence': 'AAAUGGUUCAAAAAACGUUCGGGCUUCCAUCUCUUUCCCAGCCUACAUCUCAACCUGGGCUGGCAAGAAAUGGCAGUCUACACGUUUUUCAACCAAA'},
#  {'mirbase_id': 'cel-mir-75',
#   'description': 'cel-mir-75 MI0000046 Caenorhabditis elegans miR-75 stem-loop',
#   'sequence': 'UUCUUGUUGCUUUGAAGAAUUGCAGUCGGUUGCAAGCUUAAAUACAAAUCCGAAUUGUUAUUAAAGCUACCAACCGGCUUCAAGUCUGAAAGAGCAG'},
#  {'mirbase_id': 'cel-mir-76',
#   'description': 'cel-mir-76 MI0000047 Caenorhabditis elegans miR-76 stem-loop',
#   'sequence': 'AUUUCAGCUCCUGUCUGGGCUUCACAAUAGUCGAAUACCUUAAAUUUCAAAAUUUGGAUAUUCGUUGUUGAUGAAGCCUUGAUGGGGGUGAGAAAGA'},
#  {'mirbase_id': 'cel-mir-77',
#   'description': 'cel-mir-77 MI0000048 Caenorhabditis elegans miR-77 stem-loop',
#   'sequence': 'GCAUCUGCCAAACCGCCCGUUUGGAUGGUUGUGCUCUGAGGAAAUACGCACAGAAUGUCAUUUCAUCAGGCCAUAGCUGUCCAAAUUGGUAUAGAGUUUG'},
#  {'mirbase_id': 'cel-mir-78',
#   'description': 'cel-mir-78 MI0000049 Caenorhabditis elegans miR-78 stem-loop',
#   'sequence': 'AAUAAAAUAUAUUGUUUCAUAGUGUCCGUAAAAUAACUAGAUUUAUUUUGUAAAAACUAUUGGAGGCCUGGUUGUUUGUGCUGGAAUGUUUCGAGA'},
#  {'mirbase_id': 'cel-mir-79',
#   'description': 'cel-mir-79 MI0000050 Caenorhabditis elegans miR-79 stem-loop',
#   'sequence': 'UAGUAGACAUUCUCCGAUCUUUGGUGAUUCAGCUUCAAUGAUUGGCUACAGGUUUCUUUCAUAAAGCUAGGUUACCAAAGCUCGGCGUCUUGAUCUAC'},
#  {'mirbase_id': 'cel-mir-80',
#   'description': 'cel-mir-80 MI0000051 Caenorhabditis elegans miR-80/miR-227 stem-loop',
#   'sequence': 'AUGGACACUCGUUCGCUCAGCUUUCGACAUGAUUCUGAACAAUCCGCAAGCCCAUGUUGUUGAGAUCAUUAGUUGAAAGCCGAAUGAUCAGAGAUAUC'},
#  {'mirbase_id': 'cel-mir-81',
#   'description': 'cel-mir-81 MI0000052 Caenorhabditis elegans miR-81 stem-loop',
#   'sequence': 'AUCAGUGCCAUCGUGCCCAACAGUCGGUUUUCACCGUGAUCUGAGAGCAAUCCAAAAAUGCUUUUCUGAGAUCAUCGUGAAAGCUAGUUGUUGGUCUACGGGCUUUUG'},
#  {'mirbase_id': 'cel-mir-82',
#   'description': 'cel-mir-82 MI0000053 Caenorhabditis elegans miR-82 stem-loop',
#   'sequence': 'GAAAUAGGUUCUUUUAGCAACCGGUUUUCUCUGUGAUCUACAGAAUGACAGCUAAUCGUCUGAGAUCAUCGUGAAAGCCAGUUGUUUUUAUGAACUC'},
#  {'mirbase_id': 'cel-mir-83',
#   'description': 'cel-mir-83 MI0000054 Caenorhabditis elegans miR-83 stem-loop',
#   'sequence': 'AGCACCACUCGGAACCACUGAAUUUAUGUGUGUACUUGACGGCCAACAAGAGCAUCGAUCUAGCACCAUAUAAAUUCAGUAAUUUCGCGUCGAGAGCU'},
#  {'mirbase_id': 'cel-mir-84',
#   'description': 'cel-mir-84 MI0000055 Caenorhabditis elegans miR-84 stem-loop',
#   'sequence': 'GUGGCAUCUGAGGUAGUAUGUAAUAUUGUAGACUGUCUAUAAUGUCCACAAUGUUUCAACUAACUCGGCUGUUCU'},
#  {'mirbase_id': 'cel-mir-85',
#   'description': 'cel-mir-85 MI0000056 Caenorhabditis elegans miR-85 stem-loop',
#   'sequence': 'UAUAGAAUUUUGGCGUCGGAGCCCGAUUUUUCAAUAGUUUGAAACCAGUGUACACAUAAAUGGUUACAAAGUAUUUGAAAAGUCGUGCUCUGAAAAUGAAUUCUUA'},
#  {'mirbase_id': 'cel-mir-86',
#   'description': 'cel-mir-86 MI0000057 Caenorhabditis elegans miR-86 stem-loop',
#   'sequence': 'CGUGUCCACGCCGUCUAAGUGAAUGCUUUGCCACAGUCUUCGAUGUUCUGAAAUGAAGCCUGGGCUCAGAUUCGCUUAGGCCGGAGUUUGACACGGCA'},
#  {'mirbase_id': 'cel-mir-87',
#   'description': 'cel-mir-87 MI0000058 Caenorhabditis elegans miR-87 stem-loop',
#   'sequence': 'GGUUGUGCCAUCCGGCCGCCUGAUACUUUCGUCUCAACCUCGCUGUCAGAUUGGUCGUAGGUGAGCAAAGUUUCAGGUGUGCCGGAACACACCC'},
#  {'mirbase_id': 'cel-mir-90',
#   'description': 'cel-mir-90 MI0000059 Caenorhabditis elegans miR-90 stem-loop',
#   'sequence': 'GGGCGCCAUUUCGAGCGGCUUUCAACGACGAUAUCAACCGACAACUCACACUUUUGCGUGUUGAUAUGUUGUUUGAAUGCCCCUUGAAUUGGAUGCCA'},
#  {'mirbase_id': 'hsa-let-7a-1',
#   'description': 'hsa-let-7a-1 MI0000060 Homo sapiens let-7a-1 stem-loop',
#   'sequence': 'UGGGAUGAGGUAGUAGGUUGUAUAGUUUUAGGGUCACACCCACCACUGGGAGAUAACUAUACAAUCUACUGUCUUUCCUA'},
#  {'mirbase_id': 'hsa-let-7a-2',
#   'description': 'hsa-let-7a-2 MI0000061 Homo sapiens let-7a-2 stem-loop',
#   'sequence': 'AGGUUGAGGUAGUAGGUUGUAUAGUUUAGAAUUACAUCAAGGGAGAUAACUGUACAGCCUCCUAGCUUUCCU'},
#  {'mirbase_id': 'hsa-let-7a-3',
#   'description': 'hsa-let-7a-3 MI0000062 Homo sapiens let-7a-3 stem-loop',
#   'sequence': 'GGGUGAGGUAGUAGGUUGUAUAGUUUGGGGCUCUGCCCUGCUAUGGGAUAACUAUACAAUCUACUGUCUUUCCU'},
#  {'mirbase_id': 'hsa-let-7b',
#   'description': 'hsa-let-7b MI0000063 Homo sapiens let-7b stem-loop',
#   'sequence': 'CGGGGUGAGGUAGUAGGUUGUGUGGUUUCAGGGCAGUGAUGUUGCCCCUCGGAAGAUAACUAUACAACCUACUGCCUUCCCUG'},
#  {'mirbase_id': 'hsa-let-7c',
#   'description': 'hsa-let-7c MI0000064 Homo sapiens let-7c stem-loop',
#   'sequence': 'GCAUCCGGGUUGAGGUAGUAGGUUGUAUGGUUUAGAGUUACACCCUGGGAGUUAACUGUACAACCUUCUAGCUUUCCUUGGAGC'},
#  {'mirbase_id': 'hsa-let-7d',
#   'description': 'hsa-let-7d MI0000065 Homo sapiens let-7d stem-loop',
#   'sequence': 'CCUAGGAAGAGGUAGUAGGUUGCAUAGUUUUAGGGCAGGGAUUUUGCCCACAAGGAGGUAACUAUACGACCUGCUGCCUUUCUUAGG'},
#  {'mirbase_id': 'hsa-let-7e',
#   'description': 'hsa-let-7e MI0000066 Homo sapiens let-7e stem-loop',
#   'sequence': 'CCCGGGCUGAGGUAGGAGGUUGUAUAGUUGAGGAGGACACCCAAGGAGAUCACUAUACGGCCUCCUAGCUUUCCCCAGG'},
#  {'mirbase_id': 'hsa-let-7f-1',
#   'description': 'hsa-let-7f-1 MI0000067 Homo sapiens let-7f-1 stem-loop',
#   'sequence': 'UCAGAGUGAGGUAGUAGAUUGUAUAGUUGUGGGGUAGUGAUUUUACCCUGUUCAGGAGAUAACUAUACAAUCUAUUGCCUUCCCUGA'},
#  {'mirbase_id': 'hsa-let-7f-2',
#   'description': 'hsa-let-7f-2 MI0000068 Homo sapiens let-7f-2 stem-loop',
#   'sequence': 'UGUGGGAUGAGGUAGUAGAUUGUAUAGUUUUAGGGUCAUACCCCAUCUUGGAGAUAACUAUACAGUCUACUGUCUUUCCCACG'},
#  {'mirbase_id': 'hsa-mir-15a',
#   'description': 'hsa-mir-15a MI0000069 Homo sapiens miR-15a stem-loop',
#   'sequence': 'CCUUGGAGUAAAGUAGCAGCACAUAAUGGUUUGUGGAUUUUGAAAAGGUGCAGGCCAUAUUGUGCUGCCUCAAAAAUACAAGG'},
#  {'mirbase_id': 'hsa-mir-16-1',
#   'description': 'hsa-mir-16-1 MI0000070 Homo sapiens miR-16-1 stem-loop',
#   'sequence': 'GUCAGCAGUGCCUUAGCAGCACGUAAAUAUUGGCGUUAAGAUUCUAAAAUUAUCUCCAGUAUUAACUGUGCUGCUGAAGUAAGGUUGAC'},
#  {'mirbase_id': 'hsa-mir-17',
#   'description': 'hsa-mir-17 MI0000071 Homo sapiens miR-17 stem-loop',
#   'sequence': 'GUCAGAAUAAUGUCAAAGUGCUUACAGUGCAGGUAGUGAUAUGUGCAUCUACUGCAGUGAAGGCACUUGUAGCAUUAUGGUGAC'},
#  {'mirbase_id': 'hsa-mir-18a',
#   'description': 'hsa-mir-18a MI0000072 Homo sapiens miR-18a stem-loop',
#   'sequence': 'UGUUCUAAGGUGCAUCUAGUGCAGAUAGUGAAGUAGAUUAGCAUCUACUGCCCUAAGUGCUCCUUCUGGCA'},
#  {'mirbase_id': 'hsa-mir-19a',
#   'description': 'hsa-mir-19a MI0000073 Homo sapiens miR-19a stem-loop',
#   'sequence': 'GCAGUCCUCUGUUAGUUUUGCAUAGUUGCACUACAAGAAGAAUGUAGUUGUGCAAAUCUAUGCAAAACUGAUGGUGGCCUGC'},
#  {'mirbase_id': 'hsa-mir-19b-1',
#   'description': 'hsa-mir-19b-1 MI0000074 Homo sapiens miR-19b-1 stem-loop',
#   'sequence': 'CACUGUUCUAUGGUUAGUUUUGCAGGUUUGCAUCCAGCUGUGUGAUAUUCUGCUGUGCAAAUCCAUGCAAAACUGACUGUGGUAGUG'},
#  {'mirbase_id': 'hsa-mir-19b-2',
#   'description': 'hsa-mir-19b-2 MI0000075 Homo sapiens miR-19b-2 stem-loop',
#   'sequence': 'ACAUUGCUACUUACAAUUAGUUUUGCAGGUUUGCAUUUCAGCGUAUAUAUGUAUAUGUGGCUGUGCAAAUCCAUGCAAAACUGAUUGUGAUAAUGU'},
#  {'mirbase_id': 'hsa-mir-20a',
#   'description': 'hsa-mir-20a MI0000076 Homo sapiens miR-20a stem-loop',
#   'sequence': 'GUAGCACUAAAGUGCUUAUAGUGCAGGUAGUGUUUAGUUAUCUACUGCAUUAUGAGCACUUAAAGUACUGC'},
#  {'mirbase_id': 'hsa-mir-21',
#   'description': 'hsa-mir-21 MI0000077 Homo sapiens miR-21 stem-loop',
#   'sequence': 'UGUCGGGUAGCUUAUCAGACUGAUGUUGACUGUUGAAUCUCAUGGCAACACCAGUCGAUGGGCUGUCUGACA'},
#  {'mirbase_id': 'hsa-mir-22',
#   'description': 'hsa-mir-22 MI0000078 Homo sapiens miR-22 stem-loop',
#   'sequence': 'GGCUGAGCCGCAGUAGUUCUUCAGUGGCAAGCUUUAUGUCCUGACCCAGCUAAAGCUGCCAGUUGAAGAACUGUUGCCCUCUGCC'},
#  {'mirbase_id': 'hsa-mir-23a',
#   'description': 'hsa-mir-23a MI0000079 Homo sapiens miR-23a stem-loop',
#   'sequence': 'GGCCGGCUGGGGUUCCUGGGGAUGGGAUUUGCUUCCUGUCACAAAUCACAUUGCCAGGGAUUUCCAACCGACC'},
#  {'mirbase_id': 'hsa-mir-24-1',
#   'description': 'hsa-mir-24-1 MI0000080 Homo sapiens miR-24-1 stem-loop',
#   'sequence': 'CUCCGGUGCCUACUGAGCUGAUAUCAGUUCUCAUUUUACACACUGGCUCAGUUCAGCAGGAACAGGAG'},
#  {'mirbase_id': 'hsa-mir-24-2',
#   'description': 'hsa-mir-24-2 MI0000081 Homo sapiens miR-24-2 stem-loop',
#   'sequence': 'CUCUGCCUCCCGUGCCUACUGAGCUGAAACACAGUUGGUUUGUGUACACUGGCUCAGUUCAGCAGGAACAGGG'},
#  {'mirbase_id': 'hsa-mir-25',
#   'description': 'hsa-mir-25 MI0000082 Homo sapiens miR-25 stem-loop',
#   'sequence': 'GGCCAGUGUUGAGAGGCGGAGACUUGGGCAAUUGCUGGACGCUGCCCUGGGCAUUGCACUUGUCUCGGUCUGACAGUGCCGGCC'},
#  {'mirbase_id': 'hsa-mir-26a-1',
#   'description': 'hsa-mir-26a-1 MI0000083 Homo sapiens miR-26a-1 stem-loop',
#   'sequence': 'GUGGCCUCGUUCAAGUAAUCCAGGAUAGGCUGUGCAGGUCCCAAUGGGCCUAUUCUUGGUUACUUGCACGGGGACGC'},
#  {'mirbase_id': 'hsa-mir-26b',
#   'description': 'hsa-mir-26b MI0000084 Homo sapiens miR-26b stem-loop',
#   'sequence': 'CCGGGACCCAGUUCAAGUAAUUCAGGAUAGGUUGUGUGCUGUCCAGCCUGUUCUCCAUUACUUGGCUCGGGGACCGG'},
#  {'mirbase_id': 'hsa-mir-27a',
#   'description': 'hsa-mir-27a MI0000085 Homo sapiens miR-27a stem-loop',
#   'sequence': 'CUGAGGAGCAGGGCUUAGCUGCUUGUGAGCAGGGUCCACACCAAGUCGUGUUCACAGUGGCUAAGUUCCGCCCCCCAG'},
#  {'mirbase_id': 'hsa-mir-28',
#   'description': 'hsa-mir-28 MI0000086 Homo sapiens miR-28 stem-loop',
#   'sequence': 'GGUCCUUGCCCUCAAGGAGCUCACAGUCUAUUGAGUUACCUUUCUGACUUUCCCACUAGAUUGUGAGCUCCUGGAGGGCAGGCACU'},
#  {'mirbase_id': 'hsa-mir-29a',
#   'description': 'hsa-mir-29a MI0000087 Homo sapiens miR-29a stem-loop',
#   'sequence': 'AUGACUGAUUUCUUUUGGUGUUCAGAGUCAAUAUAAUUUUCUAGCACCAUCUGAAAUCGGUUAU'},
#  {'mirbase_id': 'hsa-mir-30a',
#   'description': 'hsa-mir-30a MI0000088 Homo sapiens miR-30a stem-loop',
#   'sequence': 'GCGACUGUAAACAUCCUCGACUGGAAGCUGUGAAGCCACAGAUGGGCUUUCAGUCGGAUGUUUGCAGCUGC'},
#  {'mirbase_id': 'hsa-mir-31',
#   'description': 'hsa-mir-31 MI0000089 Homo sapiens miR-31 stem-loop',
#   'sequence': 'GGAGAGGAGGCAAGAUGCUGGCAUAGCUGUUGAACUGGGAACCUGCUAUGCCAACAUAUUGCCAUCUUUCC'},
#  {'mirbase_id': 'hsa-mir-32',
#   'description': 'hsa-mir-32 MI0000090 Homo sapiens miR-32 stem-loop',
#   'sequence': 'GGAGAUAUUGCACAUUACUAAGUUGCAUGUUGUCACGGCCUCAAUGCAAUUUAGUGUGUGUGAUAUUUUC'},
#  {'mirbase_id': 'hsa-mir-33a',
#   'description': 'hsa-mir-33a MI0000091 Homo sapiens miR-33a stem-loop',
#   'sequence': 'CUGUGGUGCAUUGUAGUUGCAUUGCAUGUUCUGGUGGUACCCAUGCAAUGUUUCCACAGUGCAUCACAG'},
#  {'mirbase_id': 'hsa-mir-92a-1',
#   'description': 'hsa-mir-92a-1 MI0000093 Homo sapiens miR-92a-1 stem-loop',
#   'sequence': 'CUUUCUACACAGGUUGGGAUCGGUUGCAAUGCUGUGUUUCUGUAUGGUAUUGCACUUGUCCCGGCCUGUUGAGUUUGG'},
#  {'mirbase_id': 'hsa-mir-92a-2',
#   'description': 'hsa-mir-92a-2 MI0000094 Homo sapiens miR-92a-2 stem-loop',
#   'sequence': 'UCAUCCCUGGGUGGGGAUUUGUUGCAUUACUUGUGUUCUAUAUAAAGUAUUGCACUUGUCCCGGCCUGUGGAAGA'},
#  {'mirbase_id': 'hsa-mir-93',
#   'description': 'hsa-mir-93 MI0000095 Homo sapiens miR-93 stem-loop',
#   'sequence': 'CUGGGGGCUCCAAAGUGCUGUUCGUGCAGGUAGUGUGAUUACCCAACCUACUGCUGAGCUAGCACUUCCCGAGCCCCCGG'},
#  {'mirbase_id': 'hsa-mir-95',
#   'description': 'hsa-mir-95 MI0000097 Homo sapiens miR-95 stem-loop',
#   'sequence': 'AACACAGUGGGCACUCAAUAAAUGUCUGUUGAAUUGAAAUGCGUUACAUUCAACGGGUAUUUAUUGAGCACCCACUCUGUG'},
#  {'mirbase_id': 'hsa-mir-96',
#   'description': 'hsa-mir-96 MI0000098 Homo sapiens miR-96 stem-loop',
#   'sequence': 'UGGCCGAUUUUGGCACUAGCACAUUUUUGCUUGUGUCUCUCCGCUCUGAGCAAUCAUGUGCAGUGCCAAUAUGGGAAA'},
#  {'mirbase_id': 'hsa-mir-98',
#   'description': 'hsa-mir-98 MI0000100 Homo sapiens miR-98 stem-loop',
#   'sequence': 'AGGAUUCUGCUCAUGCCAGGGUGAGGUAGUAAGUUGUAUUGUUGUGGGGUAGGGAUAUUAGGCCCCAAUUAGAAGAUAACUAUACAACUUACUACUUUCCCUGGUGUGUGGCAUAUUCA'},
#  {'mirbase_id': 'hsa-mir-99a',
#   'description': 'hsa-mir-99a MI0000101 Homo sapiens miR-99a stem-loop',
#   'sequence': 'CCCAUUGGCAUAAACCCGUAGAUCCGAUCUUGUGGUGAAGUGGACCGCACAAGCUCGCUUCUAUGGGUCUGUGUCAGUGUG'},
#  {'mirbase_id': 'hsa-mir-100',
#   'description': 'hsa-mir-100 MI0000102 Homo sapiens miR-100 stem-loop',
#   'sequence': 'CCUGUUGCCACAAACCCGUAGAUCCGAACUUGUGGUAUUAGUCCGCACAAGCUUGUAUCUAUAGGUAUGUGUCUGUUAGG'},
#  {'mirbase_id': 'hsa-mir-101-1',
#   'description': 'hsa-mir-101-1 MI0000103 Homo sapiens miR-101-1 stem-loop',
#   'sequence': 'UGCCCUGGCUCAGUUAUCACAGUGCUGAUGCUGUCUAUUCUAAAGGUACAGUACUGUGAUAACUGAAGGAUGGCA'},
#  {'mirbase_id': 'hsa-mir-29b-1',
#   'description': 'hsa-mir-29b-1 MI0000105 Homo sapiens miR-29b-1 stem-loop',
#   'sequence': 'CUUCAGGAAGCUGGUUUCAUAUGGUGGUUUAGAUUUAAAUAGUGAUUGUCUAGCACCAUUUGAAAUCAGUGUUCUUGGGGG'},
#  {'mirbase_id': 'hsa-mir-29b-2',
#   'description': 'hsa-mir-29b-2 MI0000107 Homo sapiens miR-29b-2 stem-loop',
#   'sequence': 'CUUCUGGAAGCUGGUUUCACAUGGUGGCUUAGAUUUUUCCAUCUUUGUAUCUAGCACCAUUUGAAAUCAGUGUUUUAGGAG'},
#  {'mirbase_id': 'hsa-mir-103a-2',
#   'description': 'hsa-mir-103a-2 MI0000108 Homo sapiens miR-103a-2 stem-loop',
#   'sequence': 'UUGUGCUUUCAGCUUCUUUACAGUGCUGCCUUGUAGCAUUCAGGUCAAGCAGCAUUGUACAGGGCUAUGAAAGAACCA'},
#  {'mirbase_id': 'hsa-mir-103a-1',
#   'description': 'hsa-mir-103a-1 MI0000109 Homo sapiens miR-103a-1 stem-loop',
#   'sequence': 'UACUGCCCUCGGCUUCUUUACAGUGCUGCCUUGUUGCAUAUGGAUCAAGCAGCAUUGUACAGGGCUAUGAAGGCAUUG'},
#  {'mirbase_id': 'hsa-mir-105-1',
#   'description': 'hsa-mir-105-1 MI0000111 Homo sapiens miR-105-1 stem-loop',
#   'sequence': 'UGUGCAUCGUGGUCAAAUGCUCAGACUCCUGUGGUGGCUGCUCAUGCACCACGGAUGUUUGAGCAUGUGCUACGGUGUCUA'},
#  {'mirbase_id': 'hsa-mir-105-2',
#   'description': 'hsa-mir-105-2 MI0000112 Homo sapiens miR-105-2 stem-loop',
#   'sequence': 'UGUGCAUCGUGGUCAAAUGCUCAGACUCCUGUGGUGGCUGCUUAUGCACCACGGAUGUUUGAGCAUGUGCUAUGGUGUCUA'},
#  {'mirbase_id': 'hsa-mir-106a',
#   'description': 'hsa-mir-106a MI0000113 Homo sapiens miR-106a stem-loop',
#   'sequence': 'CCUUGGCCAUGUAAAAGUGCUUACAGUGCAGGUAGCUUUUUGAGAUCUACUGCAAUGUAAGCACUUCUUACAUUACCAUGG'},
#  {'mirbase_id': 'hsa-mir-107',
#   'description': 'hsa-mir-107 MI0000114 Homo sapiens miR-107 stem-loop',
#   'sequence': 'CUCUCUGCUUUCAGCUUCUUUACAGUGUUGCCUUGUGGCAUGGAGUUCAAGCAGCAUUGUACAGGGCUAUCAAAGCACAGA'},
#  {'mirbase_id': 'hsa-mir-16-2',
#   'description': 'hsa-mir-16-2 MI0000115 Homo sapiens miR-16-2 stem-loop',
#   'sequence': 'GUUCCACUCUAGCAGCACGUAAAUAUUGGCGUAGUGAAAUAUAUAUUAAACACCAAUAUUACUGUGCUGCUUUAGUGUGAC'},
#  {'mirbase_id': 'dme-mir-1',
#   'description': 'dme-mir-1 MI0000116 Drosophila melanogaster miR-1 stem-loop',
#   'sequence': 'UUCAGCCUUUGAGAGUUCCAUGCUUCCUUGCAUUCAAUAGUUAUAUUCAAGCAUAUGGAAUGUAAAGAAGUAUGGAGCGAAAUCUGGCGAG'},
#  {'mirbase_id': 'dme-mir-2a-1',
#   'description': 'dme-mir-2a-1 MI0000117 Drosophila melanogaster miR-2a-1 stem-loop',
#   'sequence': 'GCUGGGCUCUCAAAGUGGUUGUGAAAUGCAUUUCCGCUUUGCGCGGCAUAUCACAGCCAGCUUUGAUGAGCUUAGC'},
#  {'mirbase_id': 'dme-mir-2a-2',
#   'description': 'dme-mir-2a-2 MI0000118 Drosophila melanogaster miR-2a-2 stem-loop',
#   'sequence': 'AUCUAAGCCUCAUCAAGUGGUUGUGAUAUGGAUACCCAACGCAUAUCACAGCCAGCUUUGAUGAGCUAGGAU'},
#  {'mirbase_id': 'dme-mir-2b-1',
#   'description': 'dme-mir-2b-1 MI0000119 Drosophila melanogaster miR-2b-1 stem-loop',
#   'sequence': 'CUUCAACUGUCUUCAAAGUGGCAGUGACAUGUUGUCAACAAUAUUCAUAUCACAGCCAGCUUUGAGGAGCGUUGCGG'},
#  {'mirbase_id': 'dme-mir-2b-2',
#   'description': 'dme-mir-2b-2 MI0000120 Drosophila melanogaster miR-2b-2 stem-loop',
#   'sequence': 'UUGUGUCAUUCUUCAAAGUGGUUGUGAAAUGUUUGCCUUUUUAUGCCUAUUCAUAUCACAGCCAGCUUUGAGGAGCGACGCGA'},
#  {'mirbase_id': 'dme-mir-3',
#   'description': 'dme-mir-3 MI0000121 Drosophila melanogaster miR-3 stem-loop',
#   'sequence': 'GAUCCUGGGAUGCAUCUUGUGCAGUUAUGUUUCAAUCUCACAUCACUGGGCAAAGUGUGUCUCAAGAUC'},
#  {'mirbase_id': 'dme-mir-4',
#   'description': 'dme-mir-4 MI0000122 Drosophila melanogaster miR-4 stem-loop',
#   'sequence': 'UUGCAAUUAGUUUCUUUGGUCGUCCAGCCUUAGGUGAUUUUUCCGGUCAUAAAGCUAGACAACCAUUGAAGUUCGUUGUGG'},
#  {'mirbase_id': 'dme-mir-5',
#   'description': 'dme-mir-5 MI0000123 Drosophila melanogaster miR-5 stem-loop',
#   'sequence': 'GCUAAAAGGAACGAUCGUUGUGAUAUGAGUUGUUUCCUAACAUAUCACAGUGAUUUUCCUUUAUAACGC'},
#  {'mirbase_id': 'dme-mir-6-1',
#   'description': 'dme-mir-6-1 MI0000124 Drosophila melanogaster miR-6-1 stem-loop',
#   'sequence': 'UUUAAUGUAGAGGGAAUAGUUGCUGUGCUGUAAGUUAAUAUACCAUAUCUAUAUCACAGUGGCUGUUCUUUUUGUACCUAAA'},
#  {'mirbase_id': 'dme-mir-6-2',
#   'description': 'dme-mir-6-2 MI0000125 Drosophila melanogaster miR-6-2 stem-loop',
#   'sequence': 'UAACCCAAGGGAACUUCUGCUGCUGAUAUAUUAUUGAAAAACUACUAUAUCACAGUGGCUGUUCUUUUUGGUUG'},
#  {'mirbase_id': 'dme-mir-6-3',
#   'description': 'dme-mir-6-3 MI0000126 Drosophila melanogaster miR-6-3 stem-loop',
#   'sequence': 'CAAAAAGAAGGGAACGGUUGCUGAUGAUGUAGUUUGAAACUCUCACAAUUUAUAUCACAGUGGCUGUUCUUUUUUGUUUG'},
#  {'mirbase_id': 'dme-mir-7',
#   'description': 'dme-mir-7 MI0000127 Drosophila melanogaster miR-7 stem-loop',
#   'sequence': 'GAGUGCAUUCCGUAUGGAAGACUAGUGAUUUUGUUGUUUGGUCUUUGGUAAUAACAAUAAAUCCCUUGUCUUCUUACGGCGUGCAUUU'},
#  {'mirbase_id': 'dme-mir-8',
#   'description': 'dme-mir-8 MI0000128 Drosophila melanogaster miR-8 stem-loop',
#   'sequence': 'AAGGACAUCUGUUCACAUCUUACCGGGCAGCAUUAGAUCCUUUUUAUAACUCUAAUACUGUCAGGUAAAGAUGUCGUCCGUGUCCUU'},
#  {'mirbase_id': 'dme-mir-9a',
#   'description': 'dme-mir-9a MI0000129 Drosophila melanogaster miR-9a stem-loop',
#   'sequence': 'GCUAUGUUGUCUUUGGUUAUCUAGCUGUAUGAGUGAUAAAUAACGUCAUAAAGCUAGCUUACCGAAGUUAAUAUUAGC'},
#  {'mirbase_id': 'dme-mir-10',
#   'description': 'dme-mir-10 MI0000130 Drosophila melanogaster miR-10 stem-loop',
#   'sequence': 'CCACGUCUACCCUGUAGAUCCGAAUUUGUUUUAUACUAGCUUUAAGGACAAAUUCGGUUCUAGAGAGGUUUGUGUGG'},
#  {'mirbase_id': 'dme-mir-11',
#   'description': 'dme-mir-11 MI0000131 Drosophila melanogaster miR-11 stem-loop',
#   'sequence': 'GCACUUGUCAAGAACUUUCUCUGUGACCCGCGUGUACUUAAAAGCCGCAUCACAGUCUGAGUUCUUGCUGAGUGC'},
#  {'mirbase_id': 'dme-mir-12',
#   'description': 'dme-mir-12 MI0000132 Drosophila melanogaster miR-12 stem-loop',
#   'sequence': 'UACGGUUGAGUAUUACAUCAGGUACUGGUGUGCCUUAAAUCCAACAACCAGUACUUAUGUCAUACUACGCCGUG'},
#  {'mirbase_id': 'dme-mir-13a',
#   'description': 'dme-mir-13a MI0000133 Drosophila melanogaster miR-13a stem-loop',
#   'sequence': 'UACGUAACUCCUCAAAGGGUUGUGAAAUGUCGACUAUUAUCUACUCAUAUCACAGCCAUUUUGAUGAGUUUCGUG'},
#  {'mirbase_id': 'dme-mir-13b-1',
#   'description': 'dme-mir-13b-1 MI0000134 Drosophila melanogaster miR-13b-1 stem-loop',
#   'sequence': 'CCAUGUCGUUAAAAUGUUUGUGAACUUAUGUAUUCACAAUCAUAUCACAGCCAUUUUGACGAGUUUGG'},
#  {'mirbase_id': 'dme-mir-13b-2',
#   'description': 'dme-mir-13b-2 MI0000135 Drosophila melanogaster miR-13b-2 stem-loop',
#   'sequence': 'UAUUAACGCGUCAAAAUGACUGUGAGCUAUGUGGAUUUGACUUCAUAUCACAGCCAUUUUGACGAGUUUG'},
#  {'mirbase_id': 'dme-mir-14',
#   'description': 'dme-mir-14 MI0000136 Drosophila melanogaster miR-14 stem-loop',
#   'sequence': 'UGUGGGAGCGAGACGGGGACUCACUGUGCUUAUUAAAUAGUCAGUCUUUUUCUCUCUCCUAUA'},
#  {'mirbase_id': 'mmu-let-7g',
#   'description': 'mmu-let-7g MI0000137 Mus musculus let-7g stem-loop',
#   'sequence': 'CCAGGCUGAGGUAGUAGUUUGUACAGUUUGAGGGUCUAUGAUACCACCCGGUACAGGAGAUAACUGUACAGGCCACUGCCUUGCCAGG'},
#  {'mirbase_id': 'mmu-let-7i',
#   'description': 'mmu-let-7i MI0000138 Mus musculus let-7i stem-loop',
#   'sequence': 'CUGGCUGAGGUAGUAGUUUGUGCUGUUGGUCGGGUUGUGACAUUGCCCGCUGUGGAGAUAACUGCGCAAGCUACUGCCUUGCUAG'},
#  {'mirbase_id': 'mmu-mir-1a-1',
#   'description': 'mmu-mir-1a-1 MI0000139 Mus musculus miR-1a-1 stem-loop',
#   'sequence': 'GCUUGGGACACAUACUUCUUUAUAUGCCCAUAUGAACCUGCUAAGCUAUGGAAUGUAAAGAAGUAUGUAUUUCAGGC'},
#  {'mirbase_id': 'mmu-mir-15b',
#   'description': 'mmu-mir-15b MI0000140 Mus musculus miR-15b stem-loop',
#   'sequence': 'CUGUAGCAGCACAUCAUGGUUUACAUACUACAGUCAAGAUGCGAAUCAUUAUUUGCUGCUCUAG'},
#  {'mirbase_id': 'mmu-mir-23b',
#   'description': 'mmu-mir-23b MI0000141 Mus musculus miR-23b stem-loop',
#   'sequence': 'GGCUGCUUGGGUUCCUGGCAUGCUGAUUUGUGACUUGAGAUUAAAAUCACAUUGCCAGGGAUUACCACGCAACC'},
#  {'mirbase_id': 'mmu-mir-27b',
#   'description': 'mmu-mir-27b MI0000142 Mus musculus miR-27b stem-loop',
#   'sequence': 'AGGUGCAGAGCUUAGCUGAUUGGUGAACAGUGAUUGGUUUCCGCUUUGUUCACAGUGGCUAAGUUCUGCACCU'},
#  {'mirbase_id': 'mmu-mir-29b-1',
#   'description': 'mmu-mir-29b-1 MI0000143 Mus musculus miR-29b-1 stem-loop',
#   'sequence': 'AGGAAGCUGGUUUCAUAUGGUGGUUUAGAUUUAAAUAGUGAUUGUCUAGCACCAUUUGAAAUCAGUGUUCU'},
#  {'mirbase_id': 'mmu-mir-30a',
#   'description': 'mmu-mir-30a MI0000144 Mus musculus miR-30a stem-loop',
#   'sequence': 'GCGACUGUAAACAUCCUCGACUGGAAGCUGUGAAGCCACAAAUGGGCUUUCAGUCGGAUGUUUGCAGCUGC'},
#  {'mirbase_id': 'mmu-mir-30b',
#   'description': 'mmu-mir-30b MI0000145 Mus musculus miR-30b stem-loop',
#   'sequence': 'CUAAGCCAAGUUUCAGUUCAUGUAAACAUCCUACACUCAGCUGUCAUACAUGCGUUGGCUGGGAUGUGGAUGUUUACGUCAGCUGUCUUGGAGUAU'},
#  {'mirbase_id': 'mmu-mir-99a',
#   'description': 'mmu-mir-99a MI0000146 Mus musculus miR-99a stem-loop',
#   'sequence': 'CAUAAACCCGUAGAUCCGAUCUUGUGGUGAAGUGGACCGCGCAAGCUCGUUUCUAUGGGUCUGUG'},
#  {'mirbase_id': 'mmu-mir-99b',
#   'description': 'mmu-mir-99b MI0000147 Mus musculus miR-99b stem-loop',
#   'sequence': 'GGCACCCACCCGUAGAACCGACCUUGCGGGGCCUUCGCCGCACACAAGCUCGUGUCUGUGGGUCCGUGUC'},
#  {'mirbase_id': 'mmu-mir-101a',
#   'description': 'mmu-mir-101a MI0000148 Mus musculus miR-101a stem-loop',
#   'sequence': 'AGGCUGCCCUGGCUCAGUUAUCACAGUGCUGAUGCUGUCCAUUCUAAAGGUACAGUACUGUGAUAACUGAAGGAUGGCAGCCA'},
#  {'mirbase_id': 'mmu-mir-124-3',
#   'description': 'mmu-mir-124-3 MI0000150 Mus musculus miR-124-3 stem-loop',
#   'sequence': 'CUCUGCGUGUUCACAGCGGACCUUGAUUUAAUGUCUAUACAAUUAAGGCACGCGGUGAAUGCCAAGAG'},
#  {'mirbase_id': 'mmu-mir-125a',
#   'description': 'mmu-mir-125a MI0000151 Mus musculus miR-125a stem-loop',
#   'sequence': 'CUGGGUCCCUGAGACCCUUUAACCUGUGAGGACGUCCAGGGUCACAGGUGAGGUUCUUGGGAGCCUGG'},
#  {'mirbase_id': 'mmu-mir-125b-2',
#   'description': 'mmu-mir-125b-2 MI0000152 Mus musculus miR-125b-2 stem-loop',
#   'sequence': 'GCCUAGUCCCUGAGACCCUAACUUGUGAGGUAUUUUAGUAACAUCACAAGUCAGGUUCUUGGGACCUAGGC'},
#  {'mirbase_id': 'mmu-mir-126a',
#   'description': 'mmu-mir-126a MI0000153 Mus musculus miR-126a stem-loop',
#   'sequence': 'UGACAGCACAUUAUUACUUUUGGUACGCGCUGUGACACUUCAAACUCGUACCGUGAGUAAUAAUGCGCGGUCA'},
#  {'mirbase_id': 'mmu-mir-127',
#   'description': 'mmu-mir-127 MI0000154 Mus musculus miR-127 stem-loop',
#   'sequence': 'CCAGCCUGCUGAAGCUCAGAGGGCUCUGAUUCAGAAAGAUCAUCGGAUCCGUCUGAGCUUGGCUGGUCGG'},
#  {'mirbase_id': 'mmu-mir-128-1',
#   'description': 'mmu-mir-128-1 MI0000155 Mus musculus miR-128-1 stem-loop',
#   'sequence': 'GUUGGAUUCGGGGCCGUAGCACUGUCUGAGAGGUUUACAUUUCUCACAGUGAACCGGUCUCUUUUUCAGC'},
#  {'mirbase_id': 'mmu-mir-130a',
#   'description': 'mmu-mir-130a MI0000156 Mus musculus miR-130a stem-loop',
#   'sequence': 'GAGCUCUUUUCACAUUGUGCUACUGUCUAACGUGUACCGAGCAGUGCAAUGUUAAAAGGGCAUC'},
#  {'mirbase_id': 'mmu-mir-9-2',
#   'description': 'mmu-mir-9-2 MI0000157 Mus musculus miR-9-2 stem-loop',
#   'sequence': 'GUUGUUAUCUUUGGUUAUCUAGCUGUAUGAGUGUAUUGGUCUUCAUAAAGCUAGAUAACCGAAAGUAAAAAC'},
#  {'mirbase_id': 'mmu-mir-132',
#   'description': 'mmu-mir-132 MI0000158 Mus musculus miR-132 stem-loop',
#   'sequence': 'GGGCAACCGUGGCUUUCGAUUGUUACUGUGGGAACCGGAGGUAACAGUCUACAGCCAUGGUCGCCC'},
#  {'mirbase_id': 'mmu-mir-133a-1',
#   'description': 'mmu-mir-133a-1 MI0000159 Mus musculus miR-133a-1 stem-loop',
#   'sequence': 'GCUAAAGCUGGUAAAAUGGAACCAAAUCGCCUCUUCAAUGGAUUUGGUCCCCUUCAACCAGCUGUAGC'},
#  {'mirbase_id': 'mmu-mir-134',
#   'description': 'mmu-mir-134 MI0000160 Mus musculus miR-134 stem-loop',
#   'sequence': 'AGGGUGUGUGACUGGUUGACCAGAGGGGCGUGCACUCUGUUCACCCUGUGGGCCACCUAGUCACCAACCCU'},
#  {'mirbase_id': 'mmu-mir-135a-1',
#   'description': 'mmu-mir-135a-1 MI0000161 Mus musculus miR-135a-1 stem-loop',
#   'sequence': 'AGGCCUCACUGUUCUCUAUGGCUUUUUAUUCCUAUGUGAUUCUAUUGCUCGCUCAUAUAGGGAUUGGAGCCGUGGCGUACGGUGAGGAUA'},
#  {'mirbase_id': 'mmu-mir-136',
#   'description': 'mmu-mir-136 MI0000162 Mus musculus miR-136 stem-loop',
#   'sequence': 'GAGGACUCCAUUUGUUUUGAUGAUGGAUUCUUAAGCUCCAUCAUCGUCUCAAAUGAGUCUUC'},
#  {'mirbase_id': 'mmu-mir-137',
#   'description': 'mmu-mir-137 MI0000163 Mus musculus miR-137 stem-loop',
#   'sequence': 'CUUCGGUGACGGGUAUUCUUGGGUGGAUAAUACGGAUUACGUUGUUAUUGCUUAAGAAUACGCGUAGUCGAGG'},
#  {'mirbase_id': 'mmu-mir-138-2',
#   'description': 'mmu-mir-138-2 MI0000164 Mus musculus miR-138-2 stem-loop',
#   'sequence': 'CAGCUGGUGUUGUGAAUCAGGCCGACGAGCAGCGCAUCCUCUUACCCGGCUAUUUCACGACACCAGGGUUG'},
#  {'mirbase_id': 'mmu-mir-140',
#   'description': 'mmu-mir-140 MI0000165 Mus musculus miR-140 stem-loop',
#   'sequence': 'CCUGCCAGUGGUUUUACCCUAUGGUAGGUUACGUCAUGCUGUUCUACCACAGGGUAGAACCACGGACAGG'},
#  {'mirbase_id': 'mmu-mir-141',
#   'description': 'mmu-mir-141 MI0000166 Mus musculus miR-141 stem-loop',
#   'sequence': 'GGGUCCAUCUUCCAGUGCAGUGUUGGAUGGUUGAAGUAUGAAGCUCCUAACACUGUCUGGUAAAGAUGGCCC'},
#  {'mirbase_id': 'mmu-mir-142a',
#   'description': 'mmu-mir-142a MI0000167 Mus musculus miR-142 stem-loop',
#   'sequence': 'ACCCAUAAAGUAGAAAGCACUACUAACAGCACUGGAGGGUGUAGUGUUUCCUACUUUAUGGAUG'},
#  {'mirbase_id': 'mmu-mir-144',
#   'description': 'mmu-mir-144 MI0000168 Mus musculus miR-144 stem-loop',
#   'sequence': 'GGCUGGGAUAUCAUCAUAUACUGUAAGUUUGUGAUGAGACACUACAGUAUAGAUGAUGUACUAGUC'},
#  {'mirbase_id': 'mmu-mir-145a',
#   'description': 'mmu-mir-145a MI0000169 Mus musculus miR-145 stem-loop',
#   'sequence': 'CUCACGGUCCAGUUUUCCCAGGAAUCCCUUGGAUGCUAAGAUGGGGAUUCCUGGAAAUACUGUUCUUGAG'},
#  {'mirbase_id': 'mmu-mir-146a',
#   'description': 'mmu-mir-146a MI0000170 Mus musculus miR-146a stem-loop',
#   'sequence': 'AGCUCUGAGAACUGAAUUCCAUGGGUUAUAUCAAUGUCAGACCUGUGAAAUUCAGUUCUUCAGCU'},
#  {'mirbase_id': 'mmu-mir-149',
#   'description': 'mmu-mir-149 MI0000171 Mus musculus miR-149 stem-loop',
#   'sequence': 'GGCUCUGGCUCCGUGUCUUCACUCCCGUGUUUGUCCGAGGAGGGAGGGAGGGACGGGGGCGGUGCU'},
#  {'mirbase_id': 'mmu-mir-150',
#   'description': 'mmu-mir-150 MI0000172 Mus musculus miR-150 stem-loop',
#   'sequence': 'CCCUGUCUCCCAACCCUUGUACCAGUGCUGUGCCUCAGACCCUGGUACAGGCCUGGGGGAUAGGG'},
#  {'mirbase_id': 'mmu-mir-151',
#   'description': 'mmu-mir-151 MI0000173 Mus musculus miR-151 stem-loop',
#   'sequence': 'CCUGCCCUCGAGGAGCUCACAGUCUAGUAUGUCUCCUCCCUACUAGACUGAGGCUCCUUGAGGACAGG'},
#  {'mirbase_id': 'mmu-mir-152',
#   'description': 'mmu-mir-152 MI0000174 Mus musculus miR-152 stem-loop',
#   'sequence': 'CCGGGCCUAGGUUCUGUGAUACACUCCGACUCGGGCUCUGGAGCAGUCAGUGCAUGACAGAACUUGGGCCCGG'},
#  {'mirbase_id': 'mmu-mir-153',
#   'description': 'mmu-mir-153 MI0000175 Mus musculus miR-153 stem-loop',
#   'sequence': 'CGGUGUCAUUUUUGUGACGUUGCAGCUAGUAAUAUGAGCCCAGUUGCAUAGUCACAAAAGUGAUCAUUG'},
#  {'mirbase_id': 'mmu-mir-154',
#   'description': 'mmu-mir-154 MI0000176 Mus musculus miR-154 stem-loop',
#   'sequence': 'GAAGAUAGGUUAUCCGUGUUGCCUUCGCUUUAUUCGUGACGAAUCAUACACGGUUGACCUAUUUUU'},
#  {'mirbase_id': 'mmu-mir-155',
#   'description': 'mmu-mir-155 MI0000177 Mus musculus miR-155 stem-loop',
#   'sequence': 'CUGUUAAUGCUAAUUGUGAUAGGGGUUUUGGCCUCUGACUGACUCCUACCUGUUAGCAUUAACAG'},
#  {'mirbase_id': 'ath-MIR156a',
#   'description': 'ath-MIR156a MI0000178 Arabidopsis thaliana miR156a stem-loop',
#   'sequence': 'CAAGAGAAACGCAAAGAAACUGACAGAAGAGAGUGAGCACACAAAGGCAAUUUGCAUAUCAUUGCACUUGCUUCUCUUGCGUGCUCACUGCUCUUUCUGUCAGAUUCCGGUGCUGAUCUCUUU'},
#  {'mirbase_id': 'ath-MIR156b',
#   'description': 'ath-MIR156b MI0000179 Arabidopsis thaliana miR156b stem-loop',
#   'sequence': 'GCUAGAAGAGGGAGAGAUGGUGAUUGAGGAAUGCAACAGAGAAAACUGACAGAAGAGAGUGAGCACAUGCAGGCACUGUUAUGUGUCUAUAACUUUGCGUGUGCGUGCUCACCUCUCUUUCUGUCAGUUGCCUAUCUCUGCCUGCUUGACCUCUCUCUCUCUCUCUCUCUCUCAAAUUUGGCU'},
#  {'mirbase_id': 'ath-MIR156c',
#   'description': 'ath-MIR156c MI0000180 Arabidopsis thaliana miR156c stem-loop',
#   'sequence': 'CGCAUAGAAACUGACAGAAGAGAGUGAGCACACAAAGGCACUUUGCAUGUUCGAUGCAUUUGCUUCUCUUGCGUGCUCACUGCUCUAUCUGUCAGAUUCCGGCU'},
#  {'mirbase_id': 'ath-MIR156d',
#   'description': 'ath-MIR156d MI0000181 Arabidopsis thaliana miR156d stem-loop',
#   'sequence': 'GAUGGGGGAAAAGAAGUUGACAGAAGAGAGUGAGCACACAAAGGGGAAGUUGUAUAAAAGUUUUGUAUAUGGUUGCUUUUGCGUGCUCACUCUCUUUUUGUCAUAACUUCUCCUUCAU'},
#  {'mirbase_id': 'ath-MIR156e',
#   'description': 'ath-MIR156e MI0000182 Arabidopsis thaliana miR156e stem-loop',
#   'sequence': 'AGGAGGUGACAGAAGAGAGUGAGCACACAUGGUGGUUUCUUGCAUGCUUUUUUGAUUAGGGUUUCAUGCUUGAAGCUAUGUGUGCUUACUCUCUCUCUGUCACCCCU'},
#  {'mirbase_id': 'ath-MIR156f',
#   'description': 'ath-MIR156f MI0000183 Arabidopsis thaliana miR156f stem-loop',
#   'sequence': 'GAGUGGUGAGGAAUUGAUGGUGACAGAAGAGAGUGAGCACACAUGGUGGCUUUCUUGCAUAUUUGAAGGUUCCAUGCUUGAAGCUAUGUGUGCUCACUCUCUAUCCGUCACCCCCUUCUCUCCCUCUCCCUC'},
#  {'mirbase_id': 'ath-MIR157a',
#   'description': 'ath-MIR157a MI0000184 Arabidopsis thaliana miR157a stem-loop',
#   'sequence': 'GUGUUGACAGAAGAUAGAGAGCACAGAUGAUGAGAUACAAUUCGGAGCAUGUUCUUUGCAUCUUACUCCUUUGUGCUCUCUAGCCUUCUGUCAUCACC'},
#  {'mirbase_id': 'ath-MIR157b',
#   'description': 'ath-MIR157b MI0000185 Arabidopsis thaliana miR157b stem-loop',
#   'sequence': 'UGGGAGGCAUUGAUAGUGUUGACAGAAGAUAGAGAGCACAGAUGAUAAGAUACAAUUCCUCGCAGCUUCUUUGCAUCUUACUCCUUUGUGCUCUCUAGCCUUCUGUCAUCACCCGUUAUUUGCCAUCACCCA'},
#  {'mirbase_id': 'ath-MIR157c',
#   'description': 'ath-MIR157c MI0000186 Arabidopsis thaliana miR157c stem-loop',
#   'sequence': 'AGGUUUGAGAGUGAUGUUGGUUGUUGACAGAAGAUAGAGAGCACUAAGGAUGACAUGCAAGUACAUACAUAUAUAUCAUCACACCGCAUGUGGAUGAUAAAAUAUGUAUAACAAAUUCAAAGAAAGAGAGGGAGAGAAAGAGAGAGAACCUGCAUCUCUACUCUUUUGUGCUCUCUAUACUUCUGUCACCACCUUUAUCUCUUCUUCUCUCUAACCU'},
#  {'mirbase_id': 'ath-MIR157d',
#   'description': 'ath-MIR157d MI0000187 Arabidopsis thaliana miR157d stem-loop',
#   'sequence': 'GUGGAGGGUGAUAGUGUGGUUGCUGACAGAAGAUAGAGAGCACUAAGGAUGCUAUGCAAAACAGACACAGAUAUGUGUUUCUAAUUGUAUUUCAUACUUUAACCUCAAAGUUGAUAUAAAAAAAGAAAGAAAGAUAGAAGAGCUAGAAGACUAUCUGCAUCUCUAUUCCUAUGUGCUCUCUAUGCUUCUGUCAUCACCUUUCUUUCUCUAUUUCUCUCUAC'},
#  {'mirbase_id': 'ath-MIR158a',
#   'description': 'ath-MIR158a MI0000188 Arabidopsis thaliana miR158a stem-loop',
#   'sequence': 'ACACGUCAUCUCUGUGCUUCUUUGUCUACAAUUUUGGAAAAAGUGAUGACGCCAUUGCUCUUUCCCAAAUGUAGACAAAGCAAUACCGUGAUGAUGUCGU'},
#  {'mirbase_id': 'ath-MIR159a',
#   'description': 'ath-MIR159a MI0000189 Arabidopsis thaliana miR159a stem-loop',
#   'sequence': 'GUAGAGCUCCUUAAAGUUCAAACAUGAGUUGAGCAGGGUAAAGAAAAGCUGCUAAGCUAUGGAUCCCAUAAGCCCUAAUCCUUGUAAAGUAAAAAAGGAUUUGGUUAUAUGGAUUGCAUAUCUCAGGAGCUUUAACUUGCCCUUUAAUGGCUUUUACUCUUCUUUGGAUUGAAGGGAGCUCUAC'},
#  {'mirbase_id': 'ath-MIR160a',
#   'description': 'ath-MIR160a MI0000190 Arabidopsis thaliana miR160a stem-loop',
#   'sequence': 'GUAUGCCUGGCUCCCUGUAUGCCAUAUGCUGAGCCCAUCGAGUAUCGAUGACCUCCGUGGAUGGCGUAUGAGGAGCCAUGCAUAU'},
#  {'mirbase_id': 'ath-MIR160b',
#   'description': 'ath-MIR160b MI0000191 Arabidopsis thaliana miR160b stem-loop',
#   'sequence': 'GUCGUGCCUGGCUCCCUGUAUGCCACAAGAAAACAUCGAUUUAGUUUCAAAAUCGAUCACUAGUGGCGUACAGAGUAGUCAAGCAUGAC'},
#  {'mirbase_id': 'ath-MIR160c',
#   'description': 'ath-MIR160c MI0000192 Arabidopsis thaliana miR160c stem-loop',
#   'sequence': 'GUUAUGCCUGGCUCCCUGUAUGCCACGAGUGGAUACCGAUUUUGGUUUUAAAAUCGGCUGCCGGUGGCGUACAAGGAGUCAAGCAUGAC'},
#  {'mirbase_id': 'ath-MIR161',
#   'description': 'ath-MIR161 MI0000193 Arabidopsis thaliana miR161 stem-loop',
#   'sequence': 'UGCUUGAUCUCGGUUUUUGACCAGUUUAUUGCGUCGAUCAAUGCAUUGAAAGUGACUACAUCGGGGUUCCGAUUUUUUUUGUUCUUCAUAUGAUGAAGCGGAAACAGUAAUCAACCCUGGUUUAGUCACUUUCACUGCAUUAAUCAAUGCAUUUGUAAAAAGAGGGAAAAGCA'},
#  {'mirbase_id': 'ath-MIR162a',
#   'description': 'ath-MIR162a MI0000194 Arabidopsis thaliana miR162a stem-loop',
#   'sequence': 'UAGUUGGAAGAAGAGUGAGAGUCGCUGGAGGCAGCGGUUCAUCGAUCUCUUCCUGUGAACACAUUAAAAAUGUAAAAGCAUGAAUAGAUCGAUAAACCUCUGCAUCCAGCGUUUGCCUCUUGUAUCUUUCUUAUUGACUU'},
#  {'mirbase_id': 'ath-MIR162b',
#   'description': 'ath-MIR162b MI0000195 Arabidopsis thaliana miR162b stem-loop',
#   'sequence': 'GAGUGAAGUCGCUGGAGGCAGCGGUUCAUCGAUCAAUUCCUGUGAAUAUUUAUUUUUGUUUACAAAAGCAAGAAUCGAUCGAUAAACCUCUGCAUCCAGCGCUGCUUGCUC'},
#  {'mirbase_id': 'ath-MIR163',
#   'description': 'ath-MIR163 MI0000196 Arabidopsis thaliana miR163 stem-loop',
#   'sequence': ''},
#  {'mirbase_id': 'ath-MIR164a',
#   'description': 'ath-MIR164a MI0000197 Arabidopsis thaliana miR164a stem-loop',
#   'sequence': 'GGGUGAGAAUCUCCAUGUUGGAGAAGCAGGGCACGUGCAAACCAACAAACACGAAAUCCGUCUCAUUUGCUUAUUUGCACGUACUUAACUUCUCCAACAUGAGCUCUUCACCC'},
#  {'mirbase_id': 'ath-MIR164b',
#   'description': 'ath-MIR164b MI0000198 Arabidopsis thaliana miR164b stem-loop',
#   'sequence': 'GAUGGAGAAGCAGGGCACGUGCAUUACUAGCUCAUAUAUACACUCUCACCACAAAUGCGUGUAUAUAUGCGGAAUUUUGUGAUAUAGAUGUGUGUGUGUGUUGAGUGUGAUGAUAUGGAUGAGUUAGUUCUUCAUGUGCCCAUCUUCACCAUC'},
#  {'mirbase_id': 'ath-MIR165a',
#   'description': 'ath-MIR165a MI0000199 Arabidopsis thaliana miR165a stem-loop',
#   'sequence': 'GUUGAGGGGAAUGUUGUCUGGAUCGAGGAUAUUAUAGAUAUAUACAUGUGUAUGUUAAUGAUUCAAGUGAUCAUAGAGAGUAUCCUCGGACCAGGCUUCAUCCCCCCCAAC'},
#  {'mirbase_id': 'ath-MIR165b',
#   'description': 'ath-MIR165b MI0000200 Arabidopsis thaliana miR165b stem-loop',
#   'sequence': 'UGAAGAGGCUAUUUCUGUUGUGGGGAAUGUUGUUUGGAUCGAGGAUAUCAUAAACGCAUACACAUGUUUAUAUGUUAUGAUGCAUUAUAUGACUGAUGUAAUGUACAUAUAUAUACAUACAUGCCACAUGGUAUCGUCGGACCAGGCUUCAUCCCCCUCAACAUGUUAAUUGCCUUCAAUCA'},
#  {'mirbase_id': 'ath-MIR166a',
#   'description': 'ath-MIR166a MI0000201 Arabidopsis thaliana miR166a stem-loop',
#   'sequence': 'AGGGGCUUUCUCUUUUGAGGGGACUGUUGUCUGGCUCGAGGACUCUGGCUCGCUCUAUUCAUGUUGGAUCUCUUUCGAUCUAACAAUCGAAUUGAACCUUCAGAUUUCAGAUUUGAUUAGGGUUUUAGCGUCUUCGGACCAGGCUUCAUUCCCCCCAAUUGUUGCUCCCU'},
#  {'mirbase_id': 'ath-MIR166b',
#   'description': 'ath-MIR166b MI0000202 Arabidopsis thaliana miR166b stem-loop',
#   'sequence': 'UUGAGGGGACUGUUGUCUGGCUCGAGGACUCUUAUUCUAAUACAAUCUCAUUUGAAUACAUUCAGAUCUGAUGAUUGAUUAGGGUUUUAGUGUCGUCGGACCAGGCUUCAUUCCCCCCAA'},
#  {'mirbase_id': 'ath-MIR166c',
#   'description': 'ath-MIR166c MI0000203 Arabidopsis thaliana miR166c stem-loop',
#   'sequence': 'GCGAUUUAGUGUUGAGAGGAUUGUUGUCUGGCUCGAGGUCAUGAAGAAGAGAAUCACUCGAAUUAAUUUGGAAGAACAAAUUAAGAAAACCCUAGAUGAUUCUCGGACCAGGCUUCAUUCCCCCUAACCUACUUAUCGC'},
#  {'mirbase_id': 'ath-MIR166d',
#   'description': 'ath-MIR166d MI0000204 Arabidopsis thaliana miR166d stem-loop',
#   'sequence': 'GGUUGAGAGGAAUAUUGUCUGGCUCGAGGUCAUGAAGAAGAUCGGUAGAUUGAUUCAUUUUAAAGAGUGAAAUCCCUAAAUGAUUCUCGGACCAGGCUUCAUUCCCCCCAACC'},
#  {'mirbase_id': 'ath-MIR166e',
#   'description': 'ath-MIR166e MI0000205 Arabidopsis thaliana miR166e stem-loop',
#   'sequence': 'UUGAGGGGAAUGUUGUCUGGCACGAGGCCCUUAACUUAGAUCUAUAUUUGAUUAUAUAUAUAUGUCUCUUCUUUAUUCAUUAGUCUAUACAUGAAUGAUCAUUUUACGGUUAAUGACGUCGGACCAGGCUUCAUUCCCCUCAA'},
#  {'mirbase_id': 'ath-MIR166f',
#   'description': 'ath-MIR166f MI0000206 Arabidopsis thaliana miR166f stem-loop',
#   'sequence': 'AAGUUCAGGUGAAUGAUGCCUGGCUCGAGACCAUUCAAUCUCAUGAUCUCAUGAUUAUAACGAUGAUGAUGAUGAUGUCGGACCAGGCUUCAUUCCCCUCAACUU'},
#  {'mirbase_id': 'ath-MIR166g',
#   'description': 'ath-MIR166g MI0000207 Arabidopsis thaliana miR166g stem-loop',
#   'sequence': 'GCGAUUUAGGGUUUAGAGGAAUGUUGUUUGGCUCGAGGUCAUGGAGAGUAAUUCGUUAACCCAACUCAAAACUCUAAAUGAUUCUCGGACCAGGCUUCAUUCCCCUCAACCUAUUUUAUCGC'},
#  {'mirbase_id': 'ath-MIR167a',
#   'description': 'ath-MIR167a MI0000208 Arabidopsis thaliana miR167a stem-loop',
#   'sequence': 'UGGUGCACCGGCAUCUGAUGAAGCUGCCAGCAUGAUCUAAUUAGCUUUCUUUAUCCUUUGUUGUGUUUCAUGACGAUGGUUAAGAGAUCAGUCUCGAUUAGAUCAUGUUCGCAGUUUCACCCGUUGACUGUCGCACCC'},
#  {'mirbase_id': 'ath-MIR167b',
#   'description': 'ath-MIR167b MI0000209 Arabidopsis thaliana miR167b stem-loop',
#   'sequence': 'GGGAACAAGUGAAGCUGCCAGCAUGAUCUAUCUUUGGUUAAGAGAUGAAUGUGGAAACAUAUUGCUUAAACCCAAGCUAGGUCAUGCUCUGACAGCCUCACUCCUUCCU'},
#  {'mirbase_id': 'ath-MIR168a',
#   'description': 'ath-MIR168a MI0000210 Arabidopsis thaliana miR168a stem-loop',
#   'sequence': 'CACCAUCGGGCUCGGAUUCGCUUGGUGCAGGUCGGGAACCAAUUCGGCUGACACAGCCUCGUGACUUUUAAACCUUUAUUGGUUUGUGAGCAGGGAUUGGAUCCCGCCUUGCAUCAACUGAAUCGGAUCCUCGAGGUG'},
#  {'mirbase_id': 'ath-MIR168b',
#   'description': 'ath-MIR168b MI0000211 Arabidopsis thaliana miR168b stem-loop',
#   'sequence': 'UUACCGGCGGUCUCGGAUUCGCUUGGUGCAGGUCGGGAACUGAUUGGCUGACACCGACACGUGUCUUGUCAUGGUUGGUUUGUGAGCUCCCGUCUUGUAUCAACUGAAUCGGAGUCCGAGGUGA'},
#  {'mirbase_id': 'ath-MIR169a',
#   'description': 'ath-MIR169a MI0000212 Arabidopsis thaliana miR169a stem-loop',
#   'sequence': 'GUGACGAAAGUAGUGUGCAGCCAAGGAUGACUUGCCGAUUUAAAUGAUCUUUCUUUAUACUCUAUUAAGACAAUUUAGUUUCAAACUUUUUUUUUUUUUUUUUUUUGAAGGAUUCAGGAAGAAAUUAGGAUAUAUUAUUCCGUAUAAAAUACAAGAUAUAUAAAACCAAAAAGAAAAAGUAACAUGAUCGGCAAGUUGUCCUUGGCUACACGUUACUUUGUGUCGC'},
#  {'mirbase_id': 'ath-MIR170',
#   'description': 'ath-MIR170 MI0000213 Arabidopsis thaliana miR170 stem-loop',
#   'sequence': 'CGAGAGAGUCCCUCUGAUAUUGGCCUGGUUCACUCAGAUUCUCUUUUACUAACUCAUCUGAUUGAGCCGUGUCAAUAUCUCAGUCCUCUCUCG'},
#  {'mirbase_id': 'ath-MIR171a',
#   'description': 'ath-MIR171a MI0000214 Arabidopsis thaliana miR171a stem-loop',
#   'sequence': 'AUGAGAGAGUCCCUUUGAUAUUGGCCUGGUUCACUCAGAUCUUACCUGACCACACACGUAGAUAUACAUUAUUCUCUCUAGAUUAUCUGAUUGAGCCGCGCCAAUAUCUCAGUACUCUCUCGU'},
#  {'mirbase_id': 'ath-MIR172a',
#   'description': 'ath-MIR172a MI0000215 Arabidopsis thaliana miR172a stem-loop',
#   'sequence': 'UGCUGUGGCAUCAUCAAGAUUCACAUCUGUUGAUGGACGGUGGUGAUUCACUCUCCACAAAGUUCUCUAUGAAAAUGAGAAUCUUGAUGAUGCUGCAUCGGC'},
#  {'mirbase_id': 'ath-MIR172b',
#   'description': 'ath-MIR172b MI0000216 Arabidopsis thaliana miR172b stem-loop',
#   'sequence': 'AGGCGCAGCACCAUUAAGAUUCACAUGGAAAUUGAUAAAUACCCUAAAUUAGGGUUUUGAUAUGUAUAUGAGAAUCUUGAUGAUGCUGCAUCAAC'},
#  {'mirbase_id': 'ath-MIR173',
#   'description': 'ath-MIR173 MI0000217 Arabidopsis thaliana miR173 stem-loop',
#   'sequence': 'UAAGUACUUUCGCUUGCAGAGAGAAAUCACAGUGGUCAAAAAAGUUGUAGUUUUCUUAAAGUCUCUUUCCUCUGUGAUUCUCUGUGUAAGCGAAAGAGCUUG'},
#  {'mirbase_id': 'ath-MIR159b',
#   'description': 'ath-MIR159b MI0000218 Arabidopsis thaliana miR159b stem-loop',
#   'sequence': 'GGAAGAGCUCCUUGAAGUUCAAUGGAGGGUUUAGCAGGGUGAAGUAAAGCUGCUAAGCUAUGGAUCCCAUAAGCCUUAUCAAAUUCAAUAUAAUUGAUGAUAAGGUUUUUUUUAUGGAUGCCAUAUCUCAGGAGCUUUCACUUACCCCUUUAAUGGCUUCACUCUUCUUUGGAUUGAAGGGAGCUCUUCAUCUCUC'},
#  {'mirbase_id': 'mmu-mir-10b',
#   'description': 'mmu-mir-10b MI0000221 Mus musculus miR-10b stem-loop',
#   'sequence': 'UAUAUACCCUGUAGAACCGAAUUUGUGUGGUACCCACAUAGUCACAGAUUCGAUUCUAGGGGAAUAUA'},
#  {'mirbase_id': 'mmu-mir-129-1',
#   'description': 'mmu-mir-129-1 MI0000222 Mus musculus miR-129-1 stem-loop',
#   'sequence': 'UGGAUCUUUUUGCGGUCUGGGCUUGCUGUUCUCUCGACAGUAGUCAGGAAGCCCUUACCCCAAAAAGUAUCUA'},
#  {'mirbase_id': 'mmu-mir-181a-2',
#   'description': 'mmu-mir-181a-2 MI0000223 Mus musculus miR-181a-2 stem-loop',
#   'sequence': 'CCAUGGAACAUUCAACGCUGUCGGUGAGUUUGGGAUUCAAAAACAAAAAAACCACCGACCGUUGACUGUACCUUGG'},
#  {'mirbase_id': 'mmu-mir-182',
#   'description': 'mmu-mir-182 MI0000224 Mus musculus miR-182 stem-loop',
#   'sequence': 'ACCAUUUUUGGCAAUGGUAGAACUCACACCGGUAAGGUAAUGGGACCCGGUGGUUCUAGACUUGCCAACUAUGGU'},
#  {'mirbase_id': 'mmu-mir-183',
#   'description': 'mmu-mir-183 MI0000225 Mus musculus miR-183 stem-loop',
#   'sequence': 'CUGUGUAUGGCACUGGUAGAAUUCACUGUGAACAGUCUCAGUCAGUGAAUUACCGAAGGGCCAUAAACAG'},
#  {'mirbase_id': 'mmu-mir-184',
#   'description': 'mmu-mir-184 MI0000226 Mus musculus miR-184 stem-loop',
#   'sequence': 'CCUUUCCUUAUCACUUUUCCAGCCAGCUUUGUGACUCUAAGUGUUGGACGGAGAACUGAUAAGGGUAGG'},
#  {'mirbase_id': 'mmu-mir-185',
#   'description': 'mmu-mir-185 MI0000227 Mus musculus miR-185 stem-loop',
#   'sequence': 'AGGGAUUGGAGAGAAAGGCAGUUCCUGAUGGUCCCCUCCCAGGGGCUGGCUUUCCUCUGGUCCUU'},
#  {'mirbase_id': 'mmu-mir-186',
#   'description': 'mmu-mir-186 MI0000228 Mus musculus miR-186 stem-loop',
#   'sequence': 'ACUUUCCAAAGAAUUCUCCUUUUGGGCUUUCUCAUUUUAUUUUAAGCCCUAAGGUGAAUUUUUUGGGAAGU'},
#  {'mirbase_id': 'mmu-mir-187',
# ...
#  {'mirbase_id': 'ath-MIR169k',
#   'description': 'ath-MIR169k MI0000985 Arabidopsis thaliana miR169k stem-loop',
#   'sequence': 'UUAGAAGGAGAUGUCAAAGAUGAAUAGGAGAACAAUAUUUGGUAGCCAAGGAUGACUUGCCUGCUUCUCUGAACAAAAUGGUCGAUGUCAUGUUUUGAAGUGACUAUAAGUUAUACCAAGAAAUGACCAUUUUGUUUAUAAAUAGACAUCAGGCAGUCUCCUUGGCUAUCCUUAUAUGUUCUUCUUUCUCAACUCAGAUAUUUACCUUCAUCC'},
#  {'mirbase_id': 'ath-MIR169l',
#   'description': 'ath-MIR169l MI0000986 Arabidopsis thaliana miR169l stem-loop',
#   'sequence': 'AUGAAGAAGAGAGGUCUAAUAUGGCGAAAAGAGUCAUGUUUAAUAGCCAAGGAUGACUUGCCUGAUCUUUUUCACCUCCAUGAUUCAAUUUUAAGUUCGUGGAUUUUGGAUUAUUAUGCGUUUAAAAGGUAUAAUAAUUUGAGAUCAUGUUGAAUCUUGCGGGUUAGGUUUCAGGCAGUCUCUUUGGCUAUCUUGACAUGCUUUCUUCAUC'},
#  {'mirbase_id': 'ath-MIR169m',
#   'description': 'ath-MIR169m MI0000987 Arabidopsis thaliana miR169m stem-loop',
#   'sequence': 'UAGAAGGAGAAGUCAAAGAUGAAUAGAAGAAUCAUAUUUGGUAGCCAAGGAUGACUUGCCUGUUUCUUUGAGUAAAAUGGGUUAGUGUCAUGUUUGACAAGUGACUAUAAGUUAUAUCAAGCAAUGACCAUUUUACUCAUCAAAAGACAUCAGGCAGUCUCCUUGGCUAUCCUUAUAUGUUCUUCUCUCUCAUCUCAGACGUUUACCUUCAU'},
#  {'mirbase_id': 'ath-MIR169n',
#   'description': 'ath-MIR169n MI0000988 Arabidopsis thaliana miR169n stem-loop',
#   'sequence': 'GAUGAAGAAGAGAGGUCUAACAUGGCGGAAAGCGUCAUGUUUAGUAGCCAAGGAUGACUUGCCUGAUCUUUUUCGCCUCCACGAUUCAAUUUCAAAUUCAUGCAUUUUGGAUUAUUAUACCUUUUAAAGUAUAAUAGGUCAAAUAUCAUGUUGAAUCUUGCGGGUUAGGUUUCAGGCAGUCUCUUUGGCUAUCUUGACAUGCUUUUUCCAUCCAU'},
#  {'mirbase_id': 'ath-MIR171b',
#   'description': 'ath-MIR171b MI0000989 Arabidopsis thaliana miR171b stem-loop',
#   'sequence': 'UGCAAGGUAACGCGAGAUAUUAGUGCGGUUCAAUCAAAUAGUCGUCCUCUUAACUCAUGGAGAACGGUGUUGUUCGAUUGAGCCGUGCCAAUAUCACGCGGUAAACCAAAAAUGGCA'},
#  {'mirbase_id': 'ath-MIR171c',
#   'description': 'ath-MIR171c MI0000990 Arabidopsis thaliana miR171c stem-loop',
#   'sequence': 'UGAGCGCACUAUCGGACAUCAAAUACGAGAUAUUGGUGCGGUUCAAUCAGAAAACCGUACUCUUUUGUUUUAAAGAUCGGUUUAUUUGAUUGAGCCGUGCCAAUAUCACGCGUUUA'},
#  {'mirbase_id': 'ath-MIR172c',
#   'description': 'ath-MIR172c MI0000991 Arabidopsis thaliana miR172c stem-loop',
#   'sequence': 'AGCUACUGUUCGCUGUUGGAGCAUCAUCAAGAUUCACAAAUCAUCAAGUAUUCGUGUAAAUAAACCCAUUUAUGAUUAGAUUUUUGAUGUAUGUAUGAGAAUCUUGAUGAUGCUGCAGCUGCAAUCAGUGGCU'},
#  {'mirbase_id': 'ath-MIR172d',
#   'description': 'ath-MIR172d MI0000992 Arabidopsis thaliana miR172d stem-loop',
#   'sequence': 'AGUCAUUGUUUGCUAUUGCAACAUCUUCAAGAUUCAGAAAUCAGAUUCUCUUAUGGGUUUUCUUUUGAGCCUUUAUUUUUUGGUUUGAGAAUCUUGAUGAUGCUGCAGCGGCAAUUAAAUGGCU'},
#  {'mirbase_id': 'ath-MIR390a',
#   'description': 'ath-MIR390a MI0001000 Arabidopsis thaliana miR390a stem-loop',
#   'sequence': 'GUAGAGAAGAAUCUGUAAAGCUCAGGAGGGAUAGCGCCAUGAUGAUCACAUUCGUUAUCUAUUUUUUGGCGCUAUCCAUCCUGAGUUUCAUUGGCUCUUCUUACUAC'},
#  {'mirbase_id': 'ath-MIR390b',
#   'description': 'ath-MIR390b MI0001001 Arabidopsis thaliana miR390b stem-loop',
#   'sequence': 'GAGAAAUAGCUAUAAAGCUCAGGAGGGAUAGCGCCAUGGCUCACCAGUGCUGUAUGUUUUGUAUAUGCGUACAUGUAUAUCUGUUGGCGCUAUCCAUCCUGAGUUCCAUAGCUUCUUCUU'},
#  {'mirbase_id': 'ath-MIR391',
#   'description': 'ath-MIR391 MI0001002 Arabidopsis thaliana miR391 stem-loop',
#   'sequence': 'UAGAGUGAUUACACAUACAAGUGGUCUUGCUUCUUCUAUGGUUUUAAAACUGCAAAUAAAGAUUUGCUUCGCAGGAGAGAUAGCGCCAUCACCUCUUCUAAGAAGUUAACUAGUGGUGACGGUAUCUCUCCUACGUAGCAAUCCUUAUAUAUGCAUCUUAAUACGGAGAGAUCAAGGUAUUUCAGUUGUUCAAUAAUCACCCUCUA'},
#  {'mirbase_id': 'ath-MIR393a',
#   'description': 'ath-MIR393a MI0001003 Arabidopsis thaliana miR393a stem-loop',
#   'sequence': 'AGAGGAAGGAUCCAAAGGGAUCGCAUUGAUCCUAAUUAAGGUGAAUUCUCCCCAUAUUUUCUUUAUAAUUGGCAAAUAAAUCACAAAAAUUUGCUUGGUUUUGGAUCAUGCUAUCUCUUUGGAUUCAUCCUUC'},
#  {'mirbase_id': 'ath-MIR393b',
#   'description': 'ath-MIR393b MI0001004 Arabidopsis thaliana miR393b stem-loop',
#   'sequence': 'AGAGAAAGGAUCCAAAGGGAUCGCAUUGAUCCUAAUUAAGCUGAUUUAUUCCCCAAUAAUUGUUUUUUUUUUCCUUCUCAAUCGAAAGAUGGAAGAAAAACAAAUUCCAAACAUUUUGCUUACUUUUCCGGAUCAUGCGAUCUCUUUGGAUUCAUUCUUU'},
#  {'mirbase_id': 'ath-MIR394a',
#   'description': 'ath-MIR394a MI0001005 Arabidopsis thaliana miR394a stem-loop',
#   'sequence': 'CUUACAGUCAUCUUUGGCAUUCUGUCCACCUCCUUCUAUACAUAUAUGCAUGUGUAUAUAUAUAUGCGUUUCGUGUGAAAGAAGGAGGUGGGUAUACUGCCAAUAGAGAUCUGUUAG'},
#  {'mirbase_id': 'ath-MIR394b',
#   'description': 'ath-MIR394b MI0001006 Arabidopsis thaliana miR394b stem-loop',
#   'sequence': 'CUUACAGAGAUCUUUGGCAUUCUGUCCACCUCCUCUCUCUAUAUUUAUGUGUAAUAAGUGUACGUAUCUACGGUGUGUUUCGUAAGAGGAGGUGGGCAUACUGCCAAUAGAGAUCUGUUAG'},
#  {'mirbase_id': 'ath-MIR395a',
#   'description': 'ath-MIR395a MI0001007 Arabidopsis thaliana miR395a stem-loop',
#   'sequence': 'AUGUCUCCUAGAGUUCCUCUGAGCACUUCAUUGGGGAUACAAUUUUUCUAAAUGAUUAUCCACUGAAGUGUUUGGGGGAACUCCCGGACCCAU'},
#  {'mirbase_id': 'ath-MIR395b',
#   'description': 'ath-MIR395b MI0001008 Arabidopsis thaliana miR395b stem-loop',
#   'sequence': 'AUGUCCCCAUGAGUUCCCUUUAACGCUUCAUUGUUAAAUACUCAAAGCCACAUUGGUUUGUAUACAACACUGAAGUGUUUGGGGGGACUCUUGGUGUCAU'},
#  {'mirbase_id': 'ath-MIR395c',
#   'description': 'ath-MIR395c MI0001009 Arabidopsis thaliana miR395c stem-loop',
#   'sequence': 'AUGUCCACAUGAGUUCCCUUUAACGCUUCAUUGUUGAAUACUCAAAGCCACAUUGGUUUGUAUAUAACACUGAAGUGUUUGGGGGGACUCUUGGUGUCAU'},
#  {'mirbase_id': 'ath-MIR395d',
#   'description': 'ath-MIR395d MI0001010 Arabidopsis thaliana miR395d stem-loop',
#   'sequence': 'AUGUCCUCUAGAGUUCUCCUGAACACUUCAUUGGAAAUUUGUUAUUCAGUAAGCUAACAGUUAAUUCCACUGAAGUGUUUGGGGGAACUCCCGAUGUCAU'},
#  {'mirbase_id': 'ath-MIR395e',
#   'description': 'ath-MIR395e MI0001011 Arabidopsis thaliana miR395e stem-loop',
#   'sequence': 'AUGUUUUCUAGAGUUCCUCUGAGCACUUCAUUGGAGAUACAAUUUUUUAUAAAAUAGUUUUCUACUGAAGUGUUUGGGGGAACUCCCGGGCUGAU'},
#  {'mirbase_id': 'ath-MIR395f',
#   'description': 'ath-MIR395f MI0001012 Arabidopsis thaliana miR395f stem-loop',
#   'sequence': 'AUGUCCCCUUGAGUUCCCUUAAACGCUUCAUUGUUCAUACUUUGUUAUCAUCUAUCGAUCGAUCAAUCAAUCUGAUGAACACUGAAGUGUUUGGGGGGACUCUAGGUGACAU'},
#  {'mirbase_id': 'ath-MIR396a',
#   'description': 'ath-MIR396a MI0001013 Arabidopsis thaliana miR396a stem-loop',
#   'sequence': 'CUCUGUAUUCUUCCACAGCUUUCUUGAACUGCAAAACUUCUUCAGAUUUUUUUUUUUUUCUUUUGAUAUCUCUUACGCAUAAAAUAGUGAUUUUCUUCAUAUCUCUGCUCGAUUGAUUUGCGGUUCAAUAAAGCUGUGGGAAGAUACAGAC'},
#  {'mirbase_id': 'ath-MIR396b',
#   'description': 'ath-MIR396b MI0001014 Arabidopsis thaliana miR396b stem-loop',
#   'sequence': 'GGUCAUACUUUUCCACAGCUUUCUUGAACUUUCUUUUUCAUUUCCAUUGUUUUUUUCUUAAACAAAAGUAAGAAGAAAAAAAACUUUAAGAUUAAGCAUUUUGGAAGCUCAAGAAAGCUGUGGGAAAACAUGACA'},
#  {'mirbase_id': 'ath-MIR397a',
#   'description': 'ath-MIR397a MI0001015 Arabidopsis thaliana miR397a stem-loop',
#   'sequence': 'UGAAUGAACAUCAUUGAGUGCAGCGUUGAUGUAAUUUCGUUUUGUUUUUCAUUGUUGAAUGGAUUAAAAGAAUUUAUACCAGCGUUGCGCUCAAUUAUGUUUUUCUA'},
#  {'mirbase_id': 'ath-MIR397b',
#   'description': 'ath-MIR397b MI0001016 Arabidopsis thaliana miR397b stem-loop',
#   'sequence': 'UGAAUGAACAUCAUUGAGUGCAUCGUUGAUGUAAUUUUACUUAUUUUAUUCCAUUGUUGAAUUAAUUAAAGAAGUAUAUAUCAGCGUUGCAUUCAAUUAUGUUUUUCUA'},
#  {'mirbase_id': 'ath-MIR398a',
#   'description': 'ath-MIR398a MI0001017 Arabidopsis thaliana miR398a stem-loop',
#   'sequence': 'UGAAAUUUCAAAGGAGUGGCAUGUGAACACAUAUCCUAUGGUUUCUUCAAAUUUCCAUUGAAACCAUUGAGUUUUGUGUUCUCAGGUCACCCCUUUGAAUCUCCC'},
#  {'mirbase_id': 'ath-MIR398b',
#   'description': 'ath-MIR398b MI0001018 Arabidopsis thaliana miR398b stem-loop',
#   'sequence': 'UGGAUCUCGACAGGGUUGAUAUGAGAACACACGAGUAAUCAACGGCUGUAAUGACGCUACGUCAUUGUUACAGCUCUCGUUUUCAUGUGUUCUCAGGUCACCCCUGCUGAGCUCUU'},
#  {'mirbase_id': 'ath-MIR398c',
#   'description': 'ath-MIR398c MI0001019 Arabidopsis thaliana miR398c stem-loop',
#   'sequence': 'UGGAUCUCGACAGGGUUGAUAUGAGAACACACGAGCAAUCAACGGCUAUAACGACGCUACGUCAUUGUUACAGCUCUCGUUUCAUGUGUUCUCAGGUCACCCCUGCUGAGCUCUU'},
#  {'mirbase_id': 'ath-MIR399a',
#   'description': 'ath-MIR399a MI0001020 Arabidopsis thaliana miR399a stem-loop',
#   'sequence': 'AAAUGCAUUACAGGGUAAGAUCUCUAUUGGCAGGAAACCAUUACUUAGAUCUUUGCAUCUCUUUAUGCAUUGCUUUUAAUUAGUGAGUUAUCUGCCAAAGGAGAUUUGCCCUGUAAUUCUUCU'},
#  {'mirbase_id': 'ath-MIR399b',
#   'description': 'ath-MIR399b MI0001021 Arabidopsis thaliana miR399b stem-loop',
#   'sequence': 'UCACUAGUUUUAGGGCGCCUCUCCAUUGGCAGGUCCUUUACUUCCAAAUAUACACAUACAUAUAUGAAUAUCGAAAAUUUCCGAUGAUCGAUUUAUAAAUGACCUGCCAAAGGAGAGUUGCCCUGAAACUGGUUC'},
#  {'mirbase_id': 'ath-MIR399c',
#   'description': 'ath-MIR399c MI0001022 Arabidopsis thaliana miR399c stem-loop',
#   'sequence': 'GGAGCAGUAAUAGGGCAUCUUUCUAUUGGCAGGCGACUUGGCUAUUUGUAUCUUUUGUGUUCUUGACUAUUGGCUAUGUCACUUGCCAAAGGAGAGUUGCCCUGUCACUGCUUC'},
#  {'mirbase_id': 'ath-MIR399d',
#   'description': 'ath-MIR399d MI0001023 Arabidopsis thaliana miR399d stem-loop',
#   'sequence': 'GGUUGGAUUACUGGGCGAAUACUCCUAUGGCAGAUCGCAUUGGCUAGAUAUGCAAGUAAAAUGCUUCUCUGCCAAAGGAGAUUUGCCCCGCAAUUCAUCC'},
#  {'mirbase_id': 'ath-MIR399e',
#   'description': 'ath-MIR399e MI0001024 Arabidopsis thaliana miR399e stem-loop',
#   'sequence': 'GAAAGCAUUACAGGGCGAAUCCUCUAUUGGCAGUGGAAGUUGAUGACCCUUAUAUGUUAUUUUCUCAUCAUUUUCCUCUGCCAAAGGAGAUUUGCCUCGCAAUGCUUCA'},
#  {'mirbase_id': 'ath-MIR399f',
#   'description': 'ath-MIR399f MI0001025 Arabidopsis thaliana miR399f stem-loop',
#   'sequence': 'AUAUGCAUUACAGGGCAAGAUCACCAUUGGCAGAGAUCUAUUACUUCAUUCUUGCAUCAUAUGCAUAAAUGUUUGUGGUGAGCUCUCUGCCAAAGGAGAUUUGCCCGGUAAUUCUCUU'},
#  {'mirbase_id': 'osa-MIR393a',
#   'description': 'osa-MIR393a MI0001026 Oryza sativa miR393 stem-loop',
#   'sequence': 'UGGGGAAGCAUCCAAAGGGAUCGCAUUGAUCCUUCAUCGCUCUCGCUCGCUUCCAUGGCGGUCGUCGUCUACAAGCAGCUUGACGGAUCAUGCGAUCCUUUUGGAGGCUUCCUCU'},
#  {'mirbase_id': 'osa-MIR394',
#   'description': 'osa-MIR394 MI0001027 Oryza sativa miR394 stem-loop',
#   'sequence': 'UACUGAGAGUUCUUUGGCAUUCUGUCCACCUCCUUGUCGAAUCCUCAGAGACAGAAAUCUCAUAUCUGUUGAUCUUGGAGGUGGGCAUACUGCCAAUGGAGCUGUGUAGG'},
#  {'mirbase_id': 'osa-MIR395b',
#   'description': 'osa-MIR395b MI0001028 Oryza sativa miR395b stem-loop',
#   'sequence': 'GAGUCCCUAGGAGUUCCUUUCAAGCACUUUACGACACACUGUAUUGAGAGUUGUCGUGAAGUGUUUGGGGGAACUCUUAGUGUCGC'},
#  {'mirbase_id': 'osa-MIR395d',
#   'description': 'osa-MIR395d MI0001029 Oryza sativa miR395d stem-loop',
#   'sequence': 'GUAUUGUCGUGAGUUCCCUUCAAGCACUUCACGUGGCACUAUCUCAAUGCCUACUAUGUGAAGUGUUUGGGGGAACUCUCGAUAUCAC'},
#  {'mirbase_id': 'osa-MIR395e',
#   'description': 'osa-MIR395e MI0001030 Oryza sativa miR395e stem-loop',
#   'sequence': 'GUAUUAUCGAGAGUUCCCUUCAACCACUUCACGUGGCACUGUUUCAAGGCCUAUUGUGUGAAGUGUUUGGGGGAACUCUCGAUAUCAC'},
#  {'mirbase_id': 'osa-MIR395g',
#   'description': 'osa-MIR395g MI0001031 Oryza sativa miR395g stem-loop',
#   'sequence': 'GUAUCACCGUGAGUUCCCUUCGAACACUUCACGUGGCACUAUUUCAAUGCCUAUUGUGAAGUGUUUGGGGGAACUCUCGAUGUCAU'},
#  {'mirbase_id': 'osa-MIR395h',
#   'description': 'osa-MIR395h MI0001032 Oryza sativa miR395h stem-loop',
#   'sequence': 'UUGUUACCUGGAGUUUCCUCAACACACUUCACAUCUGCUAGGCCCUAUUACAAUUGCGCAAUGUGGAGUCUGCAAUUGGUAGUGAAGUGUUUGGGGGAACUCUAGGUGGCAC'},
#  {'mirbase_id': 'osa-MIR395i',
#   'description': 'osa-MIR395i MI0001033 Oryza sativa miR395i stem-loop',
#   'sequence': 'GUUUUACCGGGAGUUCUCUUCAAGCACUUCACGUAGAGCUUUCUAUUGACAUGGAGCUUUAGAACAAUGUGAAGUGUUUGGGGGAACUCUUGGUACCAA'},
#  {'mirbase_id': 'osa-MIR395j',
#   'description': 'osa-MIR395j MI0001034 Oryza sativa miR395j stem-loop',
#   'sequence': 'GUGUUCCCAAGAGUUCCUUGCAAGCACUUCACAUAGAACUUCUGUUACUCUCAUGUAACAUUGGGAACUUGAGAAGCUACUGUGAAGUGUUUGGGGGAACUCUAGGUGGCAC'},
#  {'mirbase_id': 'osa-MIR395k',
#   'description': 'osa-MIR395k MI0001035 Oryza sativa miR395k stem-loop',
#   'sequence': 'GUUUUAUCGGGAGUUUCCUUCAAGCACUUCACGUAGAGCUUUCUAUUGAUAUGGAGCUUUGGAACAAUGUGAAGUGUUUGGGGGAACUCUUGAUACCAA'},
#  {'mirbase_id': 'osa-MIR395l',
#   'description': 'osa-MIR395l MI0001036 Oryza sativa miR395l stem-loop',
#   'sequence': 'GCGUUCCUUCCAAGCACUUCACACAGAGCUUUUAUUUCUCUCACAUCGAUUGAGAACUUAAUUAGAAGCUUUUGUGAAGUGUUUGGGGGAACUC'},
#  {'mirbase_id': 'osa-MIR395s',
#   'description': 'osa-MIR395s MI0001037 Oryza sativa miR395s stem-loop',
#   'sequence': 'GUAUCACCGUGAGUUCCCUUCAAGCACUUCACGUGGCACUAUUUCAAUGCCUAUUGUGAAGUGUUUGGGGGAACUCUCGAUGUUCC'},
#  {'mirbase_id': 'osa-MIR395t',
#   'description': 'osa-MIR395t MI0001038 Oryza sativa miR395t stem-loop',
#   'sequence': 'UUAUCCACUGGAGUUCUCCUCAAACCACUUCAGCAGAUAGCUAGCUAGGCCUCAUUGCAUUGCACCACUGUUGCAUAACUAUGAGCAUGGGGCCAAAAGUUAGCUGCUUAUAGUGAAGUGUUUGGGGAAACUCCGGUUGGCAA'},
#  {'mirbase_id': 'osa-MIR395c',
#   'description': 'osa-MIR395c MI0001041 Oryza sativa miR395c stem-loop',
#   'sequence': 'GUAUUAUCAAGAGUUCUCUUUAAGCACUUCAUACGACACCAUUAUUUAUAGGGUUGUUGUGAAGUGUUUGGAGGAACUCUCGGUGUCAU'},
#  {'mirbase_id': 'osa-MIR395a',
#   'description': 'osa-MIR395a MI0001042 Oryza sativa miR395a stem-loop',
#   'sequence': 'UUGUCCACUGGAGUUCUCCUCAAUCCACUUCAGUAGAUAGCUAUGGCUAGGCCUCAUUGCAUUGCACUGUUACAUAACUGUGAUCAUGGGGCCAAAAGCUAGCUAUGUAUAGUGAAGUGCUUGGGGGAACUCCAGUUGACAC'},
#  {'mirbase_id': 'osa-MIR395f',
#   'description': 'osa-MIR395f MI0001043 Oryza sativa miR395f stem-loop',
#   'sequence': 'UUAUCGCGGGUUCCCUUCAAUCACUUCACAUGGUACUAUUUCAAGGCCUACUAUGUGAAUUGUUUGGGGGAACUCUCGAUGU'},
#  {'mirbase_id': 'osa-MIR395u',
#   'description': 'osa-MIR395u MI0001044 Oryza sativa miR395u stem-loop',
#   'sequence': 'ACACUGCCAGGAAUUCCCUUCAAGCAAUUCAUGAAACAAUAUUUUGAGAGUUGUUGUGAAGCGUUUGGGGGAAAUCUCAGUGUCGC'},
#  {'mirbase_id': 'osa-MIR396a',
#   'description': 'osa-MIR396a MI0001046 Oryza sativa miR396a stem-loop',
#   'sequence': 'CUUUGUGAUCUUCCACAGCUUUCUUGAACUGCACGCAUGAUGAAUAAUCCCUUUGGUUAAUUGUGAUCUGGUCUCUGAGAGAUCGUAGUUAGACUCGAUCGGUUGCAUUGGCAUCAGAGAGAGCAGUUCAAUAAAGCUGUGGGAAAUUGCAGAG'},
#  {'mirbase_id': 'osa-MIR396b',
#   'description': 'osa-MIR396b MI0001047 Oryza sativa miR396b stem-loop',
#   'sequence': 'CUUUGUGGUCUUCCACAGCUUUCUUGAACUGCAUCUUUGAGAGAGAUUAGCAUCCCUAUGUGUGGAUUUUGCUUGCACGAGUGUGCAGUUCAAUAAAGCUGUGGGAAAUUACAGAG'},
#  {'mirbase_id': 'osa-MIR396c',
#   'description': 'osa-MIR396c MI0001048 Oryza sativa miR396c stem-loop',
#   'sequence': 'UGCCAUGCCUUUCCACAGCUUUCUUGAACUUCUCUUGUGCCUCACUCACUUUCAUUACUGGAGAGAUAUGCAUCAUCAGUGGAAGCUUAUAGGGAGAGGAGUGCAAGAAGAGGGUCAAGAAAGCUGUGGGAAGAAAUGGCA'},
#  {'mirbase_id': 'osa-MIR397a',
#   'description': 'osa-MIR397a MI0001049 Oryza sativa miR397a stem-loop',
#   'sequence': 'AUCAAAUGCAUCAUUGAGUGCAGCGUUGAUGAACAACGGUAACCGGUCCAUGUUGAUGCGCAUUUGGCCGGUGAUCUGAUCAUCAUCAGCGCUUCACUCAAUCAUGCGUUUGGC'},
#  {'mirbase_id': 'osa-MIR397b',
#   'description': 'osa-MIR397b MI0001050 Oryza sativa miR397b stem-loop',
#   'sequence': 'AGGGAAGGCAUUAUUGAGUGCAGCGUUGAUGAACCUGCCGGCCGGCUAAAUUAAUUAGCAAGAAAGUCUGAAACUGGCUCAAAGGUUCACCAGCACUGCACCCAAUCACGCCUUUGCU'},
#  {'mirbase_id': 'osa-MIR398a',
#   'description': 'osa-MIR398a MI0001051 Oryza sativa miR398a stem-loop',
#   'sequence': 'GCUGAACCCAGAGGAGUGGUACUGAGAACACAGGUGCCAAUACAAUGUAUGGUGAGCUACUGUAUAAUGGAGUAAUUCUGUAACUGUGUUCUCAGGUCACCCCUUUGGGUUUCUU'},
#  {'mirbase_id': 'osa-MIR398b',
#   'description': 'osa-MIR398b MI0001052 Oryza sativa miR398b stem-loop',
#   'sequence': 'GGAGUUCCUACAGGGGCGAGCUGGGAACACACGGUGAUGAGGCGGUCUGGUCUUUCGUGUGUUCUCAGGUCGCCCCUGCCGGGACUCU'},
#  {'mirbase_id': 'osa-MIR399a',
#   'description': 'osa-MIR399a MI0001053 Oryza sativa miR399a stem-loop',
#   'sequence': 'CUGUGAAUUACAGGGCAGUUCACCUUUGGCACAAGGGCAAGCAGUAGAAACCAUGCGUGCUUGCUAGAGCUGGAAAUGAUGCUGGUAGCAUUGCAUGGUUCAGGGAUCACAGAUCUCGUGCCAAAGGAGAAUUGCCCUGCGAUUUUGUC'},
#  {'mirbase_id': 'osa-MIR399b',
#   'description': 'osa-MIR399b MI0001054 Oryza sativa miR399b stem-loop',
#   'sequence': 'GUGAGAAUCACAGUGCGAUUCUCCUCUGGCAUGGCAUGAGAGGCCUAAAAAAGAGACGCACUGCCGUGCCAAAGGAGAAUUGCCCUGCCAUUCAGAA'},
#  {'mirbase_id': 'osa-MIR399c',
#   'description': 'osa-MIR399c MI0001055 Oryza sativa miR399c stem-loop',
#   'sequence': 'CGGCGAAUUACAGGGCGGUUUCUCCUUUGGCACGUACGGAGGCAAGGCAUGCGGUGAAAAAUCUCUAGCUAGCCAUGCGUGCCAAAGGAGAAUUGCCCUGCGAUUCACCA'},
#  {'mirbase_id': 'osa-MIR399d',
#   'description': 'osa-MIR399d MI0001056 Oryza sativa miR399d stem-loop',
#   'sequence': ''},
#  {'mirbase_id': 'osa-MIR399e',
#   'description': 'osa-MIR399e MI0001057 Oryza sativa miR399e stem-loop',
#   'sequence': 'ACAUGCAUUACCGGGUGAGUCUUCCUUGGCAGUGUUCGAAUCGGCAGUACCGGUCUGCAAGUGAUCGGUCAAUCACCAGUUCACCGCUGCCAAAGGAGAUUUGCCCAGCAAUGCAACU'},
#  ...]

# %%
q = "hsa-mir-7641-1".lower()  # cerchiamo in minuscolo per sicurezza

found = [m for m in mirna_data if q.lower() in m['description'].lower()]
if found:
    print(f"✅ {q} trovato ({len(found)} record)")
else:
    print(f"❌ {q} non trovato")
# Out:
# ❌ hsa-mir-7641-1 non trovato

# %% [markdown]
# Anyway there are some miRNA IDs that are not present.
# We create a manual mapping for those missing miRNA IDs.
#
# manual_mapping = {
#     "hsa-mir-3607": "MIR3607",
#     "hsa-mir-3653": "MIR3653",
#     "hsa-mir-3687-1": "MIR3687-1",
#     "hsa-mir-3687-2": "MIR3687-2",
#     "hsa-mir-6087": "MIR6087",
#     "hsa-mir-6723": "MIR6723",
#     "hsa-mir-6827": "MIR6827",
#     "hsa-mir-7641-1": "MIR7641-1",
#     "hsa-mir-7641-2": "MIR7641-2",
#     "hsa-mir-3656": "MIR3656",
#     "hsa-mir-4788": "MIR4788"
# }

# %%
result = mapping[mapping.astype(str).apply(lambda x: x.str.contains('hsa-mir-3607', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [Gene stable ID, Gene name, miRBase ID, miRBase accession]
# Index: []

# %%
result = mapping_grch37[mapping_grch37.astype(str).apply(lambda x: x.str.contains('hsa-mir-3607', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [Gene stable ID, Gene name, miRBase ID, miRBase accession]
# Index: []

# %% [markdown]
# We can see that not all miRNA ID are present in the mapping DataFrame of the latest Ensembl version. But they are present in the GRCh37 version.

# %%
result = df[df.astype(str).apply(lambda x: x.str.contains('ENSG00000266398', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, gene_type, gene_name, level, tag, transcript_id, transcript_type, transcript_name, exon_number, exon_id, transcript_support_level, havana_transcript, hgnc_id, havana_gene, ont, protein_id, ccdsid, artif_dupl]
# Index: []
#
# [0 rows x 26 columns]

# %%
3917502 - 3917563
# Out:
# -61

# %%
# Add miRBase IDs to the miRNA GTF DataFrame
merged_df = pd.merge(df, mapping, left_on='gene_name', right_on='Gene name', how='left')
merged_df.head()
# Out:
#   seqname   source     feature  start    end score strand frame  \
# 0    chr1  ENSEMBL        gene  17369  17436     .      -     .
# 1    chr1  ENSEMBL        gene  17369  17436     .      -     .
# 2    chr1  ENSEMBL        gene  17369  17436     .      -     .
# 3    chr1  ENSEMBL        gene  17369  17436     .      -     .
# 4    chr1  ENSEMBL  transcript  17369  17436     .      -     .
#
#              gene_id gene_type  ... havana_transcript     hgnc_id havana_gene  \
# 0  ENSG00000278267.1     miRNA  ...               NaN  HGNC:50039         NaN
# 1  ENSG00000278267.1     miRNA  ...               NaN  HGNC:50039         NaN
# 2  ENSG00000278267.1     miRNA  ...               NaN  HGNC:50039         NaN
# 3  ENSG00000278267.1     miRNA  ...               NaN  HGNC:50039         NaN
# 4  ENSG00000278267.1     miRNA  ...               NaN  HGNC:50039         NaN
#
#   ont protein_id ccdsid  artif_dupl   Gene stable ID  Gene name  \
# 0 NaN        NaN    NaN         NaN  ENSG00000278267  MIR6859-1
# 1 NaN        NaN    NaN         NaN  ENSG00000278267  MIR6859-1
# 2 NaN        NaN    NaN         NaN  ENSG00000278267  MIR6859-1
# 3 NaN        NaN    NaN         NaN  ENSG00000278267  MIR6859-1
# 4 NaN        NaN    NaN         NaN  ENSG00000278267  MIR6859-1
#
#        miRBase ID
# 0  hsa-mir-6859-1
# 1  hsa-mir-6859-2
# 2  hsa-mir-6859-3
# 3  hsa-mir-6859-4
# 4  hsa-mir-6859-1
#
# [5 rows x 29 columns]

# %% [markdown]
# #  Homo sapiens GTF

# %%
HOMO_GTF_PATH = "../../datasets/Homo_sapiens.GRCh38.115.gtf"
cols = ["seqname", "source", "feature", "start", "end", "score", "strand", "frame", "attribute"]

homo_df = pd.read_csv(GTF_PATH, sep='\t', comment='#', names=cols)
homo_df.shape
# Out:
# (8063229, 9)

# %%
def parse_attributes(attr):
    d = {}
    for a in attr.split(";"):
        a = a.strip()
        if a == "":
            continue
        if " " in a:
            key, val = a.split(" ", 1)
            d[key] = val.strip('"')
    return d

chunks = np.array_split(homo_df, 10)
results = []
for i, chunk in enumerate(chunks):
    print(f"Processing chunk {i+1}/{len(chunks)} ...")    
    attr_df = chunk['attribute'].apply(parse_attributes).apply(pd.Series)
    merged = pd.concat([chunk.drop(columns=['attribute']), attr_df], axis=1)    
    results.append(merged)

homo_complete_gtf_df = pd.concat(results, ignore_index=True)
# Out:
# c:\users\giorg\appdata\local\programs\python\python39\lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Processing chunk 1/10 ...
# Processing chunk 2/10 ...
# Processing chunk 3/10 ...
# Processing chunk 4/10 ...
# Processing chunk 5/10 ...
# Processing chunk 6/10 ...
# Processing chunk 7/10 ...
# Processing chunk 8/10 ...
# Processing chunk 9/10 ...
# Processing chunk 10/10 ...

# %%
result = homo_complete_gtf_df[homo_complete_gtf_df.astype(str).apply(lambda x: x.str.contains('hsa-let-7a-1', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, gene_type, gene_name, level, tag, transcript_id, transcript_type, transcript_name, exon_number, exon_id, transcript_support_level, havana_transcript, hgnc_id, havana_gene, ont, protein_id, ccdsid, artif_dupl]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# No results found about 'hsa-let-7a-1'.

# %%
result = homo_complete_gtf_df[homo_complete_gtf_df.astype(str).apply(lambda x: x.str.contains('MIR1254-1', case=False, na=False)).any(axis=1)]
result.head()
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, gene_type, gene_name, level, tag, transcript_id, transcript_type, transcript_name, exon_number, exon_id, transcript_support_level, havana_transcript, hgnc_id, havana_gene, ont, protein_id, ccdsid, artif_dupl]
# Index: []
#
# [0 rows x 26 columns]
