# %%
import pandas as pd
import os

CLINICAL_PATH = "../datasets/clinical_data"

# %% [markdown]
#  # Clinical data analysis
#
# These XML files contain clinical data for breast cancer (BRCA) patients from the TCGA project. Each file represents a single patient and includes:
#
# - Patient information (age, death, vital status).
# - Tumor characteristics (histology, stage).
# - Treatment details and follow-up data.

# %% [markdown]
# ### Explore columns of clinical TXT files

# %%
import pickle

def import_txt(file_path):
    df = pd.read_csv(file_path, sep="\t")
    print(f"\nTXT file {file_path}. \nCOLUMNS: {df.columns}")
    columns_to_select = df.columns[df.columns.str.contains('age|year|days|case|time', case=False)]
    print(f"COLUMNS with 'age|year|days|case|time': {columns_to_select}")

def import_parce(file_path):
    with open(file_path, "rb") as f:
        data = pickle.load(f)
    print(f"\nFile TXT PARCEL {file_path}: {data}")

count = 0
for subfolder in os.listdir(CLINICAL_PATH):
    for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
        if file == "logs":
            for f in os.listdir(f"{CLINICAL_PATH}/{subfolder}/{file}"):
                if f.endswith(".parcel"):
                    import_parce(f"{CLINICAL_PATH}/{subfolder}/{file}/{f}")
        elif file.endswith(".txt"):
            import_txt(f"{CLINICAL_PATH}/{subfolder}/{file}")
            if file != "annotations.txt":
                count += 1
count
# Out:
# TXT file ../datasets/clinical_data/051ca785-e7be-4ac3-8757-1c9ace8acf7e/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/051ca785-e7be-4ac3-8757-1c9ace8acf7e/logs/nationwidechildrens.org_clinical.TCGA-A8-A08F.xml.parcel: IntervalTree([Interval(0, 84541, {'md5sum': 'f31cca8e42209358a8f3039ee72559bb'})])
#
# TXT file ../datasets/clinical_data/07488c2c-c50f-402e-8f22-9278db6110f9/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/07488c2c-c50f-402e-8f22-9278db6110f9/logs/nationwidechildrens.org_clinical.TCGA-AO-A0JI.xml.parcel: IntervalTree([Interval(0, 95172, {'md5sum': '037c703d4ed2f76b955c928500322cbe'})])
#
# TXT file ../datasets/clinical_data/0a40467f-9495-4c5b-b56e-3347a3ee0572/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/0a40467f-9495-4c5b-b56e-3347a3ee0572/logs/nationwidechildrens.org_clinical_radiation_brca.txt.parcel: IntervalTree([Interval(0, 154883, {'md5sum': '13885c9a052e6874e14158139982bb60'})])
#
# TXT file ../datasets/clinical_data/0a40467f-9495-4c5b-b56e-3347a3ee0572/nationwidechildrens.org_clinical_radiation_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_radiation_barcode',
#        'bcr_radiation_uuid', 'form_completion_date', 'radiation_therapy_type',
#        'radiation_therapy_site', 'radiation_total_dose',
#        'radiation_adjuvant_units', 'radiation_adjuvant_fractions_total',
#        'radiation_therapy_started_days_to',
#        'radiation_therapy_ongoing_indicator',
#        'radiation_therapy_ended_days_to', 'treatment_best_response',
#        'course_number', 'radiation_type_other', 'therapy_regimen',
#        'therapy_regimen_other'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['radiation_therapy_started_days_to', 'radiation_therapy_ended_days_to'], dtype='object')
#
# TXT file ../datasets/clinical_data/0fca54d0-a1f4-47f8-87f6-e17dd98fbf6b/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/0fca54d0-a1f4-47f8-87f6-e17dd98fbf6b/logs/nationwidechildrens.org_clinical.TCGA-GI-A2C8.xml.parcel: IntervalTree([Interval(0, 68655, {'md5sum': '2e0772d3a3e5c7e04df1c1353dd46c43'})])
#
# TXT file ../datasets/clinical_data/1208942c-b692-4e29-80a7-a9bf061ca4fb/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/1208942c-b692-4e29-80a7-a9bf061ca4fb/logs/nationwidechildrens.org_omf.TCGA-BH-A1F5.xml.parcel: IntervalTree([Interval(0, 19170, {'md5sum': '0e88ec8e0405b9a4eee615ed782191e5'})])
#
# TXT file ../datasets/clinical_data/13f99438-a228-44f5-aedf-398557abc162/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/13f99438-a228-44f5-aedf-398557abc162/logs/nationwidechildrens.org_clinical.TCGA-A7-A0DC.xml.parcel: IntervalTree([Interval(0, 112171, {'md5sum': 'db4e2c17c8b24e21878afcc6bd4eba2f'})])
#
# TXT file ../datasets/clinical_data/1e6b79ff-9787-4cbe-b19d-ebabb6b43589/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/1e6b79ff-9787-4cbe-b19d-ebabb6b43589/logs/nationwidechildrens.org_clinical_drug_brca.txt.parcel: IntervalTree([Interval(0, 961048, {'md5sum': 'a83b5130bd671998aa1ec339a542121d'})])
#
# TXT file ../datasets/clinical_data/1e6b79ff-9787-4cbe-b19d-ebabb6b43589/nationwidechildrens.org_clinical_drug_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_drug_barcode',
#        'bcr_drug_uuid', 'form_completion_date',
#        'pharmaceutical_therapy_drug_name',
#        'clinical_trial_drug_classification', 'pharmaceutical_therapy_type',
#        'pharmaceutical_tx_started_days_to',
#        'pharmaceutical_tx_ongoing_indicator',
#        'pharmaceutical_tx_ended_days_to', 'treatment_best_response',
#        'days_to_stem_cell_transplantation', 'pharm_regimen',
#        'pharm_regimen_other', 'pharma_adjuvant_cycles_count',
#        'pharma_type_other', 'pharmaceutical_tx_dose_units',
#        'pharmaceutical_tx_total_dose_units', 'prescribed_dose',
#        'regimen_number', 'route_of_administration',
#        'stem_cell_transplantation', 'stem_cell_transplantation_type',
#        'therapy_regimen', 'therapy_regimen_other', 'total_dose',
#        'tx_on_clinical_trial'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['pharmaceutical_tx_started_days_to', 'pharmaceutical_tx_ended_days_to',
#        'days_to_stem_cell_transplantation'],
#       dtype='object')
#
# TXT file ../datasets/clinical_data/22f38342-3f1a-47e5-9025-c19719fa21d0/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/22f38342-3f1a-47e5-9025-c19719fa21d0/logs/nationwidechildrens.org_clinical_follow_up_v1.5_brca.txt.parcel: IntervalTree([Interval(0, 117592, {'md5sum': '0b465b3f0b9bddf2416ccd74994805a4'})])
#
# TXT file ../datasets/clinical_data/22f38342-3f1a-47e5-9025-c19719fa21d0/nationwidechildrens.org_clinical_follow_up_v1.5_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_followup_barcode',
#        'bcr_followup_uuid', 'form_completion_date',
#        'radiation_treatment_adjuvant', 'pharmaceutical_tx_adjuvant',
#        'tumor_status', 'vital_status', 'last_contact_days_to', 'death_days_to',
#        'new_tumor_event_dx_days_to', 'new_tumor_event_radiation_tx',
#        'new_tumor_event_pharmaceutical_tx', 'nte_er_status',
#        'nte_er_status_ihc__positive', 'nte_er_ihc_intensity_score',
#        'nte_er_positivity_other_scale', 'nte_er_positivity_define_method',
#        'nte_pr_status_by_ihc', 'nte_pr_status_ihc__positive',
#        'nte_pr_ihc_intensity_score', 'nte_pr_positivity_other_scale',
#        'nte_pr_positivity_define_method', 'nte_her2_status',
#        'nte_her2_status_ihc__positive', 'nte_her2_positivity_ihc_score',
#        'nte_her2_positivity_other_scale', 'nte_her2_positivity_method',
#        'nte_her2_fish_status', 'nte_her2_signal_number',
#        'nte_cent_17_signal_number', 'her2_cent17_counted_cells_count',
#        'nte_cent_17_her2_ratio', 'nte_cent17_her2_other_scale',
#        'nte_her2_fish_define_method', 'cent17_copy_number',
#        'days_to_additional_surgery_locoregional_procedure',
#        'days_to_additional_surgery_metastatic_procedure',
#        'days_to_last_known_alive', 'er_ihc_score', 'er_positivity_method',
#        'er_positivity_scale_other', 'er_status_by_ihc',
#        'er_status_ihc_Percent_Positive', 'her2_and_cent17_cells_count',
#        'her2_and_cent17_scale_other', 'her2_cent17_ratio', 'her2_copy_number',
#        'her2_fish_method', 'her2_fish_status', 'her2_ihc_percent_positive',
#        'her2_ihc_score', 'her2_positivity_method_text',
#        'her2_positivity_scale_other', 'her2_status_by_ihc',
#        'new_tumor_event_surgery', 'new_tumor_event_surgery_met',
#        'pr_positivity_define_method', 'pr_positivity_ihc_intensity_score',
#        'pr_positivity_scale_other', 'pr_status_by_ihc',
#        'pr_status_ihc_percent_positive'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['last_contact_days_to', 'death_days_to', 'new_tumor_event_dx_days_to',
#        'days_to_additional_surgery_locoregional_procedure',
#        'days_to_additional_surgery_metastatic_procedure',
#        'days_to_last_known_alive'],
#       dtype='object')
#
# TXT file ../datasets/clinical_data/25f19634-8f54-4be7-a0f1-c2756e11fec8/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/25f19634-8f54-4be7-a0f1-c2756e11fec8/logs/nationwidechildrens.org_clinical.TCGA-A8-A09E.xml.parcel: IntervalTree([Interval(0, 61112, {'md5sum': '9d314b589b34556ae1fdaf5b91bb9ed6'})])
#
# TXT file ../datasets/clinical_data/2ade91c3-a81c-4362-a7fa-5c2aeb22b476/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/2ade91c3-a81c-4362-a7fa-5c2aeb22b476/logs/nationwidechildrens.org_omf.TCGA-A8-A06U.xml.parcel: IntervalTree([Interval(0, 11048, {'md5sum': 'ea0219b8946433d285d0329d3f673176'})])
#
# TXT file ../datasets/clinical_data/2b091208-b35c-4a3d-94ff-d5d01b8fcdcc/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/2b091208-b35c-4a3d-94ff-d5d01b8fcdcc/logs/nationwidechildrens.org_clinical.TCGA-A8-A08S.xml.parcel: IntervalTree([Interval(0, 61096, {'md5sum': '291e62ad1fa79bc9f78382da474ca7d0'})])
#
# TXT file ../datasets/clinical_data/2b09f2e9-68c4-4a64-90c9-d981e89c123d/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/2b09f2e9-68c4-4a64-90c9-d981e89c123d/logs/nationwidechildrens.org_omf.TCGA-A8-A09K.xml.parcel: IntervalTree([Interval(0, 11048, {'md5sum': '4c7b7bb6ef46423a54b25dc1e85c82b0'})])
#
# TXT file ../datasets/clinical_data/2de837e4-7624-4134-b30f-089d85912e9b/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/2de837e4-7624-4134-b30f-089d85912e9b/logs/nationwidechildrens.org_clinical.TCGA-BH-A1F5.xml.parcel: IntervalTree([Interval(0, 36388, {'md5sum': 'c4cb9133377b7866cf6e4dc8467ed54c'})])
#
# TXT file ../datasets/clinical_data/3af873f5-15e1-4605-b295-a5d29fc46835/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/3af873f5-15e1-4605-b295-a5d29fc46835/logs/nationwidechildrens.org_clinical.TCGA-BH-A0B6.xml.parcel: IntervalTree([Interval(0, 55625, {'md5sum': 'f16585531188b11bbe33c59454dedba3'})])
#
# TXT file ../datasets/clinical_data/3fd204bf-0d36-463c-935e-7fd9630948ef/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/3fd204bf-0d36-463c-935e-7fd9630948ef/logs/nationwidechildrens.org_clinical.TCGA-A7-A0CD.xml.parcel: IntervalTree([Interval(0, 81567, {'md5sum': '9e6fd59e6e8b4834f13a699fba754f33'})])
#
# TXT file ../datasets/clinical_data/403b5cef-8173-47c7-b56a-cc94dcfbb2e3/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/403b5cef-8173-47c7-b56a-cc94dcfbb2e3/logs/nationwidechildrens.org_clinical_follow_up_v2.1_brca.txt.parcel: IntervalTree([Interval(0, 372177, {'md5sum': '29f6255a8ddac7f43b3a2a30fe3e2b64'})])
#
# TXT file ../datasets/clinical_data/403b5cef-8173-47c7-b56a-cc94dcfbb2e3/nationwidechildrens.org_clinical_follow_up_v2.1_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_followup_barcode',
#        'bcr_followup_uuid', 'form_completion_date',
#        'radiation_treatment_adjuvant', 'pharmaceutical_tx_adjuvant',
#        'tumor_status', 'vital_status', 'last_contact_days_to', 'death_days_to',
#        'new_tumor_event_dx_indicator', 'new_tumor_event_type',
#        'new_tumor_event_site', 'new_tumor_event_site_other',
#        'new_tumor_event_dx_days_to', 'new_tumor_event_radiation_tx',
#        'new_tumor_event_pharmaceutical_tx', 'nte_er_status',
#        'nte_er_status_ihc__positive', 'nte_er_positivity_scale_used',
#        'nte_er_ihc_intensity_score', 'nte_er_positivity_other_scale',
#        'nte_er_positivity_define_method', 'nte_pr_status_by_ihc',
#        'nte_pr_status_ihc__positive', 'nte_pr_positivity_scale_used',
#        'nte_pr_ihc_intensity_score', 'nte_pr_positivity_other_scale',
#        'nte_pr_positivity_define_method', 'nte_her2_status',
#        'nte_her2_status_ihc__positive', 'nte_her2_positivity_ihc_score',
#        'nte_her2_positivity_other_scale', 'nte_her2_positivity_method',
#        'nte_her2_fish_status', 'nte_her2_signal_number',
#        'nte_cent_17_signal_number', 'her2_cent17_counted_cells_count',
#        'nte_cent_17_her2_ratio', 'nte_cent17_her2_other_scale',
#        'nte_her2_fish_define_method',
#        'days_to_additional_surgery_metastatic_procedure', 'followup_reason',
#        'new_tumor_event_surgery'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['last_contact_days_to', 'death_days_to', 'new_tumor_event_dx_days_to',
#        'days_to_additional_surgery_metastatic_procedure'],
#       dtype='object')
#
# TXT file ../datasets/clinical_data/415848eb-7256-474f-9c80-ecdfec0f0a9d/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/415848eb-7256-474f-9c80-ecdfec0f0a9d/logs/nationwidechildrens.org_omf.TCGA-AO-A0JI.xml.parcel: IntervalTree([Interval(0, 10738, {'md5sum': '2404993a2443a2d1d91c9dc62f5cc204'})])
#
# TXT file ../datasets/clinical_data/4803d618-4362-4b22-9a5a-7ec35d7660a3/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/4803d618-4362-4b22-9a5a-7ec35d7660a3/logs/nationwidechildrens.org_clinical.TCGA-A8-A06T.xml.parcel: IntervalTree([Interval(0, 56361, {'md5sum': '8b615d46c71495df646676f285392c1b'})])
#
# TXT file ../datasets/clinical_data/5add419d-9a4b-4e30-bbb2-d1d15ef4c919/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/5add419d-9a4b-4e30-bbb2-d1d15ef4c919/logs/nationwidechildrens.org_clinical.TCGA-A8-A06U.xml.parcel: IntervalTree([Interval(0, 50483, {'md5sum': '663e5fed7462f7d8d7b2ff55d5c16aae'})])
#
# TXT file ../datasets/clinical_data/5c475a60-856c-4fab-8939-b5ed38ebab96/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/5c475a60-856c-4fab-8939-b5ed38ebab96/logs/nationwidechildrens.org_omf.TCGA-A8-A08F.xml.parcel: IntervalTree([Interval(0, 11052, {'md5sum': 'a756132f8993731938463556f278ea93'})])
#
# TXT file ../datasets/clinical_data/628b9155-834a-4a30-964a-d424a01f07b2/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/628b9155-834a-4a30-964a-d424a01f07b2/logs/nationwidechildrens.org_clinical.TCGA-D8-A146.xml.parcel: IntervalTree([Interval(0, 51379, {'md5sum': 'a4a29463713f486d9e287680eef2d619'})])
#
# TXT file ../datasets/clinical_data/62d4515f-a30b-4b1a-b2dd-c8bf9476e803/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/62d4515f-a30b-4b1a-b2dd-c8bf9476e803/logs/nationwidechildrens.org_clinical_follow_up_v4.0_brca.txt.parcel: IntervalTree([Interval(0, 123240, {'md5sum': '002ad34525a69b2603c7947c53260b82'})])
#
# TXT file ../datasets/clinical_data/62d4515f-a30b-4b1a-b2dd-c8bf9476e803/nationwidechildrens.org_clinical_follow_up_v4.0_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_followup_barcode',
#        'bcr_followup_uuid', 'form_completion_date', 'followup_lost_to',
#        'radiation_treatment_adjuvant', 'pharmaceutical_tx_adjuvant',
#        'tumor_status', 'vital_status', 'last_contact_days_to', 'death_days_to',
#        'new_tumor_event_dx_indicator'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['last_contact_days_to', 'death_days_to'], dtype='object')
#
# TXT file ../datasets/clinical_data/65b455f3-fcfb-4e50-95d8-7c513d94f0a6/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/65b455f3-fcfb-4e50-95d8-7c513d94f0a6/logs/nationwidechildrens.org_omf.TCGA-A7-A0CD.xml.parcel: IntervalTree([Interval(0, 10504, {'md5sum': '5efd3fc35d262d29e6366601b5a56186'})])
#
# TXT file ../datasets/clinical_data/8162d394-8b64-4da2-9f5b-d164c54b9608/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/8162d394-8b64-4da2-9f5b-d164c54b9608/logs/nationwidechildrens.org_clinical_patient_brca.txt.parcel: IntervalTree([Interval(0, 1048576, {'md5sum': 'd2faab4ae31d0a38f59d7ba93ce571c3'}), Interval(1048576, 1700943, {'md5sum': '07046ec27d90992c5a6c9ec2305e0b04'})])
#
# TXT file ../datasets/clinical_data/8162d394-8b64-4da2-9f5b-d164c54b9608/nationwidechildrens.org_clinical_patient_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'form_completion_date',
#        'prospective_collection', 'retrospective_collection', 'birth_days_to',
#        'gender', 'menopause_status', 'race', 'ethnicity',
#        ...
#        'icd_o_3_histology', 'icd_o_3_site', 'informed_consent_verified',
#        'metastatic_tumor_indicator', 'patient_id', 'project_code',
#        'site_of_primary_tumor_other', 'stage_other', 'tissue_source_site',
#        'tumor_tissue_site'],
#       dtype='object', length=112)
# COLUMNS with 'age|year|days|case|time': Index(['birth_days_to', 'last_contact_days_to', 'death_days_to',
#        'initial_pathologic_dx_year', 'age_at_diagnosis',
#        'ajcc_pathologic_tumor_stage', 'clinical_stage',
#        'days_to_initial_pathologic_diagnosis',
#        'days_to_patient_progression_free', 'days_to_tumor_progression',
#        'stage_other'],
#       dtype='object')
#
# TXT file ../datasets/clinical_data/890c2a98-131e-426c-8435-e18626643cdb/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/890c2a98-131e-426c-8435-e18626643cdb/logs/nationwidechildrens.org_omf.TCGA-A8-A07E.xml.parcel: IntervalTree([Interval(0, 11044, {'md5sum': 'c13ba4b1492dacd91d9cd3d97214f1b5'})])
#
# TXT file ../datasets/clinical_data/8e004ced-76ea-4bdf-a100-9b6509158a7c/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/8e004ced-76ea-4bdf-a100-9b6509158a7c/logs/nationwidechildrens.org_omf.TCGA-A8-A08S.xml.parcel: IntervalTree([Interval(0, 10918, {'md5sum': '54bfc34325f35c9583002f350997a407'})])
#
# TXT file ../datasets/clinical_data/96e2aca8-1198-4f2a-af07-470f57bc0da8/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/96e2aca8-1198-4f2a-af07-470f57bc0da8/logs/nationwidechildrens.org_clinical.TCGA-C8-A1HI.xml.parcel: IntervalTree([Interval(0, 50875, {'md5sum': '2bc2efcd7253f7d2325b41dc61f9bc6c'})])
#
# TXT file ../datasets/clinical_data/96e4600f-a92a-4b35-b6d7-5f11f27d9a4b/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/96e4600f-a92a-4b35-b6d7-5f11f27d9a4b/logs/nationwidechildrens.org_clinical.TCGA-A8-A091.xml.parcel: IntervalTree([Interval(0, 96014, {'md5sum': '49a748abd53e38689f74c894907e2468'})])
#
# TXT file ../datasets/clinical_data/a88c168e-4bba-4bd2-9c0c-77934444cc1c/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/a88c168e-4bba-4bd2-9c0c-77934444cc1c/logs/nationwidechildrens.org_clinical_nte_brca.txt.parcel: IntervalTree([Interval(0, 69088, {'md5sum': '4ab1b571056283419be174ab1e1f875a'})])
#
# TXT file ../datasets/clinical_data/a88c168e-4bba-4bd2-9c0c-77934444cc1c/nationwidechildrens.org_clinical_nte_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'new_tumor_event_type',
#        'new_tumor_event_site', 'new_tumor_event_site_other',
#        'new_tumor_event_dx_days_to', 'new_tumor_event_surgery',
#        'new_tumor_event_surgery_days_to', 'new_tumor_event_radiation_tx',
#        'new_tumor_event_pharmaceutical_tx', 'nte_er_status',
#        'nte_er_status_ihc__positive', 'nte_er_positivity_scale_used',
#        'nte_er_ihc_intensity_score', 'nte_er_positivity_other_scale',
#        'nte_er_positivity_define_method', 'nte_pr_status_by_ihc',
#        'nte_pr_status_ihc__positive', 'nte_pr_positivity_scale_used',
#        'nte_pr_ihc_intensity_score', 'nte_pr_positivity_other_scale',
#        'nte_pr_positivity_define_method', 'nte_her2_status',
#        'nte_her2_status_ihc__positive', 'nte_her2_positivity_ihc_score',
#        'nte_her2_positivity_other_scale', 'nte_her2_positivity_method',
#        'nte_her2_fish_status', 'nte_her2_signal_number',
#        'nte_cent_17_signal_number', 'her2_cent17_counted_cells_count',
#        'nte_cent_17_her2_ratio', 'nte_cent17_her2_other_scale',
#        'nte_her2_fish_define_method'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['new_tumor_event_dx_days_to', 'new_tumor_event_surgery_days_to'], dtype='object')
#
# TXT file ../datasets/clinical_data/a9baecf0-5549-4396-8805-a6d1681d11cd/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/a9baecf0-5549-4396-8805-a6d1681d11cd/logs/nationwidechildrens.org_clinical_follow_up_v4.0_nte_brca.txt.parcel: IntervalTree([Interval(0, 47061, {'md5sum': '0ac1c35b77b9278e95086c124808c759'})])
#
# TXT file ../datasets/clinical_data/a9baecf0-5549-4396-8805-a6d1681d11cd/nationwidechildrens.org_clinical_follow_up_v4.0_nte_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_followup_barcode',
#        'new_tumor_event_type', 'new_tumor_event_site',
#        'new_tumor_event_site_other', 'new_tumor_event_dx_days_to',
#        'new_tumor_event_surgery', 'new_tumor_event_surgery_days_to',
#        'new_tumor_event_radiation_tx', 'new_tumor_event_pharmaceutical_tx',
#        'nte_er_status', 'nte_er_status_ihc__positive',
#        'nte_er_positivity_scale_used', 'nte_er_ihc_intensity_score',
#        'nte_er_positivity_other_scale', 'nte_er_positivity_define_method',
#        'nte_pr_status_by_ihc', 'nte_pr_status_ihc__positive',
#        'nte_pr_positivity_scale_used', 'nte_pr_ihc_intensity_score',
#        'nte_pr_positivity_other_scale', 'nte_pr_positivity_define_method',
#        'nte_her2_status', 'nte_her2_status_ihc__positive',
#        'nte_her2_positivity_ihc_score', 'nte_her2_positivity_other_scale',
#        'nte_her2_positivity_method', 'nte_her2_fish_status',
#        'nte_her2_signal_number', 'nte_cent_17_signal_number',
#        'her2_cent17_counted_cells_count', 'nte_cent_17_her2_ratio',
#        'nte_cent17_her2_other_scale', 'nte_her2_fish_define_method'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['new_tumor_event_dx_days_to', 'new_tumor_event_surgery_days_to'], dtype='object')
#
# TXT file ../datasets/clinical_data/aaaf9a89-4783-4355-abaa-1d3dd412cc0f/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/aaaf9a89-4783-4355-abaa-1d3dd412cc0f/logs/nationwidechildrens.org_omf.TCGA-AQ-A0Y5.xml.parcel: IntervalTree([Interval(0, 10637, {'md5sum': '80edda7e76044c4f08bf5a6715049cfe'})])
#
# TXT file ../datasets/clinical_data/aaff8f3d-916c-4510-8ee2-693ca7178b65/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/aaff8f3d-916c-4510-8ee2-693ca7178b65/logs/nationwidechildrens.org_omf.TCGA-BH-A0B6.xml.parcel: IntervalTree([Interval(0, 11502, {'md5sum': 'a59545f8fb873b7072bd783c8ac90adc'})])
#
# TXT file ../datasets/clinical_data/b2235f20-5387-4548-b6d0-7d092d60bf83/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/b2235f20-5387-4548-b6d0-7d092d60bf83/logs/nationwidechildrens.org_omf.TCGA-A8-A09C.xml.parcel: IntervalTree([Interval(0, 11048, {'md5sum': '61020b3f587e1f328cd5adec97ad0da3'})])
#
# TXT file ../datasets/clinical_data/b6e8df85-fcd5-47e3-b2aa-13894cbc4326/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/b6e8df85-fcd5-47e3-b2aa-13894cbc4326/logs/nationwidechildrens.org_omf.TCGA-A8-A09E.xml.parcel: IntervalTree([Interval(0, 11047, {'md5sum': 'b18ce6333400d26c6a505a24ff7ac02f'})])
#
# TXT file ../datasets/clinical_data/b74b115b-1a48-4dad-a219-d5f5c76d9bbd/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/b74b115b-1a48-4dad-a219-d5f5c76d9bbd/logs/nationwidechildrens.org_omf.TCGA-A8-A093.xml.parcel: IntervalTree([Interval(0, 11054, {'md5sum': '2df98d1ebb04c90e9adb34cc53146f51'})])
#
# TXT file ../datasets/clinical_data/c0ab956b-762c-42c5-94cd-f6f7e2fcd6b3/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/c0ab956b-762c-42c5-94cd-f6f7e2fcd6b3/logs/nationwidechildrens.org_omf.TCGA-A8-A09I.xml.parcel: IntervalTree([Interval(0, 11044, {'md5sum': 'f0b16fddd817de29524866c691200422'})])
#
# TXT file ../datasets/clinical_data/cae7b60a-b248-46b2-b2c4-0a6892c2538c/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/cae7b60a-b248-46b2-b2c4-0a6892c2538c/logs/nationwidechildrens.org_omf.TCGA-A8-A084.xml.parcel: IntervalTree([Interval(0, 11053, {'md5sum': '63c0a5c9c10b9e4a182147007ff032c2'})])
#
# TXT file ../datasets/clinical_data/cd7890a5-76f8-479d-9298-fda762a15701/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/cd7890a5-76f8-479d-9298-fda762a15701/logs/nationwidechildrens.org_omf.TCGA-A8-A06T.xml.parcel: IntervalTree([Interval(0, 11044, {'md5sum': 'e7dc277294969220f453d63799f9faad'})])
#
# TXT file ../datasets/clinical_data/cead5fdd-c93c-4ee0-8ff3-e67af6c2371d/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/cead5fdd-c93c-4ee0-8ff3-e67af6c2371d/logs/nationwidechildrens.org_clinical.TCGA-A8-A09K.xml.parcel: IntervalTree([Interval(0, 50589, {'md5sum': '41f1fe7d07c26e56d5c1de3398c0eed3'})])
#
# TXT file ../datasets/clinical_data/d8acba39-2bfe-434c-b970-3c2661caff50/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/d8acba39-2bfe-434c-b970-3c2661caff50/logs/nationwidechildrens.org_clinical.TCGA-A8-A07E.xml.parcel: IntervalTree([Interval(0, 56404, {'md5sum': 'bdb52c5173590feea04457af538dd194'})])
#
# TXT file ../datasets/clinical_data/df77ffad-282d-41f6-84f0-6b4f759369df/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/df77ffad-282d-41f6-84f0-6b4f759369df/logs/nationwidechildrens.org_clinical.TCGA-A8-A093.xml.parcel: IntervalTree([Interval(0, 61092, {'md5sum': 'a393766e8f44b7a66b3ea4a235818084'})])
#
# TXT file ../datasets/clinical_data/dfc14560-ce1a-4d7f-9b03-6777d9ee725a/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/dfc14560-ce1a-4d7f-9b03-6777d9ee725a/logs/nationwidechildrens.org_omf.TCGA-A8-A091.xml.parcel: IntervalTree([Interval(0, 10990, {'md5sum': '12ef878ccffe412bc3cd361792116781'})])
#
# TXT file ../datasets/clinical_data/e094828e-082a-4da2-9a66-f1172af28288/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/e094828e-082a-4da2-9a66-f1172af28288/logs/nationwidechildrens.org_omf.TCGA-D8-A146.xml.parcel: IntervalTree([Interval(0, 11485, {'md5sum': '62f72160edaa2b381f0742a2c0050152'})])
#
# TXT file ../datasets/clinical_data/e0ed562e-858c-4721-9042-1e108109ea55/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/e0ed562e-858c-4721-9042-1e108109ea55/logs/nationwidechildrens.org_clinical.TCGA-A8-A09C.xml.parcel: IntervalTree([Interval(0, 36233, {'md5sum': '61275107a2211abb622394e8ce8c4704'})])
#
# TXT file ../datasets/clinical_data/e4c81b57-c83e-42f9-bb78-5fc8bbc62658/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/e4c81b57-c83e-42f9-bb78-5fc8bbc62658/logs/nationwidechildrens.org_clinical.TCGA-A8-A09I.xml.parcel: IntervalTree([Interval(0, 56411, {'md5sum': 'fe8a21189e82d9b49bf85d1678145d0c'})])
#
# TXT file ../datasets/clinical_data/e5c572f7-b378-4cfc-8f2c-548e21175d78/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/e5c572f7-b378-4cfc-8f2c-548e21175d78/logs/nationwidechildrens.org_clinical.TCGA-C8-A1HO.xml.parcel: IntervalTree([Interval(0, 68381, {'md5sum': 'd4714af4cae136726df59a92fbddc089'})])
#
# TXT file ../datasets/clinical_data/e74ed9f5-6b70-482c-b5ee-96837fa81f38/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/e74ed9f5-6b70-482c-b5ee-96837fa81f38/logs/nationwidechildrens.org_clinical.TCGA-AQ-A0Y5.xml.parcel: IntervalTree([Interval(0, 74766, {'md5sum': '47f4a23517dd4b4ab025f5027abc9a7e'})])
#
# TXT file ../datasets/clinical_data/eef0c424-f02b-4fe6-a881-0bd68b8ee216/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/eef0c424-f02b-4fe6-a881-0bd68b8ee216/logs/nationwidechildrens.org_clinical.TCGA-A8-A084.xml.parcel: IntervalTree([Interval(0, 55070, {'md5sum': '88ad121b4b34428b39b865fa65f15539'})])
#
# TXT file ../datasets/clinical_data/f434b393-9e32-4ca2-aa1a-3b0de36b5ffe/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/f434b393-9e32-4ca2-aa1a-3b0de36b5ffe/logs/nationwidechildrens.org_clinical_omf_v4.0_brca.txt.parcel: IntervalTree([Interval(0, 39381, {'md5sum': '4f6606f6b12f952e0339a40396cd7c92'})])
#
# TXT file ../datasets/clinical_data/f434b393-9e32-4ca2-aa1a-3b0de36b5ffe/nationwidechildrens.org_clinical_omf_v4.0_brca.txt.
# COLUMNS: Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_omf_barcode',
#        'bcr_omf_uuid', 'form_completion_date', 'malignancy_type',
#        'other_malignancy_dx_days_to', 'surgery_indicator',
#        'other_malignancy_surgery_type', 'other_malignancy_surgery_days_to',
#        'pharmaceutical_therapy_indicator', 'pharmaceutical_therapy_extent',
#        'pharmaceutical_therapy_drug_name', 'pharmaceutical_tx_started_days_to',
#        'radiation_therapy_indicator', 'radiation_therapy_extent',
#        'history_rt_tx_to_site_of_tcga_tumor',
#        'radiation_therapy_started_days_to', 'ajcc_staging_edition',
#        'ajcc_tumor_pathologic_pt', 'ajcc_nodes_pathologic_pn',
#        'ajcc_metastasis_pathologic_pm', 'ajcc_pathologic_tumor_stage',
#        'clinical_stage', 'other_malignancy_anatomic_site',
#        'other_malignancy_anatomic_site_text',
#        'other_malignancy_histological_type',
#        'other_malignancy_histological_type_text',
#        'other_malignancy_laterality', 'stage_other'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['other_malignancy_dx_days_to', 'other_malignancy_surgery_days_to',
#        'pharmaceutical_tx_started_days_to',
#        'radiation_therapy_started_days_to', 'ajcc_pathologic_tumor_stage',
#        'clinical_stage', 'stage_other'],
#       dtype='object')
#
# TXT file ../datasets/clinical_data/fcda6113-b7a5-4504-a4a4-c204bbf95402/annotations.txt.
# COLUMNS: Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#        'classification', 'created_datetime', 'status', 'notes'],
#       dtype='object')
# COLUMNS with 'age|year|days|case|time': Index(['created_datetime'], dtype='object')
#
# File TXT PARCEL ../datasets/clinical_data/fcda6113-b7a5-4504-a4a4-c204bbf95402/logs/nationwidechildrens.org_clinical.TCGA-A2-A0YT.xml.parcel: IntervalTree([Interval(0, 62088, {'md5sum': '1bad711cda0e80562749634e250e6fa1'})])
# 9

# %% [markdown]
# **Structures of files discarded for our analysis:**
# - Annotations TXT files.
#     - COLUMNS: `Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#            'classification', 'created_datetime', 'status', 'notes'],
#           dtype='object')`
#     - COLUMNS with 'age|year|days|case': `Index(['id', 'submitter_id', 'entity_type', 'entity_id', 'category',
#            'classification', 'created_datetime', 'status', 'notes'],
#           dtype='object')`
# - org_clinical_omf_v4 TXT files.
#     - COLUMNS: `Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_omf_barcode',
#            'bcr_omf_uuid', 'form_completion_date', 'malignancy_type',
#            'other_malignancy_dx_days_to', 'surgery_indicator',
#            'other_malignancy_surgery_type', 'other_malignancy_surgery_days_to',
#            'pharmaceutical_therapy_indicator', 'pharmaceutical_therapy_extent',
#            'pharmaceutical_therapy_drug_name', 'pharmaceutical_tx_started_days_to',
#            'radiation_therapy_indicator', 'radiation_therapy_extent',
#            'history_rt_tx_to_site_of_tcga_tumor',
#            'radiation_therapy_started_days_to', 'ajcc_staging_edition',
#            'ajcc_tumor_pathologic_pt', 'ajcc_nodes_pathologic_pn',
#            'ajcc_metastasis_pathologic_pm', 'ajcc_pathologic_tumor_stage',
#            'clinical_stage', 'other_malignancy_anatomic_site',
#            'other_malignancy_anatomic_site_text',
#            'other_malignancy_histological_type',
#            'other_malignancy_histological_type_text',
#            'other_malignancy_laterality', 'stage_other'],
#           dtype='object')`
#     - COLUMNS with 'age|year|days|case': `Index(['other_malignancy_dx_days_to', 'other_malignancy_surgery_days_to',
#        'pharmaceutical_tx_started_days_to', 'radiation_therapy_started_days_to', 'ajcc_pathologic_tumor_stage',
#        'clinical_stage', 'stage_other'],
#       dtype='object')`
# - org_clinical_follow_up_v* TXT files:
#     - COLUMNS: `Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_followup_barcode',
#        'bcr_followup_uuid', 'form_completion_date',
#        'radiation_treatment_adjuvant', 'pharmaceutical_tx_adjuvant',
#        'tumor_status', 'vital_status', 'last_contact_days_to', 'death_days_to',
#        'new_tumor_event_dx_indicator', 'new_tumor_event_type',
#        'new_tumor_event_site', 'new_tumor_event_site_other', 'new_tumor_event_dx_days_to', 'new_tumor_event_radiation_tx',
#        'new_tumor_event_pharmaceutical_tx', 'new_tumor_event_surgery_days_to', 'nte_er_status',
#        'nte_er_status_ihc__positive', 'nte_er_positivity_scale_used', 'nte_er_ihc_intensity_score', 'nte_pr_positivity_scale_used'
#        'nte_er_positivity_other_scale', 'nte_er_positivity_define_method',
#        'nte_pr_status_by_ihc', 'nte_pr_status_ihc__positive',
#        'nte_pr_ihc_intensity_score', 'nte_pr_positivity_other_scale',
#        'nte_pr_positivity_define_method', 'nte_her2_status',
#        'nte_her2_status_ihc__positive', 'nte_her2_positivity_ihc_score',
#        'nte_her2_positivity_other_scale', 'nte_her2_positivity_method',
#        'nte_her2_fish_status', 'nte_her2_signal_number',
#        'nte_cent_17_signal_number', 'her2_cent17_counted_cells_count',
#        'nte_cent_17_her2_ratio', 'nte_cent17_her2_other_scale',
#        'nte_her2_fish_define_method', 'cent17_copy_number',
#        'days_to_additional_surgery_locoregional_procedure',
#        'days_to_additional_surgery_metastatic_procedure',
#        'days_to_last_known_alive', 'er_ihc_score', 'er_positivity_method',
#        'er_positivity_scale_other', 'er_status_by_ihc',
#        'er_status_ihc_Percent_Positive', 'her2_and_cent17_cells_count',
#        'her2_and_cent17_scale_other', 'her2_cent17_ratio', 'her2_copy_number',
#        'her2_fish_method', 'her2_fish_status', 'her2_ihc_percent_positive',
#        'her2_ihc_score', 'her2_positivity_method_text',
#        'her2_positivity_scale_other', 'her2_status_by_ihc',
#        'new_tumor_event_surgery', 'new_tumor_event_surgery_met',
#        'pr_positivity_define_method', 'pr_positivity_ihc_intensity_score',
#        'pr_positivity_scale_other', 'pr_status_by_ihc',
#        'pr_status_ihc_percent_positive', 'followup_reason'],
#       dtype='object')`
#     - COLUMNS with 'age|year|days|case': `Index(['last_contact_days_to', 'death_days_to', 'new_tumor_event_dx_days_to',
#        'days_to_additional_surgery_locoregional_procedure',
#        'days_to_additional_surgery_metastatic_procedure',
#        'days_to_last_known_alive'],
#       dtype='object')`
# - org_clinical_radiation_brca TXT files:
#     - COLUMNS: `Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_radiation_barcode',
#        'bcr_radiation_uuid', 'form_completion_date', 'radiation_therapy_type',
#        'radiation_therapy_site', 'radiation_total_dose',
#        'radiation_adjuvant_units', 'radiation_adjuvant_fractions_total',
#        'radiation_therapy_started_days_to',
#        'radiation_therapy_ongoing_indicator',
#        'radiation_therapy_ended_days_to', 'treatment_best_response',
#        'course_number', 'radiation_type_other', 'therapy_regimen',
#        'therapy_regimen_other'],
#       dtype='object')`
#     - COLUMNS with 'age|year|days|case': `Index(['radiation_therapy_started_days_to', 'radiation_therapy_ended_days_to'], dtype='object')`
# - org_clinical_drug_brca TXT files:
#     - COLUMNS: `Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'bcr_drug_barcode',
#        'bcr_drug_uuid', 'form_completion_date',
#        'pharmaceutical_therapy_drug_name',
#        'clinical_trial_drug_classification', 'pharmaceutical_therapy_type',
#        'pharmaceutical_tx_started_days_to',
#        'pharmaceutical_tx_ongoing_indicator',
#        'pharmaceutical_tx_ended_days_to', 'treatment_best_response',
#        'days_to_stem_cell_transplantation', 'pharm_regimen',
#        'pharm_regimen_other', 'pharma_adjuvant_cycles_count',
#        'pharma_type_other', 'pharmaceutical_tx_dose_units',
#        'pharmaceutical_tx_total_dose_units', 'prescribed_dose',
#        'regimen_number', 'route_of_administration',
#        'stem_cell_transplantation', 'stem_cell_transplantation_type',
#        'therapy_regimen', 'therapy_regimen_other', 'total_dose',
#        'tx_on_clinical_trial'],
#       dtype='object')`
#     - COLUMNS with 'age|year|days|case': `Index(['pharmaceutical_tx_started_days_to', 'pharmaceutical_tx_ended_days_to',
#        'days_to_stem_cell_transplantation'],
#       dtype='object')`
# - org_clinical_patient|nte_brca TXT files:
#     - COLUMNS:  `Index([
#         'bcr_patient_uuid', 'bcr_patient_barcode', 'new_tumor_event_type',
#         'new_tumor_event_site', 'new_tumor_event_site_other',
#         'new_tumor_event_dx_days_to', 'new_tumor_event_surgery',
#         'new_tumor_event_surgery_days_to', 'new_tumor_event_radiation_tx',
#         'new_tumor_event_pharmaceutical_tx', 'nte_er_status',
#         'nte_er_status_ihc__positive', 'nte_er_positivity_scale_used',
#         'nte_er_ihc_intensity_score', 'nte_er_positivity_other_scale',
#         'nte_er_positivity_define_method', 'nte_pr_status_by_ihc',
#         'nte_pr_status_ihc__positive', 'nte_pr_positivity_scale_used',
#         'nte_pr_ihc_intensity_score', 'nte_pr_positivity_other_scale',
#         'nte_pr_positivity_define_method', 'nte_her2_status',
#         'nte_her2_status_ihc__positive', 'nte_her2_positivity_ihc_score',
#         'nte_her2_positivity_other_scale', 'nte_her2_positivity_method',
#         'nte_her2_fish_status', 'nte_her2_signal_number',
#         'nte_cent_17_signal_number', 'her2_cent17_counted_cells_count',
#         'nte_cent_17_her2_ratio', 'nte_cent17_her2_other_scale',
#         'nte_her2_fish_define_method'
#     ], dtype='object')`
#     - COLUMNS with 'age|year|days|case|time': `Index([
#             'new_tumor_event_dx_days_to',
#             'new_tumor_event_surgery_days_to'
#         ], dtype='object')`
# - org_* TXT PARCEL files: `IntervalTree([Interval(0, 62088, {'md5sum': '1bad711cda0e80562749634e250e6fa1'})])`

# %% [markdown]
# ## Count clinical XML files:

# %%
def import_xml(file_path):
    df = pd.read_xml(file_path, parser="etree")
    if 'days_to_birth' in df.columns and 'age_at_initial_pathologic_diagnosis' in df.columns:
        print(f"File {file_path}: OK.")
        return 0
    else:
        print(f"File {file_path}: Not contains required columns.")
        return 1

subfolders_count = 0
count_xml=0
count_txt=0
count_no=0
count_xml_omf = 0
for subfolder in os.listdir(CLINICAL_PATH):
    subfolders_count += 1
    for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
        if file.endswith(".xml"):
            count_xml += 1
            count_xml_omf += import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
        elif file == "annotations.txt":
            pass
        elif file.endswith(".txt"):
            count_txt += 1
            #import_txt(f"{CLINICAL_PATH}/{subfolder}/{file}")
        else:
            count_no += 1

print("\n------------------------------------------------")
print(f"-> Number of xml files found: {count_xml}")
print(f"\t-> Number of 'omf' xml files found: {count_xml_omf}")
print(f"-> Number of txt files found: {count_txt}")
print(f"-> Number of non-xml and non-txt files found: {count_no}")
print(f"-> Total subfolders: {subfolders_count}")
print("------------------------------------------------")
# Out:
# File ../datasets/clinical_data/00049989-fa21-48fb-8dda-710c0dd5932e/nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml: OK.
# File ../datasets/clinical_data/004b6bd4-19d0-4b40-99ef-1a76313fe7a5/nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml: OK.
# File ../datasets/clinical_data/00a5e81c-cd67-483f-9d99-3c733b2ead38/nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml: OK.
# File ../datasets/clinical_data/014f5ae1-5862-4165-9a3b-bba7bb08a527/nationwidechildrens.org_clinical.TCGA-C8-A12P.xml: OK.
# File ../datasets/clinical_data/01a962ea-a87f-49fa-9a27-7273a39f64a9/nationwidechildrens.org_clinical.TCGA-S3-A6ZF.xml: OK.
# File ../datasets/clinical_data/021d8f80-3db0-4f60-b404-a71e115102ca/nationwidechildrens.org_clinical.TCGA-BH-A18K.xml: OK.
# File ../datasets/clinical_data/024bde93-ff69-4d1f-b301-c053e8c594f5/nationwidechildrens.org_omf.TCGA-A1-A0SP.xml: Not contains required columns.
# File ../datasets/clinical_data/02726df0-5db3-4b3d-a3ca-8a1d8a0e130e/nationwidechildrens.org_clinical.TCGA-AN-A0FW.xml: OK.
# File ../datasets/clinical_data/02865683-19cc-4600-be9b-555c34c20db3/nationwidechildrens.org_clinical.TCGA-D8-A140.xml: OK.
# File ../datasets/clinical_data/02c43433-d777-4ec7-adf8-74defc7c8a24/nationwidechildrens.org_clinical.TCGA-E2-A14R.xml: OK.
# File ../datasets/clinical_data/032c6c78-a0f7-4695-a93e-3f42747353a8/nationwidechildrens.org_clinical.TCGA-A8-A08C.xml: OK.
# File ../datasets/clinical_data/0382de14-79b0-4fdc-bf14-d82494cbcdee/nationwidechildrens.org_clinical.TCGA-AN-A0FF.xml: OK.
# File ../datasets/clinical_data/03ce4d08-2d3e-4c38-892d-d22b37eb9ad5/nationwidechildrens.org_clinical.TCGA-D8-A27N.xml: OK.
# File ../datasets/clinical_data/03d2bd6f-1bb3-42b4-8ab9-823682084a1b/nationwidechildrens.org_clinical.TCGA-D8-A1X5.xml: OK.
# File ../datasets/clinical_data/04b8884d-ffa3-486e-84b7-681c51bb259e/nationwidechildrens.org_clinical.TCGA-AR-A0TT.xml: OK.
# File ../datasets/clinical_data/051ca785-e7be-4ac3-8757-1c9ace8acf7e/nationwidechildrens.org_clinical.TCGA-A8-A08F.xml: OK.
# File ../datasets/clinical_data/069ecadf-de19-4bf6-9765-e9aa8471ecd1/nationwidechildrens.org_clinical.TCGA-D8-A1XG.xml: OK.
# File ../datasets/clinical_data/07442715-1af6-42b0-801b-84fc7d01c1a0/nationwidechildrens.org_clinical.TCGA-C8-A1HG.xml: OK.
# File ../datasets/clinical_data/07488c2c-c50f-402e-8f22-9278db6110f9/nationwidechildrens.org_clinical.TCGA-AO-A0JI.xml: OK.
# File ../datasets/clinical_data/07534899-1a59-4411-b189-64c1c85f4618/nationwidechildrens.org_clinical.TCGA-LL-A73Z.xml: OK.
# File ../datasets/clinical_data/075b0201-49ad-4a23-a107-0b39fd475a5b/nationwidechildrens.org_clinical.TCGA-AC-A62V.xml: OK.
# File ../datasets/clinical_data/078a3061-8dbe-4dfa-834d-180e7f9baf57/nationwidechildrens.org_clinical.TCGA-E2-A1LL.xml: OK.
# File ../datasets/clinical_data/07eb1823-a8c0-4b38-9a71-25516b012527/nationwidechildrens.org_clinical.TCGA-EW-A1PC.xml: OK.
# File ../datasets/clinical_data/0827791a-bb0a-4a3a-98c4-26312d8880f8/nationwidechildrens.org_clinical.TCGA-AQ-A04H.xml: OK.
# File ../datasets/clinical_data/084c3393-0480-4971-ab7d-d0e8b68b26b5/nationwidechildrens.org_clinical.TCGA-AR-A251.xml: OK.
# File ../datasets/clinical_data/085b8344-828f-49a5-9d60-f2cb30de38f2/nationwidechildrens.org_clinical.TCGA-BH-A0AZ.xml: OK.
# File ../datasets/clinical_data/08770acd-4a5f-41e9-bc03-1dd153470903/nationwidechildrens.org_clinical.TCGA-E9-A245.xml: OK.
# File ../datasets/clinical_data/09216d66-84b9-47ae-82fb-0ab3a2de7ffd/nationwidechildrens.org_clinical.TCGA-BH-A0BQ.xml: OK.
# File ../datasets/clinical_data/09ced32a-4a6e-4e5f-ba75-1531cf3a64bc/nationwidechildrens.org_clinical.TCGA-A8-A09N.xml: OK.
# File ../datasets/clinical_data/0a9561ad-0d8e-4776-be26-c9d7b2825045/nationwidechildrens.org_clinical.TCGA-B6-A0IG.xml: OK.
# File ../datasets/clinical_data/0b2ccc49-bc42-498d-bf21-752f99c3d160/nationwidechildrens.org_omf.TCGA-LL-A5YP.xml: Not contains required columns.
# File ../datasets/clinical_data/0b49c0d2-ac97-4446-aeff-f756ec145b8e/nationwidechildrens.org_clinical.TCGA-AR-A0TV.xml: OK.
# File ../datasets/clinical_data/0c5baab4-37cb-48c6-88d8-56be866d8632/nationwidechildrens.org_clinical.TCGA-AR-A24P.xml: OK.
# File ../datasets/clinical_data/0c75afc8-dba8-436e-b467-21b987cb63f7/nationwidechildrens.org_clinical.TCGA-EW-A1IZ.xml: OK.
# File ../datasets/clinical_data/0cc3d450-2c60-4cb0-a073-d92dc979fa5e/nationwidechildrens.org_clinical.TCGA-BH-A18F.xml: OK.
# File ../datasets/clinical_data/0d37a02a-252e-49dd-84ef-51c9d06ec43d/nationwidechildrens.org_clinical.TCGA-A7-A26H.xml: OK.
# File ../datasets/clinical_data/0da89962-24e4-4dba-abce-854ab68843a1/nationwidechildrens.org_clinical.TCGA-AN-A0FZ.xml: OK.
# File ../datasets/clinical_data/0e5052c4-7eca-427e-9a3b-dc22bbd01be4/nationwidechildrens.org_clinical.TCGA-A7-A4SD.xml: OK.
# File ../datasets/clinical_data/0e54604a-78f9-4db3-81d7-3067e5612386/nationwidechildrens.org_clinical.TCGA-A2-A0T7.xml: OK.
# File ../datasets/clinical_data/0e58f96c-b1ba-4f93-aac2-6e0970d40067/nationwidechildrens.org_clinical.TCGA-BH-A0B1.xml: OK.
# File ../datasets/clinical_data/0e8af3a0-b315-4cd4-8b7f-646f8fdbbf0e/nationwidechildrens.org_clinical.TCGA-E2-A152.xml: OK.
# File ../datasets/clinical_data/0e8e300e-a64a-4563-97eb-a3a6bc3f3b3b/nationwidechildrens.org_clinical.TCGA-A8-A097.xml: OK.
# File ../datasets/clinical_data/0ecfe554-fdc5-41f3-b287-66080d24d1bd/nationwidechildrens.org_clinical.TCGA-BH-A1ET.xml: OK.
# File ../datasets/clinical_data/0f699751-7c08-4f0a-8d07-3b125e9c4f99/nationwidechildrens.org_clinical.TCGA-E9-A22G.xml: OK.
# File ../datasets/clinical_data/0fca54d0-a1f4-47f8-87f6-e17dd98fbf6b/nationwidechildrens.org_clinical.TCGA-GI-A2C8.xml: OK.
# File ../datasets/clinical_data/100659db-c917-4318-ab86-192cc46a32f3/nationwidechildrens.org_omf.TCGA-A7-A26I.xml: Not contains required columns.
# File ../datasets/clinical_data/1018f55a-a983-4756-9a68-ed3ce0c8e284/nationwidechildrens.org_clinical.TCGA-AC-A7VB.xml: OK.
# File ../datasets/clinical_data/10234dc5-0f34-40fd-9a21-acee9987bb78/nationwidechildrens.org_clinical.TCGA-A2-A0T1.xml: OK.
# File ../datasets/clinical_data/1035134a-5bc0-4cfd-9f15-f2563e451144/nationwidechildrens.org_clinical.TCGA-OL-A5RW.xml: OK.
# File ../datasets/clinical_data/103f2e49-b028-424f-9185-44d008ef1b1b/nationwidechildrens.org_clinical.TCGA-AR-A1AJ.xml: OK.
# File ../datasets/clinical_data/1057d0b1-d929-48f7-997c-65324a4ee9f7/nationwidechildrens.org_clinical.TCGA-E9-A243.xml: OK.
# File ../datasets/clinical_data/10fd353c-239d-4e87-813c-7245cfbeddc2/nationwidechildrens.org_clinical.TCGA-D8-A1JA.xml: OK.
# File ../datasets/clinical_data/1167479b-cd13-4a86-bc1a-319439153270/nationwidechildrens.org_clinical.TCGA-A8-A07G.xml: OK.
# File ../datasets/clinical_data/11aa9e0c-8812-475a-938d-2829d5f3432f/nationwidechildrens.org_clinical.TCGA-E2-A10B.xml: OK.
# File ../datasets/clinical_data/11f5c13a-2193-4c63-8135-5cb0aa3398bc/nationwidechildrens.org_clinical.TCGA-AR-A24U.xml: OK.
# File ../datasets/clinical_data/1208942c-b692-4e29-80a7-a9bf061ca4fb/nationwidechildrens.org_omf.TCGA-BH-A1F5.xml: Not contains required columns.
# File ../datasets/clinical_data/123e9a10-e02f-4d1b-bf84-c44cc054543e/nationwidechildrens.org_clinical.TCGA-E2-A15K.xml: OK.
# File ../datasets/clinical_data/12b473aa-57f7-4801-8d3b-d486894a8784/nationwidechildrens.org_clinical.TCGA-A7-A4SE.xml: OK.
# File ../datasets/clinical_data/135bfbe6-2402-46ff-8e36-0898dc9e4d70/nationwidechildrens.org_clinical.TCGA-BH-A0DD.xml: OK.
# File ../datasets/clinical_data/137eb1a9-7bdd-401f-8405-82e777e1df17/nationwidechildrens.org_clinical.TCGA-E9-A1N8.xml: OK.
# File ../datasets/clinical_data/13dd3055-8ed0-4d0e-a133-b3ec1078f02d/nationwidechildrens.org_clinical.TCGA-A2-A0CW.xml: OK.
# File ../datasets/clinical_data/13f99438-a228-44f5-aedf-398557abc162/nationwidechildrens.org_clinical.TCGA-A7-A0DC.xml: OK.
# File ../datasets/clinical_data/14327e55-5048-4e9a-b993-a394c5ae5a80/nationwidechildrens.org_clinical.TCGA-A8-A09Q.xml: OK.
# File ../datasets/clinical_data/15325c5a-0270-4fb8-92e4-0b98028bed1b/nationwidechildrens.org_clinical.TCGA-C8-A26V.xml: OK.
# File ../datasets/clinical_data/1543a38e-723c-40fb-8087-0f78d470303d/nationwidechildrens.org_clinical.TCGA-EW-A6S9.xml: OK.
# File ../datasets/clinical_data/1657a582-7b6c-40e7-8746-0dc11993aa39/nationwidechildrens.org_clinical.TCGA-AO-A0JD.xml: OK.
# File ../datasets/clinical_data/174eca80-6a0a-4f82-a87f-d47a117f8b91/nationwidechildrens.org_clinical.TCGA-E2-A15E.xml: OK.
# File ../datasets/clinical_data/17767d08-172b-420f-ba84-dc516e6f5dce/nationwidechildrens.org_clinical.TCGA-A8-A09A.xml: OK.
# File ../datasets/clinical_data/17a19e1b-73d3-4a96-99eb-6534650ac1b8/nationwidechildrens.org_clinical.TCGA-AR-A0TZ.xml: OK.
# File ../datasets/clinical_data/1807532f-fbb2-4434-95f5-d6b1bf5573b2/nationwidechildrens.org_clinical.TCGA-E2-A15S.xml: OK.
# File ../datasets/clinical_data/18e2f8c1-331b-4ec7-8ffc-70f351ff0bf9/nationwidechildrens.org_clinical.TCGA-OL-A5RU.xml: OK.
# File ../datasets/clinical_data/18e558aa-8a10-4387-a12d-56d551b61fc0/nationwidechildrens.org_clinical.TCGA-BH-A0EB.xml: OK.
# File ../datasets/clinical_data/18e5fd45-a1ef-4fca-a883-65be5c5846ae/nationwidechildrens.org_clinical.TCGA-BH-A0HK.xml: OK.
# File ../datasets/clinical_data/19343c65-2500-465e-b8e2-502500693889/nationwidechildrens.org_clinical.TCGA-AQ-A1H3.xml: OK.
# File ../datasets/clinical_data/19ce45e5-0530-41f8-acf2-5246499a3034/nationwidechildrens.org_clinical.TCGA-LL-A5YN.xml: OK.
# File ../datasets/clinical_data/1a543ae8-3f2b-4a5b-82f3-7501b44a3fab/nationwidechildrens.org_clinical.TCGA-E2-A1LB.xml: OK.
# File ../datasets/clinical_data/1ab00e83-3ed9-4c9f-b550-ce660bc3d996/nationwidechildrens.org_clinical.TCGA-B6-A0IJ.xml: OK.
# File ../datasets/clinical_data/1b376b9f-4132-44ca-b9bd-6ef8c1facaab/nationwidechildrens.org_clinical.TCGA-E2-A14Z.xml: OK.
# File ../datasets/clinical_data/1b5bddf8-d393-478a-bab9-ab9ae515f323/nationwidechildrens.org_clinical.TCGA-AO-A0J6.xml: OK.
# File ../datasets/clinical_data/1bb1a57a-c89d-4a2d-b816-90a08bef9133/nationwidechildrens.org_clinical.TCGA-AO-A0JM.xml: OK.
# File ../datasets/clinical_data/1bb749af-4429-454d-9ab6-40db2622b6f6/nationwidechildrens.org_clinical.TCGA-E9-A1QZ.xml: OK.
# File ../datasets/clinical_data/1bd2a479-da63-4cee-a722-31570b97c254/nationwidechildrens.org_clinical.TCGA-BH-A1EY.xml: OK.
# File ../datasets/clinical_data/1be07f2a-5c32-48ff-864c-194592954533/nationwidechildrens.org_clinical.TCGA-E2-A1BD.xml: OK.
# File ../datasets/clinical_data/1bf445b0-0b0d-4ba5-884a-ff70300b8795/nationwidechildrens.org_clinical.TCGA-AR-A0U2.xml: OK.
# File ../datasets/clinical_data/1c6ae7e6-337a-4cb4-b829-c348bca29fca/nationwidechildrens.org_clinical.TCGA-UL-AAZ6.xml: OK.
# File ../datasets/clinical_data/1e12ed31-79a1-404f-a705-2b26bfde86d5/nationwidechildrens.org_clinical.TCGA-E9-A248.xml: OK.
# File ../datasets/clinical_data/1e3fc77b-4c6a-4406-a808-7d35d56cf1a1/nationwidechildrens.org_omf.TCGA-BH-A0DO.xml: Not contains required columns.
# File ../datasets/clinical_data/1f503e8a-ec3b-4b54-a592-6bf49846dc46/nationwidechildrens.org_clinical.TCGA-AO-A03N.xml: OK.
# File ../datasets/clinical_data/1fc54ff7-d1a9-41fe-882f-99cbdafe2584/nationwidechildrens.org_clinical.TCGA-A8-A099.xml: OK.
# File ../datasets/clinical_data/1fee2a62-5246-41a7-b152-2181487eb6b5/nationwidechildrens.org_clinical.TCGA-AR-A0TQ.xml: OK.
# File ../datasets/clinical_data/201f3cd0-45c1-4a9f-8e39-fc5c9466ad80/nationwidechildrens.org_clinical.TCGA-AO-A12B.xml: OK.
# File ../datasets/clinical_data/2024e5c9-257e-42a8-b365-65fe885de9fe/nationwidechildrens.org_clinical.TCGA-A2-A3XV.xml: OK.
# File ../datasets/clinical_data/2063a07c-e9a2-422c-9773-46a5fd612bf0/nationwidechildrens.org_clinical.TCGA-GM-A2DM.xml: OK.
# File ../datasets/clinical_data/20d28c3f-8a04-4473-9b8f-e6e0ab0acd07/nationwidechildrens.org_omf.TCGA-AO-A1KT.xml: Not contains required columns.
# File ../datasets/clinical_data/2103fe4e-c511-4f07-a212-8bf24cd3aa95/nationwidechildrens.org_clinical.TCGA-C8-A12N.xml: OK.
# File ../datasets/clinical_data/216c7806-954e-4624-b627-47424a578220/nationwidechildrens.org_clinical.TCGA-C8-A12V.xml: OK.
# File ../datasets/clinical_data/21b2adf9-f20f-4019-80ac-92ab47e02763/nationwidechildrens.org_clinical.TCGA-AO-A03T.xml: OK.
# File ../datasets/clinical_data/21de7b64-f5ff-46d1-bf65-fdc8f62e6b43/nationwidechildrens.org_clinical.TCGA-D8-A1X6.xml: OK.
# File ../datasets/clinical_data/21ed8c1e-72ae-4d6c-a1e6-2304c8f77c37/nationwidechildrens.org_clinical.TCGA-AR-A252.xml: OK.
# File ../datasets/clinical_data/222fe786-6d37-414e-953d-89a63aa8ba42/nationwidechildrens.org_clinical.TCGA-LL-A5YP.xml: OK.
# File ../datasets/clinical_data/2249a1c0-e6af-4550-b890-c27e0b4ae13b/nationwidechildrens.org_clinical.TCGA-A7-A6VV.xml: OK.
# File ../datasets/clinical_data/22d7447e-94b4-4748-bee7-331a5a49bc24/nationwidechildrens.org_clinical.TCGA-E2-A1L7.xml: OK.
# File ../datasets/clinical_data/23462b8f-9187-4c33-af77-9e64e874aecd/nationwidechildrens.org_clinical.TCGA-E2-A14W.xml: OK.
# File ../datasets/clinical_data/23b0cc5f-7b66-413a-8c60-2231a2c75a2b/nationwidechildrens.org_clinical.TCGA-A2-A259.xml: OK.
# File ../datasets/clinical_data/23e1288e-c1e5-4f43-b84b-29b5d34be8d1/nationwidechildrens.org_clinical.TCGA-BH-A0AY.xml: OK.
# File ../datasets/clinical_data/24166110-f793-48b5-9ad5-fd7b33fc65c5/nationwidechildrens.org_clinical.TCGA-E2-A1B1.xml: OK.
# File ../datasets/clinical_data/2438eb6e-278a-4c4a-b93d-e7fa50cb1080/nationwidechildrens.org_clinical.TCGA-EW-A1P8.xml: OK.
# File ../datasets/clinical_data/2495917b-a873-4b71-8ff3-1832fd6daba6/nationwidechildrens.org_omf.TCGA-WT-AB41.xml: Not contains required columns.
# File ../datasets/clinical_data/24cca7f0-3a2b-4e94-84f9-f735be35dcee/nationwidechildrens.org_clinical.TCGA-E2-A10A.xml: OK.
# File ../datasets/clinical_data/2552ab12-e5c6-43c0-abc3-c3a8acc41bd9/nationwidechildrens.org_clinical.TCGA-E9-A1RH.xml: OK.
# File ../datasets/clinical_data/255cf06a-010f-4a7b-8750-9bf6ae381f42/nationwidechildrens.org_clinical.TCGA-AR-A0TW.xml: OK.
# File ../datasets/clinical_data/2574d538-333c-4448-96d7-350bbba51291/nationwidechildrens.org_clinical.TCGA-A2-A0CX.xml: OK.
# File ../datasets/clinical_data/25f19634-8f54-4be7-a0f1-c2756e11fec8/nationwidechildrens.org_clinical.TCGA-A8-A09E.xml: OK.
# File ../datasets/clinical_data/25fa4fd8-d5d7-479b-98b5-b475dc1b12ee/nationwidechildrens.org_clinical.TCGA-AN-A03Y.xml: OK.
# File ../datasets/clinical_data/261cdf1f-cd92-45c7-943a-b4e4064a1fb0/nationwidechildrens.org_clinical.TCGA-E2-A15O.xml: OK.
# File ../datasets/clinical_data/26327303-c2a1-4b52-919c-d04dde40546a/nationwidechildrens.org_clinical.TCGA-GM-A2DK.xml: OK.
# File ../datasets/clinical_data/26a363bc-d900-4ac4-af5d-da7963a964cd/nationwidechildrens.org_clinical.TCGA-E2-A150.xml: OK.
# File ../datasets/clinical_data/26af84dd-84cc-44de-8008-9119e59a0bc8/nationwidechildrens.org_clinical.TCGA-A7-A26J.xml: OK.
# File ../datasets/clinical_data/26fe7667-2972-4904-bf30-e12f9d8b6a33/nationwidechildrens.org_clinical.TCGA-BH-A18L.xml: OK.
# File ../datasets/clinical_data/278440bc-d0e8-4f02-bed6-44cc5c9679dc/nationwidechildrens.org_clinical.TCGA-BH-A0BJ.xml: OK.
# File ../datasets/clinical_data/2787ef64-0e1c-43b4-91ae-b4f27069e8c1/nationwidechildrens.org_clinical.TCGA-D8-A1J9.xml: OK.
# File ../datasets/clinical_data/28266dfa-65e5-493e-afa3-b95c8e289a72/nationwidechildrens.org_clinical.TCGA-B6-A0WV.xml: OK.
# File ../datasets/clinical_data/28d4db85-315d-4a55-887b-48b209aad1fa/nationwidechildrens.org_clinical.TCGA-AN-A0XS.xml: OK.
# File ../datasets/clinical_data/29205dd4-0edb-406b-9657-c39e30272f6a/nationwidechildrens.org_clinical.TCGA-EW-A6SA.xml: OK.
# File ../datasets/clinical_data/2923b4df-3e8c-4030-a812-e516f351428e/nationwidechildrens.org_clinical.TCGA-BH-A0BR.xml: OK.
# File ../datasets/clinical_data/295e8f96-69d9-4f8c-96e2-600ab80389b2/nationwidechildrens.org_clinical.TCGA-AN-A041.xml: OK.
# File ../datasets/clinical_data/2981e2a8-38c6-40b0-b611-bfcc55c3c30a/nationwidechildrens.org_clinical.TCGA-BH-A0GY.xml: OK.
# File ../datasets/clinical_data/2a4f1d95-a0c7-4f92-a2ea-c3b8283cf16d/nationwidechildrens.org_clinical.TCGA-BH-A0EE.xml: OK.
# File ../datasets/clinical_data/2a5b5ade-746e-4a95-ade3-596a56f35ed8/nationwidechildrens.org_clinical.TCGA-BH-A0EA.xml: OK.
# File ../datasets/clinical_data/2a679442-ab52-411e-8fa0-a100fb8a4913/nationwidechildrens.org_clinical.TCGA-A8-A082.xml: OK.
# File ../datasets/clinical_data/2a89edca-2d57-43ec-9ef2-e65b7525ed78/nationwidechildrens.org_clinical.TCGA-D8-A1JK.xml: OK.
# File ../datasets/clinical_data/2ade91c3-a81c-4362-a7fa-5c2aeb22b476/nationwidechildrens.org_omf.TCGA-A8-A06U.xml: Not contains required columns.
# File ../datasets/clinical_data/2b091208-b35c-4a3d-94ff-d5d01b8fcdcc/nationwidechildrens.org_clinical.TCGA-A8-A08S.xml: OK.
# File ../datasets/clinical_data/2b09f2e9-68c4-4a64-90c9-d981e89c123d/nationwidechildrens.org_omf.TCGA-A8-A09K.xml: Not contains required columns.
# File ../datasets/clinical_data/2b0e28e5-6571-497e-b258-b53909f6ecd6/nationwidechildrens.org_clinical.TCGA-AN-A0XT.xml: OK.
# File ../datasets/clinical_data/2b5696e1-91d2-43a1-873b-e95be5922e51/nationwidechildrens.org_clinical.TCGA-E2-A1IN.xml: OK.
# File ../datasets/clinical_data/2b629c40-f8d7-4f1b-9b62-921a9d936807/nationwidechildrens.org_clinical.TCGA-B6-A0I9.xml: OK.
# File ../datasets/clinical_data/2b7acc61-1cce-451a-9c0c-440525402e7f/nationwidechildrens.org_clinical.TCGA-A2-A4S3.xml: OK.
# File ../datasets/clinical_data/2bae8366-3b01-408c-a8c6-976df43a3a01/nationwidechildrens.org_clinical.TCGA-C8-A12L.xml: OK.
# File ../datasets/clinical_data/2bce3c85-2cef-42d7-9d75-8860062683f3/nationwidechildrens.org_clinical.TCGA-AC-A23H.xml: OK.
# File ../datasets/clinical_data/2c2acb21-606f-4816-a2f7-e69508b4cf99/nationwidechildrens.org_clinical.TCGA-E2-A14P.xml: OK.
# File ../datasets/clinical_data/2c8cfe81-1934-47c9-9fd6-24047b012b18/nationwidechildrens.org_clinical.TCGA-C8-A12Z.xml: OK.
# File ../datasets/clinical_data/2d717aea-1557-4c24-bcf5-858267636016/nationwidechildrens.org_clinical.TCGA-AO-A0JA.xml: OK.
# File ../datasets/clinical_data/2de837e4-7624-4134-b30f-089d85912e9b/nationwidechildrens.org_clinical.TCGA-BH-A1F5.xml: OK.
# File ../datasets/clinical_data/2deae878-dfd4-4778-ae31-2e3a9e5975b1/nationwidechildrens.org_clinical.TCGA-AN-A0FS.xml: OK.
# File ../datasets/clinical_data/2e31bdcd-c11a-4f47-b426-6fc0fded867d/nationwidechildrens.org_clinical.TCGA-A2-A0T3.xml: OK.
# File ../datasets/clinical_data/2e5711e2-6f5d-4f48-89e9-35df0b1292a4/nationwidechildrens.org_clinical.TCGA-B6-A0RS.xml: OK.
# File ../datasets/clinical_data/2e7768b6-6862-4d65-bb12-cfa012c875d9/nationwidechildrens.org_clinical.TCGA-A8-A08H.xml: OK.
# File ../datasets/clinical_data/2e8350e1-ff7c-4395-8a97-2aa05220dd40/nationwidechildrens.org_clinical.TCGA-A2-A04N.xml: OK.
# File ../datasets/clinical_data/2eb84b27-d505-417d-9e05-f82f2e4c023e/nationwidechildrens.org_clinical.TCGA-E9-A1R3.xml: OK.
# File ../datasets/clinical_data/2ee83b95-d19c-4ae4-bb5c-bad54e9ecbe2/nationwidechildrens.org_omf.TCGA-S3-AA12.xml: Not contains required columns.
# File ../datasets/clinical_data/2eeaea21-537d-4058-8770-905ecdb03e99/nationwidechildrens.org_clinical.TCGA-BH-A0GZ.xml: OK.
# File ../datasets/clinical_data/2f49fea2-3c8c-4690-a561-d5001a86c215/nationwidechildrens.org_clinical.TCGA-A8-A08P.xml: OK.
# File ../datasets/clinical_data/2f7ed67d-7c4c-4990-84c4-982cd5e885ab/nationwidechildrens.org_clinical.TCGA-E2-A15A.xml: OK.
# File ../datasets/clinical_data/30715284-b1ae-4f23-a690-9cab2acf9392/nationwidechildrens.org_clinical.TCGA-A8-A09B.xml: OK.
# File ../datasets/clinical_data/30758df6-d164-44de-91ab-6077ca9ac04a/nationwidechildrens.org_clinical.TCGA-S3-A6ZH.xml: OK.
# File ../datasets/clinical_data/30adafa4-a3eb-4523-92db-63c76b05515a/nationwidechildrens.org_clinical.TCGA-A2-A0YF.xml: OK.
# File ../datasets/clinical_data/30add949-c832-4a65-ba9a-5aba8e313bf8/nationwidechildrens.org_clinical.TCGA-A2-A1FW.xml: OK.
# File ../datasets/clinical_data/30bec064-c879-4d2e-bf57-76efb44d0f22/nationwidechildrens.org_clinical.TCGA-BH-A0E2.xml: OK.
# File ../datasets/clinical_data/30fddf77-25ca-4cbf-88fe-19a6820c4cc3/nationwidechildrens.org_clinical.TCGA-E9-A1ND.xml: OK.
# File ../datasets/clinical_data/312e02be-fb7d-4e6b-88a1-1b656d211f66/nationwidechildrens.org_clinical.TCGA-S3-AA10.xml: OK.
# File ../datasets/clinical_data/3132651d-c2d6-44ad-9234-939d98f356b9/nationwidechildrens.org_clinical.TCGA-B6-A0RH.xml: OK.
# File ../datasets/clinical_data/3181a3ef-3317-4b47-916b-c1527d2e3309/nationwidechildrens.org_clinical.TCGA-E2-A15P.xml: OK.
# File ../datasets/clinical_data/31dd83d7-2399-47d9-ada2-375117da8a6b/nationwidechildrens.org_clinical.TCGA-3C-AALK.xml: OK.
# File ../datasets/clinical_data/321ee2c3-5873-4cd2-b1be-24a9dcc5236c/nationwidechildrens.org_clinical.TCGA-E9-A244.xml: OK.
# File ../datasets/clinical_data/323149a5-b38e-4cc3-adb2-fcad02347ddd/nationwidechildrens.org_omf.TCGA-A2-A0CQ.xml: Not contains required columns.
# File ../datasets/clinical_data/325367f7-1345-4882-86b2-81cde2a8faaa/nationwidechildrens.org_clinical.TCGA-AO-A03L.xml: OK.
# File ../datasets/clinical_data/328d5901-cd30-446f-9a0f-12ffc01be16a/nationwidechildrens.org_clinical.TCGA-OL-A5S0.xml: OK.
# File ../datasets/clinical_data/32ce3a7e-608c-4897-8e64-bdba9ca3a0ca/nationwidechildrens.org_clinical.TCGA-E2-A570.xml: OK.
# File ../datasets/clinical_data/33369ef8-609c-4e3e-9d72-0b9facdaaece/nationwidechildrens.org_clinical.TCGA-AR-A0TY.xml: OK.
# File ../datasets/clinical_data/333f5d2e-45c7-4944-8185-5c92f0969bc3/nationwidechildrens.org_clinical.TCGA-AR-A256.xml: OK.
# File ../datasets/clinical_data/335bfc4c-0c49-4860-a522-2a0a6430455c/nationwidechildrens.org_clinical.TCGA-BH-A1EU.xml: OK.
# File ../datasets/clinical_data/33a76cf6-c60c-487d-af52-aa9a9d7b3e6d/nationwidechildrens.org_clinical.TCGA-LL-A6FQ.xml: OK.
# File ../datasets/clinical_data/33c20398-3b78-4629-b413-2f07ec00ec87/nationwidechildrens.org_clinical.TCGA-GM-A2DI.xml: OK.
# File ../datasets/clinical_data/33c36a80-c4af-47b7-a0bb-29ba0e4bd658/nationwidechildrens.org_clinical.TCGA-A7-A0DB.xml: OK.
# File ../datasets/clinical_data/340e54a9-3108-4aac-a02f-8ca81a077323/nationwidechildrens.org_clinical.TCGA-BH-A0BM.xml: OK.
# File ../datasets/clinical_data/34439f4d-1606-41c3-8b83-bed8591eb0f8/nationwidechildrens.org_clinical.TCGA-A8-A081.xml: OK.
# File ../datasets/clinical_data/352b33ed-7387-452d-b7cd-8afd94d1143c/nationwidechildrens.org_clinical.TCGA-D8-A1XF.xml: OK.
# File ../datasets/clinical_data/356d559c-1731-47b3-84b3-0afaa4a84bed/nationwidechildrens.org_clinical.TCGA-E9-A229.xml: OK.
# File ../datasets/clinical_data/35aae95f-b4ef-46ae-a64b-fd981eceeaca/nationwidechildrens.org_clinical.TCGA-OL-A5RY.xml: OK.
# File ../datasets/clinical_data/35e8376c-3b55-446d-9b71-1544b8a87fd0/nationwidechildrens.org_clinical.TCGA-E9-A1R7.xml: OK.
# File ../datasets/clinical_data/35ea5b80-5ac8-49f9-98ff-5b374d526502/nationwidechildrens.org_clinical.TCGA-C8-A27B.xml: OK.
# File ../datasets/clinical_data/35ff6555-2f56-4f8c-8d9c-5e25a198d4b6/nationwidechildrens.org_clinical.TCGA-B6-A409.xml: OK.
# File ../datasets/clinical_data/36717ad9-8d06-4b94-a7cb-bb0b309ac5c2/nationwidechildrens.org_clinical.TCGA-E2-A109.xml: OK.
# File ../datasets/clinical_data/36eef565-06b0-4e7f-a21d-e661717a2c49/nationwidechildrens.org_clinical.TCGA-EW-A3U0.xml: OK.
# File ../datasets/clinical_data/36f9ade7-bf38-4544-abbb-48edc6cad131/nationwidechildrens.org_clinical.TCGA-A2-A04P.xml: OK.
# File ../datasets/clinical_data/37298993-7dbf-45a8-ac37-70ea93f89c06/nationwidechildrens.org_clinical.TCGA-A8-A083.xml: OK.
# File ../datasets/clinical_data/37798dd5-d083-4ef7-840f-5d9ed52dc460/nationwidechildrens.org_clinical.TCGA-E2-A14O.xml: OK.
# File ../datasets/clinical_data/37939018-84b0-44ee-bf9f-cfdecd94370d/nationwidechildrens.org_clinical.TCGA-BH-A0B0.xml: OK.
# File ../datasets/clinical_data/37eaa1e3-1649-4697-8186-e1ec1ecc8e48/nationwidechildrens.org_clinical.TCGA-C8-A26X.xml: OK.
# File ../datasets/clinical_data/3838998d-819c-4118-b7d8-5344281ac5fd/nationwidechildrens.org_clinical.TCGA-D8-A27P.xml: OK.
# File ../datasets/clinical_data/38731109-4cd4-4c7b-aa6c-7c8fcc5b719a/nationwidechildrens.org_clinical.TCGA-OL-A5RZ.xml: OK.
# File ../datasets/clinical_data/38762fd0-66b8-41a6-91f8-2cec2e2fff1c/nationwidechildrens.org_clinical.TCGA-EW-A1OV.xml: OK.
# File ../datasets/clinical_data/38cb84d9-9515-4557-aa5c-e5f28a3708f2/nationwidechildrens.org_clinical.TCGA-AR-A1AO.xml: OK.
# File ../datasets/clinical_data/38d0617f-375a-4ac8-901c-bfb99a047f0a/nationwidechildrens.org_clinical.TCGA-AN-A04C.xml: OK.
# File ../datasets/clinical_data/38ddf8ea-7bad-4893-922b-b086331261fa/nationwidechildrens.org_clinical.TCGA-A2-A25E.xml: OK.
# File ../datasets/clinical_data/38fa4361-0c3c-4a20-bea0-9e01047b7622/nationwidechildrens.org_clinical.TCGA-A2-A1G6.xml: OK.
# File ../datasets/clinical_data/3a000d1a-fb70-4946-925b-e3db436fbace/nationwidechildrens.org_clinical.TCGA-BH-A0HO.xml: OK.
# File ../datasets/clinical_data/3abdcb95-3610-41a3-8510-93033f5f5142/nationwidechildrens.org_clinical.TCGA-BH-A1FJ.xml: OK.
# File ../datasets/clinical_data/3aea3241-d321-4abf-b328-c11b6c7c37da/nationwidechildrens.org_clinical.TCGA-E2-A1IG.xml: OK.
# File ../datasets/clinical_data/3af873f5-15e1-4605-b295-a5d29fc46835/nationwidechildrens.org_clinical.TCGA-BH-A0B6.xml: OK.
# File ../datasets/clinical_data/3b8ece2c-645e-4f1c-b7fd-5e957275e158/nationwidechildrens.org_clinical.TCGA-AN-A0FT.xml: OK.
# File ../datasets/clinical_data/3c4be53a-e2a9-4afd-9910-c45e539ca0be/nationwidechildrens.org_clinical.TCGA-EW-A6SB.xml: OK.
# File ../datasets/clinical_data/3c69483e-4182-4d4f-9956-f4db9fa13529/nationwidechildrens.org_clinical.TCGA-AO-A03O.xml: OK.
# File ../datasets/clinical_data/3ca09685-0c0e-494a-bde0-661efae20be8/nationwidechildrens.org_clinical.TCGA-BH-A0EI.xml: OK.
# File ../datasets/clinical_data/3cc30ed0-263e-4be1-bc66-2c015f054796/nationwidechildrens.org_clinical.TCGA-BH-A18J.xml: OK.
# File ../datasets/clinical_data/3d57c6be-c217-4d2f-891a-e6ef79bfe57e/nationwidechildrens.org_clinical.TCGA-C8-A1HN.xml: OK.
# File ../datasets/clinical_data/3d72e23a-15a1-4572-b68a-f8bf15f25cf1/nationwidechildrens.org_clinical.TCGA-GM-A2DA.xml: OK.
# File ../datasets/clinical_data/3e4a5d1e-8a8e-43c0-8149-0085c6246ab0/nationwidechildrens.org_clinical.TCGA-EW-A1PH.xml: OK.
# File ../datasets/clinical_data/3e6152a4-d844-4a07-a76c-93aac88085bc/nationwidechildrens.org_clinical.TCGA-B6-A0X5.xml: OK.
# File ../datasets/clinical_data/3e74a086-e477-4b5c-8a06-f1e4634d27c2/nationwidechildrens.org_clinical.TCGA-EW-A1OY.xml: OK.
# File ../datasets/clinical_data/3eaee49b-15f2-404e-a0cd-6c3317878c45/nationwidechildrens.org_clinical.TCGA-BH-A1FL.xml: OK.
# File ../datasets/clinical_data/3ec760b4-9722-4093-8c5a-714e385fb600/nationwidechildrens.org_clinical.TCGA-B6-A0X4.xml: OK.
# File ../datasets/clinical_data/3f197a51-8e41-4e86-a372-ea24e382308a/nationwidechildrens.org_clinical.TCGA-AO-A03M.xml: OK.
# File ../datasets/clinical_data/3f96710c-8e2d-422c-99fa-1a49106ed58b/nationwidechildrens.org_clinical.TCGA-PL-A8LZ.xml: OK.
# File ../datasets/clinical_data/3fd204bf-0d36-463c-935e-7fd9630948ef/nationwidechildrens.org_clinical.TCGA-A7-A0CD.xml: OK.
# File ../datasets/clinical_data/3ff0d2da-e6c8-434d-9a96-ba3d69dbdd8e/nationwidechildrens.org_clinical.TCGA-EW-A1P5.xml: OK.
# File ../datasets/clinical_data/3ff6cbdf-b639-48fe-8143-21b10764fcc9/nationwidechildrens.org_clinical.TCGA-E2-A1IO.xml: OK.
# File ../datasets/clinical_data/401187b6-c889-4cdc-9912-8c46c571ae00/nationwidechildrens.org_clinical.TCGA-A8-A08L.xml: OK.
# File ../datasets/clinical_data/407d26c0-0eb0-4bcf-9f30-a2acb9d33086/nationwidechildrens.org_clinical.TCGA-A8-A08A.xml: OK.
# File ../datasets/clinical_data/40db542b-6d6c-4b6b-a5cf-05a2c554d38e/nationwidechildrens.org_clinical.TCGA-GI-A2C9.xml: OK.
# File ../datasets/clinical_data/410a715e-25a6-454a-afa1-209cd379a8e1/nationwidechildrens.org_clinical.TCGA-D8-A27M.xml: OK.
# File ../datasets/clinical_data/41511c04-44e3-4971-8e47-c758cec3decd/nationwidechildrens.org_clinical.TCGA-E9-A1RF.xml: OK.
# File ../datasets/clinical_data/415848eb-7256-474f-9c80-ecdfec0f0a9d/nationwidechildrens.org_omf.TCGA-AO-A0JI.xml: Not contains required columns.
# File ../datasets/clinical_data/416ae1cf-13ed-4bca-ac5d-23255cf97221/nationwidechildrens.org_clinical.TCGA-E9-A1RB.xml: OK.
# File ../datasets/clinical_data/41cacc55-b375-4b76-8b42-ba7fefb32f40/nationwidechildrens.org_clinical.TCGA-A8-A096.xml: OK.
# File ../datasets/clinical_data/421c1a06-f3ef-474c-9128-370e90c7f9e8/nationwidechildrens.org_clinical.TCGA-D8-A1JG.xml: OK.
# File ../datasets/clinical_data/425014ce-d400-4086-9687-c91c5f1a05bc/nationwidechildrens.org_clinical.TCGA-BH-A0DO.xml: OK.
# File ../datasets/clinical_data/4276595f-a61b-42c2-aa54-cf33676d0d24/nationwidechildrens.org_clinical.TCGA-AQ-A54O.xml: OK.
# File ../datasets/clinical_data/4322a353-38f9-4c0c-a7a2-930d80278c57/nationwidechildrens.org_clinical.TCGA-A1-A0SQ.xml: OK.
# File ../datasets/clinical_data/44f81e9b-0b50-44e0-a1e3-0627f71ab877/nationwidechildrens.org_clinical.TCGA-C8-A132.xml: OK.
# File ../datasets/clinical_data/45227d46-76f6-4f1d-ac82-a5d7fecce822/nationwidechildrens.org_clinical.TCGA-EW-A2FR.xml: OK.
# File ../datasets/clinical_data/45373b3a-421c-4325-9a5d-9fbc36369c3f/nationwidechildrens.org_clinical.TCGA-AR-A0U4.xml: OK.
# File ../datasets/clinical_data/45b598f8-887e-43e9-bbdc-3ddc02f89d3f/nationwidechildrens.org_clinical.TCGA-A2-A0D3.xml: OK.
# File ../datasets/clinical_data/45cf2f5d-05e2-4181-8cf2-aabb3e15c4f1/nationwidechildrens.org_clinical.TCGA-BH-A1FU.xml: OK.
# File ../datasets/clinical_data/46238b12-60fd-4e33-98b0-bd23c6c83962/nationwidechildrens.org_clinical.TCGA-E9-A1N6.xml: OK.
# File ../datasets/clinical_data/46573cac-dd56-4c49-97e6-edec5f1144c8/nationwidechildrens.org_clinical.TCGA-BH-A0DZ.xml: OK.
# File ../datasets/clinical_data/4697c0de-da15-4daa-8b39-c2f4a1fd7be9/nationwidechildrens.org_clinical.TCGA-A2-A0YE.xml: OK.
# File ../datasets/clinical_data/46c1fb19-05c4-4543-a309-153d471cbd0b/nationwidechildrens.org_clinical.TCGA-LL-A740.xml: OK.
# File ../datasets/clinical_data/47441cb1-d47c-453d-9c9f-f8cbcbdba399/nationwidechildrens.org_clinical.TCGA-A8-A07W.xml: OK.
# File ../datasets/clinical_data/474da3bc-a7b2-4b88-9402-6169ded29117/nationwidechildrens.org_clinical.TCGA-GM-A2DH.xml: OK.
# File ../datasets/clinical_data/47a5ceb3-2163-461c-a9c1-7cf6dd6bced1/nationwidechildrens.org_clinical.TCGA-C8-A12Q.xml: OK.
# File ../datasets/clinical_data/4803d618-4362-4b22-9a5a-7ec35d7660a3/nationwidechildrens.org_clinical.TCGA-A8-A06T.xml: OK.
# File ../datasets/clinical_data/48332cac-b2c3-4a35-bc1b-76e174b9b55d/nationwidechildrens.org_clinical.TCGA-BH-A18N.xml: OK.
# File ../datasets/clinical_data/488577fa-6baa-4c11-94d1-76dffd7c5bbf/nationwidechildrens.org_clinical.TCGA-BH-A0DS.xml: OK.
# File ../datasets/clinical_data/48da1f05-062b-4f2d-9936-5064d9a1a9f3/nationwidechildrens.org_clinical.TCGA-AR-A0U1.xml: OK.
# File ../datasets/clinical_data/492170e4-90b8-4560-89ff-effa9eeb5194/nationwidechildrens.org_clinical.TCGA-B6-A0X1.xml: OK.
# File ../datasets/clinical_data/498ac741-b4be-4544-9ba2-a068b9b334bd/nationwidechildrens.org_clinical.TCGA-A1-A0SH.xml: OK.
# File ../datasets/clinical_data/49a0b7f9-bbc8-408d-b507-2a1a2928cee3/nationwidechildrens.org_clinical.TCGA-BH-A0H9.xml: OK.
# File ../datasets/clinical_data/49f86f21-3f57-4669-8b2f-e409491ad33f/nationwidechildrens.org_clinical.TCGA-E2-A1AZ.xml: OK.
# File ../datasets/clinical_data/4a3c7925-3ae9-44ca-b9d9-62ba78bcba33/nationwidechildrens.org_omf.TCGA-A2-A04V.xml: Not contains required columns.
# File ../datasets/clinical_data/4b81e1c7-f651-4326-a9b7-d9ff18ccefdb/nationwidechildrens.org_clinical.TCGA-A8-A06X.xml: OK.
# File ../datasets/clinical_data/4ba7265a-28de-46fe-961e-4d9bbffed86e/nationwidechildrens.org_clinical.TCGA-AO-A1KT.xml: OK.
# File ../datasets/clinical_data/4bded89b-7234-47e0-abe9-ad10dfeff4f8/nationwidechildrens.org_clinical.TCGA-AN-A0FJ.xml: OK.
# File ../datasets/clinical_data/4bf1399d-35c3-4336-990f-2ebe105b761c/nationwidechildrens.org_clinical.TCGA-BH-A0H6.xml: OK.
# File ../datasets/clinical_data/4c1ff644-3c62-47c3-a3d8-f9fa4a256bda/nationwidechildrens.org_clinical.TCGA-D8-A1JL.xml: OK.
# File ../datasets/clinical_data/4cb4f2d3-d48a-4843-8eb5-ee704ebfb13a/nationwidechildrens.org_clinical.TCGA-A2-A3XW.xml: OK.
# File ../datasets/clinical_data/4cc94cff-842d-4473-9de6-27a404dbe215/nationwidechildrens.org_clinical.TCGA-BH-A1EW.xml: OK.
# File ../datasets/clinical_data/4d016077-a880-49d6-8d2a-575a8c93bec5/nationwidechildrens.org_clinical.TCGA-E9-A1R4.xml: OK.
# File ../datasets/clinical_data/4d18da98-1a9b-46b5-89d6-55343189883f/nationwidechildrens.org_clinical.TCGA-BH-A0HB.xml: OK.
# File ../datasets/clinical_data/4ea54a5f-ef76-4c3f-a052-c7c024648c43/nationwidechildrens.org_clinical.TCGA-A8-A08R.xml: OK.
# File ../datasets/clinical_data/4ef9e392-0340-487f-9a2e-079a84b267fe/nationwidechildrens.org_clinical.TCGA-A7-A5ZW.xml: OK.
# File ../datasets/clinical_data/4f1bd9c8-1b7c-4853-9e38-bad0ed395411/nationwidechildrens.org_clinical.TCGA-AR-A0U0.xml: OK.
# File ../datasets/clinical_data/4f4b77cb-484c-4b57-a89f-6473eff9966e/nationwidechildrens.org_clinical.TCGA-C8-A130.xml: OK.
# File ../datasets/clinical_data/4f808abe-7d71-4741-af41-69a3f7981788/nationwidechildrens.org_clinical.TCGA-E2-A1LH.xml: OK.
# File ../datasets/clinical_data/4faa0a53-4f1b-4c2c-b6ba-af1e426f9d33/nationwidechildrens.org_clinical.TCGA-AR-A1AY.xml: OK.
# File ../datasets/clinical_data/5025cc06-de19-4fcc-9c89-c4f7d6450b2c/nationwidechildrens.org_omf.TCGA-E2-A15O.xml: Not contains required columns.
# File ../datasets/clinical_data/5038627b-4066-4919-8a89-8bc55143596c/nationwidechildrens.org_clinical.TCGA-E9-A22H.xml: OK.
# File ../datasets/clinical_data/50684ea7-f34a-459f-a4d3-ac09d88608d9/nationwidechildrens.org_clinical.TCGA-EW-A1J1.xml: OK.
# File ../datasets/clinical_data/507bdb32-c74c-4f90-9ce4-031b763c0fd9/nationwidechildrens.org_clinical.TCGA-LL-A7T0.xml: OK.
# File ../datasets/clinical_data/50842d60-e03f-4490-b3d5-4b01d2537328/nationwidechildrens.org_clinical.TCGA-B6-A0IO.xml: OK.
# File ../datasets/clinical_data/515eeb64-1c95-4e81-af64-47f75fa1a70d/nationwidechildrens.org_clinical.TCGA-E2-A1IF.xml: OK.
# File ../datasets/clinical_data/51ac596c-6215-4afa-a1a8-bc56f7bda665/nationwidechildrens.org_clinical.TCGA-A8-A06Y.xml: OK.
# File ../datasets/clinical_data/51d8681a-f953-4237-a22c-04dfba9a83a4/nationwidechildrens.org_clinical.TCGA-A2-A0D4.xml: OK.
# File ../datasets/clinical_data/51e0e5c5-b139-4a87-99a9-7b0058533b91/nationwidechildrens.org_clinical.TCGA-OL-A5D6.xml: OK.
# File ../datasets/clinical_data/521fd53d-d517-4147-90ef-86c487b1be4b/nationwidechildrens.org_clinical.TCGA-EW-A1OZ.xml: OK.
# File ../datasets/clinical_data/522aaf8f-ff00-4d42-ab64-3686e9df9301/nationwidechildrens.org_clinical.TCGA-AC-A62X.xml: OK.
# File ../datasets/clinical_data/53869135-6e62-4f95-8e5e-143485f62ed9/nationwidechildrens.org_clinical.TCGA-E2-A156.xml: OK.
# File ../datasets/clinical_data/539dbf37-39f2-4340-bc1a-c34dcc43bbe0/nationwidechildrens.org_clinical.TCGA-E9-A1R6.xml: OK.
# File ../datasets/clinical_data/541a56c1-3649-45f8-bb2f-30c0be00ec40/nationwidechildrens.org_clinical.TCGA-EW-A1J6.xml: OK.
# File ../datasets/clinical_data/541e990a-bfc8-4007-b69a-79e786eff209/nationwidechildrens.org_clinical.TCGA-E9-A1RA.xml: OK.
# File ../datasets/clinical_data/542f469a-b5d0-4fbd-89b0-758d7dd59a23/nationwidechildrens.org_clinical.TCGA-AR-A24S.xml: OK.
# File ../datasets/clinical_data/544a1685-6650-4387-9a04-4267ca56a239/nationwidechildrens.org_clinical.TCGA-AN-A0FD.xml: OK.
# File ../datasets/clinical_data/54a1e746-6d51-4f84-9fab-578b39cb8619/nationwidechildrens.org_clinical.TCGA-EW-A1PA.xml: OK.
# File ../datasets/clinical_data/54b37de1-1dce-462d-9049-31cf5a9ed1da/nationwidechildrens.org_clinical.TCGA-C8-A135.xml: OK.
# File ../datasets/clinical_data/56048722-981a-4689-9de0-42f92a116590/nationwidechildrens.org_clinical.TCGA-BH-A1F0.xml: OK.
# File ../datasets/clinical_data/560c8b13-9410-42b5-9597-e8f1c28412e3/nationwidechildrens.org_clinical.TCGA-BH-A1EX.xml: OK.
# File ../datasets/clinical_data/56388b38-52cb-4b66-a41f-06c81ad26e35/nationwidechildrens.org_clinical.TCGA-UU-A93S.xml: OK.
# File ../datasets/clinical_data/565fb3de-406c-49b0-8194-2dd129dd5876/nationwidechildrens.org_clinical.TCGA-BH-A202.xml: OK.
# File ../datasets/clinical_data/56d2480c-5d33-486a-9bc2-8c614d8b7249/nationwidechildrens.org_clinical.TCGA-AO-A126.xml: OK.
# File ../datasets/clinical_data/570355ca-64c7-4d9f-9669-5798b0080704/nationwidechildrens.org_clinical.TCGA-AR-A0TU.xml: OK.
# File ../datasets/clinical_data/57413762-35bf-44b5-8876-3f7dc3c20987/nationwidechildrens.org_clinical.TCGA-AO-A0J4.xml: OK.
# File ../datasets/clinical_data/57f570ac-1320-480e-a7b0-fffd2e882513/nationwidechildrens.org_clinical.TCGA-A2-A0SX.xml: OK.
# File ../datasets/clinical_data/5805402b-636e-458e-adfd-862c1f49b801/nationwidechildrens.org_clinical.TCGA-BH-A0AU.xml: OK.
# File ../datasets/clinical_data/58b8a73e-3975-43ec-995a-e8a3d72f3930/nationwidechildrens.org_clinical.TCGA-A7-A13F.xml: OK.
# File ../datasets/clinical_data/5931c6c2-65ed-4976-a0b7-33c07aee5fad/nationwidechildrens.org_clinical.TCGA-A2-A04R.xml: OK.
# File ../datasets/clinical_data/59a75975-f731-4bac-b088-13697e6e67cf/nationwidechildrens.org_clinical.TCGA-B6-A0RL.xml: OK.
# File ../datasets/clinical_data/5a251a59-c085-4711-98bb-97b0bb36b7db/nationwidechildrens.org_clinical.TCGA-AO-A0J2.xml: OK.
# File ../datasets/clinical_data/5a35c8af-8de9-4ae4-b2d3-5672352babf8/nationwidechildrens.org_clinical.TCGA-AO-A0JE.xml: OK.
# File ../datasets/clinical_data/5a8a653a-7555-4ac9-a907-28f7f7286a1b/nationwidechildrens.org_clinical.TCGA-BH-A0E1.xml: OK.
# File ../datasets/clinical_data/5aaad587-f550-45b6-a348-d89e70f6a3f6/nationwidechildrens.org_clinical.TCGA-C8-A12U.xml: OK.
# File ../datasets/clinical_data/5add419d-9a4b-4e30-bbb2-d1d15ef4c919/nationwidechildrens.org_clinical.TCGA-A8-A06U.xml: OK.
# File ../datasets/clinical_data/5af9bc05-ecb6-4031-9039-a5164bb91aed/nationwidechildrens.org_omf.TCGA-LL-A442.xml: Not contains required columns.
# File ../datasets/clinical_data/5c475a60-856c-4fab-8939-b5ed38ebab96/nationwidechildrens.org_omf.TCGA-A8-A08F.xml: Not contains required columns.
# File ../datasets/clinical_data/5c877a6e-5f2b-40fb-8947-c81c8373b7da/nationwidechildrens.org_clinical.TCGA-E2-A15D.xml: OK.
# File ../datasets/clinical_data/5d06d7d1-e301-44ae-aa54-2b91d46f5101/nationwidechildrens.org_clinical.TCGA-E2-A1B4.xml: OK.
# File ../datasets/clinical_data/5de507f2-c47a-4d66-b796-431547477f7f/nationwidechildrens.org_clinical.TCGA-A2-A0T0.xml: OK.
# File ../datasets/clinical_data/5ed3dafb-8a63-4f7c-8a37-eb8700afcef8/nationwidechildrens.org_clinical.TCGA-AR-A0TR.xml: OK.
# File ../datasets/clinical_data/5f7626c2-8158-4bcf-8d20-b27a72b3c857/nationwidechildrens.org_clinical.TCGA-AO-A12F.xml: OK.
# File ../datasets/clinical_data/5f96bd5e-ab83-48b3-abac-adf87f978c20/nationwidechildrens.org_clinical.TCGA-GM-A2DN.xml: OK.
# File ../datasets/clinical_data/5fa58d19-6f11-4e5b-85d5-21c5c25c8ed0/nationwidechildrens.org_clinical.TCGA-BH-A0E7.xml: OK.
# File ../datasets/clinical_data/5fffe364-2fe8-421a-92aa-a14f9b2d4cad/nationwidechildrens.org_clinical.TCGA-E9-A1RG.xml: OK.
# File ../datasets/clinical_data/60eb3b00-6911-4983-b51e-b5bfc99372a0/nationwidechildrens.org_clinical.TCGA-D8-A1XQ.xml: OK.
# File ../datasets/clinical_data/61014733-2fa9-4139-a8ab-5d0dac7c7bac/nationwidechildrens.org_omf.TCGA-E2-A158.xml: Not contains required columns.
# File ../datasets/clinical_data/61b2f83b-db6a-43a1-a85e-c285eb54e958/nationwidechildrens.org_clinical.TCGA-E9-A249.xml: OK.
# File ../datasets/clinical_data/628b9155-834a-4a30-964a-d424a01f07b2/nationwidechildrens.org_clinical.TCGA-D8-A146.xml: OK.
# File ../datasets/clinical_data/62bf0c2d-4a3c-4592-b5cc-0da1dada0a8e/nationwidechildrens.org_clinical.TCGA-D8-A1XL.xml: OK.
# File ../datasets/clinical_data/62df99b7-c37b-4961-b8f2-a24691bffb2c/nationwidechildrens.org_clinical.TCGA-A2-A3XY.xml: OK.
# File ../datasets/clinical_data/62ea25cb-0652-4064-9757-ab5d0a018423/nationwidechildrens.org_clinical.TCGA-E2-A10E.xml: OK.
# File ../datasets/clinical_data/63a2aadf-5998-4886-a7b9-a9ca188ab6f7/nationwidechildrens.org_clinical.TCGA-B6-A400.xml: OK.
# File ../datasets/clinical_data/63c5e345-11a4-4e05-8535-64126b6008ea/nationwidechildrens.org_clinical.TCGA-AN-A04A.xml: OK.
# File ../datasets/clinical_data/63e03017-0ea7-4a4d-85ee-32df750e68a8/nationwidechildrens.org_clinical.TCGA-A7-A0D9.xml: OK.
# File ../datasets/clinical_data/64608382-6e86-4ebb-a949-db48e45eea1d/nationwidechildrens.org_clinical.TCGA-BH-A0BP.xml: OK.
# File ../datasets/clinical_data/64d43d63-2e81-401a-865c-6888c1b26717/nationwidechildrens.org_clinical.TCGA-EW-A1P3.xml: OK.
# File ../datasets/clinical_data/65b455f3-fcfb-4e50-95d8-7c513d94f0a6/nationwidechildrens.org_omf.TCGA-A7-A0CD.xml: Not contains required columns.
# File ../datasets/clinical_data/6626f827-bd6d-4a58-9355-f17e970f1b47/nationwidechildrens.org_clinical.TCGA-BH-A0HU.xml: OK.
# File ../datasets/clinical_data/662cc493-43de-4370-98a3-5b90dd34bea2/nationwidechildrens.org_clinical.TCGA-E2-A14S.xml: OK.
# File ../datasets/clinical_data/6685a944-5ceb-4a3c-9680-67ac0e0b40d3/nationwidechildrens.org_clinical.TCGA-BH-A0RX.xml: OK.
# File ../datasets/clinical_data/668fec55-45fa-4113-b171-3f2053154786/nationwidechildrens.org_clinical.TCGA-BH-A1FN.xml: OK.
# File ../datasets/clinical_data/66b600cb-d793-4710-bfac-da0460d12646/nationwidechildrens.org_clinical.TCGA-A2-A3XZ.xml: OK.
# File ../datasets/clinical_data/671069e5-4730-4c23-8adf-79576bb1843f/nationwidechildrens.org_omf.TCGA-AR-A1AR.xml: Not contains required columns.
# File ../datasets/clinical_data/682a8b51-a8f5-463b-86ea-3b8bfdc26d66/nationwidechildrens.org_clinical.TCGA-A1-A0SD.xml: OK.
# File ../datasets/clinical_data/682b531b-3477-4740-8c6b-7891f2781b38/nationwidechildrens.org_clinical.TCGA-A7-A6VX.xml: OK.
# File ../datasets/clinical_data/686ff9cf-857a-4570-95a6-994425925815/nationwidechildrens.org_clinical.TCGA-OL-A66L.xml: OK.
# File ../datasets/clinical_data/687c102c-6a35-4c41-ae1c-e1457e33772b/nationwidechildrens.org_clinical.TCGA-B6-A0X7.xml: OK.
# File ../datasets/clinical_data/68901263-c6bd-4805-a332-5e284e549753/nationwidechildrens.org_clinical.TCGA-PL-A8LY.xml: OK.
# File ../datasets/clinical_data/68a0e39b-a0cf-4c77-889a-16595275f775/nationwidechildrens.org_clinical.TCGA-A2-A0EQ.xml: OK.
# File ../datasets/clinical_data/68a9278e-871e-4fdd-ab1e-f327357faa40/nationwidechildrens.org_omf.TCGA-BH-A0EA.xml: Not contains required columns.
# File ../datasets/clinical_data/69568fb0-3db1-4d63-951e-1bb2a4dc348f/nationwidechildrens.org_clinical.TCGA-BH-A0BC.xml: OK.
# File ../datasets/clinical_data/698d899c-6580-4fde-b2c9-aeb75f2bce0d/nationwidechildrens.org_clinical.TCGA-BH-A0B3.xml: OK.
# File ../datasets/clinical_data/69f707ae-8f14-4f25-8082-6ba85c42909d/nationwidechildrens.org_clinical.TCGA-BH-A0B7.xml: OK.
# File ../datasets/clinical_data/6a0ff69b-242b-4979-9d9b-684f0bc619da/nationwidechildrens.org_clinical.TCGA-BH-A0H5.xml: OK.
# File ../datasets/clinical_data/6a4fcf5a-8667-48ed-a0cd-ef88caa1ba16/nationwidechildrens.org_clinical.TCGA-E2-A1IU.xml: OK.
# File ../datasets/clinical_data/6a76b9bd-81bb-450c-9cbe-613b2653c4a8/nationwidechildrens.org_clinical.TCGA-BH-A1FG.xml: OK.
# File ../datasets/clinical_data/6a9789ac-087c-432e-a908-8123121f9ac4/nationwidechildrens.org_clinical.TCGA-E2-A1B0.xml: OK.
# File ../datasets/clinical_data/6ae5ff45-d127-47ec-9af5-6ac59b61291d/nationwidechildrens.org_clinical.TCGA-C8-A278.xml: OK.
# File ../datasets/clinical_data/6b53c8c1-76a6-465c-8e41-bcd53d1ce4e5/nationwidechildrens.org_clinical.TCGA-A1-A0SI.xml: OK.
# File ../datasets/clinical_data/6b6a57d5-6a89-4c79-932c-bc2ecb213f13/nationwidechildrens.org_clinical.TCGA-D8-A1JP.xml: OK.
# File ../datasets/clinical_data/6bd1bf4a-8a91-451a-9046-92b59de2b0ab/nationwidechildrens.org_clinical.TCGA-B6-A0IK.xml: OK.
# File ../datasets/clinical_data/6bd64a9d-c991-48ba-8db6-ff767da5ca06/nationwidechildrens.org_clinical.TCGA-A7-A0DA.xml: OK.
# File ../datasets/clinical_data/6c081aa2-be5f-446c-b37d-33d0100871c2/nationwidechildrens.org_clinical.TCGA-A2-A0SV.xml: OK.
# File ../datasets/clinical_data/6c1b7d57-2120-49a0-93c2-547ed126693c/nationwidechildrens.org_clinical.TCGA-A8-A09D.xml: OK.
# File ../datasets/clinical_data/6c53cc7e-d939-4bdc-b3ca-cf62769b3d88/nationwidechildrens.org_clinical.TCGA-BH-A1FM.xml: OK.
# File ../datasets/clinical_data/6d71fdfa-271c-43e9-87ee-045d4292551f/nationwidechildrens.org_clinical.TCGA-D8-A1JB.xml: OK.
# File ../datasets/clinical_data/6dd43709-60a7-481d-9748-03c2d248f0b6/nationwidechildrens.org_omf.TCGA-BH-A18H.xml: Not contains required columns.
# File ../datasets/clinical_data/6f59f93c-0f6a-4286-8faa-bf1a2d1beb94/nationwidechildrens.org_clinical.TCGA-D8-A1XK.xml: OK.
# File ../datasets/clinical_data/6f6d3b6b-c58b-4b15-b36a-1f563382cfe1/nationwidechildrens.org_clinical.TCGA-A8-A090.xml: OK.
# File ../datasets/clinical_data/6f7694b5-b90b-47e9-9ea5-0d0e2d7ce4a3/nationwidechildrens.org_clinical.TCGA-AO-A03V.xml: OK.
# File ../datasets/clinical_data/70345789-d8e7-47bd-93cc-4abdabf52aa7/nationwidechildrens.org_clinical.TCGA-E2-A159.xml: OK.
# File ../datasets/clinical_data/7098f789-c3c1-496b-a403-9bd26c0c6c35/nationwidechildrens.org_clinical.TCGA-A8-A075.xml: OK.
# File ../datasets/clinical_data/70a37999-db90-411e-83dc-244ebd1d2f73/nationwidechildrens.org_clinical.TCGA-BH-A0DE.xml: OK.
# File ../datasets/clinical_data/70e00e7a-2c5b-4ab8-8b75-076fbc6904c2/nationwidechildrens.org_clinical.TCGA-BH-A0C0.xml: OK.
# File ../datasets/clinical_data/716f66e9-ca43-4b17-84c6-4e4d2933b819/nationwidechildrens.org_clinical.TCGA-A7-A0CJ.xml: OK.
# File ../datasets/clinical_data/71b82ad6-557e-4027-b634-f056dd0e2700/nationwidechildrens.org_clinical.TCGA-BH-A0B4.xml: OK.
# File ../datasets/clinical_data/71ed5720-d54d-43bf-a0e3-6ef57beef1e2/nationwidechildrens.org_clinical.TCGA-EW-A1PD.xml: OK.
# File ../datasets/clinical_data/71fcd84b-bc91-40e0-a234-12eddeee6f48/nationwidechildrens.org_clinical.TCGA-BH-A0DK.xml: OK.
# File ../datasets/clinical_data/72b19dfe-18e2-4df3-af99-81205e2083be/nationwidechildrens.org_clinical.TCGA-E2-A105.xml: OK.
# File ../datasets/clinical_data/72c9aed3-6256-406d-bae3-3c32c35ba8db/nationwidechildrens.org_clinical.TCGA-B6-A0RO.xml: OK.
# File ../datasets/clinical_data/7322ca0d-71ef-4eaa-bbfd-224cdb896684/nationwidechildrens.org_omf.TCGA-A7-A2KD.xml: Not contains required columns.
# File ../datasets/clinical_data/73557aea-87e7-4a1f-aac1-819069358a9b/nationwidechildrens.org_clinical.TCGA-AN-A0FV.xml: OK.
# File ../datasets/clinical_data/73837d91-328e-479e-b31d-975de55b9108/nationwidechildrens.org_clinical.TCGA-AN-A0AM.xml: OK.
# File ../datasets/clinical_data/73edaa1c-f077-4b71-9e17-8cd0b97763c4/nationwidechildrens.org_clinical.TCGA-E2-A154.xml: OK.
# File ../datasets/clinical_data/7408bccd-d164-4e74-b8a9-b58f25761592/nationwidechildrens.org_clinical.TCGA-BH-A0C7.xml: OK.
# File ../datasets/clinical_data/745674b2-3aaa-433b-a76a-7220a8eb7e46/nationwidechildrens.org_clinical.TCGA-EW-A1P1.xml: OK.
# File ../datasets/clinical_data/745797ca-0a41-4022-a24c-c132501ac41b/nationwidechildrens.org_clinical.TCGA-AR-A24W.xml: OK.
# File ../datasets/clinical_data/7498e5d1-b78b-40eb-ae51-420f4f94e50f/nationwidechildrens.org_clinical.TCGA-BH-A0BG.xml: OK.
# File ../datasets/clinical_data/74b71434-062c-43bb-aed8-857088d7c5f2/nationwidechildrens.org_clinical.TCGA-AO-A0JF.xml: OK.
# File ../datasets/clinical_data/75a6b043-391a-4252-8f2e-023d08f56bdf/nationwidechildrens.org_clinical.TCGA-AC-A2BM.xml: OK.
# File ../datasets/clinical_data/75ab39cf-5ba4-4ef8-948c-3bd6b4d76ae4/nationwidechildrens.org_clinical.TCGA-BH-A18T.xml: OK.
# File ../datasets/clinical_data/760b0a73-db22-45ef-9443-c9b9d33f42ec/nationwidechildrens.org_clinical.TCGA-BH-A5IZ.xml: OK.
# File ../datasets/clinical_data/7618fafa-1164-40cb-b464-6ac90ad35c60/nationwidechildrens.org_clinical.TCGA-E2-A15J.xml: OK.
# File ../datasets/clinical_data/766f0098-3a5c-40e2-83d2-3c02d06b95b4/nationwidechildrens.org_clinical.TCGA-E2-A1IK.xml: OK.
# File ../datasets/clinical_data/7687181d-8ab3-49e7-8b3c-17883c79ea27/nationwidechildrens.org_clinical.TCGA-BH-A0BZ.xml: OK.
# File ../datasets/clinical_data/76bcb8a8-9222-4e53-9c17-70083c55cb14/nationwidechildrens.org_clinical.TCGA-E2-A14N.xml: OK.
# File ../datasets/clinical_data/76bf2db2-4aff-4ad8-bb8c-e27525cbe201/nationwidechildrens.org_omf.TCGA-AC-A62X.xml: Not contains required columns.
# File ../datasets/clinical_data/76e86c35-49db-4814-bf6f-47b87aee6c66/nationwidechildrens.org_clinical.TCGA-A8-A092.xml: OK.
# ...
# File ../datasets/clinical_data/df77ffad-282d-41f6-84f0-6b4f759369df/nationwidechildrens.org_clinical.TCGA-A8-A093.xml: OK.
# File ../datasets/clinical_data/df8ef24d-f88e-428d-b7c0-0310bc1afdac/nationwidechildrens.org_clinical.TCGA-A2-A0CL.xml: OK.
# File ../datasets/clinical_data/df9aed0e-a9a6-4ce9-9c84-a364f522b4c5/nationwidechildrens.org_clinical.TCGA-AO-A129.xml: OK.
# File ../datasets/clinical_data/dfc14560-ce1a-4d7f-9b03-6777d9ee725a/nationwidechildrens.org_omf.TCGA-A8-A091.xml: Not contains required columns.
# File ../datasets/clinical_data/e00b4a98-9bf6-4e77-82ea-4005adc630a8/nationwidechildrens.org_clinical.TCGA-D8-A1Y0.xml: OK.
# File ../datasets/clinical_data/e03fcb33-7cf8-40fd-bcec-cdec3050d71f/nationwidechildrens.org_clinical.TCGA-AR-A1AX.xml: OK.
# File ../datasets/clinical_data/e0793f64-1448-45c5-92d2-318f64b87915/nationwidechildrens.org_clinical.TCGA-E9-A24A.xml: OK.
# File ../datasets/clinical_data/e092a969-bf22-4266-bcd2-51d2080c0269/nationwidechildrens.org_clinical.TCGA-BH-A0HN.xml: OK.
# File ../datasets/clinical_data/e094828e-082a-4da2-9a66-f1172af28288/nationwidechildrens.org_omf.TCGA-D8-A146.xml: Not contains required columns.
# File ../datasets/clinical_data/e0cc659e-12e0-4a40-b862-3e5b6a463e85/nationwidechildrens.org_clinical.TCGA-D8-A143.xml: OK.
# File ../datasets/clinical_data/e0dde288-e903-46c2-ba05-3dc2b4662a9b/nationwidechildrens.org_clinical.TCGA-BH-A0DQ.xml: OK.
# File ../datasets/clinical_data/e0ed562e-858c-4721-9042-1e108109ea55/nationwidechildrens.org_clinical.TCGA-A8-A09C.xml: OK.
# File ../datasets/clinical_data/e128fa8e-5100-4996-87da-2ec2c1d7d5c9/nationwidechildrens.org_clinical.TCGA-AN-A049.xml: OK.
# File ../datasets/clinical_data/e12fec8b-d49c-4259-97c0-af029b35de12/nationwidechildrens.org_clinical.TCGA-E9-A226.xml: OK.
# File ../datasets/clinical_data/e1cb423c-a7bc-44d8-b460-cf2cda56af90/nationwidechildrens.org_omf.TCGA-GM-A2DD.xml: Not contains required columns.
# File ../datasets/clinical_data/e24de953-c7cc-4536-b3d4-56fc6931278e/nationwidechildrens.org_clinical.TCGA-AR-A24Q.xml: OK.
# File ../datasets/clinical_data/e2654094-6164-4f5c-a736-1a18e6f1ae97/nationwidechildrens.org_clinical.TCGA-E2-A15R.xml: OK.
# File ../datasets/clinical_data/e27e2517-2da0-47a7-af8b-25f20ff7d983/nationwidechildrens.org_clinical.TCGA-E2-A15C.xml: OK.
# File ../datasets/clinical_data/e2bd557f-6103-41c5-90aa-446ad646aae4/nationwidechildrens.org_clinical.TCGA-B6-A0I8.xml: OK.
# File ../datasets/clinical_data/e3578263-d4d3-4a12-bee2-f5d39a213ad3/nationwidechildrens.org_clinical.TCGA-BH-A0BD.xml: OK.
# File ../datasets/clinical_data/e3906724-1663-47d2-902d-61f2bedfab03/nationwidechildrens.org_clinical.TCGA-A8-A08Z.xml: OK.
# File ../datasets/clinical_data/e3b25e2c-7d9f-474f-b9dc-4eb86f563ff4/nationwidechildrens.org_clinical.TCGA-A2-A0D1.xml: OK.
# File ../datasets/clinical_data/e3f0c8ce-08ef-4681-a5c0-a0d7ae79a26d/nationwidechildrens.org_clinical.TCGA-B6-A0I2.xml: OK.
# File ../datasets/clinical_data/e43a1c1b-0a6c-4dd9-824e-000a222dbc17/nationwidechildrens.org_clinical.TCGA-A2-A0SU.xml: OK.
# File ../datasets/clinical_data/e448406d-0677-49a3-84bb-340eafed5534/nationwidechildrens.org_clinical.TCGA-A8-A06P.xml: OK.
# File ../datasets/clinical_data/e48f1a9f-15a3-4191-9d86-d330c3890afe/nationwidechildrens.org_clinical.TCGA-AO-A0JB.xml: OK.
# File ../datasets/clinical_data/e4c112c9-dee4-46b7-8964-a1f01c3830b4/nationwidechildrens.org_clinical.TCGA-C8-A273.xml: OK.
# File ../datasets/clinical_data/e4c81b57-c83e-42f9-bb78-5fc8bbc62658/nationwidechildrens.org_clinical.TCGA-A8-A09I.xml: OK.
# File ../datasets/clinical_data/e56e31f3-9d6c-4baa-b5d1-048ae7bed2eb/nationwidechildrens.org_clinical.TCGA-C8-A27A.xml: OK.
# File ../datasets/clinical_data/e5b5232e-12b0-44bb-ad47-dd2ec169986e/nationwidechildrens.org_clinical.TCGA-AO-A12C.xml: OK.
# File ../datasets/clinical_data/e5c4840c-cb57-4af9-af53-b5bdba0d42c7/nationwidechildrens.org_clinical.TCGA-A8-A08B.xml: OK.
# File ../datasets/clinical_data/e5c572f7-b378-4cfc-8f2c-548e21175d78/nationwidechildrens.org_clinical.TCGA-C8-A1HO.xml: OK.
# File ../datasets/clinical_data/e5f94c5e-9eb6-4125-979d-a34c615d31c7/nationwidechildrens.org_clinical.TCGA-C8-A1HE.xml: OK.
# File ../datasets/clinical_data/e6446932-b37a-4bd5-aa8c-2c8df94efe5d/nationwidechildrens.org_clinical.TCGA-BH-A6R8.xml: OK.
# File ../datasets/clinical_data/e6cd5673-8617-40af-8b43-3c0ce60164a1/nationwidechildrens.org_clinical.TCGA-C8-A12T.xml: OK.
# File ../datasets/clinical_data/e712ba8f-113d-428c-9799-3c2501d62273/nationwidechildrens.org_clinical.TCGA-OL-A5D7.xml: OK.
# File ../datasets/clinical_data/e74ed9f5-6b70-482c-b5ee-96837fa81f38/nationwidechildrens.org_clinical.TCGA-AQ-A0Y5.xml: OK.
# File ../datasets/clinical_data/e791ac24-adf0-47f1-966b-f20436f25fb4/nationwidechildrens.org_clinical.TCGA-A2-A1FZ.xml: OK.
# File ../datasets/clinical_data/e7921257-a2e7-4444-81ba-af4b74e73aae/nationwidechildrens.org_clinical.TCGA-3C-AALJ.xml: OK.
# File ../datasets/clinical_data/e7c0a8aa-b659-40e4-b824-7182f6bb6c2f/nationwidechildrens.org_clinical.TCGA-V7-A7HQ.xml: OK.
# File ../datasets/clinical_data/e7da24c8-76dd-4886-9541-9df037cf934d/nationwidechildrens.org_clinical.TCGA-AR-A255.xml: OK.
# File ../datasets/clinical_data/e8348454-bbcb-49f7-9b5d-fc0dde13c184/nationwidechildrens.org_clinical.TCGA-A7-A6VW.xml: OK.
# File ../datasets/clinical_data/e85ad98d-b3b8-459f-8751-ee3bb79eb797/nationwidechildrens.org_clinical.TCGA-BH-A0W4.xml: OK.
# File ../datasets/clinical_data/e85b67c4-53bf-4d54-a11a-50bfc38a3a75/nationwidechildrens.org_omf.TCGA-E2-A572.xml: Not contains required columns.
# File ../datasets/clinical_data/e884aec3-b508-40f1-a083-5b521fece9d4/nationwidechildrens.org_clinical.TCGA-GM-A2DF.xml: OK.
# File ../datasets/clinical_data/e88e5d64-04c7-4bcb-913f-fd114c63fac9/nationwidechildrens.org_clinical.TCGA-E2-A1LI.xml: OK.
# File ../datasets/clinical_data/e8c4f80a-997d-4baf-ae4e-f00d48d31e29/nationwidechildrens.org_clinical.TCGA-A2-A0ET.xml: OK.
# File ../datasets/clinical_data/e90b4a0a-2c18-4401-873e-cd15975c8c6e/nationwidechildrens.org_clinical.TCGA-B6-A0RE.xml: OK.
# File ../datasets/clinical_data/e94bb525-b657-46e6-92ad-09a9b1c9571d/nationwidechildrens.org_clinical.TCGA-A8-A06Q.xml: OK.
# File ../datasets/clinical_data/ea08fca3-dc9b-4b98-98ac-f18992326ab1/nationwidechildrens.org_clinical.TCGA-LL-A441.xml: OK.
# File ../datasets/clinical_data/ea0d8234-db1c-454e-9a6d-4f503a6ce52c/nationwidechildrens.org_clinical.TCGA-BH-A0DT.xml: OK.
# File ../datasets/clinical_data/ea285c87-ccec-481c-8caa-e07770ee66c9/nationwidechildrens.org_clinical.TCGA-C8-A274.xml: OK.
# File ../datasets/clinical_data/ea3f0338-2b32-4d7b-a3f9-c983cb954b77/nationwidechildrens.org_clinical.TCGA-LL-A442.xml: OK.
# File ../datasets/clinical_data/ea742636-3e07-44bf-b535-ef099be974ea/nationwidechildrens.org_clinical.TCGA-E2-A573.xml: OK.
# File ../datasets/clinical_data/eb239a00-980c-4ff7-9643-4420170dbbe7/nationwidechildrens.org_clinical.TCGA-C8-A26Y.xml: OK.
# File ../datasets/clinical_data/eb3b0efe-be3c-4cef-981e-e6a1eb0e65b1/nationwidechildrens.org_clinical.TCGA-GM-A2D9.xml: OK.
# File ../datasets/clinical_data/eb61e7cf-de8a-431f-98ef-95fbe1055891/nationwidechildrens.org_clinical.TCGA-A2-A0EO.xml: OK.
# File ../datasets/clinical_data/ec13b045-9b94-4955-b3f5-6f7b8f22550e/nationwidechildrens.org_clinical.TCGA-B6-A0WS.xml: OK.
# File ../datasets/clinical_data/ec8f0fd9-dfb1-41e6-a5e1-623ced6dcde0/nationwidechildrens.org_clinical.TCGA-D8-A1JU.xml: OK.
# File ../datasets/clinical_data/ecf55492-7c60-49f4-a7bd-a54bcd8f8f2f/nationwidechildrens.org_clinical.TCGA-A2-A1G4.xml: OK.
# File ../datasets/clinical_data/ed3b7a41-a4ea-40ee-9555-b40ae23154d0/nationwidechildrens.org_clinical.TCGA-A8-A094.xml: OK.
# File ../datasets/clinical_data/ed4bbecf-c10b-4299-9e53-4ef7eaeef843/nationwidechildrens.org_clinical.TCGA-BH-A0DV.xml: OK.
# File ../datasets/clinical_data/ed9a08f2-cafb-4ad7-9af5-825a448aa58b/nationwidechildrens.org_clinical.TCGA-A2-A0EY.xml: OK.
# File ../datasets/clinical_data/ee15c26a-1c33-424a-8072-57a17024a5bf/nationwidechildrens.org_clinical.TCGA-AR-A24N.xml: OK.
# File ../datasets/clinical_data/ee2c842b-d95a-42cb-b9c0-42407be0146f/nationwidechildrens.org_clinical.TCGA-AR-A1AS.xml: OK.
# File ../datasets/clinical_data/ee48372a-b15d-4a06-8ae0-c8bf719cbe21/nationwidechildrens.org_clinical.TCGA-BH-A0HI.xml: OK.
# File ../datasets/clinical_data/ee698dd2-1add-4bba-83d7-b2d14e8f08e7/nationwidechildrens.org_omf.TCGA-OL-A5RU.xml: Not contains required columns.
# File ../datasets/clinical_data/ee9cf11e-420a-48c1-a1a4-b888a65f61fc/nationwidechildrens.org_clinical.TCGA-A7-A13E.xml: OK.
# File ../datasets/clinical_data/ee9eced5-3079-41d9-a601-aa77689a12f2/nationwidechildrens.org_clinical.TCGA-AN-A0XL.xml: OK.
# File ../datasets/clinical_data/eef0c424-f02b-4fe6-a881-0bd68b8ee216/nationwidechildrens.org_clinical.TCGA-A8-A084.xml: OK.
# File ../datasets/clinical_data/eef2a297-e071-45c0-b832-30674221ce3b/nationwidechildrens.org_clinical.TCGA-AN-A0G0.xml: OK.
# File ../datasets/clinical_data/ef23dcf9-d93b-43ec-bba0-1238c311c355/nationwidechildrens.org_clinical.TCGA-D8-A13Y.xml: OK.
# File ../datasets/clinical_data/ef49519f-f30d-4781-9883-1cc6068cbfe5/nationwidechildrens.org_clinical.TCGA-AN-A0XR.xml: OK.
# File ../datasets/clinical_data/efb05f91-dffc-4ec6-969c-eae705cda834/nationwidechildrens.org_clinical.TCGA-D8-A1JI.xml: OK.
# File ../datasets/clinical_data/efba5112-e4ec-4878-9eb2-203cfe0799f1/nationwidechildrens.org_clinical.TCGA-E9-A227.xml: OK.
# File ../datasets/clinical_data/efd86c2b-4fd5-40d8-9c96-a80fc7ef9689/nationwidechildrens.org_clinical.TCGA-E2-A574.xml: OK.
# File ../datasets/clinical_data/efeb610a-2a2e-422a-b46a-27215698b797/nationwidechildrens.org_clinical.TCGA-A8-A086.xml: OK.
# File ../datasets/clinical_data/f04655d7-3575-4a0e-8622-ede68f057572/nationwidechildrens.org_clinical.TCGA-A7-A0CE.xml: OK.
# File ../datasets/clinical_data/f0b24353-c901-4ea4-8aaa-d870ee39c0c6/nationwidechildrens.org_clinical.TCGA-BH-A0DH.xml: OK.
# File ../datasets/clinical_data/f1263c03-a16e-4467-ad5f-a3d50e643a84/nationwidechildrens.org_clinical.TCGA-B6-A401.xml: OK.
# File ../datasets/clinical_data/f1891504-8531-4550-b1ca-fac9581b0be5/nationwidechildrens.org_clinical.TCGA-GM-A2DB.xml: OK.
# File ../datasets/clinical_data/f1900ead-37fd-4ca7-8aa3-670b6bfb9cb1/nationwidechildrens.org_clinical.TCGA-A2-A0ST.xml: OK.
# File ../datasets/clinical_data/f1a54fb6-0a25-415c-aadb-479e9dbaf8ad/nationwidechildrens.org_clinical.TCGA-B6-A0WT.xml: OK.
# File ../datasets/clinical_data/f28fdc37-9044-4894-adbb-43c14c73b579/nationwidechildrens.org_clinical.TCGA-D8-A1Y2.xml: OK.
# File ../datasets/clinical_data/f2944b79-5517-4064-98d1-160c6a6c75f0/nationwidechildrens.org_clinical.TCGA-D8-A1XM.xml: OK.
# File ../datasets/clinical_data/f2b02a00-542f-4d85-a66b-d16e9f1b3a56/nationwidechildrens.org_clinical.TCGA-BH-A0BW.xml: OK.
# File ../datasets/clinical_data/f363ebbb-167c-4bf9-8b91-c8d25ad63543/nationwidechildrens.org_clinical.TCGA-LL-A8F5.xml: OK.
# File ../datasets/clinical_data/f44291d2-8920-493e-a324-e19c74caa54b/nationwidechildrens.org_clinical.TCGA-E9-A1RD.xml: OK.
# File ../datasets/clinical_data/f465585a-05ff-4e81-8eb6-6f17735b24b9/nationwidechildrens.org_clinical.TCGA-OL-A6VO.xml: OK.
# File ../datasets/clinical_data/f475e8d4-db1f-4b9d-9d13-32fbc0541e10/nationwidechildrens.org_clinical.TCGA-B6-A0I5.xml: OK.
# File ../datasets/clinical_data/f4ea8ea9-c4f2-4f93-a259-29d49be19ef8/nationwidechildrens.org_clinical.TCGA-BH-A1FD.xml: OK.
# File ../datasets/clinical_data/f4ee270b-1817-4403-9614-f69bc6c1c810/nationwidechildrens.org_clinical.TCGA-D8-A1XR.xml: OK.
# File ../datasets/clinical_data/f4fe86ca-0c72-47ff-b160-d4772b1297e7/nationwidechildrens.org_clinical.TCGA-BH-A0B9.xml: OK.
# File ../datasets/clinical_data/f5a427b1-65f8-4244-a0d9-6a9a87e3bcd7/nationwidechildrens.org_clinical.TCGA-BH-A0AV.xml: OK.
# File ../datasets/clinical_data/f5f931b1-5061-4142-a5b4-4397d69f0efc/nationwidechildrens.org_clinical.TCGA-BH-A0HQ.xml: OK.
# File ../datasets/clinical_data/f68d90b2-6d21-47ab-89a0-f95220d72892/nationwidechildrens.org_clinical.TCGA-C8-A137.xml: OK.
# File ../datasets/clinical_data/f6a30e7e-dbd2-46ae-ad74-6d93e44e10c2/nationwidechildrens.org_clinical.TCGA-S3-AA17.xml: OK.
# File ../datasets/clinical_data/f6d03a60-4dc1-4e94-9c02-857c558735ca/nationwidechildrens.org_clinical.TCGA-AN-A0FK.xml: OK.
# File ../datasets/clinical_data/f7dd6841-37ca-4e68-b0cb-1a86b31d2e7c/nationwidechildrens.org_clinical.TCGA-D8-A1JH.xml: OK.
# File ../datasets/clinical_data/f7e96a5e-da81-47be-ad1c-89092c4a8ba5/nationwidechildrens.org_clinical.TCGA-BH-A0H0.xml: OK.
# File ../datasets/clinical_data/f8254292-5536-4d2c-95c3-74e7514e677c/nationwidechildrens.org_clinical.TCGA-AN-A0XW.xml: OK.
# File ../datasets/clinical_data/f968f75e-43a4-46cd-9c4d-744bc2a93206/nationwidechildrens.org_clinical.TCGA-B6-A1KI.xml: OK.
# File ../datasets/clinical_data/f9d47e8f-674e-4660-8efa-f6435d157bc4/nationwidechildrens.org_clinical.TCGA-A8-A07C.xml: OK.
# File ../datasets/clinical_data/f9f099cb-8af7-4080-af91-87778e09a91f/nationwidechildrens.org_clinical.TCGA-EW-A1IY.xml: OK.
# File ../datasets/clinical_data/fa33210b-9370-40b3-a330-e7de33f1f217/nationwidechildrens.org_omf.TCGA-S3-AA17.xml: Not contains required columns.
# File ../datasets/clinical_data/fa3ccaab-014a-41a9-8303-f6c3a10f1aca/nationwidechildrens.org_clinical.TCGA-AN-A0AL.xml: OK.
# File ../datasets/clinical_data/fa74dbf9-1918-4f14-ab6f-322def041c7d/nationwidechildrens.org_clinical.TCGA-A2-A0CM.xml: OK.
# File ../datasets/clinical_data/fabb590e-eaa6-40bd-a435-a79116d0c5c2/nationwidechildrens.org_clinical.TCGA-LL-A7SZ.xml: OK.
# File ../datasets/clinical_data/faf9e65a-90f2-4891-aaec-d31fb58a5993/nationwidechildrens.org_clinical.TCGA-D8-A1JE.xml: OK.
# File ../datasets/clinical_data/fb1dfac6-347b-4113-b03a-2a00cdf69cf3/nationwidechildrens.org_clinical.TCGA-BH-A0BO.xml: OK.
# File ../datasets/clinical_data/fb5f9cf0-f068-4ae7-bdd3-c6d5209f04d1/nationwidechildrens.org_clinical.TCGA-A8-A08G.xml: OK.
# File ../datasets/clinical_data/fc5f02e2-fc38-4702-9664-bded31b070b2/nationwidechildrens.org_clinical.TCGA-AR-A1AR.xml: OK.
# File ../datasets/clinical_data/fcda6113-b7a5-4504-a4a4-c204bbf95402/nationwidechildrens.org_clinical.TCGA-A2-A0YT.xml: OK.
# File ../datasets/clinical_data/fcfc8953-3d78-42ea-a48a-ac9f1b7c3e01/nationwidechildrens.org_clinical.TCGA-AN-A0XO.xml: OK.
# File ../datasets/clinical_data/fcfe3504-499f-4523-98c0-6cde493fd39a/nationwidechildrens.org_clinical.TCGA-A2-A0CZ.xml: OK.
# File ../datasets/clinical_data/fd4f1a8d-6208-45ee-aa98-3e1bb7e74d51/nationwidechildrens.org_clinical.TCGA-E9-A1R2.xml: OK.
# File ../datasets/clinical_data/fdc41732-6266-48ed-8f81-c942290085d4/nationwidechildrens.org_clinical.TCGA-AC-A23C.xml: OK.
# File ../datasets/clinical_data/fdccc014-12e1-4600-b6f1-1ccdb19e3e89/nationwidechildrens.org_clinical.TCGA-BH-A0BL.xml: OK.
# File ../datasets/clinical_data/fe89076f-4f25-4ad7-8ef2-ab0c4a4cdcb0/nationwidechildrens.org_clinical.TCGA-A8-A076.xml: OK.
# File ../datasets/clinical_data/ff17354b-9db5-4c98-9f9d-764d178bee17/nationwidechildrens.org_clinical.TCGA-A1-A0SN.xml: OK.
# File ../datasets/clinical_data/ff3e5f88-9279-4296-9831-a791b12837c6/nationwidechildrens.org_clinical.TCGA-A8-A08O.xml: OK.
# File ../datasets/clinical_data/ff516902-0a72-407e-ac1d-45fa20fa910c/nationwidechildrens.org_clinical.TCGA-AC-A8OQ.xml: OK.
# File ../datasets/clinical_data/ff679dd3-62be-4332-8157-0a83ffb8516a/nationwidechildrens.org_omf.TCGA-AQ-A54O.xml: Not contains required columns.
# File ../datasets/clinical_data/ff8117d3-237d-4e08-9633-f8f425381cd5/nationwidechildrens.org_clinical.TCGA-E9-A22D.xml: OK.
# File ../datasets/clinical_data/ff8e1327-3b0e-4d91-a577-9d7da3e30d22/nationwidechildrens.org_clinical.TCGA-AR-A24L.xml: OK.
# File ../datasets/clinical_data/ffb2e9d9-07dd-48dd-9c37-9f87c28b5b2c/nationwidechildrens.org_clinical.TCGA-E2-A1LK.xml: OK.
#
# ------------------------------------------------
# -> Number of xml files found: 818
# 	-> Number of 'omf' xml files found: 47
# -> Number of txt files found: 9
# -> Number of non-xml and non-txt files found: 50
# -> Total subfolders: 827
# ------------------------------------------------

# %% [markdown]
# Previous output:
# ```python
#     ------------------------------------------------
#     -> Number of xml files found: 818
#         -> Number of 'omf' xml files found: 47
#     -> Number of txt files found: 9
#     -> Number of non-xml and non-txt files found: 0
#     -> Total subfolders: 827
#     ------------------------------------------------
# ```
#
#
# **OMF files**
# The OMF (Other Malignancy Form) files keep clinical information and do not contain laboratory or transcriptomic data, such as mRNA or RNA-Seq.

# %% [markdown]
# ### Explore columns of clinical XML files

# %% [markdown]
# #### See an example of **org_clinical** XML file:

# %%
file_path = "../datasets/clinical_data/0a9561ad-0d8e-4776-be26-c9d7b2825045/nationwidechildrens.org_clinical.TCGA-B6-A0IG.xml"
temp_df = pd.read_xml(file_path, parser="etree")
pd.set_option('display.max_colwidth', None)
temp_df.describe()
# Out:
#        day_of_dcc_upload  month_of_dcc_upload  year_of_dcc_upload  program  \
# count                1.0                  1.0                 1.0      0.0
# mean                22.0                 12.0              2016.0      NaN
# std                  NaN                  NaN                 NaN      NaN
# min                 22.0                 12.0              2016.0      NaN
# 25%                 22.0                 12.0              2016.0      NaN
# 50%                 22.0                 12.0              2016.0      NaN
# 75%                 22.0                 12.0              2016.0      NaN
# max                 22.0                 12.0              2016.0      NaN
#
#        dbgap_registration_code  additional_studies  tumor_tissue_site_other  \
# count                      0.0                 0.0                      0.0
# mean                       NaN                 NaN                      NaN
# std                        NaN                 NaN                      NaN
# min                        NaN                 NaN                      NaN
# 25%                        NaN                 NaN                      NaN
# 50%                        NaN                 NaN                      NaN
# 75%                        NaN                 NaN                      NaN
# max                        NaN                 NaN                      NaN
#
#        days_to_birth  days_to_last_known_alive  days_to_death  ...  \
# count            1.0                       0.0            1.0  ...
# mean        -18433.0                       NaN         4456.0  ...
# std              NaN                       NaN            NaN  ...
# min         -18433.0                       NaN         4456.0  ...
# 25%         -18433.0                       NaN         4456.0  ...
# 50%         -18433.0                       NaN         4456.0  ...
# 75%         -18433.0                       NaN         4456.0  ...
# max         -18433.0                       NaN         4456.0  ...
#
#        her2_neu_breast_carcinoma_copy_analysis_input_total_number  \
# count                                                         0.0
# mean                                                          NaN
# std                                                           NaN
# min                                                           NaN
# 25%                                                           NaN
# 50%                                                           NaN
# 75%                                                           NaN
# max                                                           NaN
#
#        breast_carcinoma_immunohistochemistry_progesterone_receptor_pos_finding_scale  \
# count                                                                            0.0
# mean                                                                             NaN
# std                                                                              NaN
# min                                                                              NaN
# 25%                                                                              NaN
# 50%                                                                              NaN
# 75%                                                                              NaN
# max                                                                              NaN
#
#        breast_carcinoma_immunohistochemistry_pos_cell_score  \
# count                                                   0.0
# mean                                                    NaN
# std                                                     NaN
# min                                                     NaN
# 25%                                                     NaN
# 50%                                                     NaN
# 75%                                                     NaN
# max                                                     NaN
#
#        postoperative_rx_tx  radiation_therapy  day_of_form_completion  \
# count                  0.0                0.0                     1.0
# mean                   NaN                NaN                     2.0
# std                    NaN                NaN                     NaN
# min                    NaN                NaN                     2.0
# 25%                    NaN                NaN                     2.0
# 50%                    NaN                NaN                     2.0
# 75%                    NaN                NaN                     2.0
# max                    NaN                NaN                     2.0
#
#        month_of_form_completion  year_of_form_completion  drugs  radiations
# count                       1.0                      1.0    0.0         0.0
# mean                       11.0                   2010.0    NaN         NaN
# std                         NaN                      NaN    NaN         NaN
# min                        11.0                   2010.0    NaN         NaN
# 25%                        11.0                   2010.0    NaN         NaN
# 50%                        11.0                   2010.0    NaN         NaN
# 75%                        11.0                   2010.0    NaN         NaN
# max                        11.0                   2010.0    NaN         NaN
#
# [8 rows x 74 columns]

# %%
file_path = "../datasets/clinical_data/ffb2e9d9-07dd-48dd-9c37-9f87c28b5b2c/nationwidechildrens.org_clinical.TCGA-E2-A1LK.xml"
temp_df = pd.read_xml(file_path, parser="etree")
columns_to_select = temp_df.columns[temp_df.columns.str.contains('age|year|days|case|time', case=False)]
print(f"COLUMNS of a xml file, with 'age|year|days|case':\n\t{columns_to_select}")
# Out:
# COLUMNS of a xml file, with 'age|year|days|case':
# 	Index(['year_of_dcc_upload', 'days_to_birth', 'days_to_last_known_alive',
#        'days_to_death', 'days_to_last_followup',
#        'days_to_initial_pathologic_diagnosis',
#        'age_at_initial_pathologic_diagnosis',
#        'year_of_initial_pathologic_diagnosis',
#        'axillary_lymph_node_stage_method_type',
#        'axillary_lymph_node_stage_other_method_descriptive_text',
#        'er_level_cell_percentage_category', 'stage_event',
#        'year_of_form_completion'],
#       dtype='object')

# %% [markdown]
# #### See an example of org_omf XML file:

# %%
file_path = "../datasets/clinical_data/ff679dd3-62be-4332-8157-0a83ffb8516a/nationwidechildrens.org_omf.TCGA-AQ-A54O.xml"
temp_df = pd.read_xml(file_path, parser="etree")
print(f"COLUMNS of an 'omf' xml file:\n\t{temp_df.columns}")
# Out:
# COLUMNS of an 'omf' xml file:
# 	Index(['bcr', 'file_uuid', 'batch_number', 'project_code', 'disease_code',
#        'day_of_dcc_upload', 'month_of_dcc_upload', 'year_of_dcc_upload',
#        'patient_withdrawal', 'program', 'dbgap_registration_code',
#        'additional_studies', 'tissue_source_site', 'patient_id',
#        'bcr_patient_barcode', 'bcr_patient_uuid', 'omfs'],
#       dtype='object')

# %% [markdown]
# We can see that in the omf files there is no information about age or days to birth, so we will discard these files for our analysis.

# %% [markdown]
# ## Check matching between 'days_to_birth' and 'age_at_initial_pathologic_diagnosis' columns:

# %%
FLAG = True

def check_age_days(file_path):
    temp_df = pd.read_xml(file_path, parser="etree")

    if 'days_to_birth' in temp_df.columns and 'age_at_initial_pathologic_diagnosis' in temp_df.columns:
        temp_df = temp_df[["days_to_birth", "age_at_initial_pathologic_diagnosis"]]
        temp_df = temp_df.dropna(how='all')

        rows_with_nan = temp_df[temp_df.isna().any(axis=1)]
        if rows_with_nan.empty:
            # Convert days_to_birth to years
            temp_df.loc[:, "days_to_birth"] = -(temp_df["days_to_birth"]) / 365
            temp_df["days_to_birth"] = temp_df["days_to_birth"].astype(int)

            if abs(temp_df.iloc[0]["days_to_birth"] - temp_df.iloc[0]["age_at_initial_pathologic_diagnosis"]) > 1:
                print(f"{temp_df.iloc[0]['days_to_birth']} != {temp_df.iloc[0]['age_at_initial_pathologic_diagnosis']}")
                FLAG = False
            else:
                print(f"{temp_df.iloc[0]['days_to_birth']} == {temp_df.iloc[0]['age_at_initial_pathologic_diagnosis']}")

for subfolder in os.listdir(CLINICAL_PATH):
    for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
        if file.endswith(".xml"):
            check_age_days(f"{CLINICAL_PATH}/{subfolder}/{file}")
            
if FLAG is False:
    print("\n-> Some age_at_initial_pathologic_diagnosis & days_to_birth mismatches found.")
else:
    print("\n-> All age_at_initial_pathologic_diagnosis & days_to_birth match.")
# Out:
# 71.0 == 71.0
# 53.0 == 53.0
# 59.0 == 59.0
# 55.0 == 55.0
# 64.0 == 64.0
# 46.0 == 46.0
# 67.0 == 67.0
# 62.0 == 62.0
# 62.0 == 62.0
# 65.0 == 65.0
# 32.0 == 32.0
# 36.0 == 36.0
# 81.0 == 81.0
# 53.0 == 53.0
# 59.0 == 59.0
# 86.0 == 86.0
# 56.0 == 56.0
# 55.0 == 55.0
# 58.0 == 58.0
# 74.0 == 73.0
# 66.0 == 66.0
# 61.0 == 61.0
# 51.0 == 51.0
# 47.0 == 47.0
# 47.0 == 47.0
# 39.0 == 39.0
# 57.0 == 57.0
# 50.0 == 50.0
# 66.0 == 66.0
# 47.0 == 47.0
# 53.0 == 53.0
# 50.0 == 50.0
# 72.0 == 72.0
# 45.0 == 45.0
# 52.0 == 52.0
# 51.0 == 51.0
# 66.0 == 66.0
# 56.0 == 56.0
# 65.0 == 65.0
# 55.0 == 55.0
# 47.0 == 47.0
# 63.0 == 63.0
# 51.0 == 51.0
# 55.0 == 55.0
# 40.0 == 40.0
# 83.0 == 83.0
# 52.0 == 52.0
# 60.0 == 60.0
# 65.0 == 65.0
# 67.0 == 67.0
# 48.0 == 47.0
# 58.0 == 58.0
# 55.0 == 54.0
# 58.0 == 58.0
# 48.0 == 48.0
# 67.0 == 67.0
# 63.0 == 63.0
# 83.0 == 83.0
# 47.0 == 47.0
# 34.0 == 34.0
# 59.0 == 59.0
# 40.0 == 40.0
# 40.0 == 40.0
# 43.0 == 43.0
# 34.0 == 34.0
# 63.0 == 63.0
# 69.0 == 69.0
# 81.0 == 81.0
# 49.0 == 49.0
# 46.0 == 46.0
# 41.0 == 41.0
# 42.0 == 42.0
# 64.0 == 64.0
# 61.0 == 61.0
# 40.0 == 40.0
# 61.0 == 61.0
# 79.0 == 79.0
# 53.0 == 53.0
# 47.0 == 47.0
# 73.0 == 73.0
# 51.0 == 51.0
# 59.0 == 59.0
# 76.0 == 76.0
# 27.0 == 27.0
# 63.0 == 63.0
# 46.0 == 46.0
# 57.0 == 57.0
# 58.0 == 58.0
# 55.0 == 55.0
# 42.0 == 42.0
# 80.0 == 80.0
# 50.0 == 50.0
# 49.0 == 49.0
# 51.0 == 51.0
# 40.0 == 40.0
# 78.0 == 78.0
# 70.0 == 70.0
# 62.0 == 62.0
# 45.0 == 45.0
# 58.0 == 58.0
# 41.0 == 41.0
# 63.0 == 63.0
# 50.0 == 50.0
# 52.0 == 52.0
# 73.0 == 73.0
# 66.0 == 66.0
# 89.0 == 89.0
# 58.0 == 58.0
# 48.0 == 48.0
# 49.0 == 49.0
# 50.0 == 50.0
# 41.0 == 41.0
# 48.0 == 48.0
# 67.0 == 67.0
# 63.0 == 63.0
# 59.0 == 59.0
# 59.0 == 59.0
# 29.0 == 29.0
# 67.0 == 67.0
# 68.0 == 68.0
# 72.0 == 72.0
# 58.0 == 58.0
# 90.0 == 90.0
# 71.0 == 71.0
# 54.0 == 54.0
# 60.0 == 60.0
# 62.0 == 62.0
# 59.0 == 59.0
# 67.0 == 67.0
# 90.0 == 90.0
# 79.0 == 79.0
# 45.0 == 45.0
# 36.0 == 36.0
# 62.0 == 62.0
# 55.0 == 55.0
# 37.0 == 37.0
# 38.0 == 38.0
# 66.0 == 66.0
# 66.0 == 66.0
# 70.0 == 70.0
# 62.0 == 62.0
# 70.0 == 70.0
# 45.0 == 45.0
# 58.0 == 58.0
# 29.0 == 29.0
# 67.0 == 67.0
# 62.0 == 62.0
# 49.0 == 49.0
# 75.0 == 75.0
# 65.0 == 65.0
# 51.0 == 51.0
# 61.0 == 61.0
# 52.0 == 52.0
# 54.0 == 54.0
# 34.0 == 34.0
# 66.0 == 66.0
# 47.0 == 47.0
# 54.0 == 54.0
# 45.0 == 45.0
# 83.0 == 83.0
# 77.0 == 77.0
# 52.0 == 52.0
# 56.0 == 56.0
# 54.0 == 54.0
# 80.0 == 80.0
# 45.0 == 45.0
# 37.0 == 37.0
# 52.0 == 52.0
# 64.0 == 64.0
# 48.0 == 48.0
# 44.0 == 44.0
# 64.0 == 64.0
# 61.0 == 61.0
# 36.0 == 36.0
# 67.0 == 67.0
# 76.0 == 76.0
# 56.0 == 56.0
# 58.0 == 58.0
# 64.0 == 64.0
# 57.0 == 57.0
# 56.0 == 56.0
# 47.0 == 47.0
# 51.0 == 51.0
# 34.0 == 34.0
# 50.0 == 50.0
# 48.0 == 48.0
# 66.0 == 66.0
# 45.0 == 45.0
# 47.0 == 47.0
# 63.0 == 63.0
# 62.0 == 62.0
# 69.0 == 69.0
# 51.0 == 51.0
# 56.0 == 56.0
# 56.0 == 56.0
# 46.0 == 46.0
# 52.0 == 52.0
# 61.0 == 61.0
# 63.0 == 63.0
# 70.0 == 69.0
# 62.0 == 62.0
# 29.0 == 29.0
# 29.0 == 29.0
# 66.0 == 66.0
# 77.0 == 77.0
# 37.0 == 37.0
# 89.0 == 89.0
# 89.0 == 89.0
# 58.0 == 58.0
# 60.0 == 59.0
# 68.0 == 68.0
# 40.0 == 40.0
# 73.0 == 73.0
# 62.0 == 62.0
# 78.0 == 78.0
# 51.0 == 51.0
# 45.0 == 45.0
# 56.0 == 56.0
# 59.0 == 59.0
# 54.0 == 54.0
# 42.0 == 42.0
# 44.0 == 44.0
# 52.0 == 52.0
# 43.0 == 43.0
# 48.0 == 48.0
# 61.0 == 61.0
# 76.0 == 76.0
# 58.0 == 58.0
# 78.0 == 78.0
# 75.0 == 75.0
# 88.0 == 88.0
# 71.0 == 71.0
# 36.0 == 36.0
# 48.0 == 48.0
# 39.0 == 39.0
# 69.0 == 69.0
# 63.0 == 63.0
# 77.0 == 77.0
# 78.0 == 78.0
# 60.0 == 59.0
# 82.0 == 82.0
# 72.0 == 72.0
# 42.0 == 42.0
# 38.0 == 38.0
# 66.0 == 66.0
# 56.0 == 55.0
# 52.0 == 52.0
# 48.0 == 47.0
# 73.0 == 73.0
# 52.0 == 52.0
# 59.0 == 59.0
# 65.0 == 65.0
# 42.0 == 42.0
# 38.0 == 38.0
# 70.0 == 70.0
# 66.0 == 66.0
# 74.0 == 74.0
# 66.0 == 66.0
# 37.0 == 37.0
# 71.0 == 71.0
# 56.0 == 56.0
# 72.0 == 72.0
# 61.0 == 61.0
# 63.0 == 63.0
# 70.0 == 70.0
# 48.0 == 48.0
# 61.0 == 61.0
# 71.0 == 71.0
# 59.0 == 59.0
# 64.0 == 64.0
# 80.0 == 80.0
# 67.0 == 67.0
# 63.0 == 63.0
# 60.0 == 60.0
# 39.0 == 39.0
# 35.0 == 35.0
# 41.0 == 41.0
# 48.0 == 48.0
# 45.0 == 45.0
# 44.0 == 44.0
# 36.0 == 36.0
# 60.0 == 60.0
# 41.0 == 41.0
# 53.0 == 53.0
# 52.0 == 52.0
# 46.0 == 46.0
# 80.0 == 80.0
# 47.0 == 47.0
# 74.0 == 74.0
# 59.0 == 59.0
# 69.0 == 68.0
# 36.0 == 36.0
# 58.0 == 58.0
# 79.0 == 79.0
# 62.0 == 62.0
# 69.0 == 69.0
# 45.0 == 45.0
# 57.0 == 57.0
# 34.0 == 34.0
# 49.0 == 49.0
# 64.0 == 64.0
# 43.0 == 43.0
# 36.0 == 36.0
# 37.0 == 37.0
# 76.0 == 76.0
# 48.0 == 48.0
# 52.0 == 52.0
# 65.0 == 65.0
# 59.0 == 59.0
# 34.0 == 34.0
# 46.0 == 46.0
# 59.0 == 59.0
# 68.0 == 68.0
# 71.0 == 71.0
# 62.0 == 62.0
# 30.0 == 30.0
# 64.0 == 64.0
# 60.0 == 60.0
# 53.0 == 53.0
# 42.0 == 42.0
# 45.0 == 45.0
# 61.0 == 60.0
# 88.0 == 88.0
# 50.0 == 50.0
# 61.0 == 61.0
# 52.0 == 52.0
# 73.0 == 73.0
# 63.0 == 63.0
# 62.0 == 62.0
# 63.0 == 63.0
# 47.0 == 47.0
# 44.0 == 44.0
# 54.0 == 54.0
# 55.0 == 55.0
# 74.0 == 74.0
# 41.0 == 41.0
# 51.0 == 50.0
# 42.0 == 42.0
# 62.0 == 62.0
# 63.0 == 62.0
# 57.0 == 57.0
# 65.0 == 65.0
# 61.0 == 61.0
# 49.0 == 49.0
# 79.0 == 79.0
# 71.0 == 71.0
# 58.0 == 58.0
# 56.0 == 56.0
# 68.0 == 68.0
# 48.0 == 48.0
# 68.0 == 68.0
# 55.0 == 55.0
# 73.0 == 73.0
# 68.0 == 68.0
# 41.0 == 41.0
# 70.0 == 70.0
# 51.0 == 51.0
# 51.0 == 51.0
# 71.0 == 71.0
# 59.0 == 59.0
# 37.0 == 37.0
# 48.0 == 48.0
# 58.0 == 58.0
# 40.0 == 40.0
# 58.0 == 58.0
# 80.0 == 80.0
# 69.0 == 69.0
# 39.0 == 39.0
# 75.0 == 75.0
# 40.0 == 40.0
# 78.0 == 78.0
# 61.0 == 61.0
# 57.0 == 57.0
# 74.0 == 74.0
# 70.0 == 70.0
# 57.0 == 57.0
# 64.0 == 64.0
# 53.0 == 53.0
# 26.0 == 26.0
# 62.0 == 62.0
# 45.0 == 45.0
# 64.0 == 64.0
# 79.0 == 79.0
# 49.0 == 49.0
# 48.0 == 48.0
# 50.0 == 50.0
# 90.0 == 90.0
# 67.0 == 67.0
# 61.0 == 61.0
# 49.0 == 49.0
# 51.0 == 51.0
# 69.0 == 69.0
# 52.0 == 51.0
# 63.0 == 63.0
# 69.0 == 69.0
# 50.0 == 50.0
# 47.0 == 47.0
# 50.0 == 50.0
# 50.0 == 50.0
# 84.0 == 84.0
# 68.0 == 68.0
# 47.0 == 47.0
# 50.0 == 50.0
# 82.0 == 82.0
# 44.0 == 44.0
# 57.0 == 57.0
# 41.0 == 41.0
# 74.0 == 74.0
# 48.0 == 48.0
# 53.0 == 53.0
# 46.0 == 46.0
# 63.0 == 63.0
# 72.0 == 72.0
# 48.0 == 48.0
# 60.0 == 60.0
# 31.0 == 31.0
# 66.0 == 66.0
# 47.0 == 47.0
# 52.0 == 52.0
# 68.0 == 67.0
# 46.0 == 46.0
# 80.0 == 80.0
# 55.0 == 55.0
# 46.0 == 46.0
# 64.0 == 64.0
# 85.0 == 85.0
# 60.0 == 60.0
# 76.0 == 76.0
# 90.0 == 90.0
# 41.0 == 41.0
# 49.0 == 49.0
# 76.0 == 76.0
# 52.0 == 52.0
# 68.0 == 68.0
# 67.0 == 67.0
# 70.0 == 70.0
# 54.0 == 54.0
# 59.0 == 59.0
# 60.0 == 60.0
# 61.0 == 61.0
# 50.0 == 50.0
# 77.0 == 77.0
# 40.0 == 40.0
# 62.0 == 62.0
# 62.0 == 62.0
# 57.0 == 57.0
# 78.0 == 78.0
# 77.0 == 77.0
# 56.0 == 56.0
# 79.0 == 79.0
# 80.0 == 80.0
# 79.0 == 79.0
# 34.0 == 34.0
# 64.0 == 64.0
# 51.0 == 51.0
# 59.0 == 59.0
# 77.0 == 77.0
# 81.0 == 81.0
# 57.0 == 57.0
# 80.0 == 80.0
# 61.0 == 61.0
# 55.0 == 55.0
# 58.0 == 58.0
# 64.0 == 64.0
# 59.0 == 59.0
# 80.0 == 80.0
# 45.0 == 45.0
# 52.0 == 52.0
# 71.0 == 71.0
# 45.0 == 45.0
# 73.0 == 73.0
# 35.0 == 35.0
# 85.0 == 85.0
# 59.0 == 59.0
# 62.0 == 62.0
# 69.0 == 69.0
# 44.0 == 44.0
# 48.0 == 48.0
# 41.0 == 41.0
# 53.0 == 53.0
# 30.0 == 30.0
# 46.0 == 46.0
# 39.0 == 39.0
# 62.0 == 62.0
# 46.0 == 46.0
# 63.0 == 63.0
# 49.0 == 49.0
# 54.0 == 54.0
# 39.0 == 39.0
# 40.0 == 40.0
# 80.0 == 80.0
# 68.0 == 68.0
# 50.0 == 50.0
# 35.0 == 35.0
# 35.0 == 35.0
# 41.0 == 41.0
# 43.0 == 43.0
# 66.0 == 66.0
# 51.0 == 51.0
# 45.0 == 45.0
# 60.0 == 60.0
# 67.0 == 67.0
# 84.0 == 84.0
# 44.0 == 44.0
# 63.0 == 63.0
# 40.0 == 40.0
# 51.0 == 51.0
# 48.0 == 48.0
# 51.0 == 51.0
# 69.0 == 69.0
# 65.0 == 65.0
# 70.0 == 70.0
# 66.0 == 66.0
# 52.0 == 52.0
# 44.0 == 44.0
# 39.0 == 39.0
# 63.0 == 62.0
# 61.0 == 61.0
# 65.0 == 65.0
# 60.0 == 60.0
# 62.0 == 62.0
# 45.0 == 45.0
# 54.0 == 54.0
# 63.0 == 63.0
# 58.0 == 58.0
# 52.0 == 52.0
# 84.0 == 84.0
# 63.0 == 63.0
# 43.0 == 43.0
# 39.0 == 39.0
# 53.0 == 53.0
# 58.0 == 58.0
# 80.0 == 80.0
# 75.0 == 74.0
# 64.0 == 64.0
# 49.0 == 49.0
# 78.0 == 78.0
# 53.0 == 53.0
# 59.0 == 59.0
# 58.0 == 57.0
# 61.0 == 61.0
# 62.0 == 62.0
# 67.0 == 67.0
# 56.0 == 56.0
# 43.0 == 43.0
# 73.0 == 73.0
# 51.0 == 51.0
# 59.0 == 59.0
# 58.0 == 58.0
# 73.0 == 73.0
# 66.0 == 66.0
# 43.0 == 43.0
# 50.0 == 50.0
# 43.0 == 43.0
# 47.0 == 47.0
# 58.0 == 58.0
# 78.0 == 78.0
# 40.0 == 40.0
# 64.0 == 64.0
# 72.0 == 72.0
# 75.0 == 75.0
# 40.0 == 40.0
# 71.0 == 71.0
# 49.0 == 49.0
# 54.0 == 54.0
# 82.0 == 82.0
# 84.0 == 84.0
# 79.0 == 79.0
# 62.0 == 62.0
# 82.0 == 82.0
# 50.0 == 50.0
# 38.0 == 38.0
# 65.0 == 65.0
# 34.0 == 34.0
# 54.0 == 54.0
# 51.0 == 51.0
# 45.0 == 45.0
# 54.0 == 54.0
# 64.0 == 64.0
# 56.0 == 56.0
# 65.0 == 65.0
# 49.0 == 49.0
# 73.0 == 73.0
# 47.0 == 47.0
# 82.0 == 82.0
# 59.0 == 59.0
# 72.0 == 72.0
# 69.0 == 69.0
# 66.0 == 66.0
# 50.0 == 50.0
# 47.0 == 47.0
# 56.0 == 56.0
# 68.0 == 68.0
# 35.0 == 35.0
# 58.0 == 58.0
# 69.0 == 69.0
# 55.0 == 55.0
# 51.0 == 51.0
# 54.0 == 54.0
# 63.0 == 63.0
# 37.0 == 36.0
# 68.0 == 68.0
# 38.0 == 38.0
# 53.0 == 53.0
# 56.0 == 56.0
# 60.0 == 60.0
# 68.0 == 68.0
# 39.0 == 39.0
# 51.0 == 51.0
# 74.0 == 74.0
# 65.0 == 65.0
# 50.0 == 50.0
# 58.0 == 58.0
# 43.0 == 43.0
# 46.0 == 46.0
# 55.0 == 55.0
# 74.0 == 74.0
# 77.0 == 77.0
# 77.0 == 77.0
# 79.0 == 79.0
# 36.0 == 36.0
# 73.0 == 73.0
# 56.0 == 56.0
# 64.0 == 64.0
# 35.0 == 35.0
# 44.0 == 44.0
# 49.0 == 49.0
# 45.0 == 45.0
# 31.0 == 31.0
# 53.0 == 53.0
# 81.0 == 81.0
# 39.0 == 39.0
# 50.0 == 50.0
# 61.0 == 61.0
# 74.0 == 74.0
# 73.0 == 73.0
# 54.0 == 54.0
# 63.0 == 63.0
# 39.0 == 39.0
# 80.0 == 80.0
# 68.0 == 67.0
# 64.0 == 64.0
# 74.0 == 74.0
# 41.0 == 41.0
# 32.0 == 32.0
# 61.0 == 61.0
# 37.0 == 37.0
# 29.0 == 29.0
# 65.0 == 65.0
# 64.0 == 64.0
# 69.0 == 69.0
# 67.0 == 67.0
# 52.0 == 51.0
# 42.0 == 42.0
# 69.0 == 69.0
# 62.0 == 62.0
# 45.0 == 45.0
# 49.0 == 49.0
# 64.0 == 64.0
# 61.0 == 61.0
# 46.0 == 46.0
# 47.0 == 47.0
# 76.0 == 76.0
# 76.0 == 76.0
# 45.0 == 45.0
# 66.0 == 66.0
# 63.0 == 63.0
# 50.0 == 50.0
# 84.0 == 84.0
# 48.0 == 48.0
# 42.0 == 42.0
# 52.0 == 52.0
# 34.0 == 34.0
# 46.0 == 46.0
# 70.0 == 70.0
# 70.0 == 70.0
# 63.0 == 63.0
# 62.0 == 62.0
# 75.0 == 75.0
# 62.0 == 62.0
# 48.0 == 48.0
# 46.0 == 46.0
# 53.0 == 53.0
# 57.0 == 57.0
# 58.0 == 58.0
# 61.0 == 61.0
# 63.0 == 63.0
# 62.0 == 62.0
# 41.0 == 41.0
# 63.0 == 63.0
# 56.0 == 56.0
# 48.0 == 48.0
# 90.0 == 90.0
# 69.0 == 69.0
# 54.0 == 54.0
# 58.0 == 58.0
# 51.0 == 51.0
# 71.0 == 71.0
# 75.0 == 75.0
# 54.0 == 54.0
# 62.0 == 62.0
# 54.0 == 54.0
# 54.0 == 54.0
# 78.0 == 78.0
# 62.0 == 62.0
# 61.0 == 61.0
# 81.0 == 81.0
# 56.0 == 56.0
# 52.0 == 52.0
# 55.0 == 55.0
# 54.0 == 54.0
# 42.0 == 42.0
# 44.0 == 44.0
# 59.0 == 59.0
# 57.0 == 57.0
# 64.0 == 63.0
# 47.0 == 47.0
# 62.0 == 62.0
# 62.0 == 62.0
# 61.0 == 61.0
# 71.0 == 71.0
# 57.0 == 57.0
# 71.0 == 71.0
# 61.0 == 61.0
# 67.0 == 67.0
# 43.0 == 43.0
# 49.0 == 49.0
# 68.0 == 68.0
# 56.0 == 56.0
# 44.0 == 44.0
# 52.0 == 52.0
# 56.0 == 56.0
# 34.0 == 34.0
# 64.0 == 64.0
# 88.0 == 88.0
# 56.0 == 56.0
# 69.0 == 69.0
# 36.0 == 36.0
# 63.0 == 63.0
# 57.0 == 57.0
# 38.0 == 38.0
# 41.0 == 41.0
# 41.0 == 40.0
# 49.0 == 49.0
# 62.0 == 62.0
# 54.0 == 54.0
# 41.0 == 41.0
# 50.0 == 50.0
# 56.0 == 56.0
# 59.0 == 59.0
# 46.0 == 46.0
# 51.0 == 51.0
# 62.0 == 62.0
# 35.0 == 35.0
# 66.0 == 66.0
# 50.0 == 50.0
# 45.0 == 45.0
# 72.0 == 72.0
# 38.0 == 38.0
# 26.0 == 26.0
# 84.0 == 84.0
#
# -> All age_at_initial_pathologic_diagnosis & days_to_birth match.

# %% [markdown]
# We can rely on 'age_at_initial_pathologic_diagnosis' only, as 'days_to_birth' and 'age_at_initial_pathologic_diagnosis' match in all files.

# %% [markdown]
# ## info su lab e ospedale

# %% [markdown]
# The next code block is only used to explore the XML structure and tags.

# %%
import xml.etree.ElementTree as ET
file_path = "../datasets/clinical_data/0a9561ad-0d8e-4776-be26-c9d7b2825045/nationwidechildrens.org_clinical.TCGA-B6-A0IG.xml"
tree = ET.parse(file_path)
root = tree.getroot()
print(root.tag)
for elem in root.iter():
    print(elem.tag)
# Out:
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}tcga_bcr
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}tcga_bcr
# {http://tcga.nci/bcr/xml/administration/2.7}admin
# {http://tcga.nci/bcr/xml/administration/2.7}bcr
# {http://tcga.nci/bcr/xml/administration/2.7}file_uuid
# {http://tcga.nci/bcr/xml/administration/2.7}batch_number
# {http://tcga.nci/bcr/xml/administration/2.7}project_code
# {http://tcga.nci/bcr/xml/administration/2.7}disease_code
# {http://tcga.nci/bcr/xml/administration/2.7}day_of_dcc_upload
# {http://tcga.nci/bcr/xml/administration/2.7}month_of_dcc_upload
# {http://tcga.nci/bcr/xml/administration/2.7}year_of_dcc_upload
# {http://tcga.nci/bcr/xml/administration/2.7}patient_withdrawal
# {http://tcga.nci/bcr/xml/administration/2.7}withdrawn
# {http://tcga.nci/bcr/xml/administration/2.7}program
# {http://tcga.nci/bcr/xml/administration/2.7}dbgap_registration_code
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}patient
# {http://tcga.nci/bcr/xml/administration/2.7}additional_studies
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}tumor_tissue_site
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}tumor_tissue_site_other
# {http://tcga.nci/bcr/xml/shared/2.7}other_dx
# {http://tcga.nci/bcr/xml/shared/2.7}gender
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}vital_status
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_birth
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_last_known_alive
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_death
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_last_followup
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}race_list
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}race
# {http://tcga.nci/bcr/xml/shared/2.7}bcr_patient_barcode
# {http://tcga.nci/bcr/xml/shared/2.7}tissue_source_site
# {http://tcga.nci/bcr/xml/shared/2.7}patient_id
# {http://tcga.nci/bcr/xml/shared/2.7}bcr_patient_uuid
# {http://tcga.nci/bcr/xml/shared/2.7}history_of_neoadjuvant_treatment
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}informed_consent_verified
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}icd_o_3_site
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}icd_o_3_histology
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}icd_10
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_initial_pathologic_diagnosis
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}age_at_initial_pathologic_diagnosis
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}year_of_initial_pathologic_diagnosis
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}ethnicity
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}person_neoplasm_cancer_status
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}primary_lymph_node_presentation_assessment
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}lymph_node_examined_count
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}er_detection_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}pgr_detection_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}anatomic_neoplasm_subdivisions
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}anatomic_neoplasm_subdivision
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_chromosone_17_signal_ratio_value
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}axillary_lymph_node_stage_method_type
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}axillary_lymph_node_stage_other_method_descriptive_text
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}breast_carcinoma_surgical_procedure_name
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}breast_neoplasm_other_surgical_procedure_descriptive_text
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}breast_carcinoma_primary_surgical_procedure_name
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}surgical_procedure_purpose_other_text
# {http://tcga.nci/bcr/xml/shared/2.7}histological_type
# {http://tcga.nci/bcr/xml/shared/2.7}histological_type_other
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}menopause_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}breast_carcinoma_progesterone_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}cytokeratin_immunohistochemistry_staining_method_micrometastasis_indicator
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}breast_carcinoma_immunohistochemistry_er_pos_finding_scale
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}immunohistochemistry_positive_cell_score
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_immunohistochemistry_level_result
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}breast_cancer_surgery_margin_status
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}margin_status
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}initial_pathologic_diagnosis_method
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}init_pathology_dx_method_other
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}lab_procedure_her2_neu_in_situ_hybrid_outcome_type
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}breast_carcinoma_estrogen_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}lab_proc_her2_neu_immunohistochemistry_receptor_status
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}number_of_lymphnodes_positive_by_ihc
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}number_of_lymphnodes_positive_by_he
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}pos_finding_progesterone_receptor_other_measurement_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}positive_finding_estrogen_receptor_other_measurement_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_erbb_pos_finding_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}pos_finding_her2_erbb2_other_measurement_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_erbb_method_calculation_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_and_centromere_17_copy_number_analysis_input_total_number_count
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_and_centromere_17_positive_finding_other_measurement_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_erbb_pos_finding_fluorescence_in_situ_hybridization_calculation_method_text
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}tissue_prospective_collection_indicator
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}tissue_retrospective_collection_indicator
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}fluorescence_in_situ_hybridization_diagnostic_procedure_chromosome_17_signal_result_range
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}first_nonlymph_node_metastasis_anatomic_sites
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}metastatic_site_at_diagnosis
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}metastatic_site_at_diagnosis_other
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}er_level_cell_percentage_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}progesterone_receptor_level_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}distant_metastasis_present_ind2
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_estrogen_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_estrogen_receptor_level_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_immunohistochemistry_er_pos_cell_score
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}pos_finding_metastatic_breast_carcinoma_estrogen_receptor_other_measuremenet_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_estrogen_receptor_detection_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_progesterone_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_lab_proc_her2_neu_immunohistochemistry_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_progesterone_receptor_level_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_immunohistochemistry_pr_pos_cell_score
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_pos_finding_progesterone_receptor_other_measure_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_progesterone_receptor_detection_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_erbb_pos_finding_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_erbb2_immunohistochemistry_level_result
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_pos_finding_her2_erbb2_other_measure_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_erbb_method_calculation_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_lab_proc_her2_neu_in_situ_hybridization_outcome_type
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_fluorescence_in_situ_hybridization_diagnostic_proc_centromere_17_signal_result_range
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_and_centromere_17_copy_number_metastatic_breast_carcinoma_analysis_input_total_number_count
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_neu_chromosone_17_signal_ratio_value
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_pos_finding_other_scale_measurement_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_erbb_pos_finding_fluorescence_in_situ_hybridization_calculation_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_metastatic_breast_carcinoma_copy_analysis_input_total_number
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_breast_carcinoma_copy_analysis_input_total_number
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}breast_carcinoma_immunohistochemistry_progesterone_receptor_pos_finding_scale
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}breast_carcinoma_immunohistochemistry_pos_cell_score
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}stage_event
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}system_version
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}clinical_stage
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}pathologic_stage
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}tnm_categories
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}clinical_categories
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}clinical_T
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}clinical_N
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}clinical_M
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}pathologic_categories
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}pathologic_T
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}pathologic_N
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}pathologic_M
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}psa
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}psa_value
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}days_to_psa
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}gleason_grading
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}gleason_score
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}primary_pattern
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}secondary_pattern
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}tertiary_pattern
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}ann_arbor
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}b_symptoms
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}extranodal_involvement
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}serum_markers
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}igcccg_stage
# {http://tcga.nci/bcr/xml/clinical/shared/stage/2.7}masaoka_stage
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}postoperative_rx_tx
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}radiation_therapy
# {http://tcga.nci/bcr/xml/clinical/brca/shared/new_tumor_event/2.7/1.0}new_tumor_events
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}new_tumor_event_after_initial_treatment
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}day_of_form_completion
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}month_of_form_completion
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}year_of_form_completion
# {http://tcga.nci/bcr/xml/clinical/brca/2.7}follow_ups
# {http://tcga.nci/bcr/xml/clinical/brca/followup/2.7/2.1}follow_up
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}bcr_followup_barcode
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}bcr_followup_uuid
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}followup_case_report_form_submission_reason
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}radiation_therapy
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}postoperative_rx_tx
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}vital_status
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_last_followup
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}days_to_death
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}person_neoplasm_cancer_status
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}new_tumor_event_after_initial_treatment
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}days_to_new_tumor_event_after_initial_treatment
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}new_neoplasm_event_type
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}new_neoplasm_event_occurrence_anatomic_site
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}new_neoplasm_occurrence_anatomic_site_text
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}additional_surgery_locoregional_procedure
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}days_to_additional_surgery_metastatic_procedure
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}additional_radiation_therapy
# {http://tcga.nci/bcr/xml/clinical/shared/new_tumor_event/2.7}additional_pharmaceutical_therapy
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_estrogen_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_estrogen_receptor_level_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_immunohistochemistry_er_positive_finding_scale_type
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}pos_finding_metastatic_breast_carcinoma_estrogen_receptor_other_measuremenet_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_immunohistochemistry_er_pos_cell_score
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_estrogen_receptor_detection_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_progesterone_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_progesterone_receptor_level_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_immunohistochemistry_progesterone_receptor_positive_finding_scale_type
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_pos_finding_progesterone_receptor_other_measure_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_immunohistochemistry_pr_pos_cell_score
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_progesterone_receptor_detection_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_lab_proc_her2_neu_immunohistochemistry_receptor_status
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_erbb_pos_finding_cell_percent_category
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_erbb2_immunohistochemistry_level_result
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_pos_finding_her2_erbb2_other_measure_scale_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_erbb_method_calculation_method_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_lab_proc_her2_neu_in_situ_hybridization_outcome_type
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_metastatic_breast_carcinoma_copy_analysis_input_total_number
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_fluorescence_in_situ_hybridization_diagnostic_proc_centromere_17_signal_result_range
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}her2_neu_and_centromere_17_copy_number_metastatic_breast_carcinoma_analysis_input_total_number_count
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_neu_chromosone_17_signal_ratio_value
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_pos_finding_other_scale_measurement_text
# {http://tcga.nci/bcr/xml/clinical/brca/shared/2.7}metastatic_breast_carcinoma_her2_erbb_pos_finding_fluorescence_in_situ_hybridization_calculation_method_text
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}day_of_form_completion
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}month_of_form_completion
# {http://tcga.nci/bcr/xml/clinical/shared/2.7}year_of_form_completion
# {http://tcga.nci/bcr/xml/clinical/pharmaceutical/2.7}drugs
# {http://tcga.nci/bcr/xml/clinical/radiation/2.7}radiations

# %% [markdown]
# ### Collect columns from clinical XML files

# %% [markdown]
# We want extract the following columns from the XML clinical files:
# - `tissue_source_site`: Tissue Source Site code
# - `bcr`: Biospecimen Core Resource code
# - `days_to_birth`: Days to birth (negative value)
# - `days_to_death`: Days to death
# - `vital_status`: Alive/Dead
# - `patient_barcode`: Patient barcode
# - `pathologic_stage`: Pathologic stage of the tumor

# %%
import xml.etree.ElementTree as ET

def import_xml(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
            
    ns = {
        'admin': 'http://tcga.nci/bcr/xml/administration/2.7',
        'shared': 'http://tcga.nci/bcr/xml/shared/2.7',
        'clin_shared': 'http://tcga.nci/bcr/xml/clinical/shared/2.7',
        'stage': 'http://tcga.nci/bcr/xml/clinical/shared/stage/2.7'
    }
            
    tss = root.find('.//shared:tissue_source_site', ns).text
    bcr = root.find('.//admin:bcr', ns).text
    
    birth_elem = root.find('.//clin_shared:days_to_birth', ns)
    days_to_birth = int(birth_elem.text) if (birth_elem is not None and birth_elem.text) else None
    death_elem = root.find('.//clin_shared:days_to_death', ns)
    days_to_death = int(death_elem.text) if (death_elem is not None and death_elem.text) else None
    
    vital_status = root.find('.//clin_shared:vital_status', ns).text
    patient_barcode = root.find('.//shared:bcr_patient_barcode', ns).text    
    
    pathologic_stage_elem = root.find('.//stage:pathologic_stage', ns)
    pathologic_stage = pathologic_stage_elem.text if (pathologic_stage_elem is not None and pathologic_stage_elem.text) else None
        
    records.append({'file': file_path, 'tissue_source_site': tss, 'bcr': bcr, 'days_to_birth': days_to_birth, 'days_to_death': days_to_death, 'vital_status': vital_status, 'patient_barcode': patient_barcode, 'pathologic_stage': pathologic_stage})

records = []

for subfolder in os.listdir(f"{CLINICAL_PATH}"):
        file_xml_or_annotation_or_orm = 0
        for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
            if file.endswith(".xml") and "annotations" not in file and "org_omf" not in file:
                selected_data = import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")                

clinical_df = pd.DataFrame(records)
clinical_df = clinical_df.dropna(how='all')

print(clinical_df.head())
# Out:
#                                                                                                                file  \
# 0  ../datasets/clinical_data/00049989-fa21-48fb-8dda-710c0dd5932e/nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# 1  ../datasets/clinical_data/004b6bd4-19d0-4b40-99ef-1a76313fe7a5/nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml
# 2  ../datasets/clinical_data/00a5e81c-cd67-483f-9d99-3c733b2ead38/nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml
# 3  ../datasets/clinical_data/014f5ae1-5862-4165-9a3b-bba7bb08a527/nationwidechildrens.org_clinical.TCGA-C8-A12P.xml
# 4  ../datasets/clinical_data/01a962ea-a87f-49fa-9a27-7273a39f64a9/nationwidechildrens.org_clinical.TCGA-S3-A6ZF.xml
#
#   tissue_source_site                             bcr  days_to_birth  \
# 0                 A2  Nationwide Children's Hospital       -25959.0
# 1                 GM  Nationwide Children's Hospital       -19415.0
# 2                 D8  Nationwide Children's Hospital       -21602.0
# 3                 C8  Nationwide Children's Hospital       -20332.0
# 4                 S3  Nationwide Children's Hospital       -23650.0
#
#    days_to_death vital_status patient_barcode pathologic_stage
# 0            NaN        Alive    TCGA-A2-A0CT        Stage IIA
# 1            NaN        Alive    TCGA-GM-A2DD          Stage I
# 2            NaN        Alive    TCGA-D8-A1JM        Stage IIB
# 3            NaN        Alive    TCGA-C8-A12P        Stage IIB
# 4            NaN        Alive    TCGA-S3-A6ZF        Stage IIA

# %%
clinical_df.isnull().sum()
# Out:
# file                    0
# tissue_source_site      0
# bcr                     0
# days_to_birth          10
# days_to_death         696
# vital_status            0
# patient_barcode         0
# pathologic_stage        8
# dtype: int64

# %% [markdown]
# We can see that some files are missing values for `days_to_birth`, `days_to_death` and `pathologic_stage`.
# In particular, `days_to_birth` is missing in 10 files that we will drop for our analysis.

# %%
clinical_df = clinical_df.dropna(subset=['days_to_birth'])
clinical_df.shape
# Out:
# (761, 8)

# %% [markdown]
# ### Tissue source site

# %%
clinical_df[['tissue_source_site']].value_counts()
# Out:
# tissue_source_site
# BH                    117
# A2                     75
# E2                     73
# A8                     70
# D8                     56
# AR                     46
# B6                     40
# AN                     38
# E9                     36
# AO                     32
# C8                     31
# EW                     26
# A7                     25
# OL                     16
# AC                     14
# LL                     13
# GM                     13
# A1                     10
# S3                      9
# AQ                      8
# 3C                      3
# PL                      3
# GI                      2
# LD                      2
# UL                      1
# UU                      1
# V7                      1
# Name: count, dtype: int64

# %% [markdown]
# You can find the meaning of Tissue Source Site codes at: [gdc.cancer.gov - tissue source site codes](https://gdc.cancer.gov/resources-tcga-users/tcga-code-tables/tissue-source-site-codes)
#
# Our tissue source sites:
#
# | TSS Code | Source Site                  | Study Name                | BCR |
# |----------|------------------------------|---------------------------|-----|
# | BH       | University of Pittsburgh     | Breast invasive carcinoma | NCH |
# | A2       | Walter Reed                  | Breast invasive carcinoma | NCH |
# | E2       | Roswell Park                 | Breast invasive carcinoma | NCH |
# | A8       | Indivumed                    | Breast invasive carcinoma | NCH |
# | D8       | Greater Poland Cancer Center | Breast invasive carcinoma | NCH |
# | AR       | Mayo                         | Breast invasive carcinoma | NCH |
# | B6       | Duke                         | Breast invasive carcinoma | NCH |
# | AN       | Cureline                     | Breast invasive carcinoma | NCH |
# | E9       | Asterand                     | Breast invasive carcinoma | NCH |
# | AO       | MSKCC                        | Breast invasive carcinoma | NCH |

# %%
clinical_df[['bcr']].value_counts()
# Out:
# bcr
# Nationwide Children's Hospital    761
# Name: count, dtype: int64

# %% [markdown]
# So all rows have **BCR = NCH** (Nationwide Children's Hospital).

# %% [markdown]
# ### Check days_to_death and vital_status consistency

# %%
clinical_df[(clinical_df['vital_status'] == 'Dead') & (clinical_df['days_to_death'].isna())]
# Out:
# Empty DataFrame
# Columns: [file, tissue_source_site, bcr, days_to_birth, days_to_death, vital_status, patient_barcode, pathologic_stage]
# Index: []

# %% [markdown]
# So all deaths have a value for `days_to_death`.

# %%
clinical_df[(clinical_df['vital_status'] == 'Alive') & (clinical_df['days_to_death'].notna())]
# Out:
# Empty DataFrame
# Columns: [file, tissue_source_site, bcr, days_to_birth, days_to_death, vital_status, patient_barcode, pathologic_stage]
# Index: []

# %% [markdown]
# We checked that no alive patient has a value for `days_to_death`.

# %% [markdown]
# ## Check: patient represented more than once?

# %%
clinical_df[clinical_df['patient_barcode'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [file, tissue_source_site, bcr, days_to_birth, days_to_death, vital_status, patient_barcode, pathologic_stage]
# Index: []

# %% [markdown]
# Vediamo che non abbiamo più file clinici per lo stesso patiente_barcode, quindi ogni paziente è rappresentato una sola volta.

# %% [markdown]
# # Plot Alive/Dead

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
status_counts = clinical_df['vital_status'].value_counts().reset_index()
status_counts.columns = ['vital_status', 'count']

plt.figure(figsize=(6,4))
sns.barplot(data=status_counts, x='vital_status', y='count', hue='vital_status', palette={'Alive':'green','Dead':'red'}, dodge=False)
plt.title('Number of patients alive or dead')
plt.ylabel('Count')
plt.xlabel('Vital state')
plt.show()

# %%
clinical_df['age'] = (-clinical_df['days_to_birth'].astype(float) / 365).astype(int)

bins = [0, 19, 29, 39, 49, 59, 69, 79, 89, 99, 120]
labels = ['0-19','20-29','30-39','40-49','50-59','60-69','70-79','80-89','90-99','100+']

clinical_df['age_group'] = pd.cut(clinical_df['age'], bins=bins, labels=labels, right=True)

# %%
age_status_counts = clinical_df.groupby(['age_group', 'vital_status'], observed=True).size().reset_index(name='count')

plt.figure(figsize=(10,6))
sns.barplot(data=age_status_counts, x='age_group', y='count', hue='vital_status', palette=['green','red'])
plt.title('Alive and Dead per Age Group Distribution')
plt.xlabel('Age group')
plt.ylabel('Number of patients')
plt.legend(title='Vital state')
plt.show()

# %%
clinical_df['tss_group'] = clinical_df['tissue_source_site'].apply(lambda x: 'TSS: AR/AN' if x in ['AR','AN'] else 'Other TSS')

age_status_counts = clinical_df.groupby(['age_group','tss_group','vital_status'], observed=True).size().reset_index(name='count')

age_status_counts['category'] = age_status_counts['tss_group'] + ' - ' + age_status_counts['vital_status']

color_map = {
    'TSS: AR/AN - Alive': 'green',
    'TSS: AR/AN - Dead': 'red',
    'Other TSS - Alive': 'dodgerblue',
    'Other TSS - Dead': 'orange'
}

plt.figure(figsize=(14,6))
sns.barplot(
    data=age_status_counts,
    x='age_group',
    y='count',
    hue='category',
    palette=color_map
)

plt.title('Alive and Dead per Age group and Tissue Source Site (AR/AN vs Altri)')
plt.xlabel('Age group')
plt.ylabel('Number of patients')
plt.legend(title='Group / Vital state', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_filtered = clinical_df[clinical_df['tissue_source_site'].isin(['AR', 'AN'])]

age_status_counts = (
    df_filtered
    .groupby(['age_group', 'vital_status', 'tissue_source_site'], observed=True)
    .size()
    .reset_index(name='count')
)

g = sns.catplot(
    data=age_status_counts,
    x='age_group',
    y='count',
    hue='vital_status',
    col='tissue_source_site',
    kind='bar',
    palette=['green', 'red'],
    height=5,
    aspect=1.2
)

g.fig.suptitle('Alive and Dead per Age group — per Tissue Source Site (AR / AN)', y=1.05)
plt.show()

# %% [markdown]
# ### Plot stage vs age

# %%
sns.countplot(
    x='pathologic_stage', 
    data=clinical_df, 
    order=clinical_df['pathologic_stage'].value_counts().index
)
plt.title("Distribution of Pathological Stages")
plt.xlabel("Pathological Stage")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Followup Analysis

# %%
import pickle

def import_txt(file_path):
    df = pd.read_csv(file_path, sep="\t")    
    columns_to_select = df.columns[df.columns.str.contains('followup', case=False)]
    print(f"COLUMNS with 'followup': {columns_to_select}")

for subfolder in os.listdir(CLINICAL_PATH):
    for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
        if file.endswith(".txt"):
            import_txt(f"{CLINICAL_PATH}/{subfolder}/{file}")
            if file != "annotations.txt":
                import_txt(f"{CLINICAL_PATH}/{subfolder}/{file}")
# Out:
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode', 'bcr_followup_uuid'], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode', 'bcr_followup_uuid'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode', 'bcr_followup_uuid', 'followup_reason'], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode', 'bcr_followup_uuid', 'followup_reason'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode', 'bcr_followup_uuid', 'followup_lost_to'], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode', 'bcr_followup_uuid', 'followup_lost_to'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode'], dtype='object')
# COLUMNS with 'followup': Index(['bcr_followup_barcode'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')

# %%
count = 0
def import_xml(file_path):
    df = pd.read_xml(file_path, parser="etree")
    columns_to_select = df.columns[df.columns.str.contains('follow', case=False)]
    print(f"COLUMNS with 'followup': {columns_to_select}")
    if 'days_to_last_followup' in df.columns:
        if not df['days_to_last_followup'].isna().all():
            return 1
    else:
        return 0

for subfolder in os.listdir(CLINICAL_PATH):
    for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
        if file.endswith(".xml"):
            count += import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
            
count
# Out:
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# ...
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index([], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# COLUMNS with 'followup': Index(['days_to_last_followup', 'follow_ups'], dtype='object')
# 771

# %%
def import_xml(file_path):
    df = pd.read_xml(file_path, parser="etree")
    if 'days_to_last_followup' in df.columns:
        return df
    else:
        return None

filtered_dfs = []

for subfolder in os.listdir(CLINICAL_PATH):
    for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
        if file.endswith(".xml"):
            filtered_df = import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
            if filtered_df is not None:
                filtered_dfs.append(filtered_df)

# Concatenate all filtered dataframes into one
followup_df = pd.concat(filtered_dfs, ignore_index=True)
followup_df = followup_df.dropna(how='all')

# Display the resulting dataframe
followup_df
# Out:
#                                  bcr                             file_uuid  \
# 0     Nationwide Children's Hospital  172B825D-7A5C-4541-8190-33207AF474F9
# 1                               None                                  None
# 2     Nationwide Children's Hospital  1F346802-FC2F-48EC-8A1C-8773091DC45C
# 3                               None                                  None
# 4     Nationwide Children's Hospital  A19AC031-C902-455B-A37D-3BD2DAC61F52
# ...                              ...                                   ...
# 1537                            None                                  None
# 1538  Nationwide Children's Hospital  0A13A2CF-A454-4EE8-9AD0-92B84E7271CE
# 1539                            None                                  None
# 1540  Nationwide Children's Hospital  69FCF7B1-70B9-4E80-8B4D-D3EAE3529C24
# 1541                            None                                  None
#
#      batch_number project_code disease_code  day_of_dcc_upload  \
# 0         61.89.0         TCGA         BRCA               22.0
# 1            None         None         None                NaN
# 2        167.75.0         TCGA         BRCA               22.0
# 3            None         None         None                NaN
# 4        109.89.0         TCGA         BRCA               22.0
# ...           ...          ...          ...                ...
# 1537         None         None         None                NaN
# 1538     142.79.0         TCGA         BRCA               22.0
# 1539         None         None         None                NaN
# 1540     120.77.0         TCGA         BRCA               22.0
# 1541         None         None         None                NaN
#
#       month_of_dcc_upload  year_of_dcc_upload patient_withdrawal  program  \
# 0                    12.0              2016.0     \n                  NaN
# 1                     NaN                 NaN               None      NaN
# 2                    12.0              2016.0     \n                  NaN
# 3                     NaN                 NaN               None      NaN
# 4                    12.0              2016.0     \n                  NaN
# ...                   ...                 ...                ...      ...
# 1537                  NaN                 NaN               None      NaN
# 1538                 12.0              2016.0     \n                  NaN
# 1539                  NaN                 NaN               None      NaN
# 1540                 12.0              2016.0     \n                  NaN
# 1541                  NaN                 NaN               None      NaN
#
#       ...     stage_event postoperative_rx_tx radiation_therapy  \
# 0     ...            None                 NaN               NaN
# 1     ...  \n                             NaN               NaN
# 2     ...            None                 NaN               NaN
# 3     ...  \n                             NaN               NaN
# 4     ...            None                 NaN               NaN
# ...   ...             ...                 ...               ...
# 1537  ...  \n                             NaN               NaN
# 1538  ...            None                 NaN               NaN
# 1539  ...  \n                             NaN               NaN
# 1540  ...            None                 NaN               NaN
# 1541  ...  \n                             NaN               NaN
#
#       new_tumor_events day_of_form_completion month_of_form_completion  \
# 0                 None                    NaN                      NaN
# 1       \n                                9.0                      9.0
# 2                 None                    NaN                      NaN
# 3       \n                               29.0                      9.0
# 4                 None                    NaN                      NaN
# ...                ...                    ...                      ...
# 1537    \n                                2.0                      8.0
# 1538              None                    NaN                      NaN
# 1539    \n                               12.0                      8.0
# 1540              None                    NaN                      NaN
# 1541    \n                                3.0                      6.0
#
#      year_of_form_completion      follow_ups           drugs      radiations
# 0                        NaN            None            None             NaN
# 1                     2010.0  \n              \n                         NaN
# 2                        NaN            None            None             NaN
# 3                     2011.0  \n              \n                         NaN
# 4                        NaN            None            None            None
# ...                      ...             ...             ...             ...
# 1537                  2011.0  \n              \n                         NaN
# 1538                     NaN            None            None            None
# 1539                  2011.0  \n              \n              \n
# 1540                     NaN            None             NaN             NaN
# 1541                  2011.0  \n                         NaN             NaN
#
# [1542 rows x 115 columns]

# %%
followup_df.shape
# Out:
# (1542, 115)

# %%
followup_df[['days_to_last_followup']].describe()
# Out:
#        days_to_last_followup
# count             696.000000
# mean              739.989943
# std               949.046203
# min                 0.000000
# 25%               118.000000
# 50%               394.000000
# 75%              1117.750000
# max              6796.000000

# %%
followup_df[['days_to_last_followup']].isnull().sum()
# Out:
# days_to_last_followup    846
# dtype: int64

# %%
1542-846
# Out:
# 696

# %% [markdown]
# ### Create dataframe with folder name, file name and days_to_last_followup

# %%
def import_xml(file_path):
    temp_df = pd.read_xml(file_path, parser="etree")

    if 'days_to_last_followup' in temp_df.columns:
        # Remove rows in which all columns are NaN
        temp_df = temp_df[["days_to_last_followup"]]
    
        temp_df = temp_df.dropna(how='all')
        
        if temp_df.empty:
            print(f"File {file_path} has no valid age data.")

        return temp_df
    return None

def main():
    clinical_df = pd.DataFrame(columns=["folder_name", "file_name", "days_to_last_followup"])
    for subfolder in os.listdir(f"{CLINICAL_PATH}"):
        file_xml_or_annotation_or_orm = 0
        for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
            if file.endswith(".xml") and "annotations" not in file and "org_omf" not in file:
                file_xml_or_annotation_or_orm = 1
                selected_data = import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
            
                if selected_data is not None:
                    selected_data.insert(0, "file_name", file)
                    selected_data.insert(0, "folder_name", subfolder)

                    # Safe concatenation avoiding empty DataFrames or with NaN values
                    if not selected_data.empty and not selected_data.isna().all().all():
                        clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
                        
    return clinical_df

clinical_followup_df = main()
clinical_followup_df.shape

# %%
clinical_followup_df[clinical_followup_df['days_to_last_followup'] > 0].shape

# %%
clinical_followup_df['days_to_last_followup'].describe()
