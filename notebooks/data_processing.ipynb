# %%
import pandas as pd
import os

CLINICAL_PATH = "../datasets/clinical_data"

# %% [markdown]
# # Create clinical_df DataFrame with age_at_initial_pathologic_diagnosis from XML files:

# %% [markdown]
#  ## Clinical data
#
# We want to create a DataFrame clinical_df with the following columns:
# - **folder_name**: the name of the subfolder in clinical_data
# - **file_name**: the name of the XML file
# - **age_at_initial_pathologic_diagnosis**: the value from the XML file

# %%
def import_xml(file_path):
    temp_df = pd.read_xml(file_path, parser="etree")

    if 'days_to_birth' in temp_df.columns and 'age_at_initial_pathologic_diagnosis' in temp_df.columns:
        temp_df = temp_df[["age_at_initial_pathologic_diagnosis"]]
    
        temp_df = temp_df.dropna(how='all')
        
        if temp_df.empty:
            print(f"File {file_path} has no valid age data.")
        return temp_df
    return None


def main():
    clinical_df = pd.DataFrame(columns=["folder_name", "file_name", "age_at_initial_pathologic_diagnosis"])
    for subfolder in os.listdir(f"{CLINICAL_PATH}"):
        file_xml_or_annotation_or_orm = 0
        for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
            if file.endswith(".xml") and "annotations" not in file and "org_omf" not in file:
                file_xml_or_annotation_or_orm = 1
                selected_data = import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
            
                if selected_data is not None:
                    selected_data.insert(0, "file_name", file)
                    selected_data.insert(0, "folder_name", subfolder)

                    # Safe concatenation avoiding empty DataFrames or with NaN values
                    if not selected_data.empty and not selected_data.isna().all().all():
                        clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
                        
    return clinical_df

clinical_df = main()
clinical_df.shape
# Out:
# C:\Users\giorg\AppData\Local\Temp\ipykernel_20508\2494993394.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
# (771, 3)

# %%
clinical_df.head()
# Out:
#                             folder_name  \
# 0  00049989-fa21-48fb-8dda-710c0dd5932e
# 1  004b6bd4-19d0-4b40-99ef-1a76313fe7a5
# 2  00a5e81c-cd67-483f-9d99-3c733b2ead38
# 3  014f5ae1-5862-4165-9a3b-bba7bb08a527
# 4  01a962ea-a87f-49fa-9a27-7273a39f64a9
#
#                                            file_name  \
# 0  nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# 1  nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml
# 2  nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml
# 3  nationwidechildrens.org_clinical.TCGA-C8-A12P.xml
# 4  nationwidechildrens.org_clinical.TCGA-S3-A6ZF.xml
#
#    age_at_initial_pathologic_diagnosis
# 0                                 71.0
# 1                                 53.0
# 2                                 59.0
# 3                                 55.0
# 4                                 64.0

# %%
clinical_df[["age_at_initial_pathologic_diagnosis"]].describe()
# Out:
#        age_at_initial_pathologic_diagnosis
# count                           771.000000
# mean                             57.413748
# std                              13.184850
# min                              26.000000
# 25%                              48.000000
# 50%                              58.000000
# 75%                              66.000000
# max                              90.000000

# %%
print("-------------------------------------\n"
      "\t\tNaN values check:")
# Check is there are any NaN values in the DataFrame
print(clinical_df.isna().sum())
print("-------------------------------------")
# Out:
# -------------------------------------
# 		NaN values check:
# folder_name                            0
# file_name                              0
# age_at_initial_pathologic_diagnosis    0
# dtype: int64
# -------------------------------------

# %%
print("-------------------------------------")
# Check if all folder_name values are unique
print(f"-> All folder names are unique? {clinical_df['folder_name'].nunique() == len(clinical_df)}")

# Check if all file_name values are unique
print(f"-> All file names are unique? {clinical_df['file_name'].nunique() == len(clinical_df)}")
print("-------------------------------------")
# Out:
# -------------------------------------
# -> All folder names are unique? True
# -> All file names are unique? True
# -------------------------------------

# %%
def find_non_contributing_subfolders():
    all_subfolders = set(os.listdir(f"{CLINICAL_PATH}"))
    
    # Take the subfolders that contributed to clinical_df
    contributing_subfolders = set(clinical_df['folder_name'].unique())
    
    # Folders that did not contribute
    non_contributing_subfolders = all_subfolders - contributing_subfolders
    
    return non_contributing_subfolders

non_contributing_subfolders = find_non_contributing_subfolders()
print("Subfolders don't contribute:", non_contributing_subfolders)
print("\n-----------------------------------------------------")
print(f"-> Do not contribute to the dataframe {len(non_contributing_subfolders)} subfolders.")
print("-----------------------------------------------------")
# Out:
# Subfolders don't contribute: {'1e6b79ff-9787-4cbe-b19d-ebabb6b43589', 'cd7890a5-76f8-479d-9298-fda762a15701', 'dfc14560-ce1a-4d7f-9b03-6777d9ee725a', '100659db-c917-4318-ab86-192cc46a32f3', '967f57a0-b6d6-4b6f-8882-6cb524a461ca', 'ff679dd3-62be-4332-8157-0a83ffb8516a', '20d28c3f-8a04-4473-9b8f-e6e0ab0acd07', '0a40467f-9495-4c5b-b56e-3347a3ee0572', '024bde93-ff69-4d1f-b301-c053e8c594f5', 'c0ab956b-762c-42c5-94cd-f6f7e2fcd6b3', '2ade91c3-a81c-4362-a7fa-5c2aeb22b476', '4a3c7925-3ae9-44ca-b9d9-62ba78bcba33', 'd583e2e8-32e6-4846-ae69-6fb1880075d9', 'aaff8f3d-916c-4510-8ee2-693ca7178b65', '671069e5-4730-4c23-8adf-79576bb1843f', 'e094828e-082a-4da2-9a66-f1172af28288', '62d4515f-a30b-4b1a-b2dd-c8bf9476e803', '5025cc06-de19-4fcc-9c89-c4f7d6450b2c', '5af9bc05-ecb6-4031-9039-a5164bb91aed', '76bf2db2-4aff-4ad8-bb8c-e27525cbe201', '61014733-2fa9-4139-a8ab-5d0dac7c7bac', 'a88c168e-4bba-4bd2-9c0c-77934444cc1c', 'b2235f20-5387-4548-b6d0-7d092d60bf83', '2b09f2e9-68c4-4a64-90c9-d981e89c123d', '415848eb-7256-474f-9c80-ecdfec0f0a9d', '7322ca0d-71ef-4eaa-bbfd-224cdb896684', 'ee698dd2-1add-4bba-83d7-b2d14e8f08e7', 'b74b115b-1a48-4dad-a219-d5f5c76d9bbd', '323149a5-b38e-4cc3-adb2-fcad02347ddd', 'fa33210b-9370-40b3-a330-e7de33f1f217', 'cae7b60a-b248-46b2-b2c4-0a6892c2538c', '1208942c-b692-4e29-80a7-a9bf061ca4fb', '5c475a60-856c-4fab-8939-b5ed38ebab96', 'a1018c1b-c6c4-4399-86f7-a0a9bdfe37ce', '22f38342-3f1a-47e5-9025-c19719fa21d0', '6dd43709-60a7-481d-9748-03c2d248f0b6', '65b455f3-fcfb-4e50-95d8-7c513d94f0a6', 'aad15c34-a100-4834-a83e-52a0bb0a82f3', '403b5cef-8173-47c7-b56a-cc94dcfbb2e3', 'aaaf9a89-4783-4355-abaa-1d3dd412cc0f', '8162d394-8b64-4da2-9f5b-d164c54b9608', '890c2a98-131e-426c-8435-e18626643cdb', '0b2ccc49-bc42-498d-bf21-752f99c3d160', '68a9278e-871e-4fdd-ab1e-f327357faa40', '8e004ced-76ea-4bdf-a100-9b6509158a7c', '2495917b-a873-4b71-8ff3-1832fd6daba6', 'a81b89be-b50e-4e63-9821-21aa9e8ff2be', 'b6e8df85-fcd5-47e3-b2aa-13894cbc4326', '2ee83b95-d19c-4ae4-bb5c-bad54e9ecbe2', 'a3af7034-da31-47d0-8cb7-47eb8a0dc102', 'e1cb423c-a7bc-44d8-b460-cf2cda56af90', 'e85b67c4-53bf-4d54-a11a-50bfc38a3a75', 'cd6d0af9-6c41-4f71-81a6-103b11e50b93', 'f434b393-9e32-4ca2-aa1a-3b0de36b5ffe', '1e3fc77b-4c6a-4406-a808-7d35d56cf1a1', 'a9baecf0-5549-4396-8805-a6d1681d11cd'}
#
# -----------------------------------------------------
# -> Do not contribute to the dataframe 56 subfolders.
# -----------------------------------------------------

# %% [markdown]
# **771 rows** = 827 (total subfolders) - 47 (omf files) - 9 (org_clinical_radiation_brca txt files)

# %% [markdown]
# # Clinical JSON

# %%
df_clinical_json = pd.read_json('../datasets/clinical_data(json&manifest)/files.2024-12-12.json')
print(f"Data cinical JSON shape: {df_clinical_json.shape}")
df_clinical_json.columns
# Out:
# Data cinical JSON shape: (827, 9)
# Index(['data_format', 'cases', 'access', 'file_name', 'file_id', 'data_type',
#        'data_category', 'file_size', 'annotations'],
#       dtype='object')

# %%
print(f"Column 'data_category' unique values: {df_clinical_json['data_category'].unique()}")
print(f"Column 'data_format' unique values: {df_clinical_json['data_format'].unique()}")
# Out:
# Column 'data_category' unique values: ['Clinical']
# Column 'data_format' unique values: ['BCR XML' 'BCR OMF XML' 'BCR Biotab']

# %%
print(df_clinical_json[['cases', 'file_name']].shape)
df_clinical_json[['cases', 'file_name']].head()
# Out:
# (827, 2)
#                                                cases  \
# 0  [{'case_id': 'e4fc0909-f284-4471-866d-d8967b6a...
# 1  [{'case_id': '87281a89-91d2-44f7-9f80-668567ad...
# 2  [{'case_id': 'b8a615f9-d19b-4b09-8ec8-0674e5c6...
# 3  [{'case_id': '3b01d064-8c00-4972-9f07-407eac8e...
# 4  [{'case_id': '8785012f-f73e-4d68-87cf-1d804af3...
#
#                                            file_name
# 0  nationwidechildrens.org_clinical.TCGA-E2-A14P.xml
# 1  nationwidechildrens.org_clinical.TCGA-EW-A1J6.xml
# 2  nationwidechildrens.org_clinical.TCGA-C8-A12N.xml
# 3  nationwidechildrens.org_clinical.TCGA-BH-A0HX.xml
# 4  nationwidechildrens.org_clinical.TCGA-A7-A13D.xml

# %%
# La colonna 'cases' contenga liste di dizionari
cases_expanded = df_clinical_json['cases'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else {})
unique_projects = pd.json_normalize(cases_expanded)['project.project_id'].unique()

print("Column 'cases' is a dict, with project IDs value:", unique_projects)
# Out:
# Column 'cases' is a dict, with project IDs value: ['TCGA-BRCA']

# %%
# Extract the 'case_id' value from the list of dictionaries in the 'cases' column
df_clinical_json['case_id'] = df_clinical_json['cases'].apply(
    lambda x: x[0]['case_id'] if isinstance(x, list) and len(x) > 0 and 'case_id' in x[0] else None
)

print(df_clinical_json[['case_id', 'file_name']].head())
# Out:
#                                 case_id  \
# 0  e4fc0909-f284-4471-866d-d8967b6adcbc
# 1  87281a89-91d2-44f7-9f80-668567ad5c72
# 2  b8a615f9-d19b-4b09-8ec8-0674e5c648cd
# 3  3b01d064-8c00-4972-9f07-407eac8e7534
# 4  8785012f-f73e-4d68-87cf-1d804af32782
#
#                                            file_name
# 0  nationwidechildrens.org_clinical.TCGA-E2-A14P.xml
# 1  nationwidechildrens.org_clinical.TCGA-EW-A1J6.xml
# 2  nationwidechildrens.org_clinical.TCGA-C8-A12N.xml
# 3  nationwidechildrens.org_clinical.TCGA-BH-A0HX.xml
# 4  nationwidechildrens.org_clinical.TCGA-A7-A13D.xml

# %% [markdown]
# # Merge clinical_df with df_clinical_json on file_name

# %%
merged_df = pd.merge(clinical_df, df_clinical_json[['case_id', 'file_name']], on='file_name', how='inner')
merged_df.head()
# Out:
#                             folder_name  \
# 0  00049989-fa21-48fb-8dda-710c0dd5932e
# 1  004b6bd4-19d0-4b40-99ef-1a76313fe7a5
# 2  00a5e81c-cd67-483f-9d99-3c733b2ead38
# 3  014f5ae1-5862-4165-9a3b-bba7bb08a527
# 4  01a962ea-a87f-49fa-9a27-7273a39f64a9
#
#                                            file_name  \
# 0  nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# 1  nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml
# 2  nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml
# 3  nationwidechildrens.org_clinical.TCGA-C8-A12P.xml
# 4  nationwidechildrens.org_clinical.TCGA-S3-A6ZF.xml
#
#    age_at_initial_pathologic_diagnosis                               case_id
# 0                                 71.0  378778d2-b331-4867-a93b-c64028c8b4c7
# 1                                 53.0  b343bfe0-7c23-4c6a-8c84-9ee39db2ecda
# 2                                 59.0  3e775c99-ceda-4246-8d6f-0f58ca5097c8
# 3                                 55.0  abdc76db-f85e-4337-a57e-6d098789da03
# 4                                 64.0  fbee40f1-d6d8-4156-8d42-36e09bb9f095

# %%
merged_df.shape
# Out:
# (771, 4)

# %% [markdown]
# # miRNA_seq

# %%
# Check if all file in all sub folder od datasets/miRNA_seq terminate with mirnas.quantification.txt
count_not_mirnas_quantification_txt = 0
for subfolder in os.listdir("../datasets/miRNA_seq"):
    for file in os.listdir(f"../datasets/miRNA_seq/{subfolder}"):
        if not file.endswith("mirnas.quantification.txt"):
            count_not_mirnas_quantification_txt+=1
            print(f"File {file} in folder {subfolder} does not end with mirnas.quantification.txt")
print(f"Number of files not ending with mirnas.quantification.txt: {count_not_mirnas_quantification_txt}")
# Out:
# File annotations.txt in folder 1d46b67b-8c6d-4a85-a837-30f54d45dce9 does not end with mirnas.quantification.txt
# File logs in folder 1d46b67b-8c6d-4a85-a837-30f54d45dce9 does not end with mirnas.quantification.txt
# File annotations.txt in folder 2272a72a-201e-4e84-b4fb-5e20939e0fa9 does not end with mirnas.quantification.txt
# File logs in folder 2272a72a-201e-4e84-b4fb-5e20939e0fa9 does not end with mirnas.quantification.txt
# File annotations.txt in folder 22bbada8-1c32-4c82-8bf0-3d71dce76841 does not end with mirnas.quantification.txt
# File logs in folder 22bbada8-1c32-4c82-8bf0-3d71dce76841 does not end with mirnas.quantification.txt
# File annotations.txt in folder 26094c76-21b8-4583-aeb4-3bbad0da7f29 does not end with mirnas.quantification.txt
# File logs in folder 26094c76-21b8-4583-aeb4-3bbad0da7f29 does not end with mirnas.quantification.txt
# File annotations.txt in folder 28c996b2-5e2d-4a48-a4e0-dd910f8599ab does not end with mirnas.quantification.txt
# File logs in folder 28c996b2-5e2d-4a48-a4e0-dd910f8599ab does not end with mirnas.quantification.txt
# File annotations.txt in folder 2bd8a058-6019-49bc-a56b-42fd8b227db7 does not end with mirnas.quantification.txt
# File logs in folder 2bd8a058-6019-49bc-a56b-42fd8b227db7 does not end with mirnas.quantification.txt
# File annotations.txt in folder 38dafa49-8904-4098-9b2a-14c2616607d5 does not end with mirnas.quantification.txt
# File logs in folder 38dafa49-8904-4098-9b2a-14c2616607d5 does not end with mirnas.quantification.txt
# File annotations.txt in folder 4a705a20-e5f2-4307-98d1-4f8550cd3887 does not end with mirnas.quantification.txt
# File logs in folder 4a705a20-e5f2-4307-98d1-4f8550cd3887 does not end with mirnas.quantification.txt
# File annotations.txt in folder 5257a7c7-99ed-4033-b065-3cd7f38a9703 does not end with mirnas.quantification.txt
# File logs in folder 5257a7c7-99ed-4033-b065-3cd7f38a9703 does not end with mirnas.quantification.txt
# File annotations.txt in folder 5b221489-e4aa-4159-b29d-dc419328ece1 does not end with mirnas.quantification.txt
# File logs in folder 5b221489-e4aa-4159-b29d-dc419328ece1 does not end with mirnas.quantification.txt
# File annotations.txt in folder 5f32df13-1cd6-4411-a7af-d20c52406dfd does not end with mirnas.quantification.txt
# File logs in folder 5f32df13-1cd6-4411-a7af-d20c52406dfd does not end with mirnas.quantification.txt
# File annotations.txt in folder 6a3ed02c-cbd6-49a1-ab82-065dc847ce97 does not end with mirnas.quantification.txt
# File logs in folder 6a3ed02c-cbd6-49a1-ab82-065dc847ce97 does not end with mirnas.quantification.txt
# File annotations.txt in folder 7106897f-1108-4f59-a5cd-8164994ab6d6 does not end with mirnas.quantification.txt
# File logs in folder 7106897f-1108-4f59-a5cd-8164994ab6d6 does not end with mirnas.quantification.txt
# File annotations.txt in folder 7433646c-92de-450d-8dbb-9bdb029ae1e0 does not end with mirnas.quantification.txt
# File logs in folder 7433646c-92de-450d-8dbb-9bdb029ae1e0 does not end with mirnas.quantification.txt
# File annotations.txt in folder 757ee75b-674e-49a5-8ba0-cc1b574a51ae does not end with mirnas.quantification.txt
# File logs in folder 757ee75b-674e-49a5-8ba0-cc1b574a51ae does not end with mirnas.quantification.txt
# File annotations.txt in folder 790e77fb-fe92-4413-bb39-0f1edc92093d does not end with mirnas.quantification.txt
# File logs in folder 790e77fb-fe92-4413-bb39-0f1edc92093d does not end with mirnas.quantification.txt
# File annotations.txt in folder 7ee45307-85b7-437d-bf34-3c4c51e693b2 does not end with mirnas.quantification.txt
# File logs in folder 7ee45307-85b7-437d-bf34-3c4c51e693b2 does not end with mirnas.quantification.txt
# File annotations.txt in folder 9356ab97-fd04-4903-a219-1a096421b99a does not end with mirnas.quantification.txt
# File logs in folder 9356ab97-fd04-4903-a219-1a096421b99a does not end with mirnas.quantification.txt
# File annotations.txt in folder a335cf3e-1504-46c7-a130-628ef6b543aa does not end with mirnas.quantification.txt
# File logs in folder a335cf3e-1504-46c7-a130-628ef6b543aa does not end with mirnas.quantification.txt
# File annotations.txt in folder a3361ee3-2e6f-48e7-a526-e6d1b1aa6d75 does not end with mirnas.quantification.txt
# File logs in folder a3361ee3-2e6f-48e7-a526-e6d1b1aa6d75 does not end with mirnas.quantification.txt
# File annotations.txt in folder a6e94c3b-2e72-4a4a-bc47-e5f6a12b6d89 does not end with mirnas.quantification.txt
# File logs in folder a6e94c3b-2e72-4a4a-bc47-e5f6a12b6d89 does not end with mirnas.quantification.txt
# File annotations.txt in folder ca8d0a76-611f-467d-9539-3d893645c308 does not end with mirnas.quantification.txt
# File logs in folder ca8d0a76-611f-467d-9539-3d893645c308 does not end with mirnas.quantification.txt
# File annotations.txt in folder dc3fe022-54ca-43a3-a8aa-94c08635e04f does not end with mirnas.quantification.txt
# File logs in folder dc3fe022-54ca-43a3-a8aa-94c08635e04f does not end with mirnas.quantification.txt
# File annotations.txt in folder e6cb449a-c889-48bb-a650-471453c30dbb does not end with mirnas.quantification.txt
# File logs in folder e6cb449a-c889-48bb-a650-471453c30dbb does not end with mirnas.quantification.txt
# File annotations.txt in folder efa764bd-5a4b-43cd-b646-1283894094f4 does not end with mirnas.quantification.txt
# File logs in folder efa764bd-5a4b-43cd-b646-1283894094f4 does not end with mirnas.quantification.txt
# Number of files not ending with mirnas.quantification.txt: 50

# %%
def import_txt(file_path):
    temp_df = pd.read_csv(file_path, sep="\t")
    if 'reads_per_million_miRNA_mapped' in temp_df.columns:
        temp_df = temp_df[["reads_per_million_miRNA_mapped"]]
        temp_df = temp_df.dropna(how='all')
        #print(f"file {file_path}")
        #print(temp_df['reads_per_million_miRNA_mapped'])
        return temp_df
    return None

def miRNA_process():
    count_subfolders = 0
    # Initialize an empty DataFrame to store the results
    miRNA_df1 = pd.DataFrame(columns=["folder_name", "file_name", "reads_per_million_miRNA_mapped"])
    for subfolder in os.listdir("../datasets/miRNA_seq"):
        count_subfolders += 1
        for file in os.listdir(f"../datasets/miRNA_seq/{subfolder}"):
            if file.endswith(".txt") and file != "annotations.xml":
                selected_data = import_txt(f"../datasets/miRNA_seq/{subfolder}/{file}")

                if selected_data is not None:
                    selected_data.insert(0, "file_name", file)
                    selected_data.insert(0, "folder_name", subfolder)

                    # Safe concatenation avoiding empty DataFrames or with NaN values
                    if not selected_data.empty and not selected_data.isna().all().all():
                        miRNA_df1 = pd.concat([miRNA_df1, selected_data], ignore_index=True)
    print(f"Subfolders: {count_subfolders}")
    return miRNA_df1
miRNA_df1 = miRNA_process()
# Out:
# C:\Users\giorg\AppData\Local\Temp\ipykernel_20508\3093818702.py:27: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   miRNA_df1 = pd.concat([miRNA_df1, selected_data], ignore_index=True)
# Subfolders: 767

# %% [markdown]
# **Vengono prese tutte le subfolders**

# %%
miRNA_df1.head()
# Out:
#                             folder_name  \
# 0  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
# 1  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
# 2  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
# 3  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
# 4  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
#
#                                            file_name  \
# 0  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
# 1  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
# 2  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
# 3  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
# 4  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
#
#    reads_per_million_miRNA_mapped
# 0                     5652.188302
# 1                     5872.823005
# 2                     5890.158589
# 3                    14259.305663
# 4                     1534.199167

# %%
miRNA_df1.shape
# Out:
# (1442727, 3)

# %%
miRNA_df1[["reads_per_million_miRNA_mapped"]].describe()
# Out:
#        reads_per_million_miRNA_mapped
# count                    1.442727e+06
# mean                     5.316321e+02
# std                      8.026859e+03
# min                      0.000000e+00
# 25%                      0.000000e+00
# 50%                      0.000000e+00
# 75%                      5.006910e-01
# max                      6.792865e+05

# %%
simplified_miRNA_df = miRNA_df1.groupby(
    ['folder_name', 'file_name']
).agg({'reads_per_million_miRNA_mapped': list}).reset_index()

simplified_miRNA_df.shape
# Out:
# (767, 3)

# %%
simplified_miRNA_df['list_length'] = simplified_miRNA_df['reads_per_million_miRNA_mapped'].apply(len)
print(simplified_miRNA_df['list_length'].to_list())
# Out:
# [1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 1881, 188 ...

# %% [markdown]
# All files have **1881** miRNA values

# %%
simplified_miRNA_df.head()
# Out:
#                             folder_name  \
# 0  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
# 1  016db033-3cec-4c63-b90f-0428da475a63
# 2  0173d27e-ff23-42b2-afb9-9b867ace3efc
# 3  0195917c-c127-4523-aff3-9e64ebdd4363
# 4  046b15a8-38d3-41fc-b55f-04dd591a8e14
#
#                                            file_name  \
# 0  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
# 1  f46e1aef-c572-4651-964d-a0a9bc7a1128.mirbase21...
# 2  bc1018a6-62f3-4386-a545-9fa8a31a2e96.mirbase21...
# 3  75134cfe-bc9d-4838-9a88-2ef2200b34ec.mirbase21...
# 4  ad7d6f10-1dff-4bc8-a8c3-0b6ce7b45366.mirbase21...
#
#                       reads_per_million_miRNA_mapped  list_length
# 0  [5652.188302, 5872.823005, 5890.158589, 14259....         1881
# 1  [8395.099993, 8287.749902, 8330.52851, 20291.5...         1881
# 2  [19889.387965, 19847.305155, 19961.06025, 1472...         1881
# 3  [13142.168087, 13137.975295, 13098.004007, 445...         1881
# 4  [10511.654941, 10471.07787, 10569.778855, 2060...         1881

# %% [markdown]
# ### Check if all miRNA IDs are in the same order in all files

# %%
import pandas as pd
import os

def import_txt(file_path):
    temp_df = pd.read_csv(file_path, sep="\t")
    if 'miRNA_ID' in temp_df.columns:
        temp_df = temp_df[["miRNA_ID"]]
        temp_df = temp_df.dropna(how='all')
        return temp_df
    return None

def check_column_order():
    reference_order = None
    mismatches = []

    for subfolder in os.listdir("../datasets/miRNA_seq"):
        for file in os.listdir(f"../datasets/miRNA_seq/{subfolder}"):
            if file.endswith(".txt") and file != "annotations.xml":
                df = import_txt(f"../datasets/miRNA_seq/{subfolder}/{file}")
                if df is not None and not df.empty:
                    current_order = df['miRNA_ID'].tolist()
                    if reference_order is None:
                        reference_order = current_order
                    elif current_order != reference_order:
                        mismatches.append(f"{subfolder}/{file}")

    if len(mismatches) == 0:
        print("---------------------------------------------------")
        print("-> All files have the miRNA IDs in the same order.")
        print("---------------------------------------------------")
    else:
        print("-----------------------------------------------")
        print("-> Files with mismatched miRNA ID order:")
        for f in mismatches:
            print(f)        
        print("-----------------------------------------------")

check_column_order()
# Out:
# --------------------------------------------------
# -> All files have the miRNA IDs in the same order.
# --------------------------------------------------

# %% [markdown]
# # miRNA JSON

# %%
df_miRNA_json = pd.read_json('../datasets/miRNA(json&manifest)/files.2024-12-12.json')
print(df_miRNA_json.columns)
# Out:
# Index(['data_format', 'cases', 'access', 'file_name', 'file_id', 'data_type',
#        'data_category', 'experimental_strategy', 'platform', 'file_size',
#        'annotations'],
#       dtype='object')

# %%
print(df_miRNA_json[['cases', 'file_name']].head())
print(df_miRNA_json['cases'].head())
print(f"'data_category' unique: {df_miRNA_json['data_category'].unique()}")
print(df_miRNA_json['data_format'].unique())
print(df_miRNA_json.shape)
# Out:
#                                                cases  \
# 0  [{'case_id': '1c3610f7-e0aa-48d7-9a27-0dbaf6e2...
# 1  [{'case_id': '241fffc8-4250-4cfa-b2e7-e68c33ae...
# 2  [{'case_id': 'e5aae05a-478e-4a55-a27c-12b2b4be...
# 3  [{'case_id': 'b7f74ae1-6f58-447c-be50-a7666eb1...
# 4  [{'case_id': 'e7a00d67-2c26-4d1f-bd17-35f659e8...
#
#                                            file_name
# 0  a8c7bebe-a450-4a3e-b891-e2d4ac578b04.mirbase21...
# 1  97cb5037-7eea-4ba7-86c3-d13dd91e5b1e.mirbase21...
# 2  6bd02673-dd3f-42ed-9997-e371b09f22ee.mirbase21...
# 3  f846c0ad-9bbd-46a5-a678-fc3c05cdcc41.mirbase21...
# 4  fe712c27-8dbb-4531-afb3-10999e319a7b.mirbase21...
# 0    [{'case_id': '1c3610f7-e0aa-48d7-9a27-0dbaf6e2...
# 1    [{'case_id': '241fffc8-4250-4cfa-b2e7-e68c33ae...
# 2    [{'case_id': 'e5aae05a-478e-4a55-a27c-12b2b4be...
# 3    [{'case_id': 'b7f74ae1-6f58-447c-be50-a7666eb1...
# 4    [{'case_id': 'e7a00d67-2c26-4d1f-bd17-35f659e8...
# Name: cases, dtype: object
# 'data_category' unique: ['Transcriptome Profiling']
# ['TXT']
# (767, 11)

# %%
print(df_miRNA_json[['cases', 'file_name']].shape)
df_miRNA_json[['cases', 'file_name']].head(1)
# Out:
# (767, 2)
#                                                cases  \
# 0  [{'case_id': '1c3610f7-e0aa-48d7-9a27-0dbaf6e2...
#
#                                            file_name
# 0  a8c7bebe-a450-4a3e-b891-e2d4ac578b04.mirbase21...

# %%
# La colonna 'cases' contenga liste di dizionari
cases_expanded = df_miRNA_json['cases'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else {})
unique_projects = pd.json_normalize(cases_expanded)['project.project_id'].unique()

print("Unique project IDs:", unique_projects)
# Out:
# Unique project IDs: ['TCGA-BRCA']

# %%
# Estrai il valore di 'case_id' dalla lista di dizionari nella colonna 'cases'
df_miRNA_json['case_id'] = df_clinical_json['cases'].apply(
    lambda x: x[0]['case_id'] if isinstance(x, list) and len(x) > 0 and 'case_id' in x[0] else None
)

print(df_miRNA_json[['case_id', 'file_name']].head())
# Out:
#                                 case_id  \
# 0  e4fc0909-f284-4471-866d-d8967b6adcbc
# 1  87281a89-91d2-44f7-9f80-668567ad5c72
# 2  b8a615f9-d19b-4b09-8ec8-0674e5c648cd
# 3  3b01d064-8c00-4972-9f07-407eac8e7534
# 4  8785012f-f73e-4d68-87cf-1d804af32782
#
#                                            file_name
# 0  a8c7bebe-a450-4a3e-b891-e2d4ac578b04.mirbase21...
# 1  97cb5037-7eea-4ba7-86c3-d13dd91e5b1e.mirbase21...
# 2  6bd02673-dd3f-42ed-9997-e371b09f22ee.mirbase21...
# 3  f846c0ad-9bbd-46a5-a678-fc3c05cdcc41.mirbase21...
# 4  fe712c27-8dbb-4531-afb3-10999e319a7b.mirbase21...

# %% [markdown]
# # Merge miRNA_df1 with df_miRNA_json on file_name

# %%
miRNA_merged_df = pd.merge(simplified_miRNA_df, df_miRNA_json[['case_id', 'file_name']], on='file_name', how='inner')
miRNA_merged_df.head()
# Out:
#                             folder_name  \
# 0  01626fb9-a7f7-4324-97f2-ef2fee03f3c7
# 1  016db033-3cec-4c63-b90f-0428da475a63
# 2  0173d27e-ff23-42b2-afb9-9b867ace3efc
# 3  0195917c-c127-4523-aff3-9e64ebdd4363
# 4  046b15a8-38d3-41fc-b55f-04dd591a8e14
#
#                                            file_name  \
# 0  e7b7bf36-aa58-4dc0-8548-a28c11d5060f.mirbase21...
# 1  f46e1aef-c572-4651-964d-a0a9bc7a1128.mirbase21...
# 2  bc1018a6-62f3-4386-a545-9fa8a31a2e96.mirbase21...
# 3  75134cfe-bc9d-4838-9a88-2ef2200b34ec.mirbase21...
# 4  ad7d6f10-1dff-4bc8-a8c3-0b6ce7b45366.mirbase21...
#
#                       reads_per_million_miRNA_mapped  list_length  \
# 0  [5652.188302, 5872.823005, 5890.158589, 14259....         1881
# 1  [8395.099993, 8287.749902, 8330.52851, 20291.5...         1881
# 2  [19889.387965, 19847.305155, 19961.06025, 1472...         1881
# 3  [13142.168087, 13137.975295, 13098.004007, 445...         1881
# 4  [10511.654941, 10471.07787, 10569.778855, 2060...         1881
#
#                                 case_id
# 0  045c13ef-3db7-4adf-b0a3-23338f0479f3
# 1  64089c20-939f-48b4-ae8b-904ad0597145
# 2  db8d38ab-cc61-49ee-863d-40060112f2af
# 3  9495f029-9882-4c9b-a557-b3aec9e91698
# 4  97b5f490-1cd9-4833-b903-5f4c6e45670d

# %%
miRNA_merged_df.shape
# Out:
# (767, 5)

# %% [markdown]
# # Merge the two merged DataFrames on case_id

# %%
final_merged_df = pd.merge(merged_df, miRNA_merged_df, on='case_id', suffixes=('_clinical', '_miRNA'))
final_merged_df.head()
# Out:
#                    folder_name_clinical  \
# 0  00049989-fa21-48fb-8dda-710c0dd5932e
# 1  004b6bd4-19d0-4b40-99ef-1a76313fe7a5
# 2  004b6bd4-19d0-4b40-99ef-1a76313fe7a5
# 3  00a5e81c-cd67-483f-9d99-3c733b2ead38
# 4  014f5ae1-5862-4165-9a3b-bba7bb08a527
#
#                                   file_name_clinical  \
# 0  nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml
# 1  nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml
# 2  nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml
# 3  nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml
# 4  nationwidechildrens.org_clinical.TCGA-C8-A12P.xml
#
#    age_at_initial_pathologic_diagnosis                               case_id  \
# 0                                 71.0  378778d2-b331-4867-a93b-c64028c8b4c7
# 1                                 53.0  b343bfe0-7c23-4c6a-8c84-9ee39db2ecda
# 2                                 53.0  b343bfe0-7c23-4c6a-8c84-9ee39db2ecda
# 3                                 59.0  3e775c99-ceda-4246-8d6f-0f58ca5097c8
# 4                                 55.0  abdc76db-f85e-4337-a57e-6d098789da03
#
#                       folder_name_miRNA  \
# 0  b02ef951-bb51-4378-b59c-ccffeff088ec
# 1  05960e82-e648-4b99-a116-9cf917d1bff7
# 2  9326bb7f-da05-490c-a620-5c88323130d6
# 3  4e60fda1-4bbe-4901-987d-6c15a87af886
# 4  5cc8d0d0-e196-4ef2-85c8-20f8d35764e3
#
#                                      file_name_miRNA  \
# 0  ce7471cc-a727-42bb-bded-e4a657e5b8fb.mirbase21...
# 1  d042b37f-1ba7-41e8-af11-9232df313018.mirbase21...
# 2  11c5ea50-2bce-4da6-b76f-548b9f64238f.mirbase21...
# 3  397fe4a8-e6f0-4b36-88e0-dcbb488eff59.mirbase21...
# 4  004b1938-87ab-4bf2-a19b-d2953d0e81a0.mirbase21...
#
#                       reads_per_million_miRNA_mapped  list_length
# 0  [12120.990742, 12041.557881, 12141.51573, 1768...         1881
# 1  [20904.21904, 21106.26856, 20907.030164, 45794...         1881
# 2  [4742.042712, 4748.951756, 4919.239371, 4809.9...         1881
# 3  [8992.901265, 8985.700823, 9044.654437, 29490....         1881
# 4  [6540.401419, 6668.261153, 6475.719437, 19448....         1881

# %%
final_merged_df.shape
# Out:
# (758, 8)

# %%
final_merged_df.isna().sum()
# Out:
# folder_name_clinical                   0
# file_name_clinical                     0
# age_at_initial_pathologic_diagnosis    0
# case_id                                0
# folder_name_miRNA                      0
# file_name_miRNA                        0
# reads_per_million_miRNA_mapped         0
# list_length                            0
# dtype: int64

# %%
final_merged_df.columns
# Out:
# Index(['folder_name_clinical', 'file_name_clinical',
#        'age_at_initial_pathologic_diagnosis', 'case_id', 'folder_name_miRNA',
#        'file_name_miRNA', 'reads_per_million_miRNA_mapped', 'list_length'],
#       dtype='object')

# %% [markdown]
# ## Righe non mergiate

# %%
# Merge con outer join per includere tutte le righe
all_rows_df = pd.merge(merged_df, miRNA_merged_df, on='case_id', suffixes=('_clinical', '_miRNA'), how='outer')

# Filtra le righe senza corrispondenza di case_id
non_matching_rows_df = all_rows_df[all_rows_df.isna().any(axis=1)]

non_matching_rows_df.shape
# Out:
# (66, 8)

# %%
non_matching_rows_df.head(10)
# Out:
#                      folder_name_clinical  \
# 41   174eca80-6a0a-4f82-a87f-d47a117f8b91
# 46   07442715-1af6-42b0-801b-84fc7d01c1a0
# 69   77155c92-4416-4f53-9435-776ceee32845
# 73   5038627b-4066-4919-8a89-8bc55143596c
# 77   492170e4-90b8-4560-89ff-effa9eeb5194
# 78   63e03017-0ea7-4a4d-85ee-32df750e68a8
# 84   57f570ac-1320-480e-a7b0-fffd2e882513
# 99   7618fafa-1164-40cb-b464-6ac90ad35c60
# 141  58b8a73e-3975-43ec-995a-e8a3d72f3930
# 220  d1a2492b-b588-4adc-9f0f-4fc83a8cf0d3
#
#                                     file_name_clinical  \
# 41   nationwidechildrens.org_clinical.TCGA-E2-A15E.xml
# 46   nationwidechildrens.org_clinical.TCGA-C8-A1HG.xml
# 69   nationwidechildrens.org_clinical.TCGA-D8-A27F.xml
# 73   nationwidechildrens.org_clinical.TCGA-E9-A22H.xml
# 77   nationwidechildrens.org_clinical.TCGA-B6-A0X1.xml
# 78   nationwidechildrens.org_clinical.TCGA-A7-A0D9.xml
# 84   nationwidechildrens.org_clinical.TCGA-A2-A0SX.xml
# 99   nationwidechildrens.org_clinical.TCGA-E2-A15J.xml
# 141  nationwidechildrens.org_clinical.TCGA-A7-A13F.xml
# 220  nationwidechildrens.org_clinical.TCGA-AR-A1AN.xml
#
#      age_at_initial_pathologic_diagnosis  \
# 41                                  40.0
# 46                                  50.0
# 69                                  40.0
# 73                                  42.0
# 77                                  48.0
# 78                                  37.0
# 84                                  48.0
# 99                                  51.0
# 141                                 44.0
# 220                                 46.0
#
#                                   case_id folder_name_miRNA file_name_miRNA  \
# 41   0a2a3529-f645-4967-9a58-89ee20b8bb62               NaN             NaN
# 46   0c23c380-363c-474d-b64c-b47f612a8225               NaN             NaN
# 69   1549dc64-3dab-43fc-96e9-b07d520957e1               NaN             NaN
# 73   161917b8-88ad-407b-ade6-d6b98478b359               NaN             NaN
# 77   178b2c48-c07d-422e-ae17-8bcfd996ad51               NaN             NaN
# 78   17baef7c-d97d-4b98-ab53-503ef856523d               NaN             NaN
# 84   18d35983-ea6a-4b70-a209-9bef37595956               NaN             NaN
# 99   1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c               NaN             NaN
# 141  2cf68894-168b-458b-af4f-53cad72989a8               NaN             NaN
# 220  43029932-feb0-4658-97fa-645c1e775009               NaN             NaN
#
#     reads_per_million_miRNA_mapped  list_length
# 41                             NaN          NaN
# 46                             NaN          NaN
# 69                             NaN          NaN
# 73                             NaN          NaN
# 77                             NaN          NaN
# 78                             NaN          NaN
# 84                             NaN          NaN
# 99                             NaN          NaN
# 141                            NaN          NaN
# 220                            NaN          NaN

# %% [markdown]
# # Save in csv file

# %%
# Select relevant columns to save
final_merged_df_to_save = final_merged_df[['case_id', 'age_at_initial_pathologic_diagnosis', 'reads_per_million_miRNA_mapped']]
final_merged_df_to_save.to_csv('../datasets/preprocessed/final_merged_clinical_miRNA.csv', index=False)

# %%
final_merged_df = final_merged_df_to_save.copy()
# Espandi la lista in colonne separate
reads_df = pd.DataFrame(final_merged_df["reads_per_million_miRNA_mapped"].tolist()).fillna(0)

# Rinomina le colonne come miRNA_1, miRNA_2, ...
reads_df.columns = [f"miRNA_{i+1}" for i in range(reads_df.shape[1])]

# Unisci con le altre colonne (case_id, età, ecc.)
df_finale = pd.concat([final_merged_df.drop(columns=["reads_per_million_miRNA_mapped"]), reads_df], axis=1)

# Visualizza il risultato
print(df_finale.head())
df_finale.to_csv('../datasets/preprocessed/final_merged.csv', index=False)
# Out:
#                                 case_id  age_at_initial_pathologic_diagnosis  \
# 0  378778d2-b331-4867-a93b-c64028c8b4c7                                 71.0
# 1  b343bfe0-7c23-4c6a-8c84-9ee39db2ecda                                 53.0
# 2  b343bfe0-7c23-4c6a-8c84-9ee39db2ecda                                 53.0
# 3  3e775c99-ceda-4246-8d6f-0f58ca5097c8                                 59.0
# 4  abdc76db-f85e-4337-a57e-6d098789da03                                 55.0
#
#         miRNA_1       miRNA_2       miRNA_3       miRNA_4      miRNA_5  \
# 0  12120.990742  12041.557881  12141.515730  17683.610218  2483.291559
# 1  20904.219040  21106.268560  20907.030164  45794.611568  6957.179909
# 2   4742.042712   4748.951756   4919.239371   4809.913909   546.220895
# 3   8992.901265   8985.700823   9044.654437  29490.757783  3047.586817
# 4   6540.401419   6668.261153   6475.719437  19448.969676  2930.996358
#
#       miRNA_6      miRNA_7      miRNA_8  ...  miRNA_1872  miRNA_1873  \
# 0  276.913390   860.889868  3728.010288  ...         0.0    3.478811
# 1  471.917401  2279.821367  7539.785307  ...         0.0    1.054171
# 2  298.714552   869.320309  1083.094260  ...         0.0   13.411674
# 3  825.575608   577.835421  2360.394692  ...         0.0   18.901159
# 4  310.623940   563.334943  1192.103985  ...         0.0    1.504232
#
#    miRNA_1874  miRNA_1875  miRNA_1876  miRNA_1877  miRNA_1878  miRNA_1879  \
# 0         0.0    1.739406    1.159604         0.0   25.279363   33.860431
# 1         0.0    1.405562    4.919467         0.0    2.811124   52.708570
# 2         0.0    1.219243    5.689801         0.0   98.352274   20.320718
# 3         0.0    0.900055    4.950303         0.0   19.801214   67.279124
# 4         0.0    0.000000    8.273277         0.0   25.571947   30.836759
#
#     miRNA_1880     miRNA_1881
# 0   800.126629   14239.470942
# 1  1664.888045   45043.338744
# 2   293.837580  153860.753500
# 3  1639.225485   39918.797022
# 4   750.611846   15080.679492
#
# [5 rows x 1883 columns]

# %%
final_merged_df_to_save.shape
# Out:
# (758, 3)
