# %%
import pandas as pd

# %%
RESULT_PATHs = [
    "../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_log/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_log/cv_results_Net_5layers.csv",
    "../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_quant/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_quant/cv_results_Net_5layers.csv",
    "../grid_searches/deepsurv/mRNA/clinical_miRNA_normalized_log/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/mRNA/clinical_miRNA_normalized_log/cv_results_Net_5layers.csv",
    "../grid_searches/deepsurv/mRNA/clinical_miRNA_normalized_tpm_log/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/mRNA/clinical_miRNA_normalized_tpm_log/cv_results_Net_5layers.csv",    
]
for RESULT_PATH in RESULT_PATHs:
    df = pd.read_csv(RESULT_PATH)
    
    # calculate mean and all information distribution for c-index
    mean_cindex = df['c_index'].mean()
    std_cindex = df['c_index'].std()
    min_cindex = df['c_index'].min()
    max_cindex = df['c_index'].max()
    p25_cindex = df['c_index'].quantile(0.25)
    p50_cindex = df['c_index'].quantile(0.50)
    p75_cindex = df['c_index'].quantile(0.75)
    
    print(f"CSV path: {RESULT_PATH}\n")
    print(f"Mean c-index: {mean_cindex:.4f}")
    print(f"Std c-index: {std_cindex:.4f}")
    print(f"Min c-index: {min_cindex:.4f}")
    print(f"Max c-index: {max_cindex:.4f}")
    print(f"25th Percentile c-index: {p25_cindex:.4f}")
    print(f"50th Percentile c-index: {p50_cindex:.4f}")
    print(f"75th Percentile c-index: {p75_cindex:.4f}")
    print("\n=========================================================\n")
# Out:
# CSV path: ../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_log/cv_results_Net_3layers.csv
#
# Mean c-index: 0.6794
# Std c-index: 0.1262
# Min c-index: 0.5111
# Max c-index: 0.8387
# 25th Percentile c-index: 0.5503
# 50th Percentile c-index: 0.6765
# 75th Percentile c-index: 0.7947
#
# ...
#
# CSV path: ../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_log/cv_results_Net_5layers.csv
#
# Mean c-index: 0.6952
# Std c-index: 0.1227
# Min c-index: 0.5000
# Max c-index: 0.8968
# 25th Percentile c-index: 0.6338
# 50th Percentile c-index: 0.6815
# 75th Percentile c-index: 0.7815
#
# ...
#
# CSV path: ../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_quant/cv_results_Net_3layers.csv
#
# Mean c-index: 0.6567
# Std c-index: 0.1761
# Min c-index: 0.3758
# Max c-index: 0.8644
# 25th Percentile c-index: 0.4930
# 50th Percentile c-index: 0.6471
# 75th Percentile c-index: 0.7806
#
# ...
#
# CSV path: ../grid_searches/deepsurv/miRNA/clinical_miRNA_normalized_quant/cv_results_Net_5layers.csv
# ...

# %%
RESULT_PATHs = [
    "../grid_searches/deepsurv/miRNA/VAE_clinical_miRNA_normalized_log/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/miRNA/VAE_clinical_miRNA_normalized_log/cv_results_Net_5layers.csv",
    "../grid_searches/deepsurv/miRNA/VAE_clinical_miRNA_normalized_quant/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/miRNA/VAE_clinical_miRNA_normalized_quant/cv_results_Net_5layers.csv",
    "../grid_searches/deepsurv/mRNA/VAE_clinical_miRNA_normalized_log/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/mRNA/VAE_clinical_miRNA_normalized_log/cv_results_Net_5layers.csv",
    "../grid_searches/deepsurv/mRNA/VAE_clinical_miRNA_normalized_tpm_log/cv_results_Net_3layers.csv",
    "../grid_searches/deepsurv/mRNA/VAE_clinical_miRNA_normalized_tpm_log/cv_results_Net_5layers.csv",    
]
for RESULT_PATH in RESULT_PATHs:
    df = pd.read_csv(RESULT_PATH)
    
    # calculate mean and all information distribution for c-index
    mean_cindex = df['c_index'].mean()
    std_cindex = df['c_index'].std()
    min_cindex = df['c_index'].min()
    max_cindex = df['c_index'].max()
    p25_cindex = df['c_index'].quantile(0.25)
    p50_cindex = df['c_index'].quantile(0.50)
    p75_cindex = df['c_index'].quantile(0.75)
    
    print(f"CSV path: {RESULT_PATH}\n")
    print(f"Mean c-index: {mean_cindex:.4f}")
    print(f"Std c-index: {std_cindex:.4f}")
    print(f"Min c-index: {min_cindex:.4f}")
    print(f"Max c-index: {max_cindex:.4f}")
    print(f"25th Percentile c-index: {p25_cindex:.4f}")
    print(f"50th Percentile c-index: {p50_cindex:.4f}")
    print(f"75th Percentile c-index: {p75_cindex:.4f}")
    print("\n=========================================================\n")
