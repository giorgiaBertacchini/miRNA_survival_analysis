# %%
import pandas as pd
import os

CLINICAL_PATH = "../datasets/clinical_data"

# %% [markdown]
# ### Create clinical_df DataFrame with days_to_death from TXT files:

# %%
def import_xml(file_path):
    temp_df = pd.read_xml(file_path, parser="etree")

    if 'days_to_death' in temp_df.columns:
        # Remove rows in which all columns are NaN
        temp_df = temp_df[["days_to_death"]]
    
        temp_df = temp_df.dropna(how='all')
        
        if temp_df.empty:
            print(f"File {file_path} has no valid age data.")

        return temp_df
    return None

def main():
    clinical_df = pd.DataFrame(columns=["folder_name", "file_name", "days_to_death"])
    for subfolder in os.listdir(f"{CLINICAL_PATH}"):
        file_xml_or_annotation_or_orm = 0
        for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
            if file.endswith(".xml") and "annotations" not in file and "org_omf" not in file:
                file_xml_or_annotation_or_orm = 1
                selected_data = import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
            
                if selected_data is not None:
                    selected_data.insert(0, "file_name", file)
                    selected_data.insert(0, "folder_name", subfolder)

                    # Safe concatenation avoiding empty DataFrames or with NaN values
                    if not selected_data.empty and not selected_data.isna().all().all():
                        clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
                        
    return clinical_df

clinical_death_df = main()
clinical_death_df.shape
# Out:
# File ../datasets/clinical_data/00049989-fa21-48fb-8dda-710c0dd5932e/nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml has no valid age data.
# File ../datasets/clinical_data/004b6bd4-19d0-4b40-99ef-1a76313fe7a5/nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml has no valid age data.
# File ../datasets/clinical_data/00a5e81c-cd67-483f-9d99-3c733b2ead38/nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml has no valid age data.
# File ../datasets/clinical_data/014f5ae1-5862-4165-9a3b-bba7bb08a527/nationwidechildrens.org_clinical.TCGA-C8-A12P.xml has no valid age data.
# File ../datasets/clinical_data/01a962ea-a87f-49fa-9a27-7273a39f64a9/nationwidechildrens.org_clinical.TCGA-S3-A6ZF.xml has no valid age data.
# File ../datasets/clinical_data/02726df0-5db3-4b3d-a3ca-8a1d8a0e130e/nationwidechildrens.org_clinical.TCGA-AN-A0FW.xml has no valid age data.
# File ../datasets/clinical_data/02865683-19cc-4600-be9b-555c34c20db3/nationwidechildrens.org_clinical.TCGA-D8-A140.xml has no valid age data.
# File ../datasets/clinical_data/02c43433-d777-4ec7-adf8-74defc7c8a24/nationwidechildrens.org_clinical.TCGA-E2-A14R.xml has no valid age data.
# File ../datasets/clinical_data/032c6c78-a0f7-4695-a93e-3f42747353a8/nationwidechildrens.org_clinical.TCGA-A8-A08C.xml has no valid age data.
# File ../datasets/clinical_data/0382de14-79b0-4fdc-bf14-d82494cbcdee/nationwidechildrens.org_clinical.TCGA-AN-A0FF.xml has no valid age data.
# File ../datasets/clinical_data/03ce4d08-2d3e-4c38-892d-d22b37eb9ad5/nationwidechildrens.org_clinical.TCGA-D8-A27N.xml has no valid age data.
# File ../datasets/clinical_data/03d2bd6f-1bb3-42b4-8ab9-823682084a1b/nationwidechildrens.org_clinical.TCGA-D8-A1X5.xml has no valid age data.
# File ../datasets/clinical_data/04b8884d-ffa3-486e-84b7-681c51bb259e/nationwidechildrens.org_clinical.TCGA-AR-A0TT.xml has no valid age data.
# File ../datasets/clinical_data/051ca785-e7be-4ac3-8757-1c9ace8acf7e/nationwidechildrens.org_clinical.TCGA-A8-A08F.xml has no valid age data.
# File ../datasets/clinical_data/069ecadf-de19-4bf6-9765-e9aa8471ecd1/nationwidechildrens.org_clinical.TCGA-D8-A1XG.xml has no valid age data.
# File ../datasets/clinical_data/07442715-1af6-42b0-801b-84fc7d01c1a0/nationwidechildrens.org_clinical.TCGA-C8-A1HG.xml has no valid age data.
# File ../datasets/clinical_data/07488c2c-c50f-402e-8f22-9278db6110f9/nationwidechildrens.org_clinical.TCGA-AO-A0JI.xml has no valid age data.
# File ../datasets/clinical_data/07534899-1a59-4411-b189-64c1c85f4618/nationwidechildrens.org_clinical.TCGA-LL-A73Z.xml has no valid age data.
# File ../datasets/clinical_data/075b0201-49ad-4a23-a107-0b39fd475a5b/nationwidechildrens.org_clinical.TCGA-AC-A62V.xml has no valid age data.
# File ../datasets/clinical_data/078a3061-8dbe-4dfa-834d-180e7f9baf57/nationwidechildrens.org_clinical.TCGA-E2-A1LL.xml has no valid age data.
# File ../datasets/clinical_data/07eb1823-a8c0-4b38-9a71-25516b012527/nationwidechildrens.org_clinical.TCGA-EW-A1PC.xml has no valid age data.
# File ../datasets/clinical_data/0827791a-bb0a-4a3a-98c4-26312d8880f8/nationwidechildrens.org_clinical.TCGA-AQ-A04H.xml has no valid age data.
# File ../datasets/clinical_data/084c3393-0480-4971-ab7d-d0e8b68b26b5/nationwidechildrens.org_clinical.TCGA-AR-A251.xml has no valid age data.
# File ../datasets/clinical_data/085b8344-828f-49a5-9d60-f2cb30de38f2/nationwidechildrens.org_clinical.TCGA-BH-A0AZ.xml has no valid age data.
# File ../datasets/clinical_data/08770acd-4a5f-41e9-bc03-1dd153470903/nationwidechildrens.org_clinical.TCGA-E9-A245.xml has no valid age data.
# File ../datasets/clinical_data/09216d66-84b9-47ae-82fb-0ab3a2de7ffd/nationwidechildrens.org_clinical.TCGA-BH-A0BQ.xml has no valid age data.
# File ../datasets/clinical_data/09ced32a-4a6e-4e5f-ba75-1531cf3a64bc/nationwidechildrens.org_clinical.TCGA-A8-A09N.xml has no valid age data.
# C:\Users\giorg\AppData\Local\Temp\ipykernel_8492\2673299973.py:31: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
# File ../datasets/clinical_data/0b49c0d2-ac97-4446-aeff-f756ec145b8e/nationwidechildrens.org_clinical.TCGA-AR-A0TV.xml has no valid age data.
# File ../datasets/clinical_data/0c5baab4-37cb-48c6-88d8-56be866d8632/nationwidechildrens.org_clinical.TCGA-AR-A24P.xml has no valid age data.
# File ../datasets/clinical_data/0c75afc8-dba8-436e-b467-21b987cb63f7/nationwidechildrens.org_clinical.TCGA-EW-A1IZ.xml has no valid age data.
# File ../datasets/clinical_data/0cc3d450-2c60-4cb0-a073-d92dc979fa5e/nationwidechildrens.org_clinical.TCGA-BH-A18F.xml has no valid age data.
# File ../datasets/clinical_data/0d37a02a-252e-49dd-84ef-51c9d06ec43d/nationwidechildrens.org_clinical.TCGA-A7-A26H.xml has no valid age data.
# File ../datasets/clinical_data/0da89962-24e4-4dba-abce-854ab68843a1/nationwidechildrens.org_clinical.TCGA-AN-A0FZ.xml has no valid age data.
# File ../datasets/clinical_data/0e5052c4-7eca-427e-9a3b-dc22bbd01be4/nationwidechildrens.org_clinical.TCGA-A7-A4SD.xml has no valid age data.
# File ../datasets/clinical_data/0e54604a-78f9-4db3-81d7-3067e5612386/nationwidechildrens.org_clinical.TCGA-A2-A0T7.xml has no valid age data.
# File ../datasets/clinical_data/0e58f96c-b1ba-4f93-aac2-6e0970d40067/nationwidechildrens.org_clinical.TCGA-BH-A0B1.xml has no valid age data.
# File ../datasets/clinical_data/0e8af3a0-b315-4cd4-8b7f-646f8fdbbf0e/nationwidechildrens.org_clinical.TCGA-E2-A152.xml has no valid age data.
# File ../datasets/clinical_data/0e8e300e-a64a-4563-97eb-a3a6bc3f3b3b/nationwidechildrens.org_clinical.TCGA-A8-A097.xml has no valid age data.
# File ../datasets/clinical_data/0f699751-7c08-4f0a-8d07-3b125e9c4f99/nationwidechildrens.org_clinical.TCGA-E9-A22G.xml has no valid age data.
# File ../datasets/clinical_data/0fca54d0-a1f4-47f8-87f6-e17dd98fbf6b/nationwidechildrens.org_clinical.TCGA-GI-A2C8.xml has no valid age data.
# File ../datasets/clinical_data/1018f55a-a983-4756-9a68-ed3ce0c8e284/nationwidechildrens.org_clinical.TCGA-AC-A7VB.xml has no valid age data.
# File ../datasets/clinical_data/10234dc5-0f34-40fd-9a21-acee9987bb78/nationwidechildrens.org_clinical.TCGA-A2-A0T1.xml has no valid age data.
# File ../datasets/clinical_data/1035134a-5bc0-4cfd-9f15-f2563e451144/nationwidechildrens.org_clinical.TCGA-OL-A5RW.xml has no valid age data.
# File ../datasets/clinical_data/103f2e49-b028-424f-9185-44d008ef1b1b/nationwidechildrens.org_clinical.TCGA-AR-A1AJ.xml has no valid age data.
# File ../datasets/clinical_data/1057d0b1-d929-48f7-997c-65324a4ee9f7/nationwidechildrens.org_clinical.TCGA-E9-A243.xml has no valid age data.
# File ../datasets/clinical_data/10fd353c-239d-4e87-813c-7245cfbeddc2/nationwidechildrens.org_clinical.TCGA-D8-A1JA.xml has no valid age data.
# File ../datasets/clinical_data/1167479b-cd13-4a86-bc1a-319439153270/nationwidechildrens.org_clinical.TCGA-A8-A07G.xml has no valid age data.
# File ../datasets/clinical_data/11aa9e0c-8812-475a-938d-2829d5f3432f/nationwidechildrens.org_clinical.TCGA-E2-A10B.xml has no valid age data.
# File ../datasets/clinical_data/11f5c13a-2193-4c63-8135-5cb0aa3398bc/nationwidechildrens.org_clinical.TCGA-AR-A24U.xml has no valid age data.
# File ../datasets/clinical_data/123e9a10-e02f-4d1b-bf84-c44cc054543e/nationwidechildrens.org_clinical.TCGA-E2-A15K.xml has no valid age data.
# File ../datasets/clinical_data/12b473aa-57f7-4801-8d3b-d486894a8784/nationwidechildrens.org_clinical.TCGA-A7-A4SE.xml has no valid age data.
# File ../datasets/clinical_data/135bfbe6-2402-46ff-8e36-0898dc9e4d70/nationwidechildrens.org_clinical.TCGA-BH-A0DD.xml has no valid age data.
# File ../datasets/clinical_data/137eb1a9-7bdd-401f-8405-82e777e1df17/nationwidechildrens.org_clinical.TCGA-E9-A1N8.xml has no valid age data.
# File ../datasets/clinical_data/13dd3055-8ed0-4d0e-a133-b3ec1078f02d/nationwidechildrens.org_clinical.TCGA-A2-A0CW.xml has no valid age data.
# File ../datasets/clinical_data/13f99438-a228-44f5-aedf-398557abc162/nationwidechildrens.org_clinical.TCGA-A7-A0DC.xml has no valid age data.
# File ../datasets/clinical_data/14327e55-5048-4e9a-b993-a394c5ae5a80/nationwidechildrens.org_clinical.TCGA-A8-A09Q.xml has no valid age data.
# File ../datasets/clinical_data/15325c5a-0270-4fb8-92e4-0b98028bed1b/nationwidechildrens.org_clinical.TCGA-C8-A26V.xml has no valid age data.
# File ../datasets/clinical_data/1543a38e-723c-40fb-8087-0f78d470303d/nationwidechildrens.org_clinical.TCGA-EW-A6S9.xml has no valid age data.
# File ../datasets/clinical_data/1657a582-7b6c-40e7-8746-0dc11993aa39/nationwidechildrens.org_clinical.TCGA-AO-A0JD.xml has no valid age data.
# File ../datasets/clinical_data/174eca80-6a0a-4f82-a87f-d47a117f8b91/nationwidechildrens.org_clinical.TCGA-E2-A15E.xml has no valid age data.
# File ../datasets/clinical_data/17767d08-172b-420f-ba84-dc516e6f5dce/nationwidechildrens.org_clinical.TCGA-A8-A09A.xml has no valid age data.
# File ../datasets/clinical_data/17a19e1b-73d3-4a96-99eb-6534650ac1b8/nationwidechildrens.org_clinical.TCGA-AR-A0TZ.xml has no valid age data.
# File ../datasets/clinical_data/1807532f-fbb2-4434-95f5-d6b1bf5573b2/nationwidechildrens.org_clinical.TCGA-E2-A15S.xml has no valid age data.
# File ../datasets/clinical_data/18e2f8c1-331b-4ec7-8ffc-70f351ff0bf9/nationwidechildrens.org_clinical.TCGA-OL-A5RU.xml has no valid age data.
# File ../datasets/clinical_data/18e558aa-8a10-4387-a12d-56d551b61fc0/nationwidechildrens.org_clinical.TCGA-BH-A0EB.xml has no valid age data.
# File ../datasets/clinical_data/18e5fd45-a1ef-4fca-a883-65be5c5846ae/nationwidechildrens.org_clinical.TCGA-BH-A0HK.xml has no valid age data.
# File ../datasets/clinical_data/19343c65-2500-465e-b8e2-502500693889/nationwidechildrens.org_clinical.TCGA-AQ-A1H3.xml has no valid age data.
# File ../datasets/clinical_data/19ce45e5-0530-41f8-acf2-5246499a3034/nationwidechildrens.org_clinical.TCGA-LL-A5YN.xml has no valid age data.
# File ../datasets/clinical_data/1a543ae8-3f2b-4a5b-82f3-7501b44a3fab/nationwidechildrens.org_clinical.TCGA-E2-A1LB.xml has no valid age data.
# File ../datasets/clinical_data/1ab00e83-3ed9-4c9f-b550-ce660bc3d996/nationwidechildrens.org_clinical.TCGA-B6-A0IJ.xml has no valid age data.
# File ../datasets/clinical_data/1b376b9f-4132-44ca-b9bd-6ef8c1facaab/nationwidechildrens.org_clinical.TCGA-E2-A14Z.xml has no valid age data.
# File ../datasets/clinical_data/1b5bddf8-d393-478a-bab9-ab9ae515f323/nationwidechildrens.org_clinical.TCGA-AO-A0J6.xml has no valid age data.
# File ../datasets/clinical_data/1bb1a57a-c89d-4a2d-b816-90a08bef9133/nationwidechildrens.org_clinical.TCGA-AO-A0JM.xml has no valid age data.
# File ../datasets/clinical_data/1bb749af-4429-454d-9ab6-40db2622b6f6/nationwidechildrens.org_clinical.TCGA-E9-A1QZ.xml has no valid age data.
# File ../datasets/clinical_data/1be07f2a-5c32-48ff-864c-194592954533/nationwidechildrens.org_clinical.TCGA-E2-A1BD.xml has no valid age data.
# File ../datasets/clinical_data/1c6ae7e6-337a-4cb4-b829-c348bca29fca/nationwidechildrens.org_clinical.TCGA-UL-AAZ6.xml has no valid age data.
# File ../datasets/clinical_data/1e12ed31-79a1-404f-a705-2b26bfde86d5/nationwidechildrens.org_clinical.TCGA-E9-A248.xml has no valid age data.
# File ../datasets/clinical_data/1f503e8a-ec3b-4b54-a592-6bf49846dc46/nationwidechildrens.org_clinical.TCGA-AO-A03N.xml has no valid age data.
# File ../datasets/clinical_data/1fc54ff7-d1a9-41fe-882f-99cbdafe2584/nationwidechildrens.org_clinical.TCGA-A8-A099.xml has no valid age data.
# File ../datasets/clinical_data/1fee2a62-5246-41a7-b152-2181487eb6b5/nationwidechildrens.org_clinical.TCGA-AR-A0TQ.xml has no valid age data.
# File ../datasets/clinical_data/201f3cd0-45c1-4a9f-8e39-fc5c9466ad80/nationwidechildrens.org_clinical.TCGA-AO-A12B.xml has no valid age data.
# File ../datasets/clinical_data/2024e5c9-257e-42a8-b365-65fe885de9fe/nationwidechildrens.org_clinical.TCGA-A2-A3XV.xml has no valid age data.
# File ../datasets/clinical_data/2063a07c-e9a2-422c-9773-46a5fd612bf0/nationwidechildrens.org_clinical.TCGA-GM-A2DM.xml has no valid age data.
# File ../datasets/clinical_data/2103fe4e-c511-4f07-a212-8bf24cd3aa95/nationwidechildrens.org_clinical.TCGA-C8-A12N.xml has no valid age data.
# File ../datasets/clinical_data/216c7806-954e-4624-b627-47424a578220/nationwidechildrens.org_clinical.TCGA-C8-A12V.xml has no valid age data.
# File ../datasets/clinical_data/21b2adf9-f20f-4019-80ac-92ab47e02763/nationwidechildrens.org_clinical.TCGA-AO-A03T.xml has no valid age data.
# File ../datasets/clinical_data/21de7b64-f5ff-46d1-bf65-fdc8f62e6b43/nationwidechildrens.org_clinical.TCGA-D8-A1X6.xml has no valid age data.
# File ../datasets/clinical_data/21ed8c1e-72ae-4d6c-a1e6-2304c8f77c37/nationwidechildrens.org_clinical.TCGA-AR-A252.xml has no valid age data.
# File ../datasets/clinical_data/222fe786-6d37-414e-953d-89a63aa8ba42/nationwidechildrens.org_clinical.TCGA-LL-A5YP.xml has no valid age data.
# File ../datasets/clinical_data/2249a1c0-e6af-4550-b890-c27e0b4ae13b/nationwidechildrens.org_clinical.TCGA-A7-A6VV.xml has no valid age data.
# File ../datasets/clinical_data/22d7447e-94b4-4748-bee7-331a5a49bc24/nationwidechildrens.org_clinical.TCGA-E2-A1L7.xml has no valid age data.
# File ../datasets/clinical_data/23462b8f-9187-4c33-af77-9e64e874aecd/nationwidechildrens.org_clinical.TCGA-E2-A14W.xml has no valid age data.
# File ../datasets/clinical_data/23b0cc5f-7b66-413a-8c60-2231a2c75a2b/nationwidechildrens.org_clinical.TCGA-A2-A259.xml has no valid age data.
# File ../datasets/clinical_data/23e1288e-c1e5-4f43-b84b-29b5d34be8d1/nationwidechildrens.org_clinical.TCGA-BH-A0AY.xml has no valid age data.
# File ../datasets/clinical_data/24166110-f793-48b5-9ad5-fd7b33fc65c5/nationwidechildrens.org_clinical.TCGA-E2-A1B1.xml has no valid age data.
# File ../datasets/clinical_data/24cca7f0-3a2b-4e94-84f9-f735be35dcee/nationwidechildrens.org_clinical.TCGA-E2-A10A.xml has no valid age data.
# File ../datasets/clinical_data/2552ab12-e5c6-43c0-abc3-c3a8acc41bd9/nationwidechildrens.org_clinical.TCGA-E9-A1RH.xml has no valid age data.
# File ../datasets/clinical_data/255cf06a-010f-4a7b-8750-9bf6ae381f42/nationwidechildrens.org_clinical.TCGA-AR-A0TW.xml has no valid age data.
# File ../datasets/clinical_data/2574d538-333c-4448-96d7-350bbba51291/nationwidechildrens.org_clinical.TCGA-A2-A0CX.xml has no valid age data.
# File ../datasets/clinical_data/25f19634-8f54-4be7-a0f1-c2756e11fec8/nationwidechildrens.org_clinical.TCGA-A8-A09E.xml has no valid age data.
# File ../datasets/clinical_data/25fa4fd8-d5d7-479b-98b5-b475dc1b12ee/nationwidechildrens.org_clinical.TCGA-AN-A03Y.xml has no valid age data.
# File ../datasets/clinical_data/261cdf1f-cd92-45c7-943a-b4e4064a1fb0/nationwidechildrens.org_clinical.TCGA-E2-A15O.xml has no valid age data.
# File ../datasets/clinical_data/26327303-c2a1-4b52-919c-d04dde40546a/nationwidechildrens.org_clinical.TCGA-GM-A2DK.xml has no valid age data.
# File ../datasets/clinical_data/26a363bc-d900-4ac4-af5d-da7963a964cd/nationwidechildrens.org_clinical.TCGA-E2-A150.xml has no valid age data.
# File ../datasets/clinical_data/26af84dd-84cc-44de-8008-9119e59a0bc8/nationwidechildrens.org_clinical.TCGA-A7-A26J.xml has no valid age data.
# File ../datasets/clinical_data/278440bc-d0e8-4f02-bed6-44cc5c9679dc/nationwidechildrens.org_clinical.TCGA-BH-A0BJ.xml has no valid age data.
# File ../datasets/clinical_data/2787ef64-0e1c-43b4-91ae-b4f27069e8c1/nationwidechildrens.org_clinical.TCGA-D8-A1J9.xml has no valid age data.
# File ../datasets/clinical_data/28d4db85-315d-4a55-887b-48b209aad1fa/nationwidechildrens.org_clinical.TCGA-AN-A0XS.xml has no valid age data.
# File ../datasets/clinical_data/29205dd4-0edb-406b-9657-c39e30272f6a/nationwidechildrens.org_clinical.TCGA-EW-A6SA.xml has no valid age data.
# File ../datasets/clinical_data/2923b4df-3e8c-4030-a812-e516f351428e/nationwidechildrens.org_clinical.TCGA-BH-A0BR.xml has no valid age data.
# File ../datasets/clinical_data/295e8f96-69d9-4f8c-96e2-600ab80389b2/nationwidechildrens.org_clinical.TCGA-AN-A041.xml has no valid age data.
# File ../datasets/clinical_data/2981e2a8-38c6-40b0-b611-bfcc55c3c30a/nationwidechildrens.org_clinical.TCGA-BH-A0GY.xml has no valid age data.
# File ../datasets/clinical_data/2a4f1d95-a0c7-4f92-a2ea-c3b8283cf16d/nationwidechildrens.org_clinical.TCGA-BH-A0EE.xml has no valid age data.
# File ../datasets/clinical_data/2a679442-ab52-411e-8fa0-a100fb8a4913/nationwidechildrens.org_clinical.TCGA-A8-A082.xml has no valid age data.
# File ../datasets/clinical_data/2a89edca-2d57-43ec-9ef2-e65b7525ed78/nationwidechildrens.org_clinical.TCGA-D8-A1JK.xml has no valid age data.
# File ../datasets/clinical_data/2b091208-b35c-4a3d-94ff-d5d01b8fcdcc/nationwidechildrens.org_clinical.TCGA-A8-A08S.xml has no valid age data.
# File ../datasets/clinical_data/2b0e28e5-6571-497e-b258-b53909f6ecd6/nationwidechildrens.org_clinical.TCGA-AN-A0XT.xml has no valid age data.
# File ../datasets/clinical_data/2b5696e1-91d2-43a1-873b-e95be5922e51/nationwidechildrens.org_clinical.TCGA-E2-A1IN.xml has no valid age data.
# File ../datasets/clinical_data/2b7acc61-1cce-451a-9c0c-440525402e7f/nationwidechildrens.org_clinical.TCGA-A2-A4S3.xml has no valid age data.
# File ../datasets/clinical_data/2bae8366-3b01-408c-a8c6-976df43a3a01/nationwidechildrens.org_clinical.TCGA-C8-A12L.xml has no valid age data.
# File ../datasets/clinical_data/2bce3c85-2cef-42d7-9d75-8860062683f3/nationwidechildrens.org_clinical.TCGA-AC-A23H.xml has no valid age data.
# File ../datasets/clinical_data/2c2acb21-606f-4816-a2f7-e69508b4cf99/nationwidechildrens.org_clinical.TCGA-E2-A14P.xml has no valid age data.
# File ../datasets/clinical_data/2c8cfe81-1934-47c9-9fd6-24047b012b18/nationwidechildrens.org_clinical.TCGA-C8-A12Z.xml has no valid age data.
# File ../datasets/clinical_data/2d717aea-1557-4c24-bcf5-858267636016/nationwidechildrens.org_clinical.TCGA-AO-A0JA.xml has no valid age data.
# File ../datasets/clinical_data/2deae878-dfd4-4778-ae31-2e3a9e5975b1/nationwidechildrens.org_clinical.TCGA-AN-A0FS.xml has no valid age data.
# File ../datasets/clinical_data/2e31bdcd-c11a-4f47-b426-6fc0fded867d/nationwidechildrens.org_clinical.TCGA-A2-A0T3.xml has no valid age data.
# File ../datasets/clinical_data/2e7768b6-6862-4d65-bb12-cfa012c875d9/nationwidechildrens.org_clinical.TCGA-A8-A08H.xml has no valid age data.
# File ../datasets/clinical_data/2e8350e1-ff7c-4395-8a97-2aa05220dd40/nationwidechildrens.org_clinical.TCGA-A2-A04N.xml has no valid age data.
# File ../datasets/clinical_data/2eb84b27-d505-417d-9e05-f82f2e4c023e/nationwidechildrens.org_clinical.TCGA-E9-A1R3.xml has no valid age data.
# File ../datasets/clinical_data/2eeaea21-537d-4058-8770-905ecdb03e99/nationwidechildrens.org_clinical.TCGA-BH-A0GZ.xml has no valid age data.
# File ../datasets/clinical_data/2f49fea2-3c8c-4690-a561-d5001a86c215/nationwidechildrens.org_clinical.TCGA-A8-A08P.xml has no valid age data.
# File ../datasets/clinical_data/2f7ed67d-7c4c-4990-84c4-982cd5e885ab/nationwidechildrens.org_clinical.TCGA-E2-A15A.xml has no valid age data.
# File ../datasets/clinical_data/30715284-b1ae-4f23-a690-9cab2acf9392/nationwidechildrens.org_clinical.TCGA-A8-A09B.xml has no valid age data.
# File ../datasets/clinical_data/30758df6-d164-44de-91ab-6077ca9ac04a/nationwidechildrens.org_clinical.TCGA-S3-A6ZH.xml has no valid age data.
# File ../datasets/clinical_data/30adafa4-a3eb-4523-92db-63c76b05515a/nationwidechildrens.org_clinical.TCGA-A2-A0YF.xml has no valid age data.
# File ../datasets/clinical_data/30add949-c832-4a65-ba9a-5aba8e313bf8/nationwidechildrens.org_clinical.TCGA-A2-A1FW.xml has no valid age data.
# File ../datasets/clinical_data/30bec064-c879-4d2e-bf57-76efb44d0f22/nationwidechildrens.org_clinical.TCGA-BH-A0E2.xml has no valid age data.
# File ../datasets/clinical_data/30fddf77-25ca-4cbf-88fe-19a6820c4cc3/nationwidechildrens.org_clinical.TCGA-E9-A1ND.xml has no valid age data.
# File ../datasets/clinical_data/312e02be-fb7d-4e6b-88a1-1b656d211f66/nationwidechildrens.org_clinical.TCGA-S3-AA10.xml has no valid age data.
# File ../datasets/clinical_data/3132651d-c2d6-44ad-9234-939d98f356b9/nationwidechildrens.org_clinical.TCGA-B6-A0RH.xml has no valid age data.
# File ../datasets/clinical_data/3181a3ef-3317-4b47-916b-c1527d2e3309/nationwidechildrens.org_clinical.TCGA-E2-A15P.xml has no valid age data.
# File ../datasets/clinical_data/31dd83d7-2399-47d9-ada2-375117da8a6b/nationwidechildrens.org_clinical.TCGA-3C-AALK.xml has no valid age data.
# File ../datasets/clinical_data/321ee2c3-5873-4cd2-b1be-24a9dcc5236c/nationwidechildrens.org_clinical.TCGA-E9-A244.xml has no valid age data.
# File ../datasets/clinical_data/325367f7-1345-4882-86b2-81cde2a8faaa/nationwidechildrens.org_clinical.TCGA-AO-A03L.xml has no valid age data.
# File ../datasets/clinical_data/328d5901-cd30-446f-9a0f-12ffc01be16a/nationwidechildrens.org_clinical.TCGA-OL-A5S0.xml has no valid age data.
# File ../datasets/clinical_data/32ce3a7e-608c-4897-8e64-bdba9ca3a0ca/nationwidechildrens.org_clinical.TCGA-E2-A570.xml has no valid age data.
# File ../datasets/clinical_data/33a76cf6-c60c-487d-af52-aa9a9d7b3e6d/nationwidechildrens.org_clinical.TCGA-LL-A6FQ.xml has no valid age data.
# File ../datasets/clinical_data/33c20398-3b78-4629-b413-2f07ec00ec87/nationwidechildrens.org_clinical.TCGA-GM-A2DI.xml has no valid age data.
# File ../datasets/clinical_data/33c36a80-c4af-47b7-a0bb-29ba0e4bd658/nationwidechildrens.org_clinical.TCGA-A7-A0DB.xml has no valid age data.
# File ../datasets/clinical_data/340e54a9-3108-4aac-a02f-8ca81a077323/nationwidechildrens.org_clinical.TCGA-BH-A0BM.xml has no valid age data.
# File ../datasets/clinical_data/34439f4d-1606-41c3-8b83-bed8591eb0f8/nationwidechildrens.org_clinical.TCGA-A8-A081.xml has no valid age data.
# File ../datasets/clinical_data/352b33ed-7387-452d-b7cd-8afd94d1143c/nationwidechildrens.org_clinical.TCGA-D8-A1XF.xml has no valid age data.
# File ../datasets/clinical_data/356d559c-1731-47b3-84b3-0afaa4a84bed/nationwidechildrens.org_clinical.TCGA-E9-A229.xml has no valid age data.
# File ../datasets/clinical_data/35aae95f-b4ef-46ae-a64b-fd981eceeaca/nationwidechildrens.org_clinical.TCGA-OL-A5RY.xml has no valid age data.
# File ../datasets/clinical_data/35e8376c-3b55-446d-9b71-1544b8a87fd0/nationwidechildrens.org_clinical.TCGA-E9-A1R7.xml has no valid age data.
# File ../datasets/clinical_data/35ea5b80-5ac8-49f9-98ff-5b374d526502/nationwidechildrens.org_clinical.TCGA-C8-A27B.xml has no valid age data.
# File ../datasets/clinical_data/36717ad9-8d06-4b94-a7cb-bb0b309ac5c2/nationwidechildrens.org_clinical.TCGA-E2-A109.xml has no valid age data.
# File ../datasets/clinical_data/36eef565-06b0-4e7f-a21d-e661717a2c49/nationwidechildrens.org_clinical.TCGA-EW-A3U0.xml has no valid age data.
# File ../datasets/clinical_data/37298993-7dbf-45a8-ac37-70ea93f89c06/nationwidechildrens.org_clinical.TCGA-A8-A083.xml has no valid age data.
# File ../datasets/clinical_data/37798dd5-d083-4ef7-840f-5d9ed52dc460/nationwidechildrens.org_clinical.TCGA-E2-A14O.xml has no valid age data.
# File ../datasets/clinical_data/37939018-84b0-44ee-bf9f-cfdecd94370d/nationwidechildrens.org_clinical.TCGA-BH-A0B0.xml has no valid age data.
# File ../datasets/clinical_data/37eaa1e3-1649-4697-8186-e1ec1ecc8e48/nationwidechildrens.org_clinical.TCGA-C8-A26X.xml has no valid age data.
# File ../datasets/clinical_data/3838998d-819c-4118-b7d8-5344281ac5fd/nationwidechildrens.org_clinical.TCGA-D8-A27P.xml has no valid age data.
# File ../datasets/clinical_data/38731109-4cd4-4c7b-aa6c-7c8fcc5b719a/nationwidechildrens.org_clinical.TCGA-OL-A5RZ.xml has no valid age data.
# File ../datasets/clinical_data/38762fd0-66b8-41a6-91f8-2cec2e2fff1c/nationwidechildrens.org_clinical.TCGA-EW-A1OV.xml has no valid age data.
# File ../datasets/clinical_data/38cb84d9-9515-4557-aa5c-e5f28a3708f2/nationwidechildrens.org_clinical.TCGA-AR-A1AO.xml has no valid age data.
# File ../datasets/clinical_data/38d0617f-375a-4ac8-901c-bfb99a047f0a/nationwidechildrens.org_clinical.TCGA-AN-A04C.xml has no valid age data.
# File ../datasets/clinical_data/38ddf8ea-7bad-4893-922b-b086331261fa/nationwidechildrens.org_clinical.TCGA-A2-A25E.xml has no valid age data.
# File ../datasets/clinical_data/38fa4361-0c3c-4a20-bea0-9e01047b7622/nationwidechildrens.org_clinical.TCGA-A2-A1G6.xml has no valid age data.
# File ../datasets/clinical_data/3a000d1a-fb70-4946-925b-e3db436fbace/nationwidechildrens.org_clinical.TCGA-BH-A0HO.xml has no valid age data.
# File ../datasets/clinical_data/3aea3241-d321-4abf-b328-c11b6c7c37da/nationwidechildrens.org_clinical.TCGA-E2-A1IG.xml has no valid age data.
# File ../datasets/clinical_data/3af873f5-15e1-4605-b295-a5d29fc46835/nationwidechildrens.org_clinical.TCGA-BH-A0B6.xml has no valid age data.
# File ../datasets/clinical_data/3b8ece2c-645e-4f1c-b7fd-5e957275e158/nationwidechildrens.org_clinical.TCGA-AN-A0FT.xml has no valid age data.
# File ../datasets/clinical_data/3c4be53a-e2a9-4afd-9910-c45e539ca0be/nationwidechildrens.org_clinical.TCGA-EW-A6SB.xml has no valid age data.
# File ../datasets/clinical_data/3ca09685-0c0e-494a-bde0-661efae20be8/nationwidechildrens.org_clinical.TCGA-BH-A0EI.xml has no valid age data.
# File ../datasets/clinical_data/3d57c6be-c217-4d2f-891a-e6ef79bfe57e/nationwidechildrens.org_clinical.TCGA-C8-A1HN.xml has no valid age data.
# File ../datasets/clinical_data/3d72e23a-15a1-4572-b68a-f8bf15f25cf1/nationwidechildrens.org_clinical.TCGA-GM-A2DA.xml has no valid age data.
# File ../datasets/clinical_data/3e4a5d1e-8a8e-43c0-8149-0085c6246ab0/nationwidechildrens.org_clinical.TCGA-EW-A1PH.xml has no valid age data.
# File ../datasets/clinical_data/3e74a086-e477-4b5c-8a06-f1e4634d27c2/nationwidechildrens.org_clinical.TCGA-EW-A1OY.xml has no valid age data.
# File ../datasets/clinical_data/3f197a51-8e41-4e86-a372-ea24e382308a/nationwidechildrens.org_clinical.TCGA-AO-A03M.xml has no valid age data.
# File ../datasets/clinical_data/3f96710c-8e2d-422c-99fa-1a49106ed58b/nationwidechildrens.org_clinical.TCGA-PL-A8LZ.xml has no valid age data.
# File ../datasets/clinical_data/3fd204bf-0d36-463c-935e-7fd9630948ef/nationwidechildrens.org_clinical.TCGA-A7-A0CD.xml has no valid age data.
# File ../datasets/clinical_data/3ff0d2da-e6c8-434d-9a96-ba3d69dbdd8e/nationwidechildrens.org_clinical.TCGA-EW-A1P5.xml has no valid age data.
# File ../datasets/clinical_data/3ff6cbdf-b639-48fe-8143-21b10764fcc9/nationwidechildrens.org_clinical.TCGA-E2-A1IO.xml has no valid age data.
# File ../datasets/clinical_data/407d26c0-0eb0-4bcf-9f30-a2acb9d33086/nationwidechildrens.org_clinical.TCGA-A8-A08A.xml has no valid age data.
# File ../datasets/clinical_data/40db542b-6d6c-4b6b-a5cf-05a2c554d38e/nationwidechildrens.org_clinical.TCGA-GI-A2C9.xml has no valid age data.
# File ../datasets/clinical_data/410a715e-25a6-454a-afa1-209cd379a8e1/nationwidechildrens.org_clinical.TCGA-D8-A27M.xml has no valid age data.
# File ../datasets/clinical_data/41511c04-44e3-4971-8e47-c758cec3decd/nationwidechildrens.org_clinical.TCGA-E9-A1RF.xml has no valid age data.
# File ../datasets/clinical_data/416ae1cf-13ed-4bca-ac5d-23255cf97221/nationwidechildrens.org_clinical.TCGA-E9-A1RB.xml has no valid age data.
# File ../datasets/clinical_data/41cacc55-b375-4b76-8b42-ba7fefb32f40/nationwidechildrens.org_clinical.TCGA-A8-A096.xml has no valid age data.
# File ../datasets/clinical_data/421c1a06-f3ef-474c-9128-370e90c7f9e8/nationwidechildrens.org_clinical.TCGA-D8-A1JG.xml has no valid age data.
# File ../datasets/clinical_data/425014ce-d400-4086-9687-c91c5f1a05bc/nationwidechildrens.org_clinical.TCGA-BH-A0DO.xml has no valid age data.
# File ../datasets/clinical_data/4276595f-a61b-42c2-aa54-cf33676d0d24/nationwidechildrens.org_clinical.TCGA-AQ-A54O.xml has no valid age data.
# File ../datasets/clinical_data/4322a353-38f9-4c0c-a7a2-930d80278c57/nationwidechildrens.org_clinical.TCGA-A1-A0SQ.xml has no valid age data.
# File ../datasets/clinical_data/44f81e9b-0b50-44e0-a1e3-0627f71ab877/nationwidechildrens.org_clinical.TCGA-C8-A132.xml has no valid age data.
# File ../datasets/clinical_data/45227d46-76f6-4f1d-ac82-a5d7fecce822/nationwidechildrens.org_clinical.TCGA-EW-A2FR.xml has no valid age data.
# File ../datasets/clinical_data/45373b3a-421c-4325-9a5d-9fbc36369c3f/nationwidechildrens.org_clinical.TCGA-AR-A0U4.xml has no valid age data.
# File ../datasets/clinical_data/45b598f8-887e-43e9-bbdc-3ddc02f89d3f/nationwidechildrens.org_clinical.TCGA-A2-A0D3.xml has no valid age data.
# File ../datasets/clinical_data/46238b12-60fd-4e33-98b0-bd23c6c83962/nationwidechildrens.org_clinical.TCGA-E9-A1N6.xml has no valid age data.
# File ../datasets/clinical_data/46573cac-dd56-4c49-97e6-edec5f1144c8/nationwidechildrens.org_clinical.TCGA-BH-A0DZ.xml has no valid age data.
# File ../datasets/clinical_data/4697c0de-da15-4daa-8b39-c2f4a1fd7be9/nationwidechildrens.org_clinical.TCGA-A2-A0YE.xml has no valid age data.
# File ../datasets/clinical_data/46c1fb19-05c4-4543-a309-153d471cbd0b/nationwidechildrens.org_clinical.TCGA-LL-A740.xml has no valid age data.
# File ../datasets/clinical_data/47441cb1-d47c-453d-9c9f-f8cbcbdba399/nationwidechildrens.org_clinical.TCGA-A8-A07W.xml has no valid age data.
# File ../datasets/clinical_data/474da3bc-a7b2-4b88-9402-6169ded29117/nationwidechildrens.org_clinical.TCGA-GM-A2DH.xml has no valid age data.
# File ../datasets/clinical_data/47a5ceb3-2163-461c-a9c1-7cf6dd6bced1/nationwidechildrens.org_clinical.TCGA-C8-A12Q.xml has no valid age data.
# File ../datasets/clinical_data/4803d618-4362-4b22-9a5a-7ec35d7660a3/nationwidechildrens.org_clinical.TCGA-A8-A06T.xml has no valid age data.
# File ../datasets/clinical_data/488577fa-6baa-4c11-94d1-76dffd7c5bbf/nationwidechildrens.org_clinical.TCGA-BH-A0DS.xml has no valid age data.
# File ../datasets/clinical_data/48da1f05-062b-4f2d-9936-5064d9a1a9f3/nationwidechildrens.org_clinical.TCGA-AR-A0U1.xml has no valid age data.
# File ../datasets/clinical_data/492170e4-90b8-4560-89ff-effa9eeb5194/nationwidechildrens.org_clinical.TCGA-B6-A0X1.xml has no valid age data.
# File ../datasets/clinical_data/498ac741-b4be-4544-9ba2-a068b9b334bd/nationwidechildrens.org_clinical.TCGA-A1-A0SH.xml has no valid age data.
# File ../datasets/clinical_data/49a0b7f9-bbc8-408d-b507-2a1a2928cee3/nationwidechildrens.org_clinical.TCGA-BH-A0H9.xml has no valid age data.
# File ../datasets/clinical_data/49f86f21-3f57-4669-8b2f-e409491ad33f/nationwidechildrens.org_clinical.TCGA-E2-A1AZ.xml has no valid age data.
# File ../datasets/clinical_data/4ba7265a-28de-46fe-961e-4d9bbffed86e/nationwidechildrens.org_clinical.TCGA-AO-A1KT.xml has no valid age data.
# File ../datasets/clinical_data/4bded89b-7234-47e0-abe9-ad10dfeff4f8/nationwidechildrens.org_clinical.TCGA-AN-A0FJ.xml has no valid age data.
# File ../datasets/clinical_data/4bf1399d-35c3-4336-990f-2ebe105b761c/nationwidechildrens.org_clinical.TCGA-BH-A0H6.xml has no valid age data.
# File ../datasets/clinical_data/4c1ff644-3c62-47c3-a3d8-f9fa4a256bda/nationwidechildrens.org_clinical.TCGA-D8-A1JL.xml has no valid age data.
# File ../datasets/clinical_data/4cb4f2d3-d48a-4843-8eb5-ee704ebfb13a/nationwidechildrens.org_clinical.TCGA-A2-A3XW.xml has no valid age data.
# File ../datasets/clinical_data/4d016077-a880-49d6-8d2a-575a8c93bec5/nationwidechildrens.org_clinical.TCGA-E9-A1R4.xml has no valid age data.
# File ../datasets/clinical_data/4d18da98-1a9b-46b5-89d6-55343189883f/nationwidechildrens.org_clinical.TCGA-BH-A0HB.xml has no valid age data.
# File ../datasets/clinical_data/4ea54a5f-ef76-4c3f-a052-c7c024648c43/nationwidechildrens.org_clinical.TCGA-A8-A08R.xml has no valid age data.
# File ../datasets/clinical_data/4ef9e392-0340-487f-9a2e-079a84b267fe/nationwidechildrens.org_clinical.TCGA-A7-A5ZW.xml has no valid age data.
# File ../datasets/clinical_data/4f1bd9c8-1b7c-4853-9e38-bad0ed395411/nationwidechildrens.org_clinical.TCGA-AR-A0U0.xml has no valid age data.
# File ../datasets/clinical_data/4f4b77cb-484c-4b57-a89f-6473eff9966e/nationwidechildrens.org_clinical.TCGA-C8-A130.xml has no valid age data.
# File ../datasets/clinical_data/4f808abe-7d71-4741-af41-69a3f7981788/nationwidechildrens.org_clinical.TCGA-E2-A1LH.xml has no valid age data.
# File ../datasets/clinical_data/4faa0a53-4f1b-4c2c-b6ba-af1e426f9d33/nationwidechildrens.org_clinical.TCGA-AR-A1AY.xml has no valid age data.
# File ../datasets/clinical_data/5038627b-4066-4919-8a89-8bc55143596c/nationwidechildrens.org_clinical.TCGA-E9-A22H.xml has no valid age data.
# File ../datasets/clinical_data/50684ea7-f34a-459f-a4d3-ac09d88608d9/nationwidechildrens.org_clinical.TCGA-EW-A1J1.xml has no valid age data.
# File ../datasets/clinical_data/507bdb32-c74c-4f90-9ce4-031b763c0fd9/nationwidechildrens.org_clinical.TCGA-LL-A7T0.xml has no valid age data.
# File ../datasets/clinical_data/50842d60-e03f-4490-b3d5-4b01d2537328/nationwidechildrens.org_clinical.TCGA-B6-A0IO.xml has no valid age data.
# File ../datasets/clinical_data/515eeb64-1c95-4e81-af64-47f75fa1a70d/nationwidechildrens.org_clinical.TCGA-E2-A1IF.xml has no valid age data.
# File ../datasets/clinical_data/51ac596c-6215-4afa-a1a8-bc56f7bda665/nationwidechildrens.org_clinical.TCGA-A8-A06Y.xml has no valid age data.
# File ../datasets/clinical_data/51d8681a-f953-4237-a22c-04dfba9a83a4/nationwidechildrens.org_clinical.TCGA-A2-A0D4.xml has no valid age data.
# File ../datasets/clinical_data/51e0e5c5-b139-4a87-99a9-7b0058533b91/nationwidechildrens.org_clinical.TCGA-OL-A5D6.xml has no valid age data.
# File ../datasets/clinical_data/521fd53d-d517-4147-90ef-86c487b1be4b/nationwidechildrens.org_clinical.TCGA-EW-A1OZ.xml has no valid age data.
# File ../datasets/clinical_data/522aaf8f-ff00-4d42-ab64-3686e9df9301/nationwidechildrens.org_clinical.TCGA-AC-A62X.xml has no valid age data.
# File ../datasets/clinical_data/53869135-6e62-4f95-8e5e-143485f62ed9/nationwidechildrens.org_clinical.TCGA-E2-A156.xml has no valid age data.
# File ../datasets/clinical_data/539dbf37-39f2-4340-bc1a-c34dcc43bbe0/nationwidechildrens.org_clinical.TCGA-E9-A1R6.xml has no valid age data.
# File ../datasets/clinical_data/541a56c1-3649-45f8-bb2f-30c0be00ec40/nationwidechildrens.org_clinical.TCGA-EW-A1J6.xml has no valid age data.
# File ../datasets/clinical_data/541e990a-bfc8-4007-b69a-79e786eff209/nationwidechildrens.org_clinical.TCGA-E9-A1RA.xml has no valid age data.
# File ../datasets/clinical_data/542f469a-b5d0-4fbd-89b0-758d7dd59a23/nationwidechildrens.org_clinical.TCGA-AR-A24S.xml has no valid age data.
# File ../datasets/clinical_data/544a1685-6650-4387-9a04-4267ca56a239/nationwidechildrens.org_clinical.TCGA-AN-A0FD.xml has no valid age data.
# File ../datasets/clinical_data/54a1e746-6d51-4f84-9fab-578b39cb8619/nationwidechildrens.org_clinical.TCGA-EW-A1PA.xml has no valid age data.
# File ../datasets/clinical_data/54b37de1-1dce-462d-9049-31cf5a9ed1da/nationwidechildrens.org_clinical.TCGA-C8-A135.xml has no valid age data.
# File ../datasets/clinical_data/565fb3de-406c-49b0-8194-2dd129dd5876/nationwidechildrens.org_clinical.TCGA-BH-A202.xml has no valid age data.
# File ../datasets/clinical_data/56d2480c-5d33-486a-9bc2-8c614d8b7249/nationwidechildrens.org_clinical.TCGA-AO-A126.xml has no valid age data.
# File ../datasets/clinical_data/570355ca-64c7-4d9f-9669-5798b0080704/nationwidechildrens.org_clinical.TCGA-AR-A0TU.xml has no valid age data.
# File ../datasets/clinical_data/57413762-35bf-44b5-8876-3f7dc3c20987/nationwidechildrens.org_clinical.TCGA-AO-A0J4.xml has no valid age data.
# File ../datasets/clinical_data/57f570ac-1320-480e-a7b0-fffd2e882513/nationwidechildrens.org_clinical.TCGA-A2-A0SX.xml has no valid age data.
# File ../datasets/clinical_data/5805402b-636e-458e-adfd-862c1f49b801/nationwidechildrens.org_clinical.TCGA-BH-A0AU.xml has no valid age data.
# File ../datasets/clinical_data/58b8a73e-3975-43ec-995a-e8a3d72f3930/nationwidechildrens.org_clinical.TCGA-A7-A13F.xml has no valid age data.
# File ../datasets/clinical_data/5931c6c2-65ed-4976-a0b7-33c07aee5fad/nationwidechildrens.org_clinical.TCGA-A2-A04R.xml has no valid age data.
# File ../datasets/clinical_data/5a251a59-c085-4711-98bb-97b0bb36b7db/nationwidechildrens.org_clinical.TCGA-AO-A0J2.xml has no valid age data.
# File ../datasets/clinical_data/5a35c8af-8de9-4ae4-b2d3-5672352babf8/nationwidechildrens.org_clinical.TCGA-AO-A0JE.xml has no valid age data.
# File ../datasets/clinical_data/5a8a653a-7555-4ac9-a907-28f7f7286a1b/nationwidechildrens.org_clinical.TCGA-BH-A0E1.xml has no valid age data.
# File ../datasets/clinical_data/5aaad587-f550-45b6-a348-d89e70f6a3f6/nationwidechildrens.org_clinical.TCGA-C8-A12U.xml has no valid age data.
# File ../datasets/clinical_data/5c877a6e-5f2b-40fb-8947-c81c8373b7da/nationwidechildrens.org_clinical.TCGA-E2-A15D.xml has no valid age data.
# File ../datasets/clinical_data/5d06d7d1-e301-44ae-aa54-2b91d46f5101/nationwidechildrens.org_clinical.TCGA-E2-A1B4.xml has no valid age data.
# File ../datasets/clinical_data/5de507f2-c47a-4d66-b796-431547477f7f/nationwidechildrens.org_clinical.TCGA-A2-A0T0.xml has no valid age data.
# File ../datasets/clinical_data/5f7626c2-8158-4bcf-8d20-b27a72b3c857/nationwidechildrens.org_clinical.TCGA-AO-A12F.xml has no valid age data.
# File ../datasets/clinical_data/5f96bd5e-ab83-48b3-abac-adf87f978c20/nationwidechildrens.org_clinical.TCGA-GM-A2DN.xml has no valid age data.
# File ../datasets/clinical_data/5fa58d19-6f11-4e5b-85d5-21c5c25c8ed0/nationwidechildrens.org_clinical.TCGA-BH-A0E7.xml has no valid age data.
# File ../datasets/clinical_data/5fffe364-2fe8-421a-92aa-a14f9b2d4cad/nationwidechildrens.org_clinical.TCGA-E9-A1RG.xml has no valid age data.
# File ../datasets/clinical_data/60eb3b00-6911-4983-b51e-b5bfc99372a0/nationwidechildrens.org_clinical.TCGA-D8-A1XQ.xml has no valid age data.
# File ../datasets/clinical_data/61b2f83b-db6a-43a1-a85e-c285eb54e958/nationwidechildrens.org_clinical.TCGA-E9-A249.xml has no valid age data.
# File ../datasets/clinical_data/628b9155-834a-4a30-964a-d424a01f07b2/nationwidechildrens.org_clinical.TCGA-D8-A146.xml has no valid age data.
# File ../datasets/clinical_data/62bf0c2d-4a3c-4592-b5cc-0da1dada0a8e/nationwidechildrens.org_clinical.TCGA-D8-A1XL.xml has no valid age data.
# File ../datasets/clinical_data/62df99b7-c37b-4961-b8f2-a24691bffb2c/nationwidechildrens.org_clinical.TCGA-A2-A3XY.xml has no valid age data.
# File ../datasets/clinical_data/62ea25cb-0652-4064-9757-ab5d0a018423/nationwidechildrens.org_clinical.TCGA-E2-A10E.xml has no valid age data.
# File ../datasets/clinical_data/63a2aadf-5998-4886-a7b9-a9ca188ab6f7/nationwidechildrens.org_clinical.TCGA-B6-A400.xml has no valid age data.
# File ../datasets/clinical_data/63c5e345-11a4-4e05-8535-64126b6008ea/nationwidechildrens.org_clinical.TCGA-AN-A04A.xml has no valid age data.
# File ../datasets/clinical_data/63e03017-0ea7-4a4d-85ee-32df750e68a8/nationwidechildrens.org_clinical.TCGA-A7-A0D9.xml has no valid age data.
# File ../datasets/clinical_data/64608382-6e86-4ebb-a949-db48e45eea1d/nationwidechildrens.org_clinical.TCGA-BH-A0BP.xml has no valid age data.
# File ../datasets/clinical_data/64d43d63-2e81-401a-865c-6888c1b26717/nationwidechildrens.org_clinical.TCGA-EW-A1P3.xml has no valid age data.
# File ../datasets/clinical_data/6626f827-bd6d-4a58-9355-f17e970f1b47/nationwidechildrens.org_clinical.TCGA-BH-A0HU.xml has no valid age data.
# File ../datasets/clinical_data/662cc493-43de-4370-98a3-5b90dd34bea2/nationwidechildrens.org_clinical.TCGA-E2-A14S.xml has no valid age data.
# File ../datasets/clinical_data/6685a944-5ceb-4a3c-9680-67ac0e0b40d3/nationwidechildrens.org_clinical.TCGA-BH-A0RX.xml has no valid age data.
# File ../datasets/clinical_data/66b600cb-d793-4710-bfac-da0460d12646/nationwidechildrens.org_clinical.TCGA-A2-A3XZ.xml has no valid age data.
# File ../datasets/clinical_data/682a8b51-a8f5-463b-86ea-3b8bfdc26d66/nationwidechildrens.org_clinical.TCGA-A1-A0SD.xml has no valid age data.
# File ../datasets/clinical_data/682b531b-3477-4740-8c6b-7891f2781b38/nationwidechildrens.org_clinical.TCGA-A7-A6VX.xml has no valid age data.
# File ../datasets/clinical_data/686ff9cf-857a-4570-95a6-994425925815/nationwidechildrens.org_clinical.TCGA-OL-A66L.xml has no valid age data.
# File ../datasets/clinical_data/68901263-c6bd-4805-a332-5e284e549753/nationwidechildrens.org_clinical.TCGA-PL-A8LY.xml has no valid age data.
# File ../datasets/clinical_data/68a0e39b-a0cf-4c77-889a-16595275f775/nationwidechildrens.org_clinical.TCGA-A2-A0EQ.xml has no valid age data.
# File ../datasets/clinical_data/69568fb0-3db1-4d63-951e-1bb2a4dc348f/nationwidechildrens.org_clinical.TCGA-BH-A0BC.xml has no valid age data.
# File ../datasets/clinical_data/698d899c-6580-4fde-b2c9-aeb75f2bce0d/nationwidechildrens.org_clinical.TCGA-BH-A0B3.xml has no valid age data.
# File ../datasets/clinical_data/69f707ae-8f14-4f25-8082-6ba85c42909d/nationwidechildrens.org_clinical.TCGA-BH-A0B7.xml has no valid age data.
# File ../datasets/clinical_data/6a0ff69b-242b-4979-9d9b-684f0bc619da/nationwidechildrens.org_clinical.TCGA-BH-A0H5.xml has no valid age data.
# File ../datasets/clinical_data/6a4fcf5a-8667-48ed-a0cd-ef88caa1ba16/nationwidechildrens.org_clinical.TCGA-E2-A1IU.xml has no valid age data.
# File ../datasets/clinical_data/6a9789ac-087c-432e-a908-8123121f9ac4/nationwidechildrens.org_clinical.TCGA-E2-A1B0.xml has no valid age data.
# File ../datasets/clinical_data/6ae5ff45-d127-47ec-9af5-6ac59b61291d/nationwidechildrens.org_clinical.TCGA-C8-A278.xml has no valid age data.
# File ../datasets/clinical_data/6b53c8c1-76a6-465c-8e41-bcd53d1ce4e5/nationwidechildrens.org_clinical.TCGA-A1-A0SI.xml has no valid age data.
# File ../datasets/clinical_data/6b6a57d5-6a89-4c79-932c-bc2ecb213f13/nationwidechildrens.org_clinical.TCGA-D8-A1JP.xml has no valid age data.
# File ../datasets/clinical_data/6bd64a9d-c991-48ba-8db6-ff767da5ca06/nationwidechildrens.org_clinical.TCGA-A7-A0DA.xml has no valid age data.
# File ../datasets/clinical_data/6c1b7d57-2120-49a0-93c2-547ed126693c/nationwidechildrens.org_clinical.TCGA-A8-A09D.xml has no valid age data.
# File ../datasets/clinical_data/6d71fdfa-271c-43e9-87ee-045d4292551f/nationwidechildrens.org_clinical.TCGA-D8-A1JB.xml has no valid age data.
# File ../datasets/clinical_data/6f59f93c-0f6a-4286-8faa-bf1a2d1beb94/nationwidechildrens.org_clinical.TCGA-D8-A1XK.xml has no valid age data.
# File ../datasets/clinical_data/6f6d3b6b-c58b-4b15-b36a-1f563382cfe1/nationwidechildrens.org_clinical.TCGA-A8-A090.xml has no valid age data.
# File ../datasets/clinical_data/6f7694b5-b90b-47e9-9ea5-0d0e2d7ce4a3/nationwidechildrens.org_clinical.TCGA-AO-A03V.xml has no valid age data.
# File ../datasets/clinical_data/70345789-d8e7-47bd-93cc-4abdabf52aa7/nationwidechildrens.org_clinical.TCGA-E2-A159.xml has no valid age data.
# File ../datasets/clinical_data/7098f789-c3c1-496b-a403-9bd26c0c6c35/nationwidechildrens.org_clinical.TCGA-A8-A075.xml has no valid age data.
# File ../datasets/clinical_data/70a37999-db90-411e-83dc-244ebd1d2f73/nationwidechildrens.org_clinical.TCGA-BH-A0DE.xml has no valid age data.
# File ../datasets/clinical_data/70e00e7a-2c5b-4ab8-8b75-076fbc6904c2/nationwidechildrens.org_clinical.TCGA-BH-A0C0.xml has no valid age data.
# File ../datasets/clinical_data/716f66e9-ca43-4b17-84c6-4e4d2933b819/nationwidechildrens.org_clinical.TCGA-A7-A0CJ.xml has no valid age data.
# File ../datasets/clinical_data/71b82ad6-557e-4027-b634-f056dd0e2700/nationwidechildrens.org_clinical.TCGA-BH-A0B4.xml has no valid age data.
# File ../datasets/clinical_data/71ed5720-d54d-43bf-a0e3-6ef57beef1e2/nationwidechildrens.org_clinical.TCGA-EW-A1PD.xml has no valid age data.
# File ../datasets/clinical_data/71fcd84b-bc91-40e0-a234-12eddeee6f48/nationwidechildrens.org_clinical.TCGA-BH-A0DK.xml has no valid age data.
# File ../datasets/clinical_data/72b19dfe-18e2-4df3-af99-81205e2083be/nationwidechildrens.org_clinical.TCGA-E2-A105.xml has no valid age data.
# File ../datasets/clinical_data/72c9aed3-6256-406d-bae3-3c32c35ba8db/nationwidechildrens.org_clinical.TCGA-B6-A0RO.xml has no valid age data.
# File ../datasets/clinical_data/73557aea-87e7-4a1f-aac1-819069358a9b/nationwidechildrens.org_clinical.TCGA-AN-A0FV.xml has no valid age data.
# File ../datasets/clinical_data/73837d91-328e-479e-b31d-975de55b9108/nationwidechildrens.org_clinical.TCGA-AN-A0AM.xml has no valid age data.
# File ../datasets/clinical_data/73edaa1c-f077-4b71-9e17-8cd0b97763c4/nationwidechildrens.org_clinical.TCGA-E2-A154.xml has no valid age data.
# File ../datasets/clinical_data/7408bccd-d164-4e74-b8a9-b58f25761592/nationwidechildrens.org_clinical.TCGA-BH-A0C7.xml has no valid age data.
# File ../datasets/clinical_data/745674b2-3aaa-433b-a76a-7220a8eb7e46/nationwidechildrens.org_clinical.TCGA-EW-A1P1.xml has no valid age data.
# File ../datasets/clinical_data/745797ca-0a41-4022-a24c-c132501ac41b/nationwidechildrens.org_clinical.TCGA-AR-A24W.xml has no valid age data.
# File ../datasets/clinical_data/7498e5d1-b78b-40eb-ae51-420f4f94e50f/nationwidechildrens.org_clinical.TCGA-BH-A0BG.xml has no valid age data.
# File ../datasets/clinical_data/74b71434-062c-43bb-aed8-857088d7c5f2/nationwidechildrens.org_clinical.TCGA-AO-A0JF.xml has no valid age data.
# File ../datasets/clinical_data/75a6b043-391a-4252-8f2e-023d08f56bdf/nationwidechildrens.org_clinical.TCGA-AC-A2BM.xml has no valid age data.
# File ../datasets/clinical_data/760b0a73-db22-45ef-9443-c9b9d33f42ec/nationwidechildrens.org_clinical.TCGA-BH-A5IZ.xml has no valid age data.
# File ../datasets/clinical_data/7618fafa-1164-40cb-b464-6ac90ad35c60/nationwidechildrens.org_clinical.TCGA-E2-A15J.xml has no valid age data.
# File ../datasets/clinical_data/766f0098-3a5c-40e2-83d2-3c02d06b95b4/nationwidechildrens.org_clinical.TCGA-E2-A1IK.xml has no valid age data.
# File ../datasets/clinical_data/7687181d-8ab3-49e7-8b3c-17883c79ea27/nationwidechildrens.org_clinical.TCGA-BH-A0BZ.xml has no valid age data.
# File ../datasets/clinical_data/76bcb8a8-9222-4e53-9c17-70083c55cb14/nationwidechildrens.org_clinical.TCGA-E2-A14N.xml has no valid age data.
# File ../datasets/clinical_data/76e86c35-49db-4814-bf6f-47b87aee6c66/nationwidechildrens.org_clinical.TCGA-A8-A092.xml has no valid age data.
# File ../datasets/clinical_data/77155c92-4416-4f53-9435-776ceee32845/nationwidechildrens.org_clinical.TCGA-D8-A27F.xml has no valid age data.
# File ../datasets/clinical_data/776720f4-e5f2-40b3-8eed-335024066961/nationwidechildrens.org_clinical.TCGA-AN-A04D.xml has no valid age data.
# File ../datasets/clinical_data/77d93a99-3107-493f-98c0-35a9ccddb211/nationwidechildrens.org_clinical.TCGA-A8-A07R.xml has no valid age data.
# File ../datasets/clinical_data/78320d46-99bc-4ebb-ac54-aa97e32b6b6b/nationwidechildrens.org_clinical.TCGA-A8-A06R.xml has no valid age data.
# File ../datasets/clinical_data/784e2ed0-58b2-442d-a547-1d0d0290eed5/nationwidechildrens.org_clinical.TCGA-OL-A66P.xml has no valid age data.
# File ../datasets/clinical_data/78fd80cd-951e-463f-a92c-1d61022b9faa/nationwidechildrens.org_clinical.TCGA-A1-A0SP.xml has no valid age data.
# File ../datasets/clinical_data/79cba52a-7708-4631-961e-01f634d33cc8/nationwidechildrens.org_clinical.TCGA-AC-A2BK.xml has no valid age data.
# File ../datasets/clinical_data/7a83ccfc-27b8-4043-87bf-e861a5b68cf1/nationwidechildrens.org_clinical.TCGA-AO-A128.xml has no valid age data.
# File ../datasets/clinical_data/7bb94c9c-fcd2-4333-aaec-3f31fc6e3d41/nationwidechildrens.org_clinical.TCGA-AR-A24Z.xml has no valid age data.
# File ../datasets/clinical_data/7bbe3fa9-ae1d-47ed-8a8d-92a6c24c8d73/nationwidechildrens.org_clinical.TCGA-D8-A1XY.xml has no valid age data.
# File ../datasets/clinical_data/7bd61aa5-1359-4c61-9b21-f0226b59547c/nationwidechildrens.org_clinical.TCGA-C8-A12M.xml has no valid age data.
# File ../datasets/clinical_data/7c8eab79-ebd3-425c-8549-cd6e663cc66a/nationwidechildrens.org_clinical.TCGA-E2-A15F.xml has no valid age data.
# File ../datasets/clinical_data/7d31ff9d-47bb-4efb-baf9-f564d4dbd251/nationwidechildrens.org_clinical.TCGA-A2-A0YH.xml has no valid age data.
# File ../datasets/clinical_data/7d88b2fe-7b42-4f89-aa2f-05b95a228554/nationwidechildrens.org_clinical.TCGA-B6-A0RG.xml has no valid age data.
# File ../datasets/clinical_data/7d994fce-21ee-48f5-8e12-350bd65bec01/nationwidechildrens.org_clinical.TCGA-E9-A1NG.xml has no valid age data.
# ...
# File ../datasets/clinical_data/ddac841f-92fe-4a19-baa6-047f887ce5a1/nationwidechildrens.org_clinical.TCGA-AN-A03X.xml has no valid age data.
# File ../datasets/clinical_data/ddb53fa6-7ed3-4463-a11e-d7e8502b9fa7/nationwidechildrens.org_clinical.TCGA-BH-A42V.xml has no valid age data.
# File ../datasets/clinical_data/df155b5e-7291-4144-91bc-045c0a04eb82/nationwidechildrens.org_clinical.TCGA-EW-A6SD.xml has no valid age data.
# File ../datasets/clinical_data/df77ffad-282d-41f6-84f0-6b4f759369df/nationwidechildrens.org_clinical.TCGA-A8-A093.xml has no valid age data.
# File ../datasets/clinical_data/df8ef24d-f88e-428d-b7c0-0310bc1afdac/nationwidechildrens.org_clinical.TCGA-A2-A0CL.xml has no valid age data.
# File ../datasets/clinical_data/df9aed0e-a9a6-4ce9-9c84-a364f522b4c5/nationwidechildrens.org_clinical.TCGA-AO-A129.xml has no valid age data.
# File ../datasets/clinical_data/e00b4a98-9bf6-4e77-82ea-4005adc630a8/nationwidechildrens.org_clinical.TCGA-D8-A1Y0.xml has no valid age data.
# File ../datasets/clinical_data/e03fcb33-7cf8-40fd-bcec-cdec3050d71f/nationwidechildrens.org_clinical.TCGA-AR-A1AX.xml has no valid age data.
# File ../datasets/clinical_data/e0793f64-1448-45c5-92d2-318f64b87915/nationwidechildrens.org_clinical.TCGA-E9-A24A.xml has no valid age data.
# File ../datasets/clinical_data/e092a969-bf22-4266-bcd2-51d2080c0269/nationwidechildrens.org_clinical.TCGA-BH-A0HN.xml has no valid age data.
# File ../datasets/clinical_data/e0cc659e-12e0-4a40-b862-3e5b6a463e85/nationwidechildrens.org_clinical.TCGA-D8-A143.xml has no valid age data.
# File ../datasets/clinical_data/e0dde288-e903-46c2-ba05-3dc2b4662a9b/nationwidechildrens.org_clinical.TCGA-BH-A0DQ.xml has no valid age data.
# File ../datasets/clinical_data/e0ed562e-858c-4721-9042-1e108109ea55/nationwidechildrens.org_clinical.TCGA-A8-A09C.xml has no valid age data.
# File ../datasets/clinical_data/e128fa8e-5100-4996-87da-2ec2c1d7d5c9/nationwidechildrens.org_clinical.TCGA-AN-A049.xml has no valid age data.
# File ../datasets/clinical_data/e12fec8b-d49c-4259-97c0-af029b35de12/nationwidechildrens.org_clinical.TCGA-E9-A226.xml has no valid age data.
# File ../datasets/clinical_data/e24de953-c7cc-4536-b3d4-56fc6931278e/nationwidechildrens.org_clinical.TCGA-AR-A24Q.xml has no valid age data.
# File ../datasets/clinical_data/e2654094-6164-4f5c-a736-1a18e6f1ae97/nationwidechildrens.org_clinical.TCGA-E2-A15R.xml has no valid age data.
# File ../datasets/clinical_data/e27e2517-2da0-47a7-af8b-25f20ff7d983/nationwidechildrens.org_clinical.TCGA-E2-A15C.xml has no valid age data.
# File ../datasets/clinical_data/e3578263-d4d3-4a12-bee2-f5d39a213ad3/nationwidechildrens.org_clinical.TCGA-BH-A0BD.xml has no valid age data.
# File ../datasets/clinical_data/e3906724-1663-47d2-902d-61f2bedfab03/nationwidechildrens.org_clinical.TCGA-A8-A08Z.xml has no valid age data.
# File ../datasets/clinical_data/e3b25e2c-7d9f-474f-b9dc-4eb86f563ff4/nationwidechildrens.org_clinical.TCGA-A2-A0D1.xml has no valid age data.
# File ../datasets/clinical_data/e3f0c8ce-08ef-4681-a5c0-a0d7ae79a26d/nationwidechildrens.org_clinical.TCGA-B6-A0I2.xml has no valid age data.
# File ../datasets/clinical_data/e43a1c1b-0a6c-4dd9-824e-000a222dbc17/nationwidechildrens.org_clinical.TCGA-A2-A0SU.xml has no valid age data.
# File ../datasets/clinical_data/e448406d-0677-49a3-84bb-340eafed5534/nationwidechildrens.org_clinical.TCGA-A8-A06P.xml has no valid age data.
# File ../datasets/clinical_data/e48f1a9f-15a3-4191-9d86-d330c3890afe/nationwidechildrens.org_clinical.TCGA-AO-A0JB.xml has no valid age data.
# File ../datasets/clinical_data/e4c112c9-dee4-46b7-8964-a1f01c3830b4/nationwidechildrens.org_clinical.TCGA-C8-A273.xml has no valid age data.
# File ../datasets/clinical_data/e4c81b57-c83e-42f9-bb78-5fc8bbc62658/nationwidechildrens.org_clinical.TCGA-A8-A09I.xml has no valid age data.
# File ../datasets/clinical_data/e56e31f3-9d6c-4baa-b5d1-048ae7bed2eb/nationwidechildrens.org_clinical.TCGA-C8-A27A.xml has no valid age data.
# File ../datasets/clinical_data/e5b5232e-12b0-44bb-ad47-dd2ec169986e/nationwidechildrens.org_clinical.TCGA-AO-A12C.xml has no valid age data.
# File ../datasets/clinical_data/e5c4840c-cb57-4af9-af53-b5bdba0d42c7/nationwidechildrens.org_clinical.TCGA-A8-A08B.xml has no valid age data.
# File ../datasets/clinical_data/e5c572f7-b378-4cfc-8f2c-548e21175d78/nationwidechildrens.org_clinical.TCGA-C8-A1HO.xml has no valid age data.
# File ../datasets/clinical_data/e5f94c5e-9eb6-4125-979d-a34c615d31c7/nationwidechildrens.org_clinical.TCGA-C8-A1HE.xml has no valid age data.
# File ../datasets/clinical_data/e6446932-b37a-4bd5-aa8c-2c8df94efe5d/nationwidechildrens.org_clinical.TCGA-BH-A6R8.xml has no valid age data.
# File ../datasets/clinical_data/e6cd5673-8617-40af-8b43-3c0ce60164a1/nationwidechildrens.org_clinical.TCGA-C8-A12T.xml has no valid age data.
# File ../datasets/clinical_data/e712ba8f-113d-428c-9799-3c2501d62273/nationwidechildrens.org_clinical.TCGA-OL-A5D7.xml has no valid age data.
# File ../datasets/clinical_data/e791ac24-adf0-47f1-966b-f20436f25fb4/nationwidechildrens.org_clinical.TCGA-A2-A1FZ.xml has no valid age data.
# File ../datasets/clinical_data/e7921257-a2e7-4444-81ba-af4b74e73aae/nationwidechildrens.org_clinical.TCGA-3C-AALJ.xml has no valid age data.
# File ../datasets/clinical_data/e7c0a8aa-b659-40e4-b824-7182f6bb6c2f/nationwidechildrens.org_clinical.TCGA-V7-A7HQ.xml has no valid age data.
# File ../datasets/clinical_data/e7da24c8-76dd-4886-9541-9df037cf934d/nationwidechildrens.org_clinical.TCGA-AR-A255.xml has no valid age data.
# File ../datasets/clinical_data/e8348454-bbcb-49f7-9b5d-fc0dde13c184/nationwidechildrens.org_clinical.TCGA-A7-A6VW.xml has no valid age data.
# File ../datasets/clinical_data/e85ad98d-b3b8-459f-8751-ee3bb79eb797/nationwidechildrens.org_clinical.TCGA-BH-A0W4.xml has no valid age data.
# File ../datasets/clinical_data/e884aec3-b508-40f1-a083-5b521fece9d4/nationwidechildrens.org_clinical.TCGA-GM-A2DF.xml has no valid age data.
# File ../datasets/clinical_data/e88e5d64-04c7-4bcb-913f-fd114c63fac9/nationwidechildrens.org_clinical.TCGA-E2-A1LI.xml has no valid age data.
# File ../datasets/clinical_data/e8c4f80a-997d-4baf-ae4e-f00d48d31e29/nationwidechildrens.org_clinical.TCGA-A2-A0ET.xml has no valid age data.
# File ../datasets/clinical_data/e90b4a0a-2c18-4401-873e-cd15975c8c6e/nationwidechildrens.org_clinical.TCGA-B6-A0RE.xml has no valid age data.
# File ../datasets/clinical_data/e94bb525-b657-46e6-92ad-09a9b1c9571d/nationwidechildrens.org_clinical.TCGA-A8-A06Q.xml has no valid age data.
# File ../datasets/clinical_data/ea08fca3-dc9b-4b98-98ac-f18992326ab1/nationwidechildrens.org_clinical.TCGA-LL-A441.xml has no valid age data.
# File ../datasets/clinical_data/ea0d8234-db1c-454e-9a6d-4f503a6ce52c/nationwidechildrens.org_clinical.TCGA-BH-A0DT.xml has no valid age data.
# File ../datasets/clinical_data/ea285c87-ccec-481c-8caa-e07770ee66c9/nationwidechildrens.org_clinical.TCGA-C8-A274.xml has no valid age data.
# File ../datasets/clinical_data/ea3f0338-2b32-4d7b-a3f9-c983cb954b77/nationwidechildrens.org_clinical.TCGA-LL-A442.xml has no valid age data.
# File ../datasets/clinical_data/ea742636-3e07-44bf-b535-ef099be974ea/nationwidechildrens.org_clinical.TCGA-E2-A573.xml has no valid age data.
# File ../datasets/clinical_data/eb239a00-980c-4ff7-9643-4420170dbbe7/nationwidechildrens.org_clinical.TCGA-C8-A26Y.xml has no valid age data.
# File ../datasets/clinical_data/eb61e7cf-de8a-431f-98ef-95fbe1055891/nationwidechildrens.org_clinical.TCGA-A2-A0EO.xml has no valid age data.
# File ../datasets/clinical_data/ec8f0fd9-dfb1-41e6-a5e1-623ced6dcde0/nationwidechildrens.org_clinical.TCGA-D8-A1JU.xml has no valid age data.
# File ../datasets/clinical_data/ecf55492-7c60-49f4-a7bd-a54bcd8f8f2f/nationwidechildrens.org_clinical.TCGA-A2-A1G4.xml has no valid age data.
# File ../datasets/clinical_data/ed3b7a41-a4ea-40ee-9555-b40ae23154d0/nationwidechildrens.org_clinical.TCGA-A8-A094.xml has no valid age data.
# File ../datasets/clinical_data/ed4bbecf-c10b-4299-9e53-4ef7eaeef843/nationwidechildrens.org_clinical.TCGA-BH-A0DV.xml has no valid age data.
# File ../datasets/clinical_data/ed9a08f2-cafb-4ad7-9af5-825a448aa58b/nationwidechildrens.org_clinical.TCGA-A2-A0EY.xml has no valid age data.
# File ../datasets/clinical_data/ee15c26a-1c33-424a-8072-57a17024a5bf/nationwidechildrens.org_clinical.TCGA-AR-A24N.xml has no valid age data.
# File ../datasets/clinical_data/ee2c842b-d95a-42cb-b9c0-42407be0146f/nationwidechildrens.org_clinical.TCGA-AR-A1AS.xml has no valid age data.
# File ../datasets/clinical_data/ee48372a-b15d-4a06-8ae0-c8bf719cbe21/nationwidechildrens.org_clinical.TCGA-BH-A0HI.xml has no valid age data.
# File ../datasets/clinical_data/ee9cf11e-420a-48c1-a1a4-b888a65f61fc/nationwidechildrens.org_clinical.TCGA-A7-A13E.xml has no valid age data.
# File ../datasets/clinical_data/ee9eced5-3079-41d9-a601-aa77689a12f2/nationwidechildrens.org_clinical.TCGA-AN-A0XL.xml has no valid age data.
# File ../datasets/clinical_data/eef0c424-f02b-4fe6-a881-0bd68b8ee216/nationwidechildrens.org_clinical.TCGA-A8-A084.xml has no valid age data.
# File ../datasets/clinical_data/eef2a297-e071-45c0-b832-30674221ce3b/nationwidechildrens.org_clinical.TCGA-AN-A0G0.xml has no valid age data.
# File ../datasets/clinical_data/ef23dcf9-d93b-43ec-bba0-1238c311c355/nationwidechildrens.org_clinical.TCGA-D8-A13Y.xml has no valid age data.
# File ../datasets/clinical_data/ef49519f-f30d-4781-9883-1cc6068cbfe5/nationwidechildrens.org_clinical.TCGA-AN-A0XR.xml has no valid age data.
# File ../datasets/clinical_data/efb05f91-dffc-4ec6-969c-eae705cda834/nationwidechildrens.org_clinical.TCGA-D8-A1JI.xml has no valid age data.
# File ../datasets/clinical_data/efba5112-e4ec-4878-9eb2-203cfe0799f1/nationwidechildrens.org_clinical.TCGA-E9-A227.xml has no valid age data.
# File ../datasets/clinical_data/efd86c2b-4fd5-40d8-9c96-a80fc7ef9689/nationwidechildrens.org_clinical.TCGA-E2-A574.xml has no valid age data.
# File ../datasets/clinical_data/efeb610a-2a2e-422a-b46a-27215698b797/nationwidechildrens.org_clinical.TCGA-A8-A086.xml has no valid age data.
# File ../datasets/clinical_data/f04655d7-3575-4a0e-8622-ede68f057572/nationwidechildrens.org_clinical.TCGA-A7-A0CE.xml has no valid age data.
# File ../datasets/clinical_data/f0b24353-c901-4ea4-8aaa-d870ee39c0c6/nationwidechildrens.org_clinical.TCGA-BH-A0DH.xml has no valid age data.
# File ../datasets/clinical_data/f1263c03-a16e-4467-ad5f-a3d50e643a84/nationwidechildrens.org_clinical.TCGA-B6-A401.xml has no valid age data.
# File ../datasets/clinical_data/f1891504-8531-4550-b1ca-fac9581b0be5/nationwidechildrens.org_clinical.TCGA-GM-A2DB.xml has no valid age data.
# File ../datasets/clinical_data/f1900ead-37fd-4ca7-8aa3-670b6bfb9cb1/nationwidechildrens.org_clinical.TCGA-A2-A0ST.xml has no valid age data.
# File ../datasets/clinical_data/f1a54fb6-0a25-415c-aadb-479e9dbaf8ad/nationwidechildrens.org_clinical.TCGA-B6-A0WT.xml has no valid age data.
# File ../datasets/clinical_data/f28fdc37-9044-4894-adbb-43c14c73b579/nationwidechildrens.org_clinical.TCGA-D8-A1Y2.xml has no valid age data.
# File ../datasets/clinical_data/f2944b79-5517-4064-98d1-160c6a6c75f0/nationwidechildrens.org_clinical.TCGA-D8-A1XM.xml has no valid age data.
# File ../datasets/clinical_data/f2b02a00-542f-4d85-a66b-d16e9f1b3a56/nationwidechildrens.org_clinical.TCGA-BH-A0BW.xml has no valid age data.
# File ../datasets/clinical_data/f363ebbb-167c-4bf9-8b91-c8d25ad63543/nationwidechildrens.org_clinical.TCGA-LL-A8F5.xml has no valid age data.
# File ../datasets/clinical_data/f44291d2-8920-493e-a324-e19c74caa54b/nationwidechildrens.org_clinical.TCGA-E9-A1RD.xml has no valid age data.
# File ../datasets/clinical_data/f465585a-05ff-4e81-8eb6-6f17735b24b9/nationwidechildrens.org_clinical.TCGA-OL-A6VO.xml has no valid age data.
# File ../datasets/clinical_data/f475e8d4-db1f-4b9d-9d13-32fbc0541e10/nationwidechildrens.org_clinical.TCGA-B6-A0I5.xml has no valid age data.
# File ../datasets/clinical_data/f4ee270b-1817-4403-9614-f69bc6c1c810/nationwidechildrens.org_clinical.TCGA-D8-A1XR.xml has no valid age data.
# File ../datasets/clinical_data/f4fe86ca-0c72-47ff-b160-d4772b1297e7/nationwidechildrens.org_clinical.TCGA-BH-A0B9.xml has no valid age data.
# File ../datasets/clinical_data/f5a427b1-65f8-4244-a0d9-6a9a87e3bcd7/nationwidechildrens.org_clinical.TCGA-BH-A0AV.xml has no valid age data.
# File ../datasets/clinical_data/f5f931b1-5061-4142-a5b4-4397d69f0efc/nationwidechildrens.org_clinical.TCGA-BH-A0HQ.xml has no valid age data.
# File ../datasets/clinical_data/f68d90b2-6d21-47ab-89a0-f95220d72892/nationwidechildrens.org_clinical.TCGA-C8-A137.xml has no valid age data.
# File ../datasets/clinical_data/f6a30e7e-dbd2-46ae-ad74-6d93e44e10c2/nationwidechildrens.org_clinical.TCGA-S3-AA17.xml has no valid age data.
# File ../datasets/clinical_data/f6d03a60-4dc1-4e94-9c02-857c558735ca/nationwidechildrens.org_clinical.TCGA-AN-A0FK.xml has no valid age data.
# File ../datasets/clinical_data/f7dd6841-37ca-4e68-b0cb-1a86b31d2e7c/nationwidechildrens.org_clinical.TCGA-D8-A1JH.xml has no valid age data.
# File ../datasets/clinical_data/f7e96a5e-da81-47be-ad1c-89092c4a8ba5/nationwidechildrens.org_clinical.TCGA-BH-A0H0.xml has no valid age data.
# File ../datasets/clinical_data/f8254292-5536-4d2c-95c3-74e7514e677c/nationwidechildrens.org_clinical.TCGA-AN-A0XW.xml has no valid age data.
# File ../datasets/clinical_data/f968f75e-43a4-46cd-9c4d-744bc2a93206/nationwidechildrens.org_clinical.TCGA-B6-A1KI.xml has no valid age data.
# File ../datasets/clinical_data/f9d47e8f-674e-4660-8efa-f6435d157bc4/nationwidechildrens.org_clinical.TCGA-A8-A07C.xml has no valid age data.
# File ../datasets/clinical_data/f9f099cb-8af7-4080-af91-87778e09a91f/nationwidechildrens.org_clinical.TCGA-EW-A1IY.xml has no valid age data.
# File ../datasets/clinical_data/fa3ccaab-014a-41a9-8303-f6c3a10f1aca/nationwidechildrens.org_clinical.TCGA-AN-A0AL.xml has no valid age data.
# File ../datasets/clinical_data/fabb590e-eaa6-40bd-a435-a79116d0c5c2/nationwidechildrens.org_clinical.TCGA-LL-A7SZ.xml has no valid age data.
# File ../datasets/clinical_data/faf9e65a-90f2-4891-aaec-d31fb58a5993/nationwidechildrens.org_clinical.TCGA-D8-A1JE.xml has no valid age data.
# File ../datasets/clinical_data/fb1dfac6-347b-4113-b03a-2a00cdf69cf3/nationwidechildrens.org_clinical.TCGA-BH-A0BO.xml has no valid age data.
# File ../datasets/clinical_data/fb5f9cf0-f068-4ae7-bdd3-c6d5209f04d1/nationwidechildrens.org_clinical.TCGA-A8-A08G.xml has no valid age data.
# File ../datasets/clinical_data/fcfc8953-3d78-42ea-a48a-ac9f1b7c3e01/nationwidechildrens.org_clinical.TCGA-AN-A0XO.xml has no valid age data.
# File ../datasets/clinical_data/fcfe3504-499f-4523-98c0-6cde493fd39a/nationwidechildrens.org_clinical.TCGA-A2-A0CZ.xml has no valid age data.
# File ../datasets/clinical_data/fd4f1a8d-6208-45ee-aa98-3e1bb7e74d51/nationwidechildrens.org_clinical.TCGA-E9-A1R2.xml has no valid age data.
# File ../datasets/clinical_data/fdc41732-6266-48ed-8f81-c942290085d4/nationwidechildrens.org_clinical.TCGA-AC-A23C.xml has no valid age data.
# File ../datasets/clinical_data/fdccc014-12e1-4600-b6f1-1ccdb19e3e89/nationwidechildrens.org_clinical.TCGA-BH-A0BL.xml has no valid age data.
# File ../datasets/clinical_data/fe89076f-4f25-4ad7-8ef2-ab0c4a4cdcb0/nationwidechildrens.org_clinical.TCGA-A8-A076.xml has no valid age data.
# File ../datasets/clinical_data/ff17354b-9db5-4c98-9f9d-764d178bee17/nationwidechildrens.org_clinical.TCGA-A1-A0SN.xml has no valid age data.
# File ../datasets/clinical_data/ff3e5f88-9279-4296-9831-a791b12837c6/nationwidechildrens.org_clinical.TCGA-A8-A08O.xml has no valid age data.
# File ../datasets/clinical_data/ff516902-0a72-407e-ac1d-45fa20fa910c/nationwidechildrens.org_clinical.TCGA-AC-A8OQ.xml has no valid age data.
# File ../datasets/clinical_data/ff8117d3-237d-4e08-9633-f8f425381cd5/nationwidechildrens.org_clinical.TCGA-E9-A22D.xml has no valid age data.
# File ../datasets/clinical_data/ff8e1327-3b0e-4d91-a577-9d7da3e30d22/nationwidechildrens.org_clinical.TCGA-AR-A24L.xml has no valid age data.
# (75, 3)

# %%
clinical_death_df.head()
# Out:
#                             folder_name  \
# 0  021d8f80-3db0-4f60-b404-a71e115102ca
# 1  0a9561ad-0d8e-4776-be26-c9d7b2825045
# 2  0ecfe554-fdc5-41f3-b287-66080d24d1bd
# 3  1bd2a479-da63-4cee-a722-31570b97c254
# 4  1bf445b0-0b0d-4ba5-884a-ff70300b8795
#
#                                            file_name  days_to_death
# 0  nationwidechildrens.org_clinical.TCGA-BH-A18K.xml         2763.0
# 1  nationwidechildrens.org_clinical.TCGA-B6-A0IG.xml         4456.0
# 2  nationwidechildrens.org_clinical.TCGA-BH-A1ET.xml         2520.0
# 3  nationwidechildrens.org_clinical.TCGA-BH-A1EY.xml          538.0
# 4  nationwidechildrens.org_clinical.TCGA-AR-A0U2.xml         2551.0

# %%
clinical_death_df[clinical_death_df['days_to_death'] > 0].shape
# Out:
# (75, 3)

# %%
clinical_death_df['days_to_death'].describe()
# Out:
# count      75.000000
# mean     1466.960000
# std      1064.430179
# min         1.000000
# 25%       575.000000
# 50%      1142.000000
# 75%      2317.000000
# max      4456.000000
# Name: days_to_death, dtype: float64

# %% [markdown]
# ### Create clinical_df DataFrame with days_to_last_followup from TXT files:

# %%
def import_xml(file_path):
    temp_df = pd.read_xml(file_path, parser="etree")

    if 'days_to_last_followup' in temp_df.columns:
        # Remove rows in which all columns are NaN
        temp_df = temp_df[["days_to_last_followup"]]
    
        temp_df = temp_df.dropna(how='all')
        
        if temp_df.empty:
            print(f"File {file_path} has no valid age data.")

        return temp_df
    return None

def main():
    clinical_df = pd.DataFrame(columns=["folder_name", "file_name", "days_to_last_followup"])
    for subfolder in os.listdir(f"{CLINICAL_PATH}"):
        file_xml_or_annotation_or_orm = 0
        for file in os.listdir(f"{CLINICAL_PATH}/{subfolder}"):
            if file.endswith(".xml") and "annotations" not in file and "org_omf" not in file:
                file_xml_or_annotation_or_orm = 1
                selected_data = import_xml(f"{CLINICAL_PATH}/{subfolder}/{file}")
            
                if selected_data is not None:
                    selected_data.insert(0, "file_name", file)
                    selected_data.insert(0, "folder_name", subfolder)

                    # Safe concatenation avoiding empty DataFrames or with NaN values
                    if not selected_data.empty and not selected_data.isna().all().all():
                        clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
                        
    return clinical_df

clinical_followup_df = main()
clinical_followup_df.shape
# Out:
# C:\Users\giorg\AppData\Local\Temp\ipykernel_8492\326278238.py:31: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   clinical_df = pd.concat([clinical_df, selected_data], ignore_index=True)
# File ../datasets/clinical_data/021d8f80-3db0-4f60-b404-a71e115102ca/nationwidechildrens.org_clinical.TCGA-BH-A18K.xml has no valid age data.
# File ../datasets/clinical_data/0a9561ad-0d8e-4776-be26-c9d7b2825045/nationwidechildrens.org_clinical.TCGA-B6-A0IG.xml has no valid age data.
# File ../datasets/clinical_data/0ecfe554-fdc5-41f3-b287-66080d24d1bd/nationwidechildrens.org_clinical.TCGA-BH-A1ET.xml has no valid age data.
# File ../datasets/clinical_data/1bd2a479-da63-4cee-a722-31570b97c254/nationwidechildrens.org_clinical.TCGA-BH-A1EY.xml has no valid age data.
# File ../datasets/clinical_data/1bf445b0-0b0d-4ba5-884a-ff70300b8795/nationwidechildrens.org_clinical.TCGA-AR-A0U2.xml has no valid age data.
# File ../datasets/clinical_data/2438eb6e-278a-4c4a-b93d-e7fa50cb1080/nationwidechildrens.org_clinical.TCGA-EW-A1P8.xml has no valid age data.
# File ../datasets/clinical_data/26fe7667-2972-4904-bf30-e12f9d8b6a33/nationwidechildrens.org_clinical.TCGA-BH-A18L.xml has no valid age data.
# File ../datasets/clinical_data/28266dfa-65e5-493e-afa3-b95c8e289a72/nationwidechildrens.org_clinical.TCGA-B6-A0WV.xml has no valid age data.
# File ../datasets/clinical_data/2a5b5ade-746e-4a95-ade3-596a56f35ed8/nationwidechildrens.org_clinical.TCGA-BH-A0EA.xml has no valid age data.
# File ../datasets/clinical_data/2b629c40-f8d7-4f1b-9b62-921a9d936807/nationwidechildrens.org_clinical.TCGA-B6-A0I9.xml has no valid age data.
# File ../datasets/clinical_data/2de837e4-7624-4134-b30f-089d85912e9b/nationwidechildrens.org_clinical.TCGA-BH-A1F5.xml has no valid age data.
# File ../datasets/clinical_data/2e5711e2-6f5d-4f48-89e9-35df0b1292a4/nationwidechildrens.org_clinical.TCGA-B6-A0RS.xml has no valid age data.
# File ../datasets/clinical_data/33369ef8-609c-4e3e-9d72-0b9facdaaece/nationwidechildrens.org_clinical.TCGA-AR-A0TY.xml has no valid age data.
# File ../datasets/clinical_data/333f5d2e-45c7-4944-8185-5c92f0969bc3/nationwidechildrens.org_clinical.TCGA-AR-A256.xml has no valid age data.
# File ../datasets/clinical_data/335bfc4c-0c49-4860-a522-2a0a6430455c/nationwidechildrens.org_clinical.TCGA-BH-A1EU.xml has no valid age data.
# File ../datasets/clinical_data/35ff6555-2f56-4f8c-8d9c-5e25a198d4b6/nationwidechildrens.org_clinical.TCGA-B6-A409.xml has no valid age data.
# File ../datasets/clinical_data/36f9ade7-bf38-4544-abbb-48edc6cad131/nationwidechildrens.org_clinical.TCGA-A2-A04P.xml has no valid age data.
# File ../datasets/clinical_data/3abdcb95-3610-41a3-8510-93033f5f5142/nationwidechildrens.org_clinical.TCGA-BH-A1FJ.xml has no valid age data.
# File ../datasets/clinical_data/3c69483e-4182-4d4f-9956-f4db9fa13529/nationwidechildrens.org_clinical.TCGA-AO-A03O.xml has no valid age data.
# File ../datasets/clinical_data/3cc30ed0-263e-4be1-bc66-2c015f054796/nationwidechildrens.org_clinical.TCGA-BH-A18J.xml has no valid age data.
# File ../datasets/clinical_data/3e6152a4-d844-4a07-a76c-93aac88085bc/nationwidechildrens.org_clinical.TCGA-B6-A0X5.xml has no valid age data.
# File ../datasets/clinical_data/3eaee49b-15f2-404e-a0cd-6c3317878c45/nationwidechildrens.org_clinical.TCGA-BH-A1FL.xml has no valid age data.
# File ../datasets/clinical_data/3ec760b4-9722-4093-8c5a-714e385fb600/nationwidechildrens.org_clinical.TCGA-B6-A0X4.xml has no valid age data.
# File ../datasets/clinical_data/401187b6-c889-4cdc-9912-8c46c571ae00/nationwidechildrens.org_clinical.TCGA-A8-A08L.xml has no valid age data.
# File ../datasets/clinical_data/45cf2f5d-05e2-4181-8cf2-aabb3e15c4f1/nationwidechildrens.org_clinical.TCGA-BH-A1FU.xml has no valid age data.
# File ../datasets/clinical_data/48332cac-b2c3-4a35-bc1b-76e174b9b55d/nationwidechildrens.org_clinical.TCGA-BH-A18N.xml has no valid age data.
# File ../datasets/clinical_data/4b81e1c7-f651-4326-a9b7-d9ff18ccefdb/nationwidechildrens.org_clinical.TCGA-A8-A06X.xml has no valid age data.
# File ../datasets/clinical_data/4cc94cff-842d-4473-9de6-27a404dbe215/nationwidechildrens.org_clinical.TCGA-BH-A1EW.xml has no valid age data.
# File ../datasets/clinical_data/56048722-981a-4689-9de0-42f92a116590/nationwidechildrens.org_clinical.TCGA-BH-A1F0.xml has no valid age data.
# File ../datasets/clinical_data/560c8b13-9410-42b5-9597-e8f1c28412e3/nationwidechildrens.org_clinical.TCGA-BH-A1EX.xml has no valid age data.
# File ../datasets/clinical_data/56388b38-52cb-4b66-a41f-06c81ad26e35/nationwidechildrens.org_clinical.TCGA-UU-A93S.xml has no valid age data.
# File ../datasets/clinical_data/59a75975-f731-4bac-b088-13697e6e67cf/nationwidechildrens.org_clinical.TCGA-B6-A0RL.xml has no valid age data.
# File ../datasets/clinical_data/5add419d-9a4b-4e30-bbb2-d1d15ef4c919/nationwidechildrens.org_clinical.TCGA-A8-A06U.xml has no valid age data.
# File ../datasets/clinical_data/5ed3dafb-8a63-4f7c-8a37-eb8700afcef8/nationwidechildrens.org_clinical.TCGA-AR-A0TR.xml has no valid age data.
# File ../datasets/clinical_data/668fec55-45fa-4113-b171-3f2053154786/nationwidechildrens.org_clinical.TCGA-BH-A1FN.xml has no valid age data.
# File ../datasets/clinical_data/687c102c-6a35-4c41-ae1c-e1457e33772b/nationwidechildrens.org_clinical.TCGA-B6-A0X7.xml has no valid age data.
# File ../datasets/clinical_data/6a76b9bd-81bb-450c-9cbe-613b2653c4a8/nationwidechildrens.org_clinical.TCGA-BH-A1FG.xml has no valid age data.
# File ../datasets/clinical_data/6bd1bf4a-8a91-451a-9046-92b59de2b0ab/nationwidechildrens.org_clinical.TCGA-B6-A0IK.xml has no valid age data.
# File ../datasets/clinical_data/6c081aa2-be5f-446c-b37d-33d0100871c2/nationwidechildrens.org_clinical.TCGA-A2-A0SV.xml has no valid age data.
# File ../datasets/clinical_data/6c53cc7e-d939-4bdc-b3ca-cf62769b3d88/nationwidechildrens.org_clinical.TCGA-BH-A1FM.xml has no valid age data.
# File ../datasets/clinical_data/75ab39cf-5ba4-4ef8-948c-3bd6b4d76ae4/nationwidechildrens.org_clinical.TCGA-BH-A18T.xml has no valid age data.
# File ../datasets/clinical_data/76fcc198-ed96-4d7b-bb4a-ce0b8c99ed89/nationwidechildrens.org_clinical.TCGA-B6-A0WW.xml has no valid age data.
# File ../datasets/clinical_data/78399ce9-6c27-40c8-ae92-1ea264834d4f/nationwidechildrens.org_clinical.TCGA-A2-A04V.xml has no valid age data.
# File ../datasets/clinical_data/7c4da523-677a-4bf3-8b02-cc3432d4b932/nationwidechildrens.org_clinical.TCGA-B6-A0RM.xml has no valid age data.
# File ../datasets/clinical_data/82496e3d-9461-4d99-b920-a9d1ca0e3b78/nationwidechildrens.org_clinical.TCGA-B6-A0I6.xml has no valid age data.
# File ../datasets/clinical_data/862be851-7147-4f96-b93e-3c8067a0f514/nationwidechildrens.org_clinical.TCGA-BH-A18R.xml has no valid age data.
# File ../datasets/clinical_data/8f3d7550-7089-42ef-b753-c383491db9b6/nationwidechildrens.org_clinical.TCGA-BH-A1FH.xml has no valid age data.
# File ../datasets/clinical_data/90545f52-281d-49c4-af4a-4c79fd6b3600/nationwidechildrens.org_clinical.TCGA-B6-A0IB.xml has no valid age data.
# File ../datasets/clinical_data/9122469d-6ae7-41a3-abdf-84daca4b07f7/nationwidechildrens.org_clinical.TCGA-BH-A1F8.xml has no valid age data.
# File ../datasets/clinical_data/983e6d40-862e-43a8-8e8f-ef339e4dbc9e/nationwidechildrens.org_clinical.TCGA-BH-A1EN.xml has no valid age data.
# File ../datasets/clinical_data/9b6a8860-938c-48f8-8a1b-4622edc6163f/nationwidechildrens.org_clinical.TCGA-BH-A204.xml has no valid age data.
# File ../datasets/clinical_data/9cb8e5c9-0fb6-47eb-b665-97986254356f/nationwidechildrens.org_clinical.TCGA-E2-A1LE.xml has no valid age data.
# File ../datasets/clinical_data/9dd5c3e4-904f-436e-bb37-26e841a745a4/nationwidechildrens.org_clinical.TCGA-BH-A1ES.xml has no valid age data.
# File ../datasets/clinical_data/a08d9d34-348e-4178-9607-283fdd6aafec/nationwidechildrens.org_clinical.TCGA-BH-A208.xml has no valid age data.
# File ../datasets/clinical_data/adcb8bbd-99c5-4375-9464-3867616cf03b/nationwidechildrens.org_clinical.TCGA-A2-A0T2.xml has no valid age data.
# File ../datasets/clinical_data/ae80c0c3-be85-4d13-9b1b-d78d7d229bed/nationwidechildrens.org_clinical.TCGA-A2-A3XS.xml has no valid age data.
# File ../datasets/clinical_data/af8d9d58-d7ab-4728-aeeb-6ea6f2668162/nationwidechildrens.org_clinical.TCGA-BH-A1EV.xml has no valid age data.
# File ../datasets/clinical_data/b5c295e5-eb24-4b24-8ac3-0d1da0308ea8/nationwidechildrens.org_clinical.TCGA-BH-A203.xml has no valid age data.
# File ../datasets/clinical_data/b9fb544d-8770-42f4-9fd4-82ebfdfe241e/nationwidechildrens.org_clinical.TCGA-B6-A0I1.xml has no valid age data.
# File ../datasets/clinical_data/baefea60-c906-42cd-b135-96000c3989f7/nationwidechildrens.org_clinical.TCGA-BH-A1F6.xml has no valid age data.
# File ../datasets/clinical_data/c0a1fd85-f501-467e-915c-806f12fa3af2/nationwidechildrens.org_clinical.TCGA-B6-A0WY.xml has no valid age data.
# File ../datasets/clinical_data/c3a26332-ad7d-4e06-803a-038330992cdf/nationwidechildrens.org_clinical.TCGA-A2-A0SW.xml has no valid age data.
# File ../datasets/clinical_data/cdcbc7b5-5df0-41ac-92cb-e0cc3ec75bde/nationwidechildrens.org_clinical.TCGA-BH-A1FB.xml has no valid age data.
# File ../datasets/clinical_data/d7235171-f6f3-4e34-b3cb-c39abfe7b57a/nationwidechildrens.org_clinical.TCGA-A2-A3XU.xml has no valid age data.
# File ../datasets/clinical_data/d8119766-a28a-4a38-8308-f9d07d17c627/nationwidechildrens.org_clinical.TCGA-BH-A1FE.xml has no valid age data.
# File ../datasets/clinical_data/db749c2f-afb2-4ace-8f83-809c8679e64c/nationwidechildrens.org_clinical.TCGA-A2-A0CU.xml has no valid age data.
# File ../datasets/clinical_data/e2bd557f-6103-41c5-90aa-446ad646aae4/nationwidechildrens.org_clinical.TCGA-B6-A0I8.xml has no valid age data.
# File ../datasets/clinical_data/e74ed9f5-6b70-482c-b5ee-96837fa81f38/nationwidechildrens.org_clinical.TCGA-AQ-A0Y5.xml has no valid age data.
# File ../datasets/clinical_data/eb3b0efe-be3c-4cef-981e-e6a1eb0e65b1/nationwidechildrens.org_clinical.TCGA-GM-A2D9.xml has no valid age data.
# File ../datasets/clinical_data/ec13b045-9b94-4955-b3f5-6f7b8f22550e/nationwidechildrens.org_clinical.TCGA-B6-A0WS.xml has no valid age data.
# File ../datasets/clinical_data/f4ea8ea9-c4f2-4f93-a259-29d49be19ef8/nationwidechildrens.org_clinical.TCGA-BH-A1FD.xml has no valid age data.
# File ../datasets/clinical_data/fa74dbf9-1918-4f14-ab6f-322def041c7d/nationwidechildrens.org_clinical.TCGA-A2-A0CM.xml has no valid age data.
# File ../datasets/clinical_data/fc5f02e2-fc38-4702-9664-bded31b070b2/nationwidechildrens.org_clinical.TCGA-AR-A1AR.xml has no valid age data.
# File ../datasets/clinical_data/fcda6113-b7a5-4504-a4a4-c204bbf95402/nationwidechildrens.org_clinical.TCGA-A2-A0YT.xml has no valid age data.
# File ../datasets/clinical_data/ffb2e9d9-07dd-48dd-9c37-9f87c28b5b2c/nationwidechildrens.org_clinical.TCGA-E2-A1LK.xml has no valid age data.
# (696, 3)

# %%
clinical_followup_df.head()
# Out:
#                             folder_name  \
# 0  00049989-fa21-48fb-8dda-710c0dd5932e
# 1  004b6bd4-19d0-4b40-99ef-1a76313fe7a5
# 2  00a5e81c-cd67-483f-9d99-3c733b2ead38
# 3  014f5ae1-5862-4165-9a3b-bba7bb08a527
# 4  01a962ea-a87f-49fa-9a27-7273a39f64a9
#
#                                            file_name  days_to_last_followup
# 0  nationwidechildrens.org_clinical.TCGA-A2-A0CT.xml                 1918.0
# 1  nationwidechildrens.org_clinical.TCGA-GM-A2DD.xml                 1309.0
# 2  nationwidechildrens.org_clinical.TCGA-D8-A1JM.xml                  238.0
# 3  nationwidechildrens.org_clinical.TCGA-C8-A12P.xml                    0.0
# 4  nationwidechildrens.org_clinical.TCGA-S3-A6ZF.xml                  212.0

# %%
clinical_followup_df[clinical_followup_df['days_to_last_followup'] > 0].shape
# Out:
# (654, 3)

# %%
clinical_followup_df['days_to_last_followup'].describe()
# Out:
# count     696.000000
# mean      739.989943
# std       949.046203
# min         0.000000
# 25%       118.000000
# 50%       394.000000
# 75%      1117.750000
# max      6796.000000
# Name: days_to_last_followup, dtype: float64
